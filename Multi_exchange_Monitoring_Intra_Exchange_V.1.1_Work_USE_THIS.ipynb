# %%
import ccxt
import time

# Replace with your actual API keys for Bybit and Bitget
BYBIT_API_KEY = 'I6m01uNAWiensHbIBA'
BYBIT_API_SECRET = 'vkaviS9xw903NJPncMtHgGfyiWB4mnhSJTyK'
BITGET_API_KEY = 'bg_b0a9d721607623216a87b066a3df34c3'
BITGET_API_SECRET = '6c4a5016562624b6d7f3b1c59563d4a1a573f630e0e49422fbf509399e56918b'

# Connect to Bybit API
bybit = ccxt.bybit({
    'apiKey': BYBIT_API_KEY,
    'secret': BYBIT_API_SECRET,
    'options': {'adjustForTimeDifference': True}
})

# Connect to Bitget API
bitget = ccxt.bitget({
    'apiKey': BITGET_API_KEY,
    'secret': BITGET_API_SECRET,
    'options': {'adjustForTimeDifference': True}
})

# %%
# Arbitrage settings
SPREAD_THRESHOLD = 0.5 / 100  # 0.5% profit target
MIN_VOLUME = 50000  # Minimum 24h volume required (in USDT)
CHECK_INTERVAL = 5  # Check every 5 seconds
TRADING_FEE = 0.001  # 0.1% trading fee per trade

exchanges = {'Bybit': bybit, 'Bitget': bitget}

def get_tradable_tokens(exchange, exchange_name):
    """Fetches all tradable tokens on an exchange and filters out low-volume pairs"""
    try:
        markets = exchange.load_markets()
        tradable_tokens = []
        for symbol, market in markets.items():
            if exchange_name == "Bitget":
                if not market.get('spot', False):  # Ensure it's a spot market
                    continue
            if '/USDT' in symbol and ':USDT' not in symbol:
                try:
                    market_data = exchange.fetch_ticker(symbol)
                    volume = market_data.get('quoteVolume', 0)
                    if volume and volume >= MIN_VOLUME:
                        tradable_tokens.append(symbol)
                except Exception as e:
                    print(f"⚠️ Skipping {symbol} on {exchange_name} due to error: {e}")
        print(f"✅ Found {len(tradable_tokens)} tradable tokens on {exchange_name}")
        return tradable_tokens
    except Exception as e:
        print(f"❌ Error fetching tradable tokens from {exchange_name}: {e}")
        return []

def get_price(exchange, symbol):
    """Fetch latest price for a given token if the market exists on an exchange"""
    try:
        if symbol in exchange.load_markets():
            ticker = exchange.fetch_ticker(symbol)
            return ticker.get("last", None)
    except Exception as e:
        print(f"❌ Error fetching price for {symbol} on {exchange}: {e}")
    return None

def check_intra_exchange_arbitrage(exchange, exchange_name, symbol):
    """Checks for spot vs futures arbitrage opportunities within an exchange"""
    spot_price = get_price(exchange, symbol)
    futures_symbol = symbol.replace('/USDT', '/USDT:USDT')

    if futures_symbol not in exchange.load_markets():
        return
    
    futures_price = get_price(exchange, futures_symbol)
    if not spot_price or not futures_price:
        return
    
    spread = (futures_price - spot_price) / spot_price  # Calculate spread %
    net_profit = spread - (TRADING_FEE * 2)  # Adjust for fees

    if net_profit >= SPREAD_THRESHOLD:
        print(f"🔍 Arbitrage Opportunity on {exchange_name}: {symbol}")
        print(f"    ✅ Spot Price: {spot_price:.2f} USDT")
        print(f"    ✅ Futures Price: {futures_price:.2f} USDT")
        print(f"    ✅ Spread: {spread:.4%}")
        print(f"    ✅ Net Profit After Fees: {net_profit:.4%}")
        print(f"    ⚡ Execute arbitrage on {exchange_name}")
        print("-" * 50)

def main():
    while True:
        try:
            for exchange_name, exchange in exchanges.items():
                tradable_tokens = get_tradable_tokens(exchange, exchange_name)
                if not tradable_tokens:
                    print(f"❌ No tradable tokens found on {exchange_name}. Retrying in 10 seconds...")
                    time.sleep(10)
                    continue
                print(f"🔄 Checking for arbitrage opportunities on {exchange_name}...")
                for token in tradable_tokens:
                    check_intra_exchange_arbitrage(exchange, exchange_name, token)
            print("✅ Cycle complete. Waiting for next check...")
            time.sleep(CHECK_INTERVAL)
        except Exception as e:
            print(f"❌ Error in main loop: {e}")
            time.sleep(10)

if __name__ == "__main__":
    main()
# Out:
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/asset/coin/query-info?
# ❌ No tradable tokens found on Bybit. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/public/coins
# ❌ No tradable tokens found on Bitget. Retrying in 10 seconds...
# ✅ Cycle complete. Waiting for next check...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/asset/coin/query-info?
# ❌ No tradable tokens found on Bybit. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/public/coins
# ❌ No tradable tokens found on Bitget. Retrying in 10 seconds...
# ✅ Cycle complete. Waiting for next check...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/asset/coin/query-info?
# ❌ No tradable tokens found on Bybit. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/public/coins
# ❌ No tradable tokens found on Bitget. Retrying in 10 seconds...
# ✅ Cycle complete. Waiting for next check...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/asset/coin/query-info?
# ❌ No tradable tokens found on Bybit. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/public/coins
# ❌ No tradable tokens found on Bitget. Retrying in 10 seconds...
# ✅ Cycle complete. Waiting for next check...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/asset/coin/query-info?
# ❌ No tradable tokens found on Bybit. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/public/coins
# ❌ No tradable tokens found on Bitget. Retrying in 10 seconds...
# ✅ Cycle complete. Waiting for next check...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/asset/coin/query-info?
# ❌ No tradable tokens found on Bybit. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/public/coins
# ❌ No tradable tokens found on Bitget. Retrying in 10 seconds...
# ✅ Cycle complete. Waiting for next check...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/asset/coin/query-info?
# ❌ No tradable tokens found on Bybit. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/public/coins
# ❌ No tradable tokens found on Bitget. Retrying in 10 seconds...
# ✅ Cycle complete. Waiting for next check...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/asset/coin/query-info?
# ❌ No tradable tokens found on Bybit. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/contracts?productType=USDT-FUTURES
# ❌ No tradable tokens found on Bitget. Retrying in 10 seconds...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: MOVE/USDT
#     ✅ Spot Price: 0.44 USDT
#     ✅ Futures Price: 0.45 USDT
#     ✅ Spread: 1.0426%
#     ✅ Net Profit After Fees: 0.8426%
#     ⚡ Execute arbitrage on Bybit
# --------------------------------------------------
# ✅ Found 540 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: LUCE/USDT
#     ✅ Spot Price: 0.01 USDT
#     ✅ Futures Price: 0.01 USDT
#     ✅ Spread: 0.9149%
#     ✅ Net Profit After Fees: 0.7149%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: CFX/USDT
#     ✅ Spot Price: 0.09 USDT
#     ✅ Futures Price: 0.09 USDT
#     ✅ Spread: 0.7852%
#     ✅ Net Profit After Fees: 0.5852%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT
#     ✅ Spot Price: 6.44 USDT
#     ✅ Futures Price: 6.49 USDT
#     ✅ Spread: 0.7359%
#     ✅ Net Profit After Fees: 0.5359%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: MOVE/USDT
#     ✅ Spot Price: 0.44 USDT
#     ✅ Futures Price: 0.45 USDT
#     ✅ Spread: 1.1333%
#     ✅ Net Profit After Fees: 0.9333%
#     ⚡ Execute arbitrage on Bybit
# --------------------------------------------------
# ✅ Found 539 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT
#     ✅ Spot Price: 6.44 USDT
#     ✅ Futures Price: 6.49 USDT
#     ✅ Spread: 0.7903%
#     ✅ Net Profit After Fees: 0.5903%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: MOVE/USDT
#     ✅ Spot Price: 0.44 USDT
#     ✅ Futures Price: 0.45 USDT
#     ✅ Spread: 0.8613%
#     ✅ Net Profit After Fees: 0.6613%
#     ⚡ Execute arbitrage on Bybit
# --------------------------------------------------
# ✅ Found 539 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: JELLYJELLY/USDT
#     ✅ Spot Price: 0.02 USDT
#     ✅ Futures Price: 0.02 USDT
#     ✅ Spread: 0.7046%
#     ✅ Net Profit After Fees: 0.5046%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: MOVE/USDT
#     ✅ Spot Price: 0.44 USDT
#     ✅ Futures Price: 0.45 USDT
#     ✅ Spread: 0.9293%
#     ✅ Net Profit After Fees: 0.7293%
#     ⚡ Execute arbitrage on Bybit
# --------------------------------------------------
# ✅ Found 542 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: ARKM/USDT
#     ✅ Spot Price: 0.56 USDT
#     ✅ Futures Price: 0.56 USDT
#     ✅ Spread: 0.7181%
#     ✅ Net Profit After Fees: 0.5181%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BURGER/USDT
#     ✅ Spot Price: 0.11 USDT
#     ✅ Futures Price: 0.11 USDT
#     ✅ Spread: 0.9726%
#     ✅ Net Profit After Fees: 0.7726%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 425 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: MOVE/USDT
#     ✅ Spot Price: 0.44 USDT
#     ✅ Futures Price: 0.45 USDT
#     ✅ Spread: 1.1106%
#     ✅ Net Profit After Fees: 0.9106%
#     ⚡ Execute arbitrage on Bybit
# --------------------------------------------------
# ✅ Found 541 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: LUCE/USDT
#     ✅ Spot Price: 0.01 USDT
#     ✅ Futures Price: 0.01 USDT
#     ✅ Spread: 0.8857%
#     ✅ Net Profit After Fees: 0.6857%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT
#     ✅ Spot Price: 6.46 USDT
#     ✅ Futures Price: 6.50 USDT
#     ✅ Spread: 0.7382%
#     ✅ Net Profit After Fees: 0.5382%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: JELLYJELLY/USDT
#     ✅ Spot Price: 0.02 USDT
#     ✅ Futures Price: 0.02 USDT
#     ✅ Spread: 0.8772%
#     ✅ Net Profit After Fees: 0.6772%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: SAGA/USDT
#     ✅ Spot Price: 0.36 USDT
#     ✅ Futures Price: 0.37 USDT
#     ✅ Spread: 0.8249%
#     ✅ Net Profit After Fees: 0.6249%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 424 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: MOVE/USDT
#     ✅ Spot Price: 0.44 USDT
#     ✅ Futures Price: 0.45 USDT
#     ✅ Spread: 1.3599%
#     ✅ Net Profit After Fees: 1.1599%
#     ⚡ Execute arbitrage on Bybit
# --------------------------------------------------
# ✅ Found 541 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: SAGA/USDT
#     ✅ Spot Price: 0.36 USDT
#     ✅ Futures Price: 0.37 USDT
#     ✅ Spread: 0.7699%
#     ✅ Net Profit After Fees: 0.5699%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BURGER/USDT
#     ✅ Spot Price: 0.12 USDT
#     ✅ Futures Price: 0.12 USDT
#     ✅ Spread: 0.8613%
#     ✅ Net Profit After Fees: 0.6613%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 423 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: MOVE/USDT
#     ✅ Spot Price: 0.44 USDT
#     ✅ Futures Price: 0.45 USDT
#     ✅ Spread: 1.3826%
#     ✅ Net Profit After Fees: 1.1826%
#     ⚡ Execute arbitrage on Bybit
# --------------------------------------------------
# ✅ Found 541 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 423 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: MOVE/USDT
#     ✅ Spot Price: 0.44 USDT
#     ✅ Futures Price: 0.45 USDT
#     ✅ Spread: 1.3599%
#     ✅ Net Profit After Fees: 1.1599%
#     ⚡ Execute arbitrage on Bybit
# --------------------------------------------------
# ⚠️ Skipping MCADE/USDT on Bitget due to error: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742549925930,"data":null}
# ✅ Found 540 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 423 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: MOVE/USDT
#     ✅ Spot Price: 0.44 USDT
#     ✅ Futures Price: 0.45 USDT
#     ✅ Spread: 1.2466%
#     ✅ Net Profit After Fees: 1.0466%
#     ⚡ Execute arbitrage on Bybit
# --------------------------------------------------
# ✅ Found 541 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 422 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: MOVE/USDT
#     ✅ Spot Price: 0.44 USDT
#     ✅ Futures Price: 0.44 USDT
#     ✅ Spread: 0.7253%
#     ✅ Net Profit After Fees: 0.5253%
#     ⚡ Execute arbitrage on Bybit
# --------------------------------------------------
# ✅ Found 541 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: SUNDOG/USDT
#     ✅ Spot Price: 0.06 USDT
#     ✅ Futures Price: 0.06 USDT
#     ✅ Spread: 0.8292%
#     ✅ Net Profit After Fees: 0.6292%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 422 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 541 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: GPS/USDT
#     ✅ Spot Price: 0.03 USDT
#     ✅ Futures Price: 0.03 USDT
#     ✅ Spread: 1.4534%
#     ✅ Net Profit After Fees: 1.2534%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: JELLYJELLY/USDT
#     ✅ Spot Price: 0.02 USDT
#     ✅ Futures Price: 0.02 USDT
#     ✅ Spread: 0.8173%
#     ✅ Net Profit After Fees: 0.6173%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 423 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 541 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT
#     ✅ Spot Price: 6.43 USDT
#     ✅ Futures Price: 6.47 USDT
#     ✅ Spread: 0.7436%
#     ✅ Net Profit After Fees: 0.5436%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 423 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 541 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: JELLYJELLY/USDT
#     ✅ Spot Price: 0.02 USDT
#     ✅ Futures Price: 0.02 USDT
#     ✅ Spread: 1.2289%
#     ✅ Net Profit After Fees: 1.0289%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 422 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 542 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT
#     ✅ Spot Price: 6.41 USDT
#     ✅ Futures Price: 6.46 USDT
#     ✅ Spread: 0.7852%
#     ✅ Net Profit After Fees: 0.5852%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: SUNDOG/USDT
#     ✅ Spot Price: 0.06 USDT
#     ✅ Futures Price: 0.06 USDT
#     ✅ Spread: 0.8278%
#     ✅ Net Profit After Fees: 0.6278%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 421 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 540 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: JELLYJELLY/USDT
#     ✅ Spot Price: 0.02 USDT
#     ✅ Futures Price: 0.02 USDT
#     ✅ Spread: 1.0232%
#     ✅ Net Profit After Fees: 0.8232%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 419 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 540 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 417 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 541 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT
#     ✅ Spot Price: 6.41 USDT
#     ✅ Futures Price: 6.45 USDT
#     ✅ Spread: 0.7299%
#     ✅ Net Profit After Fees: 0.5299%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 419 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 542 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT
#     ✅ Spot Price: 6.39 USDT
#     ✅ Futures Price: 6.44 USDT
#     ✅ Spread: 0.7714%
#     ✅ Net Profit After Fees: 0.5714%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 421 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 542 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT
#     ✅ Spot Price: 6.39 USDT
#     ✅ Futures Price: 6.44 USDT
#     ✅ Spread: 0.7192%
#     ✅ Net Profit After Fees: 0.5192%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 421 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT
#     ✅ Spot Price: 6.39 USDT
#     ✅ Futures Price: 6.43 USDT
#     ✅ Spread: 0.7297%
#     ✅ Net Profit After Fees: 0.5297%
#     ⚡ Execute arbitrage on Bybit
# --------------------------------------------------
# ✅ Found 543 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: LUCE/USDT
#     ✅ Spot Price: 0.01 USDT
#     ✅ Futures Price: 0.01 USDT
#     ✅ Spread: 0.7414%
#     ✅ Net Profit After Fees: 0.5414%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT
#     ✅ Spot Price: 6.39 USDT
#     ✅ Futures Price: 6.45 USDT
#     ✅ Spread: 0.8799%
#     ✅ Net Profit After Fees: 0.6799%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 421 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT
#     ✅ Spot Price: 6.38 USDT
#     ✅ Futures Price: 6.43 USDT
#     ✅ Spread: 0.8670%
#     ✅ Net Profit After Fees: 0.6670%
#     ⚡ Execute arbitrage on Bybit
# --------------------------------------------------
# ⚠️ Skipping RPL/USDT on Bitget due to error: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742554618322,"data":null}
# ✅ Found 542 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT
#     ✅ Spot Price: 6.39 USDT
#     ✅ Futures Price: 6.43 USDT
#     ✅ Spread: 0.7145%
#     ✅ Net Profit After Fees: 0.5145%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 423 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT
#     ✅ Spot Price: 6.37 USDT
#     ✅ Futures Price: 6.42 USDT
#     ✅ Spread: 0.8634%
#     ✅ Net Profit After Fees: 0.6634%
#     ⚡ Execute arbitrage on Bybit
# --------------------------------------------------
# ✅ Found 543 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT
#     ✅ Spot Price: 6.38 USDT
#     ✅ Futures Price: 6.43 USDT
#     ✅ Spread: 0.8858%
#     ✅ Net Profit After Fees: 0.6858%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 424 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT
#     ✅ Spot Price: 6.37 USDT
#     ✅ Futures Price: 6.43 USDT
#     ✅ Spread: 0.9407%
#     ✅ Net Profit After Fees: 0.7407%
#     ⚡ Execute arbitrage on Bybit
# --------------------------------------------------
