# %%
import ccxt
import time
from itertools import permutations
from ccxt.base.errors import RateLimitExceeded

# Replace with your actual Bitget API keys
BITGET_API_KEY = 'bg_b0a9d721607623216a87b066a3df34c3'
BITGET_API_SECRET = '6c4a5016562624b6d7f3b1c59563d4a1a573f630e0e49422fbf509399e56918b'
BITGET_PASSPHRASE = 'BgSecure789Trade2025'  # Required for Bitget authentication

# Connect to Bitget API
bitget = ccxt.bitget({
    'apiKey': BITGET_API_KEY,
    'secret': BITGET_API_SECRET,
    'password': BITGET_PASSPHRASE,
    'options': {'adjustForTimeDifference': True}
})

# %%
# Arbitrage settings
SPREAD_THRESHOLD = 0.1 / 100  # 0.1% profit target
MIN_VOLUME = 1000  # Minimum 24h volume required (in USDT)
CHECK_INTERVAL = 5  # Check every 5 seconds
TRADING_FEE = 0.001  # 0.1% trading fee per trade
STARTING_CAPITAL = 1000  # Configurable capital in USDT

def get_tradable_tokens():
    """Fetches only active spot trading pairs on Bitget and filters out low-volume pairs."""
    try:
        markets = bitget.load_markets()
        tradable_tokens = []

        for symbol, market in markets.items():
            # Ensure the market is a SPOT market and is active
            if market.get("type") == "spot" and market.get("active", False):
                if '/USDT' in symbol and ':USDT' not in symbol:  # Ensure it's a valid USDT spot pair
                    try:
                        market_data = bitget.fetch_ticker(symbol)
                        volume = market_data.get('quoteVolume', 0)  # 24h volume
                        if volume and volume >= MIN_VOLUME:
                            tradable_tokens.append(symbol)
                    except RateLimitExceeded:
                        print("⚠️ Rate limit hit while fetching ticker. Pausing for 60 seconds...")
                        time.sleep(60)
                        continue
                    except Exception as e:
                        print(f"⚠️ Error fetching market data for {symbol}: {e}")
                        continue  # Skip symbols that cause errors

        print(f"✅ Found {len(tradable_tokens)} tradable tokens on Bitget")
        return tradable_tokens

    except Exception as e:
        print(f"❌ Error fetching tradable tokens: {e}")
        return []

def get_price(symbol):
    """Fetch latest price for a given token if the market exists."""
    try:
        if symbol in bitget.load_markets():
            ticker = bitget.fetch_ticker(symbol)
            return float(ticker.get("last", 0)) if ticker else None
        return None
    except RateLimitExceeded:
        print("⚠️ Rate limit hit while fetching price. Pausing for 60 seconds...")
        time.sleep(60)
        return None
    except Exception as e:
        print(f"❌ Error fetching price for {symbol}: {e}")
        return None

def log_arbitrage(trade_path, expected_return, net_profit):
    """Logs detected arbitrage trades to a file."""
    with open("bitget_triangular_arbitrage.log", "a") as log_file:
        log_file.write(f"{trade_path} | Expected: {expected_return:.4%} | Net Profit: {net_profit:.4%}\n")

def check_triangular_arbitrage(tradable_tokens):
    """Checks for triangular arbitrage opportunities within Bitget."""
    for route in permutations(tradable_tokens, 3):  # Ensure three different assets
        base_asset = route[0].split('/')[0]  # First asset in the path
        mid_asset = route[1].split('/')[0]
        final_asset = route[2].split('/')[1]  # Final conversion back to USDT

        if base_asset == final_asset:  # Ensure a valid cycle
            try:
                # Get price data for each leg
                first_leg_price = get_price(route[0])
                second_leg_price = get_price(route[1])
                third_leg_price = get_price(route[2])

                # Ensure all prices are valid
                if None in [first_leg_price, second_leg_price, third_leg_price]:
                    continue  

                # Convert using proper exchange path
                amount_after_first_trade = (STARTING_CAPITAL / first_leg_price) * second_leg_price
                amount_after_second_trade = (amount_after_first_trade / second_leg_price) * third_leg_price
                final_amount = amount_after_second_trade

                expected_return = final_amount / STARTING_CAPITAL
                net_expected_return = expected_return * (1 - TRADING_FEE) ** 3  # Adjust for fees

                # Print all paths for debugging
                print(f"🔍 Checking Arbitrage Path: {route[0]} ➝ {route[1]} ➝ {route[2]}")
                print(f"    ✅ Expected Return: {expected_return:.4%}")
                print(f"    ✅ Net Profit After Fees: {net_expected_return:.4%}")

                # Detect and log only profitable trades
                if net_expected_return > 1.001:  # Ensure profit > 0.1%
                    print(f"✅ VALID Triangular Arbitrage Detected on Bitget")
                    print(f"    ✅ Trade Path: {route[0]} ➝ {route[1]} ➝ {route[2]}")
                    print(f"    ✅ Expected Return: {expected_return:.4%}")
                    print(f"    ✅ Net Profit After Fees: {net_expected_return:.4%}")
                    print("-" * 50)
                    log_arbitrage(f"{route[0]} ➝ {route[1]} ➝ {route[2]}", expected_return, net_expected_return)
            except Exception as e:
                print(f"⚠️ Error in arbitrage check: {e}")
                continue

while True:
    try:
        bitget_tokens = get_tradable_tokens()
        if not bitget_tokens:
            print("❌ No tradable tokens found. Retrying in 10 seconds...")
            time.sleep(10)
            continue

        print("🔄 Checking for arbitrage opportunities...")

        check_triangular_arbitrage(bitget_tokens)

        print("✅ Completed this cycle. Waiting for next check...")
        time.sleep(CHECK_INTERVAL)
    except Exception as e:
        print(f"❌ Error in main loop: {e}")
        time.sleep(10)  # Avoid infinite crash loops
# Out:
# ⚠️ Error fetching market data for AZERO/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742530396931,"data":null}
# ✅ Found 703 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 705 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 705 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 705 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 705 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 705 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 705 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# ✅ Completed this cycle. Waiting for next check...
# ⚠️ Error fetching market data for CROS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CROSUSDT
# ⚠️ Error fetching market data for COMP/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=COMPUSDT
# ⚠️ Error fetching market data for AAVE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AAVEUSDT
# ⚠️ Error fetching market data for SCR/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SCRUSDT
# ⚠️ Error fetching market data for YFI/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=YFIUSDT
# ⚠️ Error fetching market data for DOGE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DOGEUSDT
# ⚠️ Error fetching market data for CHZ/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CHZUSDT
# ⚠️ Error fetching market data for PNUT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PNUTUSDT
# ⚠️ Error fetching market data for SWELL/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SWELLUSDT
# ⚠️ Error fetching market data for SMILE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SMILEUSDT
# ⚠️ Error fetching market data for ARCA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ARCAUSDT
# ⚠️ Error fetching market data for LUCE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LUCEUSDT
# ⚠️ Error fetching market data for FUSE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FUSEUSDT
# ⚠️ Error fetching market data for BAN/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BANUSDT
# ⚠️ Error fetching market data for NFP/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NFPUSDT
# ⚠️ Error fetching market data for FRED/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FREDUSDT
# ⚠️ Error fetching market data for NS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NSUSDT
# ⚠️ Error fetching market data for HIPPO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HIPPOUSDT
# ⚠️ Error fetching market data for PEPECOIN/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PEPECOINUSDT
# ⚠️ Error fetching market data for UP/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=UPUSDT
# ⚠️ Error fetching market data for FARTCOIN/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FARTCOINUSDT
# ⚠️ Error fetching market data for SILLY/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SILLYUSDT
# ⚠️ Error fetching market data for PEAQ/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PEAQUSDT
# ⚠️ Error fetching market data for MV/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MVUSDT
# ⚠️ Error fetching market data for MOBILE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MOBILEUSDT
# ⚠️ Error fetching market data for SWCH/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SWCHUSDT
# ⚠️ Error fetching market data for AI/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AIUSDT
# ⚠️ Error fetching market data for SNEK/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SNEKUSDT
# ⚠️ Error fetching market data for RIFSOL/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RIFSOLUSDT
# ⚠️ Error fetching market data for URO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=UROUSDT
# ⚠️ Error fetching market data for OORT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=OORTUSDT
# ⚠️ Error fetching market data for SOLO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SOLOUSDT
# ⚠️ Error fetching market data for XAI/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=XAIUSDT
# ⚠️ Error fetching market data for FIS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FISUSDT
# ⚠️ Error fetching market data for ELA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ELAUSDT
# ⚠️ Error fetching market data for BONE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BONEUSDT
# ⚠️ Error fetching market data for RDNT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RDNTUSDT
# ⚠️ Error fetching market data for SAROS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SAROSUSDT
# ⚠️ Error fetching market data for MANTA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MANTAUSDT
# ⚠️ Error fetching market data for PONKE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PONKEUSDT
# ⚠️ Error fetching market data for PROPS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PROPSUSDT
# ⚠️ Error fetching market data for UPC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=UPCUSDT
# ⚠️ Error fetching market data for ORAI/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ORAIUSDT
# ⚠️ Error fetching market data for IOST/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=IOSTUSDT
# ⚠️ Error fetching market data for CORE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=COREUSDT
# ⚠️ Error fetching market data for ALT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ALTUSDT
# ⚠️ Error fetching market data for ONDO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ONDOUSDT
# ⚠️ Error fetching market data for WIF/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WIFUSDT
# ⚠️ Error fetching market data for AVA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AVAUSDT
# ⚠️ Error fetching market data for THE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=THEUSDT
# ⚠️ Error fetching market data for CHESS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CHESSUSDT
# ⚠️ Error fetching market data for DEFI/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DEFIUSDT
# ⚠️ Error fetching market data for ORNJ/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ORNJUSDT
# ⚠️ Error fetching market data for JUP/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=JUPUSDT
# ⚠️ Error fetching market data for DMAIL/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DMAILUSDT
# ⚠️ Error fetching market data for BLUR/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BLURUSDT
# ⚠️ Error fetching market data for API3/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=API3USDT
# ⚠️ Error fetching market data for XAUT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=XAUTUSDT
# ⚠️ Error fetching market data for RARE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RAREUSDT
# ⚠️ Error fetching market data for TRU/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TRUUSDT
# ⚠️ Error fetching market data for BIZA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BIZAUSDT
# ⚠️ Error fetching market data for VR/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=VRUSDT
# ⚠️ Error fetching market data for FIRE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FIREUSDT
# ⚠️ Error fetching market data for CFX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CFXUSDT
# ⚠️ Error fetching market data for ZETA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZETAUSDT
# ⚠️ Error fetching market data for MDT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MDTUSDT
# ⚠️ Error fetching market data for COREUM/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=COREUMUSDT
# ⚠️ Error fetching market data for VELODROME/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=VELODROMEUSDT
# ⚠️ Error fetching market data for CLORE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CLOREUSDT
# ⚠️ Error fetching market data for DYM/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DYMUSDT
# ⚠️ Error fetching market data for MAVIA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MAVIAUSDT
# ⚠️ Error fetching market data for NAVX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NAVXUSDT
# ⚠️ Error fetching market data for TRAC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TRACUSDT
# ⚠️ Error fetching market data for LQTY/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LQTYUSDT
# ⚠️ Error fetching market data for STRK/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=STRKUSDT
# ⚠️ Error fetching market data for ASTO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ASTOUSDT
# ⚠️ Error fetching market data for HTX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HTXUSDT
# ⚠️ Error fetching market data for NEO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NEOUSDT
# ⚠️ Error fetching market data for FLM/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FLMUSDT
# ⚠️ Error fetching market data for AZERO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AZEROUSDT
# ⚠️ Error fetching market data for PIXEL/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PIXELUSDT
# ⚠️ Error fetching market data for PRIME/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PRIMEUSDT
# ⚠️ Error fetching market data for ELON/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ELONUSDT
# ⚠️ Error fetching market data for VAI/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=VAIUSDT
# ⚠️ Error fetching market data for HALO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HALOUSDT
# ⚠️ Error fetching market data for ASTR/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ASTRUSDT
# ⚠️ Error fetching market data for VELO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=VELOUSDT
# ⚠️ Error fetching market data for STX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=STXUSDT
# ⚠️ Error fetching market data for FON/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FONUSDT
# ⚠️ Error fetching market data for GFAL/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GFALUSDT
# ⚠️ Error fetching market data for RJV/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RJVUSDT
# ⚠️ Error fetching market data for RON/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RONUSDT
# ⚠️ Error fetching market data for XEM/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=XEMUSDT
# ⚠️ Error fetching market data for ZEN/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZENUSDT
# ⚠️ Error fetching market data for LOOKS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LOOKSUSDT
# ⚠️ Error fetching market data for PEOPLE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PEOPLEUSDT
# ⚠️ Error fetching market data for METIS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=METISUSDT
# ⚠️ Error fetching market data for ACA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ACAUSDT
# ⚠️ Error fetching market data for ALPHA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ALPHAUSDT
# ⚠️ Error fetching market data for BABYDOGE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BABYDOGEUSDT
# ⚠️ Error fetching market data for JUV/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=JUVUSDT
# ⚠️ Error fetching market data for KAIA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=KAIAUSDT
# ⚠️ Error fetching market data for USDC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=USDCUSDT
# ⚠️ Error fetching market data for AUDIO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AUDIOUSDT
# ⚠️ Error fetching market data for C98/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=C98USDT
# ⚠️ Error fetching market data for TLOS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TLOSUSDT
# ⚠️ Error fetching market data for ILV/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ILVUSDT
# ⚠️ Error fetching market data for WEMIX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WEMIXUSDT
# ⚠️ Error fetching market data for RSS3/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RSS3USDT
# ⚠️ Error fetching market data for ARPA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ARPAUSDT
# ⚠️ Error fetching market data for DUSK/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DUSKUSDT
# ⚠️ Error fetching market data for WOO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WOOUSDT
# ⚠️ Error fetching market data for FTT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FTTUSDT
# ⚠️ Error fetching market data for WIN/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WINUSDT
# ⚠️ Error fetching market data for SUN/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SUNUSDT
# ⚠️ Error fetching market data for PSTAKE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PSTAKEUSDT
# ⚠️ Error fetching market data for AR/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ARUSDT
# ⚠️ Error fetching market data for PERP/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PERPUSDT
# ⚠️ Error fetching market data for LUNA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LUNAUSDT
# ⚠️ Error fetching market data for GMT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GMTUSDT
# ⚠️ Error fetching market data for SD/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SDUSDT
# ⚠️ Error fetching market data for MAGIC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MAGICUSDT
# ⚠️ Error fetching market data for KSM/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=KSMUSDT
# ⚠️ Error fetching market data for APE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=APEUSDT
# ⚠️ Error fetching market data for KP3R/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=KP3RUSDT
# ⚠️ Error fetching market data for XDC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=XDCUSDT
# ⚠️ Error fetching market data for ADA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ADAUSDT
# ⚠️ Error fetching market data for NPT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NPTUSDT
# ⚠️ Error fetching market data for EGLD/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=EGLDUSDT
# ⚠️ Error fetching market data for STG/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=STGUSDT
# ⚠️ Error fetching market data for RUNE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RUNEUSDT
# ⚠️ Error fetching market data for COW/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=COWUSDT
# ⚠️ Error fetching market data for RAY/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RAYUSDT
# ⚠️ Error fetching market data for BSW/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BSWUSDT
# ⚠️ Error fetching market data for DODO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DODOUSDT
# ⚠️ Error fetching market data for ORCA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ORCAUSDT
# ⚠️ Error fetching market data for ASI/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ASIUSDT
# ⚠️ Error fetching market data for MORPHO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MORPHOUSDT
# ⚠️ Error fetching market data for CHEEMS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CHEEMSUSDT
# ⚠️ Error fetching market data for ZRC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZRCUSDT
# ⚠️ Error fetching market data for MEMEFI/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MEMEFIUSDT
# ⚠️ Error fetching market data for AIXBT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AIXBTUSDT
# ⚠️ Error fetching market data for CLANKER/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CLANKERUSDT
# ⚠️ Error fetching market data for CHILLGUY/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CHILLGUYUSDT
# ⚠️ Error fetching market data for MAJOR/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MAJORUSDT
# ⚠️ Error fetching market data for MGT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MGTUSDT
# ⚠️ Error fetching market data for F/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FUSDT
# ⚠️ Error fetching market data for OM/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=OMUSDT
# ⚠️ Error fetching market data for GOATS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GOATSUSDT
# ⚠️ Error fetching market data for XION/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=XIONUSDT
# ⚠️ Error fetching market data for HBAR/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HBARUSDT
# ⚠️ Error fetching market data for ALCH/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ALCHUSDT
# ⚠️ Error fetching market data for KOMA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=KOMAUSDT
# ⚠️ Error fetching market data for MOZ/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MOZUSDT
# ⚠️ Error fetching market data for ME/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MEUSDT
# ⚠️ Error fetching market data for BGSC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BGSCUSDT
# ⚠️ Error fetching market data for MOVE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MOVEUSDT
# ⚠️ Error fetching market data for ARC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ARCUSDT
# ⚠️ Error fetching market data for STNK/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=STNKUSDT
# ⚠️ Error fetching market data for HOLDCOIN/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HOLDCOINUSDT
# ⚠️ Error fetching market data for GRIFFAIN/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GRIFFAINUSDT
# ⚠️ Error fetching market data for HYPE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HYPEUSDT
# ⚠️ Error fetching market data for REX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=REXUSDT
# ⚠️ Error fetching market data for ISLAND/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ISLANDUSDT
# ⚠️ Error fetching market data for USUAL/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=USUALUSDT
# ⚠️ Error fetching market data for PENGU/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PENGUUSDT
# ⚠️ Error fetching market data for VANA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=VANAUSDT
# ⚠️ Error fetching market data for ALGO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ALGOUSDT
# ⚠️ Error fetching market data for TOMA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TOMAUSDT
# ⚠️ Error fetching market data for EARNM/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=EARNMUSDT
# ⚠️ Error fetching market data for FUEL/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FUELUSDT
# ⚠️ Error fetching market data for SONIC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SONICUSDT
# ⚠️ Error fetching market data for BIO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BIOUSDT
# ⚠️ Error fetching market data for SWARMS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SWARMSUSDT
# ⚠️ Error fetching market data for ZEREBRO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZEREBROUSDT
# ⚠️ Error fetching market data for BLUE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BLUEUSDT
# ⚠️ Error fetching market data for WEETH/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WEETHUSDT
# ⚠️ Error fetching market data for OGC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=OGCUSDT
# ⚠️ Error fetching market data for PHA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PHAUSDT
# ⚠️ Error fetching market data for SOON/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SOONUSDT
# ⚠️ Error fetching market data for MTOS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MTOSUSDT
# ⚠️ Error fetching market data for AI16Z/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AI16ZUSDT
# ⚠️ Error fetching market data for GPS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GPSUSDT
# ⚠️ Error fetching market data for SOLV/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SOLVUSDT
# ⚠️ Error fetching market data for TREAT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TREATUSDT
# ⚠️ Error fetching market data for PIPPIN/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PIPPINUSDT
# ⚠️ Error fetching market data for CATGOLD/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CATGOLDUSDT
# ⚠️ Error fetching market data for D/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DUSDT
# ⚠️ Error fetching market data for BUZZ/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BUZZUSDT
# ⚠️ Error fetching market data for U2U/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=U2UUSDT
# ⚠️ Error fetching market data for XTER/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=XTERUSDT
# ⚠️ Error fetching market data for HIVE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HIVEUSDT
# ⚠️ Error fetching market data for S/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SUSDT
# ⚠️ Error fetching market data for MELANIA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MELANIAUSDT
# ⚠️ Error fetching market data for GAME/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GAMEUSDT
# ⚠️ Error fetching market data for TRUMP/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TRUMPUSDT
# ⚠️ Error fetching market data for AVAAI/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AVAAIUSDT
# ⚠️ Error fetching market data for FARM/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FARMUSDT
# ⚠️ Error fetching market data for NC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NCUSDT
# ⚠️ Error fetching market data for VERT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=VERTUSDT
# ⚠️ Error fetching market data for WOOF/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WOOFUSDT
# ⚠️ Error fetching market data for MXNA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MXNAUSDT
# ⚠️ Error fetching market data for DUCK/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DUCKUSDT
# ⚠️ Error fetching market data for CLAY/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CLAYUSDT
# ⚠️ Error fetching market data for USDS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=USDSUSDT
# ⚠️ Error fetching market data for VINE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=VINEUSDT
# ⚠️ Error fetching market data for ANIME/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ANIMEUSDT
# ⚠️ Error fetching market data for SKY/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SKYUSDT
# ⚠️ Error fetching market data for MDOGS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MDOGSUSDT
# ⚠️ Error fetching market data for YULI/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=YULIUSDT
# ⚠️ Error fetching market data for VTHO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=VTHOUSDT
# ⚠️ Error fetching market data for J/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=JUSDT
# ⚠️ Error fetching market data for PLUME/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PLUMEUSDT
# ⚠️ Error fetching market data for TRIAS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TRIASUSDT
# ⚠️ Error fetching market data for ANLOG/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ANLOGUSDT
# ⚠️ Error fetching market data for JELLYJELLY/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=JELLYJELLYUSDT
# ⚠️ Error fetching market data for PORTAL/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PORTALUSDT
# ⚠️ Error fetching market data for GPT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GPTUSDT
# ⚠️ Error fetching market data for ICE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ICEUSDT
# ⚠️ Error fetching market data for UFD/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=UFDUSDT
# ⚠️ Error fetching market data for ML/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MLUSDT
# ⚠️ Error fetching market data for MAPO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MAPOUSDT
# ⚠️ Error fetching market data for ALVA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ALVAUSDT
# ⚠️ Error fetching market data for NESS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NESSUSDT
# ⚠️ Error fetching market data for WEN/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WENUSDT
# ⚠️ Error fetching market data for BERA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BERAUSDT
# ⚠️ Error fetching market data for NUUM/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NUUMUSDT
# ⚠️ Error fetching market data for KLV/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=KLVUSDT
# ⚠️ Error fetching market data for AEVO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AEVOUSDT
# ⚠️ Error fetching market data for FMB/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FMBUSDT
# ⚠️ Error fetching market data for IVPAY/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=IVPAYUSDT
# ⚠️ Error fetching market data for ID/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=IDUSDT
# ⚠️ Error fetching market data for SCA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SCAUSDT
# ⚠️ Error fetching market data for ARB/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ARBUSDT
# ⚠️ Error fetching market data for TAO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TAOUSDT
# ⚠️ Error fetching market data for ETHFI/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ETHFIUSDT
# ⚠️ Error fetching market data for BOME/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BOMEUSDT
# ⚠️ Error fetching market data for BRETT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BRETTUSDT
# ⚠️ Error fetching market data for CGPT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CGPTUSDT
# ⚠️ Error fetching market data for CREO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CREOUSDT
# ⚠️ Error fetching market data for PENDLE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PENDLEUSDT
# ⚠️ Error fetching market data for STETH/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=STETHUSDT
# ⚠️ Error fetching market data for AIDOGE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AIDOGEUSDT
# ⚠️ Error fetching market data for PEPE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PEPEUSDT
# ⚠️ Error fetching market data for ZZZ/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZZZUSDT
# ⚠️ Error fetching market data for SHIDO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SHIDOUSDT
# ⚠️ Error fetching market data for ZKJ/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZKJUSDT
# ⚠️ Error fetching market data for SLERF/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SLERFUSDT
# ⚠️ Error fetching market data for TOMI/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TOMIUSDT
# ⚠️ Error fetching market data for ALE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ALEUSDT
# ⚠️ Error fetching market data for MC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MCUSDT
# ⚠️ Error fetching market data for MVL/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MVLUSDT
# ⚠️ Error fetching market data for SUI/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SUIUSDT
# ⚠️ Error fetching market data for DegenReborn/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DEGENUSDT
# ⚠️ Error fetching market data for TURBO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TURBOUSDT
# ⚠️ Error fetching market data for KAS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=KASUSDT
# ⚠️ Error fetching market data for PCI/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PCIUSDT
# ⚠️ Error fetching market data for GFI/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GFIUSDT
# ⚠️ Error fetching market data for DCB/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DCBUSDT
# ⚠️ Error fetching market data for ZBU/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZBUUSDT
# ⚠️ Error fetching market data for ORDI/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ORDIUSDT
# ⚠️ Error fetching market data for CATBOY/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CATBOYUSDT
# ⚠️ Error fetching market data for AERO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AEROUSDT
# ⚠️ Error fetching market data for LADYS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LADYSUSDT
# ⚠️ Error fetching market data for LYX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LYXUSDT
# ⚠️ Error fetching market data for USDE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=USDEUSDT
# ⚠️ Error fetching market data for BIP1/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BIP1USDT
# ⚠️ Error fetching market data for PROPC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PROPCUSDT
# ⚠️ Error fetching market data for COMBO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=COMBOUSDT
# ⚠️ Error fetching market data for LAI/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LAIUSDT
# ⚠️ Error fetching market data for OSMO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=OSMOUSDT
# ⚠️ Error fetching market data for ZIL/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZILUSDT
# ⚠️ Error fetching market data for MAV/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MAVUSDT
# ⚠️ Error fetching market data for AURORA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AURORAUSDT
# ⚠️ Error fetching market data for NEXO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NEXOUSDT
# ⚠️ Error fetching market data for AMP/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AMPUSDT
# ⚠️ Error fetching market data for LPT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LPTUSDT
# ⚠️ Error fetching market data for PEPE2/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PEPE2USDT
# ⚠️ Error fetching market data for LBR/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LBRUSDT
# ⚠️ Error fetching market data for PAXG/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PAXGUSDT
# ⚠️ Error fetching market data for TEL/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TELUSDT
# ⚠️ Error fetching market data for NFT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NFTUSDT
# ⚠️ Error fetching market data for TUSD/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TUSDUSDT
# ⚠️ Error fetching market data for BTT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BTTUSDT
# ⚠️ Error fetching market data for GLM/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GLMUSDT
# ⚠️ Error fetching market data for NYM/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NYMUSDT
# ⚠️ Error fetching market data for GST/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GSTUSDT
# ⚠️ Error fetching market data for VT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=VTUSDT
# ⚠️ Error fetching market data for FLUX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FLUXUSDT
# ⚠️ Error fetching market data for FITFI/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FITFIUSDT
# ⚠️ Error fetching market data for ROSE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ROSEUSDT
# ⚠️ Error fetching market data for NEAR/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NEARUSDT
# ⚠️ Error fetching market data for DAI/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DAIUSDT
# ⚠️ Error fetching market data for HNT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HNTUSDT
# ⚠️ Error fetching market data for WAXP/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WAXPUSDT
# ⚠️ Error fetching market data for GALFAN/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GALFANUSDT
# ⚠️ Error fetching market data for LINA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LINAUSDT
# ⚠️ Error fetching market data for ENJ/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ENJUSDT
# ⚠️ Error fetching market data for MANA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MANAUSDT
# ⚠️ Error fetching market data for XRP/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=XRPUSDT
# ⚠️ Error fetching market data for BTC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BTCUSDT
# ⚠️ Error fetching market data for ETH/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ETHUSDT
# ⚠️ Error fetching market data for LTC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LTCUSDT
# ⚠️ Error fetching market data for BCH/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BCHUSDT
# ⚠️ Error fetching market data for ETC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ETCUSDT
# ⚠️ Error fetching market data for EOS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=EOSUSDT
# ⚠️ Error fetching market data for SHIB/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SHIBUSDT
# ⚠️ Error fetching market data for 1INCH/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=1INCHUSDT
# ⚠️ Error fetching market data for MKR/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MKRUSDT
# ⚠️ Error fetching market data for REN/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RENUSDT
# ⚠️ Error fetching market data for UMA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=UMAUSDT
# ⚠️ Error fetching market data for ZRX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZRXUSDT
# ⚠️ Error fetching market data for LUNC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LUNCUSDT
# ⚠️ Error fetching market data for USTC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=USTCUSDT
# ⚠️ Error fetching market data for SXP/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SXPUSDT
# ⚠️ Error fetching market data for OP/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=OPUSDT
# ⚠️ Error fetching market data for LRC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LRCUSDT
# ⚠️ Error fetching market data for BAL/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BALUSDT
# ⚠️ Error fetching market data for BNT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BNTUSDT
# ⚠️ Error fetching market data for CRV/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CRVUSDT
# ⚠️ Error fetching market data for BAT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BATUSDT
# ⚠️ Error fetching market data for STORJ/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=STORJUSDT
# ⚠️ Error fetching market data for SNX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SNXUSDT
# ⚠️ Error fetching market data for QTUM/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=QTUMUSDT
# ⚠️ Error fetching market data for OMG/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=OMGUSDT
# ⚠️ Error fetching market data for KNC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=KNCUSDT
# ⚠️ Error fetching market data for BAND/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BANDUSDT
# ⚠️ Error fetching market data for GRT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GRTUSDT
# ⚠️ Error fetching market data for JOE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=JOEUSDT
# ⚠️ Error fetching market data for QUICK/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=QUICKUSDT
# ⚠️ Error fetching market data for NKN/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NKNUSDT
# ⚠️ Error fetching market data for WBTC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WBTCUSDT
# ⚠️ Error fetching market data for RLC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RLCUSDT
# ⚠️ Error fetching market data for OGN/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=OGNUSDT
# ⚠️ Error fetching market data for CAKE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CAKEUSDT
# ⚠️ Error fetching market data for BNB/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BNBUSDT
# ⚠️ Error fetching market data for CHR/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CHRUSDT
# ⚠️ Error fetching market data for ANKR/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ANKRUSDT
# ⚠️ Error fetching market data for RSR/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RSRUSDT
# ⚠️ Error fetching market data for JST/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=JSTUSDT
# ⚠️ Error fetching market data for ICP/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ICPUSDT
# ⚠️ Error fetching market data for MASK/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MASKUSDT
# ⚠️ Error fetching market data for TSTBSC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TSTBSCUSDT
# ⚠️ Error fetching market data for BROCCOLI/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BROCCOLIUSDT
# ⚠️ Error fetching market data for PI/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PIUSDT
# ⚠️ Error fetching market data for SHELL/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SHELLUSDT
# ⚠️ Error fetching market data for SOL/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SOLUSDT
# ⚠️ Error fetching market data for IP/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=IPUSDT
# ⚠️ Error fetching market data for HEI/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HEIUSDT
# ⚠️ Error fetching market data for LAYER/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LAYERUSDT
# ⚠️ Error fetching market data for JAILSTOOL/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=JAILSTOOLUSDT
# ⚠️ Error fetching market data for ZOO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZOOUSDT
# ⚠️ Error fetching market data for BGSOL/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BGSOLUSDT
# ⚠️ Error fetching market data for KAITO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=KAITOUSDT
# ⚠️ Error fetching market data for TAPS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TAPSUSDT
# ⚠️ Error fetching market data for RED/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=REDUSDT
# ⚠️ Error fetching market data for ROAM/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ROAMUSDT
# ⚠️ Error fetching market data for FIL/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FILUSDT
# ⚠️ Error fetching market data for DEUSD/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DEUSDUSDT
# ⚠️ Error fetching market data for CELO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CELOUSDT
# ⚠️ Error fetching market data for AB/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ABUSDT
# ⚠️ Error fetching market data for BGB/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BGBUSDT
# ⚠️ Error fetching market data for MEMHASH/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MEMHASHUSDT
# ⚠️ Error fetching market data for YGG/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=YGGUSDT
# ⚠️ Error fetching market data for PDA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PDAUSDT
# ⚠️ Error fetching market data for LDO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LDOUSDT
# ⚠️ Error fetching market data for OIK/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=OIKUSDT
# ⚠️ Error fetching market data for LVVA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LVVAUSDT
# ⚠️ Error fetching market data for BMT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BMTUSDT
# ⚠️ Error fetching market data for MINT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MINTUSDT
# ⚠️ Error fetching market data for ELX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ELXUSDT
# ⚠️ Error fetching market data for BR/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BRUSDT
# ⚠️ Error fetching market data for TUT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TUTUSDT
# ⚠️ Error fetching market data for MUBARAK/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MUBARAKUSDT
# ⚠️ Error fetching market data for MEW/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MEWUSDT
# ⚠️ Error fetching market data for W/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WUSDT
# ⚠️ Error fetching market data for IAG/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=IAGUSDT
# ⚠️ Error fetching market data for SERSH/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SERSHUSDT
# ⚠️ Error fetching market data for ENA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ENAUSDT
# ⚠️ Error fetching market data for MASA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MASAUSDT
# ⚠️ Error fetching market data for SAGA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SAGAUSDT
# ⚠️ Error fetching market data for TNSR/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TNSRUSDT
# ⚠️ Error fetching market data for MUMU/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MUMUUSDT
# ⚠️ Error fetching market data for MOEW/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MOEWUSDT
# ⚠️ Error fetching market data for OMNI1/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=OMNI1USDT
# ...
# ⚠️ Error fetching market data for LMWR/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LMWRUSDT
# ⚠️ Error fetching market data for ONE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ONEUSDT
# ⚠️ Error fetching market data for SSV/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SSVUSDT
# ⚠️ Error fetching market data for AXL/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AXLUSDT
# ⚠️ Error fetching market data for IDEX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=IDEXUSDT
# ⚠️ Error fetching market data for INJ/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=INJUSDT
# ⚠️ Error fetching market data for IOTX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=IOTXUSDT
# ⚠️ Error fetching market data for IQ/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=IQUSDT
# ⚠️ Error fetching market data for ALEX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ALEXUSDT
# ⚠️ Error fetching market data for MBX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MBXUSDT
# ⚠️ Error fetching market data for ACE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ACEUSDT
# ⚠️ Error fetching market data for ARG/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ARGUSDT
# ⚠️ Error fetching market data for ALU/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ALUUSDT
# ⚠️ Error fetching market data for COQ/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=COQUSDT
# ⚠️ Error fetching market data for GMX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GMXUSDT
# ⚠️ Error fetching market data for LEVER/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LEVERUSDT
# ⚠️ Error fetching market data for LOKA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LOKAUSDT
# ⚠️ Error fetching market data for LOOM/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LOOMUSDT
# ⚠️ Error fetching market data for XEN/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=XENUSDT
# ⚠️ Error fetching market data for MTL/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MTLUSDT
# ⚠️ Error fetching market data for MINA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MINAUSDT
# ⚠️ Error fetching market data for MXC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MXCUSDT
# ⚠️ Error fetching market data for NMR/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NMRUSDT
# ⚠️ Error fetching market data for OXT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=OXTUSDT
# ⚠️ Error fetching market data for OG/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=OGUSDT
# ⚠️ Error fetching market data for POWR/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=POWRUSDT
# ⚠️ Error fetching market data for PYR/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PYRUSDT
# ⚠️ Error fetching market data for PUNDIX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PUNDIXUSDT
# ⚠️ Error fetching market data for POND/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PONDUSDT
# ⚠️ Error fetching market data for PROM/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PROMUSDT
# ⚠️ Error fetching market data for PHB/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PHBUSDT
# ⚠️ Error fetching market data for QKC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=QKCUSDT
# ⚠️ Error fetching market data for QNT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=QNTUSDT
# ⚠️ Error fetching market data for ROUTE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ROUTEUSDT
# ⚠️ Error fetching market data for APT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=APTUSDT
# ⚠️ Error fetching market data for SNT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SNTUSDT
# ⚠️ Error fetching market data for STMX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=STMXUSDT
# ⚠️ Error fetching market data for STPT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=STPTUSDT
# ⚠️ Error fetching market data for SUPER/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SUPERUSDT
# ⚠️ Error fetching market data for SYN/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SYNUSDT
# ⚠️ Error fetching market data for T/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TUSDT
# ⚠️ Error fetching market data for TRB/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TRBUSDT
# ⚠️ Error fetching market data for TWT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TWTUSDT
# ⚠️ Error fetching market data for VIB/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=VIBUSDT
# ⚠️ Error fetching market data for WAVES/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WAVESUSDT
# ⚠️ Error fetching market data for XCN/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=XCNUSDT
# ⚠️ Error fetching market data for XPR/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=XPRUSDT
# ⚠️ Error fetching market data for RAD/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RADUSDT
# ⚠️ Error fetching market data for HFT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HFTUSDT
# ⚠️ Error fetching market data for ONT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ONTUSDT
# ⚠️ Error fetching market data for WING/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WINGUSDT
# ⚠️ Error fetching market data for ONG/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ONGUSDT
# ⚠️ Error fetching market data for HOOK/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HOOKUSDT
# ⚠️ Error fetching market data for AGLD/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AGLDUSDT
# ⚠️ Error fetching market data for KAVA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=KAVAUSDT
# ⚠️ Error fetching market data for DYDX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DYDXUSDT
# ⚠️ Error fetching market data for OAS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=OASUSDT
# ⚠️ Error fetching market data for CELR/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CELRUSDT
# ⚠️ Error fetching market data for GEAR/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GEARUSDT
# ⚠️ Error fetching market data for RACA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RACAUSDT
# ⚠️ Error fetching market data for BONK/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BONKUSDT
# ⚠️ Error fetching market data for BETA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BETAUSDT
# ⚠️ Error fetching market data for MBOX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MBOXUSDT
# ⚠️ Error fetching market data for AXS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AXSUSDT
# ⚠️ Error fetching market data for HIGH/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HIGHUSDT
# ⚠️ Error fetching market data for GNS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GNSUSDT
# ⚠️ Error fetching market data for SLP/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SLPUSDT
# ⚠️ Error fetching market data for GALA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GALAUSDT
# ⚠️ Error fetching market data for SAND/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SANDUSDT
# ⚠️ Error fetching market data for ALICE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ALICEUSDT
# ⚠️ Error fetching market data for TLM/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TLMUSDT
# ⚠️ Error fetching market data for RPL/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RPLUSDT
# ⚠️ Error fetching market data for GODS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GODSUSDT
# ⚠️ Error fetching market data for DOT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DOTUSDT
# ⚠️ Error fetching market data for ATOM/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ATOMUSDT
# ⚠️ Error fetching market data for IMX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=IMXUSDT
# ⚠️ Error fetching market data for MOVR/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MOVRUSDT
# ⚠️ Error fetching market data for ENS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ENSUSDT
# ⚠️ Error fetching market data for WILD/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WILDUSDT
# ⚠️ Error fetching market data for AVAX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AVAXUSDT
# ⚠️ Error fetching market data for CRO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CROUSDT
# ⚠️ Error fetching market data for JASMY/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=JASMYUSDT
# ⚠️ Error fetching market data for TON/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TONUSDT
# ⚠️ Error fetching market data for CVX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CVXUSDT
# ⚠️ Error fetching market data for SPELL/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SPELLUSDT
# ⚠️ Error fetching market data for HOT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HOTUSDT
# ⚠️ Error fetching market data for COTI/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=COTIUSDT
# ⚠️ Error fetching market data for FXS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FXSUSDT
# ⚠️ Error fetching market data for CEEK/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CEEKUSDT
# ⚠️ Error fetching market data for DENT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DENTUSDT
# ⚠️ Error fetching market data for FLOKI/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FLOKIUSDT
# ⚠️ Error fetching market data for WHY/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WHYUSDT
# ⚠️ Error fetching market data for RENDER/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RENDERUSDT
# ⚠️ Error fetching market data for LSD/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LSDUSDT
# ⚠️ Error fetching market data for L3/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=L3USDT
# ⚠️ Error fetching market data for MAX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MAXUSDT
# ⚠️ Error fetching market data for INVITE/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=INVITEUSDT
# ⚠️ Error fetching market data for NEIROETH/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NEIROETHUSDT
# ⚠️ Error fetching market data for DTEC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DTECUSDT
# ⚠️ Error fetching market data for AIN/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AINUSDT
# ⚠️ Error fetching market data for WUF/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WUFUSDT
# ⚠️ Error fetching market data for ICX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ICXUSDT
# ⚠️ Error fetching market data for NMT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NMTUSDT
# ⚠️ Error fetching market data for DOGS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DOGSUSDT
# ⚠️ Error fetching market data for SUNDOG/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SUNDOGUSDT
# ⚠️ Error fetching market data for CEC/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CECUSDT
# ⚠️ Error fetching market data for MAK/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MAKUSDT
# ⚠️ Error fetching market data for CPOOL/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CPOOLUSDT
# ⚠️ Error fetching market data for BRN/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BRNUSDT
# ⚠️ Error fetching market data for SLF/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SLFUSDT
# ⚠️ Error fetching market data for RFRM/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RFRMUSDT
# ⚠️ Error fetching market data for ORDER/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ORDERUSDT
# ⚠️ Error fetching market data for BOX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BOXUSDT
# ⚠️ Error fetching market data for LOGX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LOGXUSDT
# ⚠️ Error fetching market data for EGP/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=EGPUSDT
# ⚠️ Error fetching market data for WAT/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WATUSDT
# ⚠️ Error fetching market data for CATI/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CATIUSDT
# ⚠️ Error fetching market data for NEIROCTO/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NEIROCTOUSDT
# ⚠️ Error fetching market data for ZCX/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZCXUSDT
# ⚠️ Error fetching market data for HMSTR/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HMSTRUSDT
# ⚠️ Error fetching market data for PUFFER/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PUFFERUSDT
# ⚠️ Error fetching market data for MOODENGETH/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MOODENGETHUSDT
# ⚠️ Error fetching market data for CARV/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CARVUSDT
# ⚠️ Error fetching market data for CATS/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CATSUSDT
# ⚠️ Error fetching market data for EIGEN/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=EIGENUSDT
# ⚠️ Error fetching market data for MOODENG/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MOODENGUSDT
# ⚠️ Error fetching market data for GEEK/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GEEKUSDT
# ✅ Found 273 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 705 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 705 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# ✅ Completed this cycle. Waiting for next check...
# ⚠️ Error fetching market data for LUMIA/USDT: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LUMIAUSDT
