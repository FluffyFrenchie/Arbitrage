# %%
import ccxt
import time

# API Keys (Replace with actual keys)
BYBIT_API_KEY = 'I6m01uNAWiensHbIBA'
BYBIT_API_SECRET = 'vkaviS9xw903NJPncMtHgGfyiWB4mnhSJTyK'
BITGET_API_KEY = 'bg_b0a9d721607623216a87b066a3df34c3'
BITGET_API_SECRET = '6c4a5016562624b6d7f3b1c59563d4a1a573f630e0e49422fbf509399e56918b'

# Connect to exchanges
bybit = ccxt.bybit({
    'apiKey': BYBIT_API_KEY,
    'secret': BYBIT_API_SECRET,
    'options': {'adjustForTimeDifference': True}
})

bitget = ccxt.bitget({
    'apiKey': BITGET_API_KEY,
    'secret': BITGET_API_SECRET,
    'options': {'adjustForTimeDifference': True}
})

# %%
# Arbitrage settings
SPREAD_THRESHOLD = 0.5 / 100  # 0.5% profit target
MIN_VOLUME = 50000  # Minimum 24h volume required (in USDT)
CHECK_INTERVAL = 5  # Check every 5 seconds
TRADING_FEE = 0.001  # 0.1% trading fee per trade

def get_tradable_tokens(exchange, exchange_name):
    """Fetch tradable spot tokens and filter out low-volume pairs"""
    try:
        markets = exchange.load_markets()
        tradable_tokens = []

        for symbol in markets:
            if "/USDT" in symbol and ":" not in symbol:  # Spot trading pairs
                market_data = exchange.fetch_ticker(symbol)
                volume = market_data.get('quoteVolume', 0) or market_data.get('baseVolume', 0)
                if volume and volume >= MIN_VOLUME:
                    tradable_tokens.append(symbol)

        print(f"✅ Found {len(tradable_tokens)} spot tokens on {exchange_name}")
        return tradable_tokens
    except Exception as e:
        print(f"❌ Error fetching tradable tokens from {exchange_name}: {e}")
        return []

def get_price(exchange, symbol):
    """Fetch latest price for a given token if the market exists"""
    try:
        if symbol in exchange.load_markets():
            ticker = exchange.fetch_ticker(symbol)
            return float(ticker.get("last", ticker.get("lastPrice", None)))
        return None
    except Exception as e:
        print(f"❌ Error fetching price for {symbol}: {e}")
        return None

def check_inter_exchange_arbitrage(symbol):
    """Checks for arbitrage opportunities between Bybit and Bitget for Spot Trading"""
    bybit_price = get_price(bybit, symbol)
    bitget_price = get_price(bitget, symbol)

    if not bybit_price or not bitget_price:
        return

    spread_buy_bybit_sell_bitget = (bitget_price - bybit_price) / bybit_price
    spread_buy_bitget_sell_bybit = (bybit_price - bitget_price) / bitget_price

    net_profit_bybit_to_bitget = spread_buy_bybit_sell_bitget - (TRADING_FEE * 2)
    net_profit_bitget_to_bybit = spread_buy_bitget_sell_bybit - (TRADING_FEE * 2)

    if net_profit_bybit_to_bitget >= SPREAD_THRESHOLD:
        print(f"🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for {symbol}")
        print(f"    ✅ Bybit Spot Price: {bybit_price:.5f} USDT")
        print(f"    ✅ Bitget Spot Price: {bitget_price:.5f} USDT")
        print(f"    ✅ Spread: {spread_buy_bybit_sell_bitget:.4%}")
        print(f"    ✅ Net Profit After Fees: {net_profit_bybit_to_bitget:.4%}")
        print("-" * 50)

    if net_profit_bitget_to_bybit >= SPREAD_THRESHOLD:
        print(f"🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for {symbol}")
        print(f"    ✅ Bitget Spot Price: {bitget_price:.5f} USDT")
        print(f"    ✅ Bybit Spot Price: {bybit_price:.5f} USDT")
        print(f"    ✅ Spread: {spread_buy_bitget_sell_bybit:.4%}")
        print(f"    ✅ Net Profit After Fees: {net_profit_bitget_to_bybit:.4%}")
        print("-" * 50)

while True:
    try:
        bybit_tokens = get_tradable_tokens(bybit, "Bybit")
        bitget_tokens = get_tradable_tokens(bitget, "Bitget")

        common_spot_tokens = list(set(bybit_tokens) & set(bitget_tokens))

        if not common_spot_tokens:
            print("❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...")
            time.sleep(10)
            continue

        print("🔄 Checking for arbitrage opportunities...")

        for token in common_spot_tokens:
            check_inter_exchange_arbitrage(token)

        print("✅ Completed this cycle. Waiting for next check...")
        time.sleep(CHECK_INTERVAL)

    except Exception as e:
        print(f"❌ Error in main loop: {e}")
        time.sleep(10)
# Out:
# ✅ Found 430 spot tokens on Bybit
# ✅ Found 549 spot tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for FMB/USDT
#     ✅ Bitget Spot Price: 0.00501 USDT
#     ✅ Bybit Spot Price: 0.00510 USDT
#     ✅ Spread: 1.7964%
#     ✅ Net Profit After Fees: 1.5964%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for AEVO/USDT
#     ✅ Bitget Spot Price: 0.13260 USDT
#     ✅ Bybit Spot Price: 0.13390 USDT
#     ✅ Spread: 0.9804%
#     ✅ Net Profit After Fees: 0.7804%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for TOMI/USDT
#     ✅ Bybit Spot Price: 0.00314 USDT
#     ✅ Bitget Spot Price: 0.00316 USDT
#     ✅ Spread: 0.7011%
#     ✅ Net Profit After Fees: 0.5011%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for SUNDOG/USDT
#     ✅ Bybit Spot Price: 0.06049 USDT
#     ✅ Bitget Spot Price: 0.06100 USDT
#     ✅ Spread: 0.8431%
#     ✅ Net Profit After Fees: 0.6431%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for WELL/USDT
#     ✅ Bitget Spot Price: 0.00020 USDT
#     ✅ Bybit Spot Price: 0.00021 USDT
#     ✅ Spread: 0.7349%
#     ✅ Net Profit After Fees: 0.5349%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 430 spot tokens on Bybit
# ✅ Found 549 spot tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for FMB/USDT
#     ✅ Bitget Spot Price: 0.00501 USDT
#     ✅ Bybit Spot Price: 0.00510 USDT
#     ✅ Spread: 1.7764%
#     ✅ Net Profit After Fees: 1.5764%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for REN/USDT
#     ✅ Bybit Spot Price: 0.00979 USDT
#     ✅ Bitget Spot Price: 0.00988 USDT
#     ✅ Spread: 0.9193%
#     ✅ Net Profit After Fees: 0.7193%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for RPL/USDT
#     ✅ Bybit Spot Price: 5.42200 USDT
#     ✅ Bitget Spot Price: 5.46500 USDT
#     ✅ Spread: 0.7931%
#     ✅ Net Profit After Fees: 0.5931%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for ZENT/USDT
#     ✅ Bybit Spot Price: 0.01260 USDT
#     ✅ Bitget Spot Price: 0.01272 USDT
#     ✅ Spread: 0.9524%
#     ✅ Net Profit After Fees: 0.7524%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for AEVO/USDT
#     ✅ Bitget Spot Price: 0.13260 USDT
#     ✅ Bybit Spot Price: 0.13380 USDT
#     ✅ Spread: 0.9050%
#     ✅ Net Profit After Fees: 0.7050%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for SUNDOG/USDT
#     ✅ Bybit Spot Price: 0.06038 USDT
#     ✅ Bitget Spot Price: 0.06100 USDT
#     ✅ Spread: 1.0268%
#     ✅ Net Profit After Fees: 0.8268%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for WELL/USDT
#     ✅ Bitget Spot Price: 0.00020 USDT
#     ✅ Bybit Spot Price: 0.00021 USDT
#     ✅ Spread: 0.7839%
#     ✅ Net Profit After Fees: 0.5839%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 430 spot tokens on Bybit
# ✅ Found 550 spot tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for FMB/USDT
#     ✅ Bitget Spot Price: 0.00501 USDT
#     ✅ Bybit Spot Price: 0.00510 USDT
#     ✅ Spread: 1.7565%
#     ✅ Net Profit After Fees: 1.5565%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for REN/USDT
#     ✅ Bybit Spot Price: 0.00979 USDT
#     ✅ Bitget Spot Price: 0.00989 USDT
#     ✅ Spread: 1.0215%
#     ✅ Net Profit After Fees: 0.8215%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for ZENT/USDT
#     ✅ Bybit Spot Price: 0.01261 USDT
#     ✅ Bitget Spot Price: 0.01272 USDT
#     ✅ Spread: 0.8723%
#     ✅ Net Profit After Fees: 0.6723%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for SUNDOG/USDT
#     ✅ Bybit Spot Price: 0.06035 USDT
#     ✅ Bitget Spot Price: 0.06100 USDT
#     ✅ Spread: 1.0771%
#     ✅ Net Profit After Fees: 0.8771%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for ANIME/USDT
#     ✅ Bybit Spot Price: 0.01975 USDT
#     ✅ Bitget Spot Price: 0.01990 USDT
#     ✅ Spread: 0.7595%
#     ✅ Net Profit After Fees: 0.5595%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 429 spot tokens on Bybit
# ✅ Found 550 spot tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for FMB/USDT
#     ✅ Bitget Spot Price: 0.00501 USDT
#     ✅ Bybit Spot Price: 0.00510 USDT
#     ✅ Spread: 1.7764%
#     ✅ Net Profit After Fees: 1.5764%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for SUNDOG/USDT
#     ✅ Bybit Spot Price: 0.06045 USDT
#     ✅ Bitget Spot Price: 0.06100 USDT
#     ✅ Spread: 0.9098%
#     ✅ Net Profit After Fees: 0.7098%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for WELL/USDT
#     ✅ Bitget Spot Price: 0.00020 USDT
#     ✅ Bybit Spot Price: 0.00021 USDT
#     ✅ Spread: 0.7349%
#     ✅ Net Profit After Fees: 0.5349%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for MON/USDT
#     ✅ Bitget Spot Price: 0.02844 USDT
#     ✅ Bybit Spot Price: 0.02864 USDT
#     ✅ Spread: 0.7032%
#     ✅ Net Profit After Fees: 0.5032%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for ANIME/USDT
#     ✅ Bybit Spot Price: 0.01976 USDT
#     ✅ Bitget Spot Price: 0.01990 USDT
#     ✅ Spread: 0.7085%
#     ✅ Net Profit After Fees: 0.5085%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=DEFIUSDT&category=spot
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DBRUSDT
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BTCUSDT&category=spot
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LUMIAUSDT
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BTCUSDT&category=spot
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LUMIAUSDT
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BTCUSDT&category=spot
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LUMIAUSDT
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BTCUSDT&category=spot
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LUMIAUSDT
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BTCUSDT&category=spot
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LUMIAUSDT
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BTCUSDT&category=spot
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LUMIAUSDT
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BTCUSDT&category=spot
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LUMIAUSDT
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BTCUSDT&category=spot
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LUMIAUSDT
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BTCUSDT&category=spot
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LUMIAUSDT
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BTCUSDT&category=spot
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LUMIAUSDT
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BTCUSDT&category=spot
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LUMIAUSDT
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=GALFTUSDT&category=spot
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LUMIAUSDT
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ✅ Found 429 spot tokens on Bybit
# ✅ Found 553 spot tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for FMB/USDT
#     ✅ Bitget Spot Price: 0.00500 USDT
#     ✅ Bybit Spot Price: 0.00510 USDT
#     ✅ Spread: 1.9400%
#     ✅ Net Profit After Fees: 1.7400%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for REN/USDT
#     ✅ Bitget Spot Price: 0.00978 USDT
#     ✅ Bybit Spot Price: 0.00987 USDT
#     ✅ Spread: 0.9202%
#     ✅ Net Profit After Fees: 0.7202%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for WELL/USDT
#     ✅ Bitget Spot Price: 0.00020 USDT
#     ✅ Bybit Spot Price: 0.00021 USDT
#     ✅ Spread: 1.6320%
#     ✅ Net Profit After Fees: 1.4320%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for A8/USDT
#     ✅ Bybit Spot Price: 0.15500 USDT
#     ✅ Bitget Spot Price: 0.15610 USDT
#     ✅ Spread: 0.7097%
#     ✅ Net Profit After Fees: 0.5097%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for ANIME/USDT
#     ✅ Bybit Spot Price: 0.01975 USDT
#     ✅ Bitget Spot Price: 0.01990 USDT
#     ✅ Spread: 0.7595%
#     ✅ Net Profit After Fees: 0.5595%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 429 spot tokens on Bybit
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DTECUSDT
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BTCUSDT&category=spot
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LUMIAUSDT
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FLOWUSDT&category=spot
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LUMIAUSDT
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BTCUSDT&category=spot
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LUMIAUSDT
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ✅ Found 429 spot tokens on Bybit
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BAKEUSDT
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BTCUSDT&category=spot
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LUMIAUSDT
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BTCUSDT&category=spot
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LUMIAUSDT
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens from Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BTCUSDT&category=spot
# ❌ Error fetching tradable tokens from Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LUMIAUSDT
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ✅ Found 429 spot tokens on Bybit
# ✅ Found 553 spot tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for PPT/USDT
#     ✅ Bitget Spot Price: 0.23790 USDT
#     ✅ Bybit Spot Price: 0.24722 USDT
#     ✅ Spread: 3.9176%
#     ✅ Net Profit After Fees: 3.7176%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for FMB/USDT
#     ✅ Bitget Spot Price: 0.00498 USDT
#     ✅ Bybit Spot Price: 0.00505 USDT
#     ✅ Spread: 1.5060%
#     ✅ Net Profit After Fees: 1.3060%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for WELL/USDT
#     ✅ Bitget Spot Price: 0.00020 USDT
#     ✅ Bybit Spot Price: 0.00021 USDT
#     ✅ Spread: 1.9297%
#     ✅ Net Profit After Fees: 1.7297%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for ANIME/USDT
#     ✅ Bybit Spot Price: 0.01975 USDT
#     ✅ Bitget Spot Price: 0.01990 USDT
#     ✅ Spread: 0.7595%
#     ✅ Net Profit After Fees: 0.5595%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 429 spot tokens on Bybit
# ✅ Found 554 spot tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for PPT/USDT
#     ✅ Bitget Spot Price: 0.23210 USDT
#     ✅ Bybit Spot Price: 0.23507 USDT
#     ✅ Spread: 1.2796%
#     ✅ Net Profit After Fees: 1.0796%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for FMB/USDT
#     ✅ Bitget Spot Price: 0.00496 USDT
#     ✅ Bybit Spot Price: 0.00505 USDT
#     ✅ Spread: 1.8145%
#     ✅ Net Profit After Fees: 1.6145%
# --------------------------------------------------
# ❌ Error fetching price for GMT/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742808606688,"data":null}
# ❌ Error fetching price for XTER/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742808609750,"data":null}
# ❌ Error fetching price for FUEL/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742808611394,"data":null}
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for WELL/USDT
#     ✅ Bitget Spot Price: 0.00020 USDT
#     ✅ Bybit Spot Price: 0.00021 USDT
#     ✅ Spread: 1.8308%
#     ✅ Net Profit After Fees: 1.6308%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 429 spot tokens on Bybit
# ❌ Error fetching tradable tokens from Bitget: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742808788130,"data":null}
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ✅ Found 430 spot tokens on Bybit
# ✅ Found 554 spot tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# ❌ Error fetching price for SATS/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742808956172,"data":null}
# ❌ Error fetching price for ME/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742808956692,"data":null}
# ❌ Error fetching price for MKR/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742808957399,"data":null}
# ❌ Error fetching price for IMX/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742808960429,"data":null}
# ❌ Error fetching price for FTT/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742808961784,"data":null}
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for FMB/USDT
#     ✅ Bitget Spot Price: 0.00496 USDT
#     ✅ Bybit Spot Price: 0.00506 USDT
#     ✅ Spread: 1.9556%
#     ✅ Net Profit After Fees: 1.7556%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for ZENT/USDT
#     ✅ Bybit Spot Price: 0.01259 USDT
#     ✅ Bitget Spot Price: 0.01272 USDT
#     ✅ Spread: 1.0326%
#     ✅ Net Profit After Fees: 0.8326%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for WELL/USDT
#     ✅ Bitget Spot Price: 0.00020 USDT
#     ✅ Bybit Spot Price: 0.00021 USDT
#     ✅ Spread: 1.9297%
#     ✅ Net Profit After Fees: 1.7297%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for ANIME/USDT
#     ✅ Bybit Spot Price: 0.01974 USDT
#     ✅ Bitget Spot Price: 0.01990 USDT
#     ✅ Spread: 0.8105%
#     ✅ Net Profit After Fees: 0.6105%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 430 spot tokens on Bybit
# ❌ Error fetching tradable tokens from Bitget: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742809135430,"data":null}
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ✅ Found 430 spot tokens on Bybit
# ✅ Found 554 spot tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# ❌ Error fetching price for SCA/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742809304455,"data":null}
# ❌ Error fetching price for CARV/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742809306169,"data":null}
# ❌ Error fetching price for FMB/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742809307291,"data":null}
# ❌ Error fetching price for LINK/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742809308441,"data":null}
# ❌ Error fetching price for MAVIA/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742809308668,"data":null}
# ❌ Error fetching price for INJ/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742809309333,"data":null}
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for ZENT/USDT
#     ✅ Bybit Spot Price: 0.01257 USDT
#     ✅ Bitget Spot Price: 0.01272 USDT
#     ✅ Spread: 1.1933%
#     ✅ Net Profit After Fees: 0.9933%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for WELL/USDT
#     ✅ Bitget Spot Price: 0.00020 USDT
#     ✅ Bybit Spot Price: 0.00021 USDT
#     ✅ Spread: 1.8308%
#     ✅ Net Profit After Fees: 1.6308%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for ANIME/USDT
#     ✅ Bybit Spot Price: 0.01976 USDT
#     ✅ Bitget Spot Price: 0.01990 USDT
#     ✅ Spread: 0.7085%
#     ✅ Net Profit After Fees: 0.5085%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 430 spot tokens on Bybit
# ❌ Error fetching tradable tokens from Bitget: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742809471877,"data":null}
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ✅ Found 430 spot tokens on Bybit
# ✅ Found 554 spot tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# ❌ Error fetching price for PPT/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742809643236,"data":null}
# ❌ Error fetching price for ONE/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742809645007,"data":null}
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for FMB/USDT
#     ✅ Bitget Spot Price: 0.00498 USDT
#     ✅ Bybit Spot Price: 0.00506 USDT
#     ✅ Spread: 1.6867%
#     ✅ Net Profit After Fees: 1.4867%
# --------------------------------------------------
# ❌ Error fetching price for LINK/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742809646372,"data":null}
# ❌ Error fetching price for MOVR/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742809647093,"data":null}
# ❌ Error fetching price for INJ/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742809647321,"data":null}
# ❌ Error fetching price for ZKL/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742809648003,"data":null}
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for ZENT/USDT
#     ✅ Bybit Spot Price: 0.01260 USDT
#     ✅ Bitget Spot Price: 0.01272 USDT
#     ✅ Spread: 0.9524%
#     ✅ Net Profit After Fees: 0.7524%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for WELL/USDT
#     ✅ Bitget Spot Price: 0.00020 USDT
#     ✅ Bybit Spot Price: 0.00021 USDT
#     ✅ Spread: 1.6320%
#     ✅ Net Profit After Fees: 1.4320%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 430 spot tokens on Bybit
# ❌ Error fetching tradable tokens from Bitget: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742809814020,"data":null}
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ✅ Found 429 spot tokens on Bybit
# ✅ Found 553 spot tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# ❌ Error fetching price for TON/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742809985091,"data":null}
# ❌ Error fetching price for APT/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742809986180,"data":null}
# ❌ Error fetching price for PERP/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742809988565,"data":null}
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for FMB/USDT
#     ✅ Bitget Spot Price: 0.00497 USDT
#     ✅ Bybit Spot Price: 0.00506 USDT
#     ✅ Spread: 1.8712%
#     ✅ Net Profit After Fees: 1.6712%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for WELL/USDT
#     ✅ Bitget Spot Price: 0.00020 USDT
#     ✅ Bybit Spot Price: 0.00021 USDT
#     ✅ Spread: 1.5834%
#     ✅ Net Profit After Fees: 1.3834%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for ZEREBRO/USDT
#     ✅ Bitget Spot Price: 0.04030 USDT
#     ✅ Bybit Spot Price: 0.04060 USDT
#     ✅ Spread: 0.7444%
#     ✅ Net Profit After Fees: 0.5444%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 429 spot tokens on Bybit
# ❌ Error fetching tradable tokens from Bitget: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742810154150,"data":null}
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ✅ Found 430 spot tokens on Bybit
# ✅ Found 554 spot tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for MAK/USDT
#     ✅ Bybit Spot Price: 0.01799 USDT
#     ✅ Bitget Spot Price: 0.01813 USDT
#     ✅ Spread: 0.7782%
#     ✅ Net Profit After Fees: 0.5782%
# --------------------------------------------------
# ❌ Error fetching price for BTC/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742810325455,"data":null}
# ❌ Error fetching price for TEL/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742810327548,"data":null}
# ❌ Error fetching price for TUSD/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742810328331,"data":null}
# ❌ Error fetching price for TON/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742810329366,"data":null}
# ❌ Error fetching price for LEVER/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742810330150,"data":null}
# ❌ Error fetching price for APT/USDT: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742810330469,"data":null}
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for FMB/USDT
#     ✅ Bitget Spot Price: 0.00497 USDT
#     ✅ Bybit Spot Price: 0.00505 USDT
#     ✅ Spread: 1.6901%
#     ✅ Net Profit After Fees: 1.4901%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for BEAM/USDT
#     ✅ Bybit Spot Price: 0.00843 USDT
#     ✅ Bitget Spot Price: 0.00849 USDT
#     ✅ Spread: 0.7117%
#     ✅ Net Profit After Fees: 0.5117%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget Spot, Sell on Bybit Spot for WELL/USDT
#     ✅ Bitget Spot Price: 0.00020 USDT
#     ✅ Bybit Spot Price: 0.00021 USDT
#     ✅ Spread: 1.4837%
#     ✅ Net Profit After Fees: 1.2837%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 430 spot tokens on Bybit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 70
#      68 try:
#      69     bybit_tokens = get_tradable_tokens(bybit, "Bybit")
# ---> 70     bitget_tokens = get_tradable_tokens(bitget, "Bitget")
#      72     common_spot_tokens = list(set(bybit_tokens) & set(bitget_tokens))
#      74     if not common_spot_tokens:
#
# Cell In[8], line 15, in get_tradable_tokens(exchange, exchange_name)
#      13 for symbol in markets:
#      14     if "/USDT" in symbol and ":" not in symbol:  # Spot trading pairs
# ---> 15         market_data = exchange.fetch_ticker(symbol)
#      16         volume = market_data.get('quoteVolume', 0) or market_data.get('baseVolume', 0)
#      17         if volume and volume >= MIN_VOLUME:
#
# File ~\anaconda3\Lib\site-packages\ccxt\bitget.py:2840, in bitget.fetch_ticker(self, symbol, params)
#    2838 response = None
#    2839 if market['spot']:
# -> 2840     response = self.publicSpotGetV2SpotMarketTickers(self.extend(request, params))
#    2841 else:
#    2842     productType = None
#
# File ~\anaconda3\Lib\site-packages\ccxt\base\types.py:35, in Entry.__init__.<locals>.unbound_method(_self, params)
#      34 def unbound_method(_self, params={}):
# ---> 35     return _self.request(self.path, self.api, self.method, params, config=self.config)
#
# File ~\anaconda3\Lib\site-packages\ccxt\base\exchange.py:4368, in Exchange.request(self, path, api, method, params, headers, body, config)
#    4367 def request(self, path, api: Any = 'public', method='GET', params={}, headers: Any = None, body: Any = None, config={}):
# -> 4368     return self.fetch2(path, api, method, params, headers, body, config)
#
# File ~\anaconda3\Lib\site-packages\ccxt\base\exchange.py:4353, in Exchange.fetch2(self, path, api, method, params, headers, body, config)
#    4351 for i in range(0, retries + 1):
#    4352     try:
# -> 4353         return self.fetch(request['url'], request['method'], request['headers'], request['body'])
#    4354     except Exception as e:
#    4355         if isinstance(e, OperationFailed):
#
# File ~\anaconda3\Lib\site-packages\ccxt\base\exchange.py:548, in Exchange.fetch(self, url, method, headers, body)
#     546 json_response = None
#     547 try:
# --> 548     response = self.session.request(
#     549         method,
#     550         url,
#     551         data=body,
#     552         headers=request_headers,
#     553         timeout=(self.timeout / 1000),
#     554         proxies=proxies,
#     555         verify=self.verify and self.validateServerSsl
#     556     )
#     557     # does not try to detect encoding
#     558     response.encoding = 'utf-8'
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File ~\anaconda3\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File ~\anaconda3\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~\anaconda3\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~\anaconda3\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File ~\anaconda3\Lib\ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\Lib\ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:
