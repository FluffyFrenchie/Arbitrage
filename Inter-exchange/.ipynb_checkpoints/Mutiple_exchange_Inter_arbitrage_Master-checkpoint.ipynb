# %%
import ccxt
import time
from itertools import permutations

# Replace with your actual API keys
BYBIT_API_KEY = 'I6m01uNAWiensHbIBA'
BYBIT_API_SECRET = 'vkaviS9xw903NJPncMtHgGfyiWB4mnhSJTyK'
BITGET_API_KEY = 'bg_b0a9d721607623216a87b066a3df34c3'
BITGET_API_SECRET = '6c4a5016562624b6d7f3b1c59563d4a1a573f630e0e49422fbf509399e56918b'

# Connect to Bybit and Bitget APIs
bybit = ccxt.bybit({
    'apiKey': BYBIT_API_KEY,
    'secret': BYBIT_API_SECRET,
    'options': {'adjustForTimeDifference': True}
})

bitget = ccxt.bitget({
    'apiKey': BITGET_API_KEY,
    'secret': BITGET_API_SECRET,
    'options': {'adjustForTimeDifference': True}
})

# %%
# Arbitrage settings
SPREAD_THRESHOLD = 0.5 / 100  # 0.5% profit target
MIN_VOLUME = 50000  # Minimum 24h volume required (in USDT)
CHECK_INTERVAL = 5  # Check every 5 seconds
TRADING_FEE = 0.001  # 0.1% trading fee per trade

def get_tradable_tokens(exchange, exchange_name):
    """Fetches all tradable tokens on the given exchange and filters out low-volume pairs"""
    try:
        markets = exchange.load_markets()
        tradable_tokens = []
        for symbol in markets:
            if '/USDT' in symbol and ':USDT' not in symbol:
                market_data = exchange.fetch_ticker(symbol)
                volume = market_data.get('quoteVolume', 0)
                if volume and volume >= MIN_VOLUME:
                    tradable_tokens.append(symbol)
        print(f"✅ Found {len(tradable_tokens)} tradable tokens on {exchange_name}")
        return tradable_tokens
    except Exception as e:
        print(f"❌ Error fetching tradable tokens from {exchange_name}: {e}")
        return []

def get_price(exchange, symbol):
    """Fetch latest price for a given token if the market exists"""
    try:
        if symbol in exchange.load_markets():
            ticker = exchange.fetch_ticker(symbol)
            return float(ticker.get("last", ticker.get("lastPrice", None)))
        return None
    except Exception as e:
        print(f"❌ Error fetching price for {symbol}: {e}")
        return None

def check_inter_exchange_arbitrage(symbol):
    """Checks for arbitrage opportunities between Bybit and Bitget"""
    bybit_price = get_price(bybit, symbol)
    bitget_price = get_price(bitget, symbol)
    
    if not bybit_price or not bitget_price:
        return
    
    spread_buy_bybit_sell_bitget = (bitget_price - bybit_price) / bybit_price
    spread_buy_bitget_sell_bybit = (bybit_price - bitget_price) / bitget_price
    
    net_profit_bybit_to_bitget = spread_buy_bybit_sell_bitget - (TRADING_FEE * 2)
    net_profit_bitget_to_bybit = spread_buy_bitget_sell_bybit - (TRADING_FEE * 2)
    
    if net_profit_bybit_to_bitget >= SPREAD_THRESHOLD:
        print(f"🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for {symbol}")
        print(f"    ✅ Bybit Price: {bybit_price:.2f} USDT")
        print(f"    ✅ Bitget Price: {bitget_price:.2f} USDT")
        print(f"    ✅ Spread: {spread_buy_bybit_sell_bitget:.4%}")
        print(f"    ✅ Net Profit After Fees: {net_profit_bybit_to_bitget:.4%}")
        print("-" * 50)
    
    if net_profit_bitget_to_bybit >= SPREAD_THRESHOLD:
        print(f"🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for {symbol}")
        print(f"    ✅ Bitget Price: {bitget_price:.2f} USDT")
        print(f"    ✅ Bybit Price: {bybit_price:.2f} USDT")
        print(f"    ✅ Spread: {spread_buy_bitget_sell_bybit:.4%}")
        print(f"    ✅ Net Profit After Fees: {net_profit_bitget_to_bybit:.4%}")
        print("-" * 50)

while True:
    try:
        bybit_tokens = get_tradable_tokens(bybit, "Bybit")
        bitget_tokens = get_tradable_tokens(bitget, "Bitget")
        common_tokens = list(set(bybit_tokens) & set(bitget_tokens))

        if not common_tokens:
            print("❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...")
            time.sleep(10)
            continue

        print("🔄 Checking for arbitrage opportunities...")

        for token in common_tokens:
            check_inter_exchange_arbitrage(token)

        print("✅ Completed this cycle. Waiting for next check...")
        time.sleep(CHECK_INTERVAL)
    except Exception as e:
        print(f"❌ Error in main loop: {e}")
        time.sleep(10)
# Out:
# ✅ Found 427 tradable tokens on Bybit
# ✅ Found 576 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 57.6324%
#     ✅ Net Profit After Fees: 57.4324%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for ZIG/USDT
#     ✅ Bybit Price: 0.09 USDT
#     ✅ Bitget Price: 0.09 USDT
#     ✅ Spread: 1.1481%
#     ✅ Net Profit After Fees: 0.9481%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for MOZ/USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Spread: 0.7707%
#     ✅ Net Profit After Fees: 0.5707%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for FUEL/USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Spread: 0.7752%
#     ✅ Net Profit After Fees: 0.5752%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for FMB/USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 0.8394%
#     ✅ Net Profit After Fees: 0.6394%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for PIXFI/USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Spread: 0.8247%
#     ✅ Net Profit After Fees: 0.6247%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 574 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 58.6604%
#     ✅ Net Profit After Fees: 58.4604%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for ZIG/USDT
#     ✅ Bybit Price: 0.09 USDT
#     ✅ Bitget Price: 0.09 USDT
#     ✅ Spread: 1.1481%
#     ✅ Net Profit After Fees: 0.9481%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for REN/USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 0.7764%
#     ✅ Net Profit After Fees: 0.5764%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for FMB/USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 1.0969%
#     ✅ Net Profit After Fees: 0.8969%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 427 tradable tokens on Bybit
# ✅ Found 574 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for DMAIL/USDT
#     ✅ Bybit Price: 0.11 USDT
#     ✅ Bitget Price: 0.11 USDT
#     ✅ Spread: 0.8865%
#     ✅ Net Profit After Fees: 0.6865%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 57.2923%
#     ✅ Net Profit After Fees: 57.0923%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for AR/USDT
#     ✅ Bitget Price: 6.99 USDT
#     ✅ Bybit Price: 7.04 USDT
#     ✅ Spread: 0.7153%
#     ✅ Net Profit After Fees: 0.5153%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for ZIG/USDT
#     ✅ Bybit Price: 0.09 USDT
#     ✅ Bitget Price: 0.09 USDT
#     ✅ Spread: 1.0320%
#     ✅ Net Profit After Fees: 0.8320%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for FMB/USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 0.8029%
#     ✅ Net Profit After Fees: 0.6029%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for WEMIX/USDT
#     ✅ Bybit Price: 0.53 USDT
#     ✅ Bitget Price: 0.53 USDT
#     ✅ Spread: 0.7190%
#     ✅ Net Profit After Fees: 0.5190%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 575 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for DMAIL/USDT
#     ✅ Bybit Price: 0.11 USDT
#     ✅ Bitget Price: 0.11 USDT
#     ✅ Spread: 0.9760%
#     ✅ Net Profit After Fees: 0.7760%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 61.7081%
#     ✅ Net Profit After Fees: 61.5081%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for ZIG/USDT
#     ✅ Bybit Price: 0.09 USDT
#     ✅ Bitget Price: 0.09 USDT
#     ✅ Spread: 0.9969%
#     ✅ Net Profit After Fees: 0.7969%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for MOZ/USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Spread: 0.7864%
#     ✅ Net Profit After Fees: 0.5864%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for FMB/USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 0.9672%
#     ✅ Net Profit After Fees: 0.7672%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 575 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 59.3210%
#     ✅ Net Profit After Fees: 59.1210%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for ZIG/USDT
#     ✅ Bybit Price: 0.09 USDT
#     ✅ Bitget Price: 0.09 USDT
#     ✅ Spread: 0.9969%
#     ✅ Net Profit After Fees: 0.7969%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for FIRE/USDT
#     ✅ Bybit Price: 0.04 USDT
#     ✅ Bitget Price: 0.04 USDT
#     ✅ Spread: 0.7109%
#     ✅ Net Profit After Fees: 0.5109%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for ANIME/USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Spread: 0.8043%
#     ✅ Net Profit After Fees: 0.6043%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for SAROS/USDT
#     ✅ Bybit Price: 0.05 USDT
#     ✅ Bitget Price: 0.05 USDT
#     ✅ Spread: 0.9129%
#     ✅ Net Profit After Fees: 0.7129%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for FMB/USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 1.2088%
#     ✅ Net Profit After Fees: 1.0088%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for WEMIX/USDT
#     ✅ Bybit Price: 0.53 USDT
#     ✅ Bitget Price: 0.53 USDT
#     ✅ Spread: 0.9506%
#     ✅ Net Profit After Fees: 0.7506%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 575 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 58.8037%
#     ✅ Net Profit After Fees: 58.6037%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for ZIG/USDT
#     ✅ Bybit Price: 0.09 USDT
#     ✅ Bitget Price: 0.09 USDT
#     ✅ Spread: 0.9969%
#     ✅ Net Profit After Fees: 0.7969%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for ANIME/USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Spread: 0.9125%
#     ✅ Net Profit After Fees: 0.7125%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for LUCE/USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Spread: 0.7511%
#     ✅ Net Profit After Fees: 0.5511%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for PIXFI/USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Spread: 1.3269%
#     ✅ Net Profit After Fees: 1.1269%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for WEMIX/USDT
#     ✅ Bybit Price: 0.53 USDT
#     ✅ Bitget Price: 0.53 USDT
#     ✅ Spread: 0.8729%
#     ✅ Net Profit After Fees: 0.6729%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 427 tradable tokens on Bybit
# ✅ Found 576 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 59.3578%
#     ✅ Net Profit After Fees: 59.1578%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for SAROS/USDT
#     ✅ Bybit Price: 0.05 USDT
#     ✅ Bitget Price: 0.05 USDT
#     ✅ Spread: 1.2579%
#     ✅ Net Profit After Fees: 1.0579%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for FMB/USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 0.7130%
#     ✅ Net Profit After Fees: 0.5130%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for PIXFI/USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Spread: 0.9248%
#     ✅ Net Profit After Fees: 0.7248%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for WEMIX/USDT
#     ✅ Bybit Price: 0.52 USDT
#     ✅ Bitget Price: 0.53 USDT
#     ✅ Spread: 1.1268%
#     ✅ Net Profit After Fees: 0.9268%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 427 tradable tokens on Bybit
# ✅ Found 577 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 66.6667%
#     ✅ Net Profit After Fees: 66.4667%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for ZIG/USDT
#     ✅ Bitget Price: 0.09 USDT
#     ✅ Bybit Price: 0.09 USDT
#     ✅ Spread: 0.9639%
#     ✅ Net Profit After Fees: 0.7639%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for SAROS/USDT
#     ✅ Bybit Price: 0.05 USDT
#     ✅ Bitget Price: 0.05 USDT
#     ✅ Spread: 0.9555%
#     ✅ Net Profit After Fees: 0.7555%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for FMB/USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 0.8029%
#     ✅ Net Profit After Fees: 0.6029%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for PIXFI/USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Spread: 0.9248%
#     ✅ Net Profit After Fees: 0.7248%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for WEMIX/USDT
#     ✅ Bybit Price: 0.53 USDT
#     ✅ Bitget Price: 0.53 USDT
#     ✅ Spread: 0.9332%
#     ✅ Net Profit After Fees: 0.7332%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 577 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 66.3467%
#     ✅ Net Profit After Fees: 66.1467%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for ZIG/USDT
#     ✅ Bitget Price: 0.09 USDT
#     ✅ Bybit Price: 0.09 USDT
#     ✅ Spread: 0.9174%
#     ✅ Net Profit After Fees: 0.7174%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for FMB/USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 0.9341%
#     ✅ Net Profit After Fees: 0.7341%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for PIXFI/USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Spread: 1.0588%
#     ✅ Net Profit After Fees: 0.8588%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for WEMIX/USDT
#     ✅ Bybit Price: 0.52 USDT
#     ✅ Bitget Price: 0.53 USDT
#     ✅ Spread: 0.8023%
#     ✅ Net Profit After Fees: 0.6023%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 424 tradable tokens on Bybit
# ✅ Found 576 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for A8/USDT
#     ✅ Bybit Price: 0.16 USDT
#     ✅ Bitget Price: 0.16 USDT
#     ✅ Spread: 0.7412%
#     ✅ Net Profit After Fees: 0.5412%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 67.4154%
#     ✅ Net Profit After Fees: 67.2154%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for AR/USDT
#     ✅ Bybit Price: 7.05 USDT
#     ✅ Bitget Price: 7.10 USDT
#     ✅ Spread: 0.7092%
#     ✅ Net Profit After Fees: 0.5092%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for MOVR/USDT
#     ✅ Bybit Price: 6.31 USDT
#     ✅ Bitget Price: 6.36 USDT
#     ✅ Spread: 0.7288%
#     ✅ Net Profit After Fees: 0.5288%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for PENGU/USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 0.8047%
#     ✅ Net Profit After Fees: 0.6047%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for FIRE/USDT
#     ✅ Bybit Price: 0.04 USDT
#     ✅ Bitget Price: 0.04 USDT
#     ✅ Spread: 0.7160%
#     ✅ Net Profit After Fees: 0.5160%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for AARK/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 0.7249%
#     ✅ Net Profit After Fees: 0.5249%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for FMB/USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 0.8044%
#     ✅ Net Profit After Fees: 0.6044%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for BRETT/USDT
#     ✅ Bitget Price: 0.03 USDT
#     ✅ Bybit Price: 0.03 USDT
#     ✅ Spread: 0.8563%
#     ✅ Net Profit After Fees: 0.6563%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 425 tradable tokens on Bybit
# ✅ Found 577 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for GOAT/USDT
#     ✅ Bitget Price: 0.06 USDT
#     ✅ Bybit Price: 0.06 USDT
#     ✅ Spread: 0.8818%
#     ✅ Net Profit After Fees: 0.6818%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for A8/USDT
#     ✅ Bybit Price: 0.16 USDT
#     ✅ Bitget Price: 0.16 USDT
#     ✅ Spread: 1.1787%
#     ✅ Net Profit After Fees: 0.9787%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 66.8712%
#     ✅ Net Profit After Fees: 66.6712%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for ZIG/USDT
#     ✅ Bitget Price: 0.09 USDT
#     ✅ Bybit Price: 0.09 USDT
#     ✅ Spread: 0.8594%
#     ✅ Net Profit After Fees: 0.6594%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for MOZ/USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Spread: 1.0731%
#     ✅ Net Profit After Fees: 0.8731%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for FMB/USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 0.9872%
#     ✅ Net Profit After Fees: 0.7872%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for BRETT/USDT
#     ✅ Bitget Price: 0.03 USDT
#     ✅ Bybit Price: 0.03 USDT
#     ✅ Spread: 0.8869%
#     ✅ Net Profit After Fees: 0.6869%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 425 tradable tokens on Bybit
# ✅ Found 576 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for A8/USDT
#     ✅ Bybit Price: 0.16 USDT
#     ✅ Bitget Price: 0.16 USDT
#     ✅ Spread: 0.8035%
#     ✅ Net Profit After Fees: 0.6035%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 64.7077%
#     ✅ Net Profit After Fees: 64.5077%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 575 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for A8/USDT
#     ✅ Bybit Price: 0.16 USDT
#     ✅ Bitget Price: 0.16 USDT
#     ✅ Spread: 1.0533%
#     ✅ Net Profit After Fees: 0.8533%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 65.3067%
#     ✅ Net Profit After Fees: 65.1067%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for CBK/USDT
#     ✅ Bitget Price: 0.54 USDT
#     ✅ Bybit Price: 0.54 USDT
#     ✅ Spread: 0.7259%
#     ✅ Net Profit After Fees: 0.5259%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for MOZ/USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Spread: 0.7253%
#     ✅ Net Profit After Fees: 0.5253%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 575 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for A8/USDT
#     ✅ Bybit Price: 0.16 USDT
#     ✅ Bitget Price: 0.16 USDT
#     ✅ Spread: 1.6833%
#     ✅ Net Profit After Fees: 1.4833%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for BLAST/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 0.8642%
#     ✅ Net Profit After Fees: 0.6642%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 66.4087%
#     ✅ Net Profit After Fees: 66.2087%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for ZENT/USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 0.7692%
#     ✅ Net Profit After Fees: 0.5692%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for AEVO/USDT
#     ✅ Bitget Price: 0.12 USDT
#     ✅ Bybit Price: 0.12 USDT
#     ✅ Spread: 0.8104%
#     ✅ Net Profit After Fees: 0.6104%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for TEL/USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 0.8476%
#     ✅ Net Profit After Fees: 0.6476%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for REN/USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Spread: 0.8277%
#     ✅ Net Profit After Fees: 0.6277%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for BOME/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 0.7790%
#     ✅ Net Profit After Fees: 0.5790%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 427 tradable tokens on Bybit
# ✅ Found 575 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for BLAST/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 0.9877%
#     ✅ Net Profit After Fees: 0.7877%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 65.1235%
#     ✅ Net Profit After Fees: 64.9235%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for AEVO/USDT
#     ✅ Bitget Price: 0.12 USDT
#     ✅ Bybit Price: 0.12 USDT
#     ✅ Spread: 0.7293%
#     ✅ Net Profit After Fees: 0.5293%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for MOZ/USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Spread: 0.9906%
#     ✅ Net Profit After Fees: 0.7906%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for FIRE/USDT
#     ✅ Bybit Price: 0.04 USDT
#     ✅ Bitget Price: 0.04 USDT
#     ✅ Spread: 0.7194%
#     ✅ Net Profit After Fees: 0.5194%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 425 tradable tokens on Bybit
# ✅ Found 575 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for BLAST/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 1.0185%
#     ✅ Net Profit After Fees: 0.8185%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 66.0248%
#     ✅ Net Profit After Fees: 65.8248%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for ZENT/USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 0.9224%
#     ✅ Net Profit After Fees: 0.7224%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for AEVO/USDT
#     ✅ Bitget Price: 0.12 USDT
#     ✅ Bybit Price: 0.12 USDT
#     ✅ Spread: 0.7293%
#     ✅ Net Profit After Fees: 0.5293%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MAK/USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Spread: 0.8179%
#     ✅ Net Profit After Fees: 0.6179%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for SAROS/USDT
#     ✅ Bybit Price: 0.05 USDT
#     ✅ Bitget Price: 0.05 USDT
#     ✅ Spread: 1.1327%
#     ✅ Net Profit After Fees: 0.9327%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 425 tradable tokens on Bybit
# ✅ Found 575 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for BLAST/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 1.1420%
#     ✅ Net Profit After Fees: 0.9420%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 64.7988%
#     ✅ Net Profit After Fees: 64.5988%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for ZENT/USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 0.9992%
#     ✅ Net Profit After Fees: 0.7992%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for AEVO/USDT
#     ✅ Bitget Price: 0.12 USDT
#     ✅ Bybit Price: 0.12 USDT
#     ✅ Spread: 0.8104%
#     ✅ Net Profit After Fees: 0.6104%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 425 tradable tokens on Bybit
# ✅ Found 575 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for BLAST/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 1.1728%
#     ✅ Net Profit After Fees: 0.9728%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 63.7846%
#     ✅ Net Profit After Fees: 63.5846%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for ZENT/USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 1.3836%
#     ✅ Net Profit After Fees: 1.1836%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for ZIG/USDT
#     ✅ Bitget Price: 0.09 USDT
#     ✅ Bybit Price: 0.09 USDT
#     ✅ Spread: 0.9122%
#     ✅ Net Profit After Fees: 0.7122%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for AEVO/USDT
#     ✅ Bitget Price: 0.12 USDT
#     ✅ Bybit Price: 0.12 USDT
#     ✅ Spread: 0.8104%
#     ✅ Net Profit After Fees: 0.6104%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for TEL/USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 1.0510%
#     ✅ Net Profit After Fees: 0.8510%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for MOZ/USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Spread: 1.1366%
#     ✅ Net Profit After Fees: 0.9366%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for AARK/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 1.2595%
#     ✅ Net Profit After Fees: 1.0595%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 427 tradable tokens on Bybit
