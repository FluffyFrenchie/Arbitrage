# %%
import ccxt
import time
from itertools import permutations

# Replace with your actual API keys
BYBIT_API_KEY = 'I6m01uNAWiensHbIBA'
BYBIT_API_SECRET = 'vkaviS9xw903NJPncMtHgGfyiWB4mnhSJTyK'
BITGET_API_KEY = 'bg_b0a9d721607623216a87b066a3df34c3'
BITGET_API_SECRET = '6c4a5016562624b6d7f3b1c59563d4a1a573f630e0e49422fbf509399e56918b'

# Connect to Bybit and Bitget APIs
bybit = ccxt.bybit({
    'apiKey': BYBIT_API_KEY,
    'secret': BYBIT_API_SECRET,
    'options': {'adjustForTimeDifference': True}
})

bitget = ccxt.bitget({
    'apiKey': BITGET_API_KEY,
    'secret': BITGET_API_SECRET,
    'options': {'adjustForTimeDifference': True}
})

# %%
# Arbitrage settings
SPREAD_THRESHOLD = 0.5 / 100  # 0.5% profit target
MIN_VOLUME = 50000  # Minimum 24h volume required (in USDT)
CHECK_INTERVAL = 5  # Check every 5 seconds
TRADING_FEE = 0.001  # 0.1% trading fee per trade

def get_tradable_tokens(exchange, exchange_name):
    """Fetches all tradable tokens on the given exchange and filters out low-volume pairs"""
    try:
        markets = exchange.load_markets()
        tradable_tokens = []
        for symbol in markets:
            if '/USDT' in symbol and ':USDT' not in symbol:
                market_data = exchange.fetch_ticker(symbol)
                volume = market_data.get('quoteVolume', 0)
                if volume and volume >= MIN_VOLUME:
                    tradable_tokens.append(symbol)
        print(f"✅ Found {len(tradable_tokens)} tradable tokens on {exchange_name}")
        return tradable_tokens
    except Exception as e:
        print(f"❌ Error fetching tradable tokens from {exchange_name}: {e}")
        return []

def get_price(exchange, symbol):
    """Fetch latest price for a given token if the market exists"""
    try:
        if symbol in exchange.load_markets():
            ticker = exchange.fetch_ticker(symbol)
            return float(ticker.get("last", ticker.get("lastPrice", None)))
        return None
    except Exception as e:
        print(f"❌ Error fetching price for {symbol}: {e}")
        return None

def check_inter_exchange_arbitrage(symbol):
    """Checks for arbitrage opportunities between Bybit and Bitget"""
    bybit_price = get_price(bybit, symbol)
    bitget_price = get_price(bitget, symbol)
    
    if not bybit_price or not bitget_price:
        return
    
    spread_buy_bybit_sell_bitget = (bitget_price - bybit_price) / bybit_price
    spread_buy_bitget_sell_bybit = (bybit_price - bitget_price) / bitget_price
    
    net_profit_bybit_to_bitget = spread_buy_bybit_sell_bitget - (TRADING_FEE * 2)
    net_profit_bitget_to_bybit = spread_buy_bitget_sell_bybit - (TRADING_FEE * 2)
    
    if net_profit_bybit_to_bitget >= SPREAD_THRESHOLD:
        print(f"🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for {symbol}")
        print(f"    ✅ Bybit Price: {bybit_price:.2f} USDT")
        print(f"    ✅ Bitget Price: {bitget_price:.2f} USDT")
        print(f"    ✅ Spread: {spread_buy_bybit_sell_bitget:.4%}")
        print(f"    ✅ Net Profit After Fees: {net_profit_bybit_to_bitget:.4%}")
        print("-" * 50)
    
    if net_profit_bitget_to_bybit >= SPREAD_THRESHOLD:
        print(f"🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for {symbol}")
        print(f"    ✅ Bitget Price: {bitget_price:.2f} USDT")
        print(f"    ✅ Bybit Price: {bybit_price:.2f} USDT")
        print(f"    ✅ Spread: {spread_buy_bitget_sell_bybit:.4%}")
        print(f"    ✅ Net Profit After Fees: {net_profit_bitget_to_bybit:.4%}")
        print("-" * 50)

while True:
    try:
        bybit_tokens = get_tradable_tokens(bybit, "Bybit")
        bitget_tokens = get_tradable_tokens(bitget, "Bitget")
        common_tokens = list(set(bybit_tokens) & set(bitget_tokens))

        if not common_tokens:
            print("❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...")
            time.sleep(10)
            continue

        print("🔄 Checking for arbitrage opportunities...")

        for token in common_tokens:
            check_inter_exchange_arbitrage(token)

        print("✅ Completed this cycle. Waiting for next check...")
        time.sleep(CHECK_INTERVAL)
    except Exception as e:
        print(f"❌ Error in main loop: {e}")
        time.sleep(10)
# Out:
# ❌ Error fetching tradable tokens from Bybit: bybit {"retCode":10002,"retMsg":"invalid request, please check your server timestamp or recv_window param. req_timestamp[1742549728335],server_timestamp[1742549733364],recv_window[5000]","result":{},"retExtInfo":{},"time":1742549733364}
# ✅ Found 541 tradable tokens on Bitget
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ✅ Found 423 tradable tokens on Bybit
# ✅ Found 541 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for MOVE/USDT
#     ✅ Bybit Price: 0.44 USDT
#     ✅ Bitget Price: 0.45 USDT
#     ✅ Spread: 1.3599%
#     ✅ Net Profit After Fees: 1.1599%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MOZ/USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Spread: 0.7092%
#     ✅ Net Profit After Fees: 0.5092%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for F/USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Spread: 0.7130%
#     ✅ Net Profit After Fees: 0.5130%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for VANRY/USDT
#     ✅ Bitget Price: 0.03 USDT
#     ✅ Bybit Price: 0.03 USDT
#     ✅ Spread: 0.8244%
#     ✅ Net Profit After Fees: 0.6244%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 6.4516%
#     ✅ Net Profit After Fees: 6.2516%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for GSWIFT/USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Spread: 1.0905%
#     ✅ Net Profit After Fees: 0.8905%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 423 tradable tokens on Bybit
# ✅ Found 541 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for BR/USDT
#     ✅ Bybit Price: 0.16 USDT
#     ✅ Bitget Price: 0.17 USDT
#     ✅ Spread: 1.8749%
#     ✅ Net Profit After Fees: 1.6749%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MAK/USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Spread: 0.9874%
#     ✅ Net Profit After Fees: 0.7874%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for MON/USDT
#     ✅ Bybit Price: 0.03 USDT
#     ✅ Bitget Price: 0.03 USDT
#     ✅ Spread: 1.6255%
#     ✅ Net Profit After Fees: 1.4255%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for AARK/USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Spread: 0.9021%
#     ✅ Net Profit After Fees: 0.7021%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for MOVE/USDT
#     ✅ Bybit Price: 0.44 USDT
#     ✅ Bitget Price: 0.45 USDT
#     ✅ Spread: 1.4053%
#     ✅ Net Profit After Fees: 1.2053%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MOZ/USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Spread: 0.8262%
#     ✅ Net Profit After Fees: 0.6262%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 12.5161%
#     ✅ Net Profit After Fees: 12.3161%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for DEFI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 0.9694%
#     ✅ Net Profit After Fees: 0.7694%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 422 tradable tokens on Bybit
# ✅ Found 541 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for BEAM/USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Spread: 0.7237%
#     ✅ Net Profit After Fees: 0.5237%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for BR/USDT
#     ✅ Bybit Price: 0.16 USDT
#     ✅ Bitget Price: 0.17 USDT
#     ✅ Spread: 1.9820%
#     ✅ Net Profit After Fees: 1.7820%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MAK/USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Spread: 1.0428%
#     ✅ Net Profit After Fees: 0.8428%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for ROOT/USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Spread: 0.7539%
#     ✅ Net Profit After Fees: 0.5539%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MON/USDT
#     ✅ Bitget Price: 0.03 USDT
#     ✅ Bybit Price: 0.03 USDT
#     ✅ Spread: 5.3079%
#     ✅ Net Profit After Fees: 5.1079%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for AARK/USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Spread: 0.8088%
#     ✅ Net Profit After Fees: 0.6088%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for MOVE/USDT
#     ✅ Bybit Price: 0.44 USDT
#     ✅ Bitget Price: 0.45 USDT
#     ✅ Spread: 1.2239%
#     ✅ Net Profit After Fees: 1.0239%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MOZ/USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Spread: 0.9372%
#     ✅ Net Profit After Fees: 0.7372%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 13.3117%
#     ✅ Net Profit After Fees: 13.1117%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 422 tradable tokens on Bybit
# ✅ Found 541 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for COMP/USDT
#     ✅ Bitget Price: 42.33 USDT
#     ✅ Bybit Price: 42.65 USDT
#     ✅ Spread: 0.7560%
#     ✅ Net Profit After Fees: 0.5560%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for BEAM/USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Spread: 0.9772%
#     ✅ Net Profit After Fees: 0.7772%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for ULTI/USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Spread: 0.8505%
#     ✅ Net Profit After Fees: 0.6505%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for BR/USDT
#     ✅ Bybit Price: 0.16 USDT
#     ✅ Bitget Price: 0.16 USDT
#     ✅ Spread: 1.1692%
#     ✅ Net Profit After Fees: 0.9692%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MAK/USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Spread: 1.0977%
#     ✅ Net Profit After Fees: 0.8977%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for ROOT/USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Spread: 0.7539%
#     ✅ Net Profit After Fees: 0.5539%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for MOVE/USDT
#     ✅ Bybit Price: 0.44 USDT
#     ✅ Bitget Price: 0.45 USDT
#     ✅ Spread: 0.8613%
#     ✅ Net Profit After Fees: 0.6613%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MOZ/USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Spread: 0.8469%
#     ✅ Net Profit After Fees: 0.6469%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for VANRY/USDT
#     ✅ Bitget Price: 0.03 USDT
#     ✅ Bybit Price: 0.03 USDT
#     ✅ Spread: 0.8273%
#     ✅ Net Profit After Fees: 0.6273%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 13.3117%
#     ✅ Net Profit After Fees: 13.1117%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 422 tradable tokens on Bybit
# ✅ Found 541 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for BEAM/USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Spread: 0.9174%
#     ✅ Net Profit After Fees: 0.7174%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for BR/USDT
#     ✅ Bybit Price: 0.16 USDT
#     ✅ Bitget Price: 0.16 USDT
#     ✅ Spread: 0.8699%
#     ✅ Net Profit After Fees: 0.6699%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MAK/USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Spread: 0.7663%
#     ✅ Net Profit After Fees: 0.5663%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for ROOT/USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Spread: 0.7539%
#     ✅ Net Profit After Fees: 0.5539%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for OIK/USDT
#     ✅ Bitget Price: 0.07 USDT
#     ✅ Bybit Price: 0.07 USDT
#     ✅ Spread: 1.2295%
#     ✅ Net Profit After Fees: 1.0295%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MON/USDT
#     ✅ Bitget Price: 0.03 USDT
#     ✅ Bybit Price: 0.03 USDT
#     ✅ Spread: 2.6624%
#     ✅ Net Profit After Fees: 2.4624%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for MOVE/USDT
#     ✅ Bybit Price: 0.44 USDT
#     ✅ Bitget Price: 0.44 USDT
#     ✅ Spread: 0.7253%
#     ✅ Net Profit After Fees: 0.5253%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MOZ/USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Spread: 0.8777%
#     ✅ Net Profit After Fees: 0.6777%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 13.0945%
#     ✅ Net Profit After Fees: 12.8945%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for DEFI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 1.0230%
#     ✅ Net Profit After Fees: 0.8230%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 422 tradable tokens on Bybit
# ✅ Found 541 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for BEAM/USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Spread: 0.9174%
#     ✅ Net Profit After Fees: 0.7174%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MAK/USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Spread: 0.7663%
#     ✅ Net Profit After Fees: 0.5663%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MON/USDT
#     ✅ Bitget Price: 0.03 USDT
#     ✅ Bybit Price: 0.03 USDT
#     ✅ Spread: 7.8200%
#     ✅ Net Profit After Fees: 7.6200%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MOZ/USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Spread: 0.8262%
#     ✅ Net Profit After Fees: 0.6262%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 1.8831%
#     ✅ Net Profit After Fees: 1.6831%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for ZEREBRO/USDT
#     ✅ Bitget Price: 0.03 USDT
#     ✅ Bybit Price: 0.03 USDT
#     ✅ Spread: 0.9202%
#     ✅ Net Profit After Fees: 0.7202%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 423 tradable tokens on Bybit
# ✅ Found 541 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for BR/USDT
#     ✅ Bybit Price: 0.16 USDT
#     ✅ Bitget Price: 0.17 USDT
#     ✅ Spread: 1.2519%
#     ✅ Net Profit After Fees: 1.0519%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MAK/USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Spread: 0.7112%
#     ✅ Net Profit After Fees: 0.5112%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for MOVE/USDT
#     ✅ Bybit Price: 0.44 USDT
#     ✅ Bitget Price: 0.44 USDT
#     ✅ Spread: 0.7253%
#     ✅ Net Profit After Fees: 0.5253%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 9.6721%
#     ✅ Net Profit After Fees: 9.4721%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 423 tradable tokens on Bybit
# ✅ Found 541 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for BEAM/USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Spread: 1.0071%
#     ✅ Net Profit After Fees: 0.8071%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MAK/USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Spread: 0.9874%
#     ✅ Net Profit After Fees: 0.7874%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MON/USDT
#     ✅ Bitget Price: 0.03 USDT
#     ✅ Bybit Price: 0.03 USDT
#     ✅ Spread: 2.7536%
#     ✅ Net Profit After Fees: 2.5536%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for MBX/USDT
#     ✅ Bybit Price: 0.25 USDT
#     ✅ Bitget Price: 0.25 USDT
#     ✅ Spread: 0.7585%
#     ✅ Net Profit After Fees: 0.5585%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MOZ/USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Spread: 0.7089%
#     ✅ Net Profit After Fees: 0.5089%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 1.0891%
#     ✅ Net Profit After Fees: 0.8891%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for A8/USDT
#     ✅ Bybit Price: 0.15 USDT
#     ✅ Bitget Price: 0.15 USDT
#     ✅ Spread: 1.4315%
#     ✅ Net Profit After Fees: 1.2315%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 423 tradable tokens on Bybit
# ✅ Found 541 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for BEAM/USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Spread: 0.7981%
#     ✅ Net Profit After Fees: 0.5981%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for ULTI/USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Spread: 0.7977%
#     ✅ Net Profit After Fees: 0.5977%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for REN/USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Spread: 0.7143%
#     ✅ Net Profit After Fees: 0.5143%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for MON/USDT
#     ✅ Bybit Price: 0.03 USDT
#     ✅ Bitget Price: 0.03 USDT
#     ✅ Spread: 0.7299%
#     ✅ Net Profit After Fees: 0.5299%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for AARK/USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Spread: 0.8041%
#     ✅ Net Profit After Fees: 0.6041%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 8.9000%
#     ✅ Net Profit After Fees: 8.7000%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for DEFI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 0.7143%
#     ✅ Net Profit After Fees: 0.5143%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for GSWIFT/USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Spread: 0.9302%
#     ✅ Net Profit After Fees: 0.7302%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 422 tradable tokens on Bybit
# ✅ Found 541 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for BR/USDT
#     ✅ Bybit Price: 0.16 USDT
#     ✅ Bitget Price: 0.17 USDT
#     ✅ Spread: 0.7076%
#     ✅ Net Profit After Fees: 0.5076%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MAK/USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Spread: 1.0983%
#     ✅ Net Profit After Fees: 0.8983%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MON/USDT
#     ✅ Bitget Price: 0.03 USDT
#     ✅ Bybit Price: 0.03 USDT
#     ✅ Spread: 1.6141%
#     ✅ Net Profit After Fees: 1.4141%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for ZENT/USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Spread: 1.0586%
#     ✅ Net Profit After Fees: 0.8586%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 12.9568%
#     ✅ Net Profit After Fees: 12.7568%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for DEFI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 2.2798%
#     ✅ Net Profit After Fees: 2.0798%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 422 tradable tokens on Bybit
# ✅ Found 542 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MAK/USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Spread: 0.9874%
#     ✅ Net Profit After Fees: 0.7874%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MON/USDT
#     ✅ Bitget Price: 0.03 USDT
#     ✅ Bybit Price: 0.03 USDT
#     ✅ Spread: 1.3206%
#     ✅ Net Profit After Fees: 1.1206%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for PIXFI/USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Spread: 1.0538%
#     ✅ Net Profit After Fees: 0.8538%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for VANRY/USDT
#     ✅ Bitget Price: 0.03 USDT
#     ✅ Bybit Price: 0.03 USDT
#     ✅ Spread: 0.7942%
#     ✅ Net Profit After Fees: 0.5942%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 15.4983%
#     ✅ Net Profit After Fees: 15.2983%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for DEFI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 1.7098%
#     ✅ Net Profit After Fees: 1.5098%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 422 tradable tokens on Bybit
# ✅ Found 541 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for BB/USDT
#     ✅ Bybit Price: 0.12 USDT
#     ✅ Bitget Price: 0.12 USDT
#     ✅ Spread: 0.7407%
#     ✅ Net Profit After Fees: 0.5407%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for BR/USDT
#     ✅ Bybit Price: 0.16 USDT
#     ✅ Bitget Price: 0.16 USDT
#     ✅ Spread: 1.8957%
#     ✅ Net Profit After Fees: 1.6957%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MON/USDT
#     ✅ Bitget Price: 0.03 USDT
#     ✅ Bybit Price: 0.03 USDT
#     ✅ Spread: 1.4749%
#     ✅ Net Profit After Fees: 1.2749%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 17.0990%
#     ✅ Net Profit After Fees: 16.8990%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for DEFI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 2.9243%
#     ✅ Net Profit After Fees: 2.7243%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 419 tradable tokens on Bybit
# ✅ Found 541 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for PIRATE/USDT
#     ✅ Bybit Price: 0.07 USDT
#     ✅ Bitget Price: 0.07 USDT
#     ✅ Spread: 0.7993%
#     ✅ Net Profit After Fees: 0.5993%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for AVA/USDT
#     ✅ Bitget Price: 0.63 USDT
#     ✅ Bybit Price: 0.63 USDT
#     ✅ Spread: 1.0701%
#     ✅ Net Profit After Fees: 0.8701%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for VANRY/USDT
#     ✅ Bitget Price: 0.03 USDT
#     ✅ Bybit Price: 0.03 USDT
#     ✅ Spread: 0.8364%
#     ✅ Net Profit After Fees: 0.6364%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for ZENT/USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 0.9009%
#     ✅ Net Profit After Fees: 0.7009%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 19.6928%
#     ✅ Net Profit After Fees: 19.4928%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for DEFI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 2.9948%
#     ✅ Net Profit After Fees: 2.7948%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 419 tradable tokens on Bybit
# ✅ Found 540 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for AVA/USDT
#     ✅ Bitget Price: 0.63 USDT
#     ✅ Bybit Price: 0.63 USDT
#     ✅ Spread: 1.0701%
#     ✅ Net Profit After Fees: 0.8701%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for PIXFI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 0.7715%
#     ✅ Net Profit After Fees: 0.5715%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 18.8552%
#     ✅ Net Profit After Fees: 18.6552%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for DEFI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 2.3177%
#     ✅ Net Profit After Fees: 2.1177%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for GSWIFT/USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Spread: 1.0417%
#     ✅ Net Profit After Fees: 0.8417%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 417 tradable tokens on Bybit
# ✅ Found 540 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for AVA/USDT
#     ✅ Bitget Price: 0.63 USDT
#     ✅ Bybit Price: 0.63 USDT
#     ✅ Spread: 1.2318%
#     ✅ Net Profit After Fees: 1.0318%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for WELL/USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Spread: 0.8353%
#     ✅ Net Profit After Fees: 0.6353%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for MON/USDT
#     ✅ Bybit Price: 0.03 USDT
#     ✅ Bitget Price: 0.03 USDT
#     ✅ Spread: 1.1326%
#     ✅ Net Profit After Fees: 0.9326%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for PIXFI/USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Spread: 0.8772%
#     ✅ Net Profit After Fees: 0.6772%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 20.2694%
#     ✅ Net Profit After Fees: 20.0694%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for DEFI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 1.1795%
#     ✅ Net Profit After Fees: 0.9795%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 417 tradable tokens on Bybit
# ✅ Found 541 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for ZK/USDT
#     ✅ Bybit Price: 0.07 USDT
#     ✅ Bitget Price: 0.07 USDT
#     ✅ Spread: 0.7174%
#     ✅ Net Profit After Fees: 0.5174%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for AVA/USDT
#     ✅ Bitget Price: 0.62 USDT
#     ✅ Bybit Price: 0.63 USDT
#     ✅ Spread: 1.2804%
#     ✅ Net Profit After Fees: 1.0804%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for WELL/USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Spread: 0.7885%
#     ✅ Net Profit After Fees: 0.5885%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for MON/USDT
#     ✅ Bybit Price: 0.03 USDT
#     ✅ Bitget Price: 0.03 USDT
#     ✅ Spread: 1.1326%
#     ✅ Net Profit After Fees: 0.9326%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for MBX/USDT
#     ✅ Bybit Price: 0.24 USDT
#     ✅ Bitget Price: 0.24 USDT
#     ✅ Spread: 1.0195%
#     ✅ Net Profit After Fees: 0.8195%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for F/USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Spread: 0.8555%
#     ✅ Net Profit After Fees: 0.6555%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for VANRY/USDT
#     ✅ Bitget Price: 0.03 USDT
#     ✅ Bybit Price: 0.03 USDT
#     ✅ Spread: 0.8727%
#     ✅ Net Profit After Fees: 0.6727%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 19.7324%
#     ✅ Net Profit After Fees: 19.5324%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for NEXO/USDT
#     ✅ Bitget Price: 1.11 USDT
#     ✅ Bybit Price: 1.12 USDT
#     ✅ Spread: 0.7540%
#     ✅ Net Profit After Fees: 0.5540%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for DEFI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 3.5884%
#     ✅ Net Profit After Fees: 3.3884%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 418 tradable tokens on Bybit
# ✅ Found 541 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for AVA/USDT
#     ✅ Bitget Price: 0.62 USDT
#     ✅ Bybit Price: 0.63 USDT
#     ✅ Spread: 1.2642%
#     ✅ Net Profit After Fees: 1.0642%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MAK/USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Spread: 0.7663%
#     ✅ Net Profit After Fees: 0.5663%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for MON/USDT
#     ✅ Bybit Price: 0.03 USDT
#     ✅ Bitget Price: 0.03 USDT
#     ✅ Spread: 0.8769%
#     ✅ Net Profit After Fees: 0.6769%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 25.9259%
#     ✅ Net Profit After Fees: 25.7259%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for DEFI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 2.8947%
#     ✅ Net Profit After Fees: 2.6947%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for GSWIFT/USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Spread: 0.8724%
#     ✅ Net Profit After Fees: 0.6724%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 420 tradable tokens on Bybit
# ✅ Found 542 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MAK/USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Spread: 0.8767%
#     ✅ Net Profit After Fees: 0.6767%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for MON/USDT
#     ✅ Bybit Price: 0.03 USDT
#     ✅ Bitget Price: 0.03 USDT
#     ✅ Spread: 1.2097%
#     ✅ Net Profit After Fees: 1.0097%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for OAS/USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Spread: 0.7756%
#     ✅ Net Profit After Fees: 0.5756%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 23.8514%
#     ✅ Net Profit After Fees: 23.6514%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for DEFI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 2.9024%
#     ✅ Net Profit After Fees: 2.7024%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for MV/USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Spread: 0.8208%
#     ✅ Net Profit After Fees: 0.6208%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 421 tradable tokens on Bybit
# ✅ Found 542 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for ZK/USDT
#     ✅ Bitget Price: 0.07 USDT
#     ✅ Bybit Price: 0.07 USDT
#     ✅ Spread: 0.7215%
#     ✅ Net Profit After Fees: 0.5215%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MAK/USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Spread: 1.1532%
#     ✅ Net Profit After Fees: 0.9532%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for MON/USDT
#     ✅ Bybit Price: 0.03 USDT
#     ✅ Bitget Price: 0.03 USDT
#     ✅ Spread: 0.7297%
#     ✅ Net Profit After Fees: 0.5297%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for PIXFI/USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Spread: 0.9834%
#     ✅ Net Profit After Fees: 0.7834%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 25.1361%
#     ✅ Net Profit After Fees: 24.9361%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for DEFI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 2.7368%
#     ✅ Net Profit After Fees: 2.5368%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 421 tradable tokens on Bybit
# ✅ Found 542 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for BR/USDT
#     ✅ Bitget Price: 0.17 USDT
#     ✅ Bybit Price: 0.17 USDT
#     ✅ Spread: 2.4484%
#     ✅ Net Profit After Fees: 2.2484%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for F/USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Spread: 0.8145%
#     ✅ Net Profit After Fees: 0.6145%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 26.1017%
#     ✅ Net Profit After Fees: 25.9017%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for DEFI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 3.9523%
#     ✅ Net Profit After Fees: 3.7523%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 421 tradable tokens on Bybit
# ✅ Found 543 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for BR/USDT
#     ✅ Bybit Price: 0.18 USDT
#     ✅ Bitget Price: 0.18 USDT
#     ✅ Spread: 0.9003%
#     ✅ Net Profit After Fees: 0.7003%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for REN/USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Spread: 0.9883%
#     ✅ Net Profit After Fees: 0.7883%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for TOMI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 0.8824%
#     ✅ Net Profit After Fees: 0.6824%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for PIXFI/USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Spread: 0.8366%
#     ✅ Net Profit After Fees: 0.6366%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 23.1788%
#     ✅ Net Profit After Fees: 22.9788%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for DEFI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 4.9733%
#     ✅ Net Profit After Fees: 4.7733%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for RATS/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 0.8527%
#     ✅ Net Profit After Fees: 0.6527%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 421 tradable tokens on Bybit
# ✅ Found 543 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for MAK/USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Spread: 0.8758%
#     ✅ Net Profit After Fees: 0.6758%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for TOMI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 0.7059%
#     ✅ Net Profit After Fees: 0.5059%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 22.4252%
#     ✅ Net Profit After Fees: 22.2252%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for DEFI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 2.0424%
#     ✅ Net Profit After Fees: 1.8424%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 421 tradable tokens on Bybit
# ✅ Found 543 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for WELL/USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Spread: 0.7421%
#     ✅ Net Profit After Fees: 0.5421%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for ZENT/USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 1.2285%
#     ✅ Net Profit After Fees: 1.0285%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 23.5786%
#     ✅ Net Profit After Fees: 23.3786%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for DEFI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 2.4332%
#     ✅ Net Profit After Fees: 2.2332%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for RATS/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 0.7752%
#     ✅ Net Profit After Fees: 0.5752%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 423 tradable tokens on Bybit
# ✅ Found 543 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for WELL/USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Spread: 0.7421%
#     ✅ Net Profit After Fees: 0.5421%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for ZENT/USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Spread: 1.1466%
#     ✅ Net Profit After Fees: 0.9466%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for LAI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 24.0741%
#     ✅ Net Profit After Fees: 23.8741%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for DEFI/USDT
#     ✅ Bitget Price: 0.00 USDT
#     ✅ Bybit Price: 0.00 USDT
#     ✅ Spread: 3.6119%
#     ✅ Net Profit After Fees: 3.4119%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit, Sell on Bitget for MV/USDT
#     ✅ Bybit Price: 0.01 USDT
#     ✅ Bitget Price: 0.01 USDT
#     ✅ Spread: 0.8519%
#     ✅ Net Profit After Fees: 0.6519%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for GSWIFT/USDT
#     ✅ Bitget Price: 0.02 USDT
#     ✅ Bybit Price: 0.02 USDT
#     ✅ Spread: 1.0960%
#     ✅ Net Profit After Fees: 0.8960%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bitget, Sell on Bybit for A8/USDT
#     ✅ Bitget Price: 0.15 USDT
#     ✅ Bybit Price: 0.15 USDT
#     ✅ Spread: 0.7503%
#     ✅ Net Profit After Fees: 0.5503%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 423 tradable tokens on Bybit
# ❌ Error fetching tradable tokens from Bitget: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742554925023,"data":null}
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ✅ Found 424 tradable tokens on Bybit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 68
#      66 try:
#      67     bybit_tokens = get_tradable_tokens(bybit, "Bybit")
# ---> 68     bitget_tokens = get_tradable_tokens(bitget, "Bitget")
#      69     common_tokens = list(set(bybit_tokens) & set(bitget_tokens))
#      71     if not common_tokens:
#
# Cell In[3], line 14, in get_tradable_tokens(exchange, exchange_name)
#      12 for symbol in markets:
#      13     if '/USDT' in symbol and ':USDT' not in symbol:
# ---> 14         market_data = exchange.fetch_ticker(symbol)
#      15         volume = market_data.get('quoteVolume', 0)
#      16         if volume and volume >= MIN_VOLUME:
#
# File ~\anaconda3\Lib\site-packages\ccxt\bitget.py:2840, in bitget.fetch_ticker(self, symbol, params)
#    2838 response = None
#    2839 if market['spot']:
# -> 2840     response = self.publicSpotGetV2SpotMarketTickers(self.extend(request, params))
#    2841 else:
#    2842     productType = None
#
# File ~\anaconda3\Lib\site-packages\ccxt\base\types.py:35, in Entry.__init__.<locals>.unbound_method(_self, params)
#      34 def unbound_method(_self, params={}):
# ---> 35     return _self.request(self.path, self.api, self.method, params, config=self.config)
#
# File ~\anaconda3\Lib\site-packages\ccxt\base\exchange.py:4368, in Exchange.request(self, path, api, method, params, headers, body, config)
#    4367 def request(self, path, api: Any = 'public', method='GET', params={}, headers: Any = None, body: Any = None, config={}):
# -> 4368     return self.fetch2(path, api, method, params, headers, body, config)
#
# File ~\anaconda3\Lib\site-packages\ccxt\base\exchange.py:4353, in Exchange.fetch2(self, path, api, method, params, headers, body, config)
#    4351 for i in range(0, retries + 1):
#    4352     try:
# -> 4353         return self.fetch(request['url'], request['method'], request['headers'], request['body'])
#    4354     except Exception as e:
#    4355         if isinstance(e, OperationFailed):
#
# File ~\anaconda3\Lib\site-packages\ccxt\base\exchange.py:548, in Exchange.fetch(self, url, method, headers, body)
#     546 json_response = None
#     547 try:
# --> 548     response = self.session.request(
#     549         method,
#     550         url,
#     551         data=body,
#     552         headers=request_headers,
#     553         timeout=(self.timeout / 1000),
#     554         proxies=proxies,
#     555         verify=self.verify and self.validateServerSsl
#     556     )
#     557     # does not try to detect encoding
#     558     response.encoding = 'utf-8'
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File ~\anaconda3\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File ~\anaconda3\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~\anaconda3\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~\anaconda3\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File ~\anaconda3\Lib\ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\Lib\ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:
