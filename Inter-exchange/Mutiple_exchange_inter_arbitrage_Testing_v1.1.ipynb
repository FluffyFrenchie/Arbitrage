# %%
import ccxt
import time

# API Keys (Replace with actual keys)
BYBIT_API_KEY = 'I6m01uNAWiensHbIBA'
BYBIT_API_SECRET = 'vkaviS9xw903NJPncMtHgGfyiWB4mnhSJTyK'
BITGET_API_KEY = 'bg_b0a9d721607623216a87b066a3df34c3'
BITGET_API_SECRET = '6c4a5016562624b6d7f3b1c59563d4a1a573f630e0e49422fbf509399e56918b'

# Connect to exchanges
bybit = ccxt.bybit({
    'apiKey': BYBIT_API_KEY,
    'secret': BYBIT_API_SECRET,
    'options': {'adjustForTimeDifference': True}
})

bitget = ccxt.bitget({
    'apiKey': BITGET_API_KEY,
    'secret': BITGET_API_SECRET,
    'options': {'adjustForTimeDifference': True}
})

# %%
# Arbitrage settings
SPREAD_THRESHOLD = 0.5 / 100  # 0.5% profit target
MIN_VOLUME = 50000  # Minimum 24h volume required (in USDT)
CHECK_INTERVAL = 5  # Check every 5 seconds
TRADING_FEE = 0.001  # 0.1% trading fee per trade

def get_tradable_tokens(exchange, exchange_name, futures=False):
    """Fetches all tradable tokens on the given exchange and filters out low-volume pairs"""
    try:
        markets = exchange.load_markets()
        tradable_tokens = {"spot": [], "futures": []}

        for symbol in markets:
            # Identify if it's a Spot or Futures pair
            if futures:
                if ":USDT" in symbol:  # Futures trading pairs have a colon (Bybit & Bitget)
                    market_data = exchange.fetch_ticker(symbol)
                    volume = market_data.get('quoteVolume', 0) or market_data.get('baseVolume', 0)
                    if volume and volume >= MIN_VOLUME:
                        tradable_tokens["futures"].append(symbol)
            else:
                if "/USDT" in symbol and ":" not in symbol:  # Spot trading pairs
                    market_data = exchange.fetch_ticker(symbol)
                    volume = market_data.get('quoteVolume', 0) or market_data.get('baseVolume', 0)
                    if volume and volume >= MIN_VOLUME:
                        tradable_tokens["spot"].append(symbol)

        print(f"✅ Found {len(tradable_tokens['spot'])} spot tokens and {len(tradable_tokens['futures'])} futures tokens on {exchange_name}")
        return tradable_tokens
    except Exception as e:
        print(f"❌ Error fetching tradable tokens from {exchange_name}: {e}")
        return {"spot": [], "futures": []}

def get_price(exchange, symbol):
    """Fetch latest price for a given token if the market exists"""
    try:
        if symbol in exchange.load_markets():
            ticker = exchange.fetch_ticker(symbol)
            return float(ticker.get("last", ticker.get("lastPrice", None)))
        return None
    except Exception as e:
        print(f"❌ Error fetching price for {symbol}: {e}")
        return None

def check_inter_exchange_arbitrage(symbol_spot, symbol_futures):
    """Checks for arbitrage opportunities between Bybit and Bitget across Spot and Futures"""
    bybit_spot_price = get_price(bybit, symbol_spot)
    bitget_spot_price = get_price(bitget, symbol_spot)
    bybit_futures_price = get_price(bybit, symbol_futures)
    bitget_futures_price = get_price(bitget, symbol_futures)

    # Store possible trade options
    trade_options = []

    if bybit_spot_price and bitget_spot_price:
        trade_options.append(("Spot", "Spot", bybit_spot_price, bitget_spot_price))

    if bybit_spot_price and bitget_futures_price:
        trade_options.append(("Spot", "Futures", bybit_spot_price, bitget_futures_price))

    if bybit_futures_price and bitget_spot_price:
        trade_options.append(("Futures", "Spot", bybit_futures_price, bitget_spot_price))

    if bybit_futures_price and bitget_futures_price:
        trade_options.append(("Futures", "Futures", bybit_futures_price, bitget_futures_price))

    for buy_market, sell_market, buy_price, sell_price in trade_options:
        spread = (sell_price - buy_price) / buy_price
        net_profit = spread - (TRADING_FEE * 2)

        if net_profit >= SPREAD_THRESHOLD:
            print(f"🔍 Inter-exchange Arbitrage Detected: Buy on Bybit {buy_market}, Sell on Bitget {sell_market} for {symbol_spot}")
            print(f"    ✅ Bybit {buy_market} Price: {buy_price:.2f} USDT")
            print(f"    ✅ Bitget {sell_market} Price: {sell_price:.2f} USDT")
            print(f"    ✅ Spread: {spread:.4%}")
            print(f"    ✅ Net Profit After Fees: {net_profit:.4%}")
            print("-" * 50)

while True:
    try:
        bybit_tokens = get_tradable_tokens(bybit, "Bybit")
        bitget_tokens = get_tradable_tokens(bitget, "Bitget")

        common_spot_tokens = list(set(bybit_tokens["spot"]) & set(bitget_tokens["spot"]))
        common_futures_tokens = list(set(bybit_tokens["futures"]) & set(bitget_tokens["futures"]))

        if not common_spot_tokens and not common_futures_tokens:
            print("❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...")
            time.sleep(10)
            continue

        print("🔄 Checking for arbitrage opportunities...")

        for token in common_spot_tokens:
            futures_token = token.replace("/USDT", ":USDT")
            check_inter_exchange_arbitrage(token, futures_token)

        print("✅ Completed this cycle. Waiting for next check...")
        time.sleep(CHECK_INTERVAL)

    except Exception as e:
        print(f"❌ Error in main loop: {e}")
        time.sleep(10)
# Out:
# ❌ Error fetching tradable tokens from Bybit: bybit {"retCode":10002,"retMsg":"invalid request, please check your server timestamp or recv_window param. req_timestamp[1742549722235],server_timestamp[1742549727249],recv_window[5000]","result":{},"retExtInfo":{},"time":1742549727249}
# ✅ Found 541 spot tokens and 0 futures tokens on Bitget
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ✅ Found 423 spot tokens and 0 futures tokens on Bybit
# ✅ Found 541 spot tokens and 0 futures tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for MOVE/USDT
#     ✅ Bybit Spot Price: 0.44 USDT
#     ✅ Bitget Spot Price: 0.45 USDT
#     ✅ Spread: 1.3373%
#     ✅ Net Profit After Fees: 1.1373%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for F/USDT
#     ✅ Bybit Spot Price: 0.02 USDT
#     ✅ Bitget Spot Price: 0.02 USDT
#     ✅ Spread: 0.7130%
#     ✅ Net Profit After Fees: 0.5130%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 423 spot tokens and 0 futures tokens on Bybit
# ❌ Error fetching tradable tokens from Bitget: bitget {"code":"429","msg":"Too Many Requests","requestTime":1742550155898,"data":null}
# ❌ No common tradable tokens found between Bybit and Bitget. Retrying in 10 seconds...
# ✅ Found 423 spot tokens and 0 futures tokens on Bybit
# ✅ Found 541 spot tokens and 0 futures tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for ROOT/USDT
#     ✅ Bybit Spot Price: 0.01 USDT
#     ✅ Bitget Spot Price: 0.01 USDT
#     ✅ Spread: 0.7539%
#     ✅ Net Profit After Fees: 0.5539%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for REN/USDT
#     ✅ Bybit Spot Price: 0.01 USDT
#     ✅ Bitget Spot Price: 0.01 USDT
#     ✅ Spread: 0.8937%
#     ✅ Net Profit After Fees: 0.6937%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for BR/USDT
#     ✅ Bybit Spot Price: 0.16 USDT
#     ✅ Bitget Spot Price: 0.17 USDT
#     ✅ Spread: 1.6661%
#     ✅ Net Profit After Fees: 1.4661%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for MOVE/USDT
#     ✅ Bybit Spot Price: 0.44 USDT
#     ✅ Bitget Spot Price: 0.45 USDT
#     ✅ Spread: 1.3599%
#     ✅ Net Profit After Fees: 1.1599%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 422 spot tokens and 0 futures tokens on Bybit
# ✅ Found 541 spot tokens and 0 futures tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for ROOT/USDT
#     ✅ Bybit Spot Price: 0.01 USDT
#     ✅ Bitget Spot Price: 0.01 USDT
#     ✅ Spread: 0.7539%
#     ✅ Net Profit After Fees: 0.5539%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for BEAM/USDT
#     ✅ Bybit Spot Price: 0.01 USDT
#     ✅ Bitget Spot Price: 0.01 USDT
#     ✅ Spread: 0.7088%
#     ✅ Net Profit After Fees: 0.5088%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for ZK/USDT
#     ✅ Bybit Spot Price: 0.07 USDT
#     ✅ Bitget Spot Price: 0.07 USDT
#     ✅ Spread: 0.7062%
#     ✅ Net Profit After Fees: 0.5062%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for BR/USDT
#     ✅ Bybit Spot Price: 0.16 USDT
#     ✅ Bitget Spot Price: 0.17 USDT
#     ✅ Spread: 1.6814%
#     ✅ Net Profit After Fees: 1.4814%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for MOVE/USDT
#     ✅ Bybit Spot Price: 0.44 USDT
#     ✅ Bitget Spot Price: 0.45 USDT
#     ✅ Spread: 1.0879%
#     ✅ Net Profit After Fees: 0.8879%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 422 spot tokens and 0 futures tokens on Bybit
# ✅ Found 541 spot tokens and 0 futures tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for ROOT/USDT
#     ✅ Bybit Spot Price: 0.01 USDT
#     ✅ Bitget Spot Price: 0.01 USDT
#     ✅ Spread: 0.7539%
#     ✅ Net Profit After Fees: 0.5539%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for BEAM/USDT
#     ✅ Bybit Spot Price: 0.01 USDT
#     ✅ Bitget Spot Price: 0.01 USDT
#     ✅ Spread: 0.8428%
#     ✅ Net Profit After Fees: 0.6428%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for BR/USDT
#     ✅ Bybit Spot Price: 0.16 USDT
#     ✅ Bitget Spot Price: 0.16 USDT
#     ✅ Spread: 1.2892%
#     ✅ Net Profit After Fees: 1.0892%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 422 spot tokens and 0 futures tokens on Bybit
# ✅ Found 541 spot tokens and 0 futures tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for AARK/USDT
#     ✅ Bybit Spot Price: 0.00 USDT
#     ✅ Bitget Spot Price: 0.00 USDT
#     ✅ Spread: 0.7398%
#     ✅ Net Profit After Fees: 0.5398%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for ROOT/USDT
#     ✅ Bybit Spot Price: 0.01 USDT
#     ✅ Bitget Spot Price: 0.01 USDT
#     ✅ Spread: 0.7539%
#     ✅ Net Profit After Fees: 0.5539%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for BEAM/USDT
#     ✅ Bybit Spot Price: 0.01 USDT
#     ✅ Bitget Spot Price: 0.01 USDT
#     ✅ Spread: 0.9623%
#     ✅ Net Profit After Fees: 0.7623%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for BR/USDT
#     ✅ Bybit Spot Price: 0.16 USDT
#     ✅ Bitget Spot Price: 0.16 USDT
#     ✅ Spread: 1.0980%
#     ✅ Net Profit After Fees: 0.8980%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for MOVE/USDT
#     ✅ Bybit Spot Price: 0.44 USDT
#     ✅ Bitget Spot Price: 0.44 USDT
#     ✅ Spread: 0.7026%
#     ✅ Net Profit After Fees: 0.5026%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for ZENT/USDT
#     ✅ Bybit Spot Price: 0.01 USDT
#     ✅ Bitget Spot Price: 0.01 USDT
#     ✅ Spread: 0.7323%
#     ✅ Net Profit After Fees: 0.5323%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 423 spot tokens and 0 futures tokens on Bybit
# ✅ Found 541 spot tokens and 0 futures tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for AARK/USDT
#     ✅ Bybit Spot Price: 0.00 USDT
#     ✅ Bitget Spot Price: 0.00 USDT
#     ✅ Spread: 1.1579%
#     ✅ Net Profit After Fees: 0.9579%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for BEAM/USDT
#     ✅ Bybit Spot Price: 0.01 USDT
#     ✅ Bitget Spot Price: 0.01 USDT
#     ✅ Spread: 0.9174%
#     ✅ Net Profit After Fees: 0.7174%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for BR/USDT
#     ✅ Bybit Spot Price: 0.16 USDT
#     ✅ Bitget Spot Price: 0.17 USDT
#     ✅ Spread: 1.0287%
#     ✅ Net Profit After Fees: 0.8287%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for MOVE/USDT
#     ✅ Bybit Spot Price: 0.44 USDT
#     ✅ Bitget Spot Price: 0.44 USDT
#     ✅ Spread: 0.7253%
#     ✅ Net Profit After Fees: 0.5253%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 423 spot tokens and 0 futures tokens on Bybit
# ✅ Found 541 spot tokens and 0 futures tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for BEAM/USDT
#     ✅ Bybit Spot Price: 0.01 USDT
#     ✅ Bitget Spot Price: 0.01 USDT
#     ✅ Spread: 0.7237%
#     ✅ Net Profit After Fees: 0.5237%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for REN/USDT
#     ✅ Bybit Spot Price: 0.01 USDT
#     ✅ Bitget Spot Price: 0.01 USDT
#     ✅ Spread: 0.8043%
#     ✅ Net Profit After Fees: 0.6043%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for LAI/USDT
#     ✅ Bybit Spot Price: 0.00 USDT
#     ✅ Bitget Spot Price: 0.00 USDT
#     ✅ Spread: 0.7649%
#     ✅ Net Profit After Fees: 0.5649%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 423 spot tokens and 0 futures tokens on Bybit
# ✅ Found 541 spot tokens and 0 futures tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for LUCE/USDT
#     ✅ Bybit Spot Price: 0.01 USDT
#     ✅ Bitget Spot Price: 0.01 USDT
#     ✅ Spread: 1.4842%
#     ✅ Net Profit After Fees: 1.2842%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for AARK/USDT
#     ✅ Bybit Spot Price: 0.00 USDT
#     ✅ Bitget Spot Price: 0.00 USDT
#     ✅ Spread: 1.0936%
#     ✅ Net Profit After Fees: 0.8936%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for BEAM/USDT
#     ✅ Bybit Spot Price: 0.01 USDT
#     ✅ Bitget Spot Price: 0.01 USDT
#     ✅ Spread: 0.7832%
#     ✅ Net Profit After Fees: 0.5832%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 422 spot tokens and 0 futures tokens on Bybit
# ✅ Found 541 spot tokens and 0 futures tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for LUCE/USDT
#     ✅ Bybit Spot Price: 0.01 USDT
#     ✅ Bitget Spot Price: 0.01 USDT
#     ✅ Spread: 0.7512%
#     ✅ Net Profit After Fees: 0.5512%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for ZENT/USDT
#     ✅ Bybit Spot Price: 0.01 USDT
#     ✅ Bitget Spot Price: 0.01 USDT
#     ✅ Spread: 1.0586%
#     ✅ Net Profit After Fees: 0.8586%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 422 spot tokens and 0 futures tokens on Bybit
# ✅ Found 542 spot tokens and 0 futures tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for REN/USDT
#     ✅ Bybit Spot Price: 0.01 USDT
#     ✅ Bitget Spot Price: 0.01 USDT
#     ✅ Spread: 0.8050%
#     ✅ Net Profit After Fees: 0.6050%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for ZENT/USDT
#     ✅ Bybit Spot Price: 0.01 USDT
#     ✅ Bitget Spot Price: 0.01 USDT
#     ✅ Spread: 0.8943%
#     ✅ Net Profit After Fees: 0.6943%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 421 spot tokens and 0 futures tokens on Bybit
# ✅ Found 540 spot tokens and 0 futures tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for BR/USDT
#     ✅ Bybit Spot Price: 0.16 USDT
#     ✅ Bitget Spot Price: 0.16 USDT
#     ✅ Spread: 0.8094%
#     ✅ Net Profit After Fees: 0.6094%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for PIXFI/USDT
#     ✅ Bybit Spot Price: 0.00 USDT
#     ✅ Bitget Spot Price: 0.00 USDT
#     ✅ Spread: 1.0538%
#     ✅ Net Profit After Fees: 0.8538%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 421 spot tokens and 0 futures tokens on Bybit
# ✅ Found 541 spot tokens and 0 futures tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 419 spot tokens and 0 futures tokens on Bybit
# ✅ Found 541 spot tokens and 0 futures tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 417 spot tokens and 0 futures tokens on Bybit
# ✅ Found 540 spot tokens and 0 futures tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for MON/USDT
#     ✅ Bybit Spot Price: 0.03 USDT
#     ✅ Bitget Spot Price: 0.03 USDT
#     ✅ Spread: 1.1326%
#     ✅ Net Profit After Fees: 0.9326%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 417 spot tokens and 0 futures tokens on Bybit
# ✅ Found 540 spot tokens and 0 futures tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for PIXFI/USDT
#     ✅ Bybit Spot Price: 0.00 USDT
#     ✅ Bitget Spot Price: 0.00 USDT
#     ✅ Spread: 1.0234%
#     ✅ Net Profit After Fees: 0.8234%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for MON/USDT
#     ✅ Bybit Spot Price: 0.03 USDT
#     ✅ Bitget Spot Price: 0.03 USDT
#     ✅ Spread: 1.1326%
#     ✅ Net Profit After Fees: 0.9326%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 418 spot tokens and 0 futures tokens on Bybit
# ✅ Found 541 spot tokens and 0 futures tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for WELL/USDT
#     ✅ Bybit Spot Price: 0.00 USDT
#     ✅ Bitget Spot Price: 0.00 USDT
#     ✅ Spread: 0.8825%
#     ✅ Net Profit After Fees: 0.6825%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for MON/USDT
#     ✅ Bybit Spot Price: 0.03 USDT
#     ✅ Bitget Spot Price: 0.03 USDT
#     ✅ Spread: 0.8769%
#     ✅ Net Profit After Fees: 0.6769%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for F/USDT
#     ✅ Bybit Spot Price: 0.02 USDT
#     ✅ Bitget Spot Price: 0.02 USDT
#     ✅ Spread: 0.9464%
#     ✅ Net Profit After Fees: 0.7464%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 419 spot tokens and 0 futures tokens on Bybit
# ✅ Found 542 spot tokens and 0 futures tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for REN/USDT
#     ✅ Bybit Spot Price: 0.01 USDT
#     ✅ Bitget Spot Price: 0.01 USDT
#     ✅ Spread: 0.7194%
#     ✅ Net Profit After Fees: 0.5194%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for PIXFI/USDT
#     ✅ Bybit Spot Price: 0.00 USDT
#     ✅ Bitget Spot Price: 0.00 USDT
#     ✅ Spread: 0.8772%
#     ✅ Net Profit After Fees: 0.6772%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for WELL/USDT
#     ✅ Bybit Spot Price: 0.00 USDT
#     ✅ Bitget Spot Price: 0.00 USDT
#     ✅ Spread: 0.8825%
#     ✅ Net Profit After Fees: 0.6825%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for MON/USDT
#     ✅ Bybit Spot Price: 0.03 USDT
#     ✅ Bitget Spot Price: 0.03 USDT
#     ✅ Spread: 0.8769%
#     ✅ Net Profit After Fees: 0.6769%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 421 spot tokens and 0 futures tokens on Bybit
# ✅ Found 542 spot tokens and 0 futures tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for WELL/USDT
#     ✅ Bybit Spot Price: 0.00 USDT
#     ✅ Bitget Spot Price: 0.00 USDT
#     ✅ Spread: 0.9294%
#     ✅ Net Profit After Fees: 0.7294%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for MV/USDT
#     ✅ Bybit Spot Price: 0.01 USDT
#     ✅ Bitget Spot Price: 0.01 USDT
#     ✅ Spread: 0.8898%
#     ✅ Net Profit After Fees: 0.6898%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 421 spot tokens and 0 futures tokens on Bybit
# ✅ Found 542 spot tokens and 0 futures tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for PIXFI/USDT
#     ✅ Bybit Spot Price: 0.00 USDT
#     ✅ Bitget Spot Price: 0.00 USDT
#     ✅ Spread: 1.1302%
#     ✅ Net Profit After Fees: 0.9302%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for MV/USDT
#     ✅ Bybit Spot Price: 0.01 USDT
#     ✅ Bitget Spot Price: 0.01 USDT
#     ✅ Spread: 0.8070%
#     ✅ Net Profit After Fees: 0.6070%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 421 spot tokens and 0 futures tokens on Bybit
# ✅ Found 542 spot tokens and 0 futures tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for BR/USDT
#     ✅ Bybit Spot Price: 0.17 USDT
#     ✅ Bitget Spot Price: 0.18 USDT
#     ✅ Spread: 1.8439%
#     ✅ Net Profit After Fees: 1.6439%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for PIXFI/USDT
#     ✅ Bybit Spot Price: 0.00 USDT
#     ✅ Bitget Spot Price: 0.00 USDT
#     ✅ Spread: 0.8366%
#     ✅ Net Profit After Fees: 0.6366%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for WELL/USDT
#     ✅ Bybit Spot Price: 0.00 USDT
#     ✅ Bitget Spot Price: 0.00 USDT
#     ✅ Spread: 0.7889%
#     ✅ Net Profit After Fees: 0.5889%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 421 spot tokens and 0 futures tokens on Bybit
# ✅ Found 543 spot tokens and 0 futures tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 421 spot tokens and 0 futures tokens on Bybit
# ✅ Found 543 spot tokens and 0 futures tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for MV/USDT
#     ✅ Bybit Spot Price: 0.01 USDT
#     ✅ Bitget Spot Price: 0.01 USDT
#     ✅ Spread: 1.0697%
#     ✅ Net Profit After Fees: 0.8697%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 423 spot tokens and 0 futures tokens on Bybit
# ✅ Found 543 spot tokens and 0 futures tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for SAROS/USDT
#     ✅ Bybit Spot Price: 0.05 USDT
#     ✅ Bitget Spot Price: 0.05 USDT
#     ✅ Spread: 1.3010%
#     ✅ Net Profit After Fees: 1.1010%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for WELL/USDT
#     ✅ Bybit Spot Price: 0.00 USDT
#     ✅ Bitget Spot Price: 0.00 USDT
#     ✅ Spread: 0.7421%
#     ✅ Net Profit After Fees: 0.5421%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 423 spot tokens and 0 futures tokens on Bybit
# ✅ Found 543 spot tokens and 0 futures tokens on Bitget
# 🔄 Checking for arbitrage opportunities...
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for BR/USDT
#     ✅ Bybit Spot Price: 0.18 USDT
#     ✅ Bitget Spot Price: 0.18 USDT
#     ✅ Spread: 0.7953%
#     ✅ Net Profit After Fees: 0.5953%
# --------------------------------------------------
# 🔍 Inter-exchange Arbitrage Detected: Buy on Bybit Spot, Sell on Bitget Spot for WELL/USDT
#     ✅ Bybit Spot Price: 0.00 USDT
#     ✅ Bitget Spot Price: 0.00 USDT
#     ✅ Spread: 0.7421%
#     ✅ Net Profit After Fees: 0.5421%
# --------------------------------------------------
# ✅ Completed this cycle. Waiting for next check...
