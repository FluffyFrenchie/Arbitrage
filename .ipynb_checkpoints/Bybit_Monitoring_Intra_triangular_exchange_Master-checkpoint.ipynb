# %%
import ccxt
import time
from itertools import permutations

# Replace with your actual Bybit API keys
BYBIT_API_KEY = 'I6m01uNAWiensHbIBA'
BYBIT_API_SECRET = 'vkaviS9xw903NJPncMtHgGfyiWB4mnhSJTyK'

# Connect to Bybit API
bybit = ccxt.bybit({
    'apiKey': BYBIT_API_KEY,
    'secret': BYBIT_API_SECRET,
    'options': {'adjustForTimeDifference': True}
})

# %%
# Arbitrage settings
SPREAD_THRESHOLD = 0.5 / 100  # 0.5% profit target
MIN_VOLUME = 50000  # Minimum 24h volume required (in USDT)
CHECK_INTERVAL = 5  # Check every 5 seconds
TRADING_FEE = 0.001  # 0.1% trading fee per trade

# %%
def get_tradable_tokens():
    """Fetches all tradable tokens on Bybit and filters out low-volume pairs"""
    try:
        markets = bybit.load_markets()
        tradable_tokens = []
        for symbol in markets:
            if '/USDT' in symbol and ':USDT' not in symbol:
                market_data = bybit.fetch_ticker(symbol)
                volume = market_data.get('quoteVolume', 0)  # Get 24h trading volume
                if volume and volume >= MIN_VOLUME:
                    tradable_tokens.append(symbol)

        print(f"✅ Found {len(tradable_tokens)} tradable tokens")  # Debug print
        return tradable_tokens
    except Exception as e:
        print(f"❌ Error fetching tradable tokens: {e}")
        return []

# %%
def get_price(symbol):
    """Fetch latest spot price for a given token"""
    try:
        ticker = bybit.fetch_ticker(symbol)
        return float(ticker['last'])
    except Exception as e:
        print(f"❌ Error fetching price for {symbol}: {e}")
        return None

# %%
def get_funding_rate(symbol):
    """Fetches the funding rate for a given futures contract"""
    try:
        funding_data = bybit.public_get_v2_public_funding_rate({'symbol': symbol.replace('/USDT', '')})
        return float(funding_data['result']['funding_rate'])
    except Exception as e:
        print(f"❌ Error fetching funding rate for {symbol}: {e}")
        return None

# %%
def check_intra_exchange_arbitrage(symbol):
    """Checks for spot vs futures arbitrage opportunities within Bybit"""
    spot_price = get_price(symbol)
    futures_price = get_price(symbol.replace('/USDT', '/USDT:USDT'))
    funding_rate = get_funding_rate(symbol)

    if not spot_price or not futures_price or funding_rate is None:
        return

    spread = (futures_price - spot_price) / spot_price  # Calculate spread %
    net_profit = spread - (TRADING_FEE * 2)  # Adjust for fees

    if net_profit >= SPREAD_THRESHOLD and funding_rate > 0:
        print(f"🔍 Intra-exchange Arbitrage Detected on Bybit for {symbol}")
        print(f"    ✅ Spot Price: {spot_price:.2f} USDT")
        print(f"    ✅ Futures Price: {futures_price:.2f} USDT")
        print(f"    ✅ Spread: {spread:.4%}")
        print(f"    ✅ Net Profit After Fees: {net_profit:.4%}")
        print(f"    ✅ Funding Rate: {funding_rate:.6%}")
        print("-" * 50)

# %%
def check_funding_rate_arbitrage(symbol):
    """Checks for funding rate arbitrage where funding rates pay to hold positions"""
    funding_rate = get_funding_rate(symbol)
    if funding_rate and funding_rate > 0.0005:  # Consider only positive funding rates above 0.05%
        print(f"💰 Funding Rate Arbitrage Detected for {symbol}")
        print(f"    ✅ Funding Rate: {funding_rate:.6%} (Earn passive yield)")
        print("-" * 50)

def check_triangular_arbitrage(tradable_tokens):
    """Checks for valid triangular arbitrage opportunities within Bybit"""
    for route in permutations(tradable_tokens, 3):  # Ensure three different assets
        base_asset = route[0].split('/')[0]  # First asset in the path
        mid_asset = route[1].split('/')[0]
        final_asset = route[2].split('/')[1]  # Final conversion back to USDT

        if base_asset == final_asset:  # Ensure a valid cycle
            try:
                # Get price data for each leg
                first_leg_price = get_price(route[0])
                second_leg_price = get_price(route[1])
                third_leg_price = get_price(route[2])

                if first_leg_price and second_leg_price and third_leg_price:
                    # Convert using proper exchange path
                    amount_after_first_trade = (1 / first_leg_price) * second_leg_price
                    amount_after_second_trade = (1 / second_leg_price) * third_leg_price
                    final_amount = amount_after_second_trade

                    expected_return = final_amount
                    net_expected_return = expected_return - (TRADING_FEE * 3)  # Adjust for fees

                    # Filter out unrealistic profits
                    if 1.005 < net_expected_return < 10:
                        print(f"🔍 Valid Triangular Arbitrage Detected on Bybit")
                        print(f"    ✅ Trade Path: {route[0]} ➝ {route[1]} ➝ {route[2]}")
                        print(f"    ✅ Expected Return: {expected_return:.4%}")
                        print(f"    ✅ Net Profit After Fees: {net_expected_return:.4%}")
                        print("-" * 50)
            except Exception:
                continue

# %%
# Run the bot continuously with debugging
while True:
    try:
        bybit_tokens = get_tradable_tokens()
        if not bybit_tokens:
            print("❌ No tradable tokens found. Retrying in 10 seconds...")
            time.sleep(10)
            continue

        print("🔄 Checking for arbitrage opportunities...")

        for token in bybit_tokens:
            check_intra_exchange_arbitrage(token)
            check_funding_rate_arbitrage(token)

        check_triangular_arbitrage(bybit_tokens)

        print("✅ Completed this cycle. Waiting for next check...")
        time.sleep(CHECK_INTERVAL)
    except Exception as e:
        print(f"❌ Error in main loop: {e}")
        time.sleep(10)  # Avoid infinite crash loops
# Out:
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359737544}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359747770}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359757801}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359767837}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359777895}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359787935}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359797975}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359808021}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359818061}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359828098}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359838138}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359848178}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359858251}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359868300}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359878334}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359888366}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359898399}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359908455}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359918559}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359928590}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359938630}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359948664}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359958698}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359968733}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359978776}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359988813}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742359998843}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360008875}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360018911}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360028947}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360038979}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360049013}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360059062}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360069095}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360079127}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360089159}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360099194}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360109228}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360119262}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360129293}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360139325}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360149364}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360159392}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360169422}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360179462}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360189505}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360199543}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360209576}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360219615}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360229647}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360239683}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360249734}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360259772}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360269818}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360280078}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360290187}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360300244}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360310299}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360320329}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360330363}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360340393}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360350464}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360360498}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360370530}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360380560}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360390597}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360400640}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360410712}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360420763}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360430805}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360440853}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360450886}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360460920}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360470966}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360480999}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360491053}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360501090}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360511125}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360521160}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360531212}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360541278}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360551319}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360561352}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360571385}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360581510}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360591552}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360601585}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360611621}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360621655}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360631701}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360641765}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360651805}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360661836}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360671869}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360681904}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360691937}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360701974}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360712010}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360722046}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360732083}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360742119}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360752150}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360762181}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360772483}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360782581}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360792614}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360802644}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360812674}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360822903}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360833179}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360843222}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360853258}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360863294}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360873328}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360883364}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360893469}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360903515}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360913553}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360923586}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360933622}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360943662}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360953696}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360963730}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360973758}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360983803}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742360993837}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742361003872}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742361013912}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742361023945}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ❌ Error fetching tradable tokens: bybit {"retCode":10003,"retMsg":"API key is invalid.","result":{},"retExtInfo":{},"time":1742361033986}
# ❌ No tradable tokens found. Retrying in 10 seconds...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[126], line 7
#       5 if not bybit_tokens:
#       6     print("❌ No tradable tokens found. Retrying in 10 seconds...")
# ----> 7     time.sleep(10)
#       8     continue
#      10 print("🔄 Checking for arbitrage opportunities...")
#
# KeyboardInterrupt:
