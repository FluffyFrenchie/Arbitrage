# %%
import ccxt
import time
from itertools import permutations
from ccxt.base.errors import RateLimitExceeded

# Replace with your actual API keys
BYBIT_API_KEY = 'I6m01uNAWiensHbIBA'
BYBIT_API_SECRET = 'vkaviS9xw903NJPncMtHgGfyiWB4mnhSJTyK'

BITGET_API_KEY = 'bg_b0a9d721607623216a87b066a3df34c3'
BITGET_API_SECRET = '6c4a5016562624b6d7f3b1c59563d4a1a573f630e0e49422fbf509399e56918b'
BITGET_PASSPHRASE = 'BgSecure789Trade2025'  # Required for Bitget authentication

# Connect to Bybit API
bybit = ccxt.bybit({
    'apiKey': BYBIT_API_KEY,
    'secret': BYBIT_API_SECRET,
    'options': {'adjustForTimeDifference': True}
})

# Connect to Bitget API
bitget = ccxt.bitget({
    'apiKey': BITGET_API_KEY,
    'secret': BITGET_API_SECRET,
    'password': BITGET_PASSPHRASE,
    'options': {'adjustForTimeDifference': True}
})

# %%
# Arbitrage settings
SPREAD_THRESHOLD = 0.1 / 100  # 0.1% profit target
MIN_VOLUME = 50000  # Minimum 24h volume required (in USDT)
CHECK_INTERVAL = 5  # Check every 5 seconds
STARTING_CAPITAL = 100  # Configurable capital in USDT

# Trading Fees per Exchange
TRADING_FEES = {
    "Bybit": 0.001,  # 0.1% per trade
    "Bitget": 0.001  # 0.1% per trade
}

def get_tradable_tokens(exchange, exchange_name):
    """Fetches only active spot trading pairs on the given exchange."""
    try:
        markets = exchange.load_markets()
        tradable_tokens = []

        for symbol, market in markets.items():
            # Ensure it's an active SPOT market
            if market.get("type") == "spot" and market.get("active", False):
                if '/USDT' in symbol and ':USDT' not in symbol:  # Ensure it's a valid USDT spot pair
                    try:
                        market_data = exchange.fetch_ticker(symbol)
                        volume = market_data.get('quoteVolume', 0)  # 24h volume
                        if volume and volume >= MIN_VOLUME:
                            tradable_tokens.append(symbol)
                    except RateLimitExceeded:
                        print(f"⚠️ Rate limit hit on {exchange_name}. Pausing...")
                        time.sleep(60)
                        continue
                    except Exception as e:
                        print(f"⚠️ Error fetching market data for {symbol} on {exchange_name}: {e}")
                        continue  # Skip symbols that cause errors

        print(f"✅ Found {len(tradable_tokens)} tradable tokens on {exchange_name}")
        return tradable_tokens

    except Exception as e:
        print(f"❌ Error fetching tradable tokens on {exchange_name}: {e}")
        return []

def get_price(exchange, symbol, exchange_name):
    """Fetch latest price for a given token from the specified exchange."""
    try:
        if exchange_name == "Bybit":
            # Bybit requires a manual request with category='spot'
            symbol_formatted = symbol.replace("/", "")  # Convert "XLM/USDT" -> "XLMUSDT"
            response = exchange.public_get_v5_market_tickers({'symbol': symbol_formatted, 'category': 'spot'})
            return float(response['result']['list'][0]['lastPrice']) if response['result']['list'] else None
        else:
            # Standard fetch_ticker for other exchanges
            if symbol in exchange.load_markets():
                ticker = exchange.fetch_ticker(symbol)
                return float(ticker.get("last", 0)) if ticker else None
        return None
    except RateLimitExceeded:
        print(f"⚠️ Rate limit hit while fetching price from {exchange_name}. Pausing...")
        time.sleep(60)
        return None
    except Exception as e:
        print(f"❌ Error fetching price for {symbol} from {exchange_name}: {e}")
        return None

def log_arbitrage(exchange_name, trade_path, expected_return, net_profit):
    """Logs detected arbitrage trades to a file."""
    with open(f"{exchange_name}_triangular_arbitrage.log", "a") as log_file:
        log_file.write(f"{trade_path} | Expected: {expected_return:.4%} | Net Profit: {net_profit:.4%}\n")

def check_triangular_arbitrage(exchange, exchange_name, tradable_tokens):
    """Checks for triangular arbitrage opportunities within a specific exchange."""
    for route in permutations(tradable_tokens, 3):  # Ensure three different assets
        base_asset = route[0].split('/')[0]  # First asset in the path
        mid_asset = route[1].split('/')[0]
        final_asset = route[2].split('/')[1]  # Final conversion back to USDT

        if base_asset == final_asset:  # Ensure a valid cycle
            try:
                # Get price data for each leg
                first_leg_price = get_price(exchange, route[0], exchange_name)
                second_leg_price = get_price(exchange, route[1], exchange_name)
                third_leg_price = get_price(exchange, route[2], exchange_name)

                # Ensure all prices are valid
                if None in [first_leg_price, second_leg_price, third_leg_price]:
                    continue  

                # Convert using proper exchange path
                amount_after_first_trade = (STARTING_CAPITAL / first_leg_price) * second_leg_price
                amount_after_second_trade = (amount_after_first_trade / second_leg_price) * third_leg_price
                final_amount = amount_after_second_trade

                expected_return = final_amount / STARTING_CAPITAL
                net_expected_return = expected_return * (1 - TRADING_FEES[exchange_name]) ** 3  # Adjust for fees

                # Print all paths for debugging
                print(f"🔍 Checking Arbitrage Path on {exchange_name}: {route[0]} ➝ {route[1]} ➝ {route[2]}")
                print(f"    ✅ Expected Return: {expected_return:.4%}")
                print(f"    ✅ Net Profit After Fees: {net_expected_return:.4%}")

                # Detect and log only profitable trades
                if net_expected_return > 1.001:  # Ensure profit > 0.1%
                    print(f"✅ VALID Triangular Arbitrage Detected on {exchange_name}")
                    print(f"    ✅ Trade Path: {route[0]} ➝ {route[1]} ➝ {route[2]}")
                    print(f"    ✅ Expected Return: {expected_return:.4%}")
                    print(f"    ✅ Net Profit After Fees: {net_expected_return:.4%}")
                    print("-" * 50)
                    log_arbitrage(exchange_name, f"{route[0]} ➝ {route[1]} ➝ {route[2]}", expected_return, net_expected_return)
            except Exception as e:
                print(f"⚠️ Error in arbitrage check on {exchange_name}: {e}")
                continue

while True:
    try:
        # Fetch tradable tokens for each exchange
        bybit_tokens = get_tradable_tokens(bybit, "Bybit")
        bitget_tokens = get_tradable_tokens(bitget, "Bitget")

        if not bybit_tokens and not bitget_tokens:
            print("❌ No tradable tokens found on either exchange. Retrying in 10 seconds...")
            time.sleep(10)
            continue

        print("🔄 Checking for arbitrage opportunities on Bybit and Bitget...")

        # Check arbitrage on Bybit
        if bybit_tokens:
            check_triangular_arbitrage(bybit, "Bybit", bybit_tokens)

        # Check arbitrage on Bitget
        if bitget_tokens:
            check_triangular_arbitrage(bitget, "Bitget", bitget_tokens)

        print("✅ Completed this cycle. Waiting for next check...")
        time.sleep(CHECK_INTERVAL)

    except Exception as e:
        print(f"❌ Error in main loop: {e}")
        time.sleep(10)  # Avoid infinite crash loops
# Out:
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 576 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 425 tradable tokens on Bybit
# ✅ Found 576 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ⚠️ Error fetching market data for ZOO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZOOUSDT
# ⚠️ Error fetching market data for BGSOL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BGSOLUSDT
# ⚠️ Error fetching market data for KAITO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=KAITOUSDT
# ⚠️ Error fetching market data for TAPS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TAPSUSDT
# ⚠️ Error fetching market data for RED/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=REDUSDT
# ⚠️ Error fetching market data for ROAM/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ROAMUSDT
# ⚠️ Error fetching market data for FIL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FILUSDT
# ⚠️ Error fetching market data for DEUSD/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DEUSDUSDT
# ⚠️ Error fetching market data for CELO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CELOUSDT
# ⚠️ Error fetching market data for AB/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ABUSDT
# ⚠️ Error fetching market data for BGB/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BGBUSDT
# ⚠️ Error fetching market data for MEMHASH/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MEMHASHUSDT
# ⚠️ Error fetching market data for YGG/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=YGGUSDT
# ⚠️ Error fetching market data for PDA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PDAUSDT
# ⚠️ Error fetching market data for LDO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LDOUSDT
# ⚠️ Error fetching market data for OIK/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=OIKUSDT
# ⚠️ Error fetching market data for LVVA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LVVAUSDT
# ⚠️ Error fetching market data for BMT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BMTUSDT
# ⚠️ Error fetching market data for MINT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MINTUSDT
# ⚠️ Error fetching market data for ELX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ELXUSDT
# ⚠️ Error fetching market data for TUT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TUTUSDT
# ⚠️ Error fetching market data for MUBARAK/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MUBARAKUSDT
# ⚠️ Error fetching market data for MEW/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MEWUSDT
# ⚠️ Error fetching market data for W/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WUSDT
# ⚠️ Error fetching market data for IAG/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=IAGUSDT
# ⚠️ Error fetching market data for SERSH/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SERSHUSDT
# ⚠️ Error fetching market data for ENA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ENAUSDT
# ⚠️ Error fetching market data for MASA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MASAUSDT
# ⚠️ Error fetching market data for SAGA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SAGAUSDT
# ⚠️ Error fetching market data for TNSR/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TNSRUSDT
# ⚠️ Error fetching market data for MUMU/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MUMUUSDT
# ⚠️ Error fetching market data for MOEW/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MOEWUSDT
# ⚠️ Error fetching market data for OMNI1/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=OMNI1USDT
# ⚠️ Error fetching market data for PRCL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PRCLUSDT
# ⚠️ Error fetching market data for MAS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MASUSDT
# ⚠️ Error fetching market data for 0X0/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=0X0USDT
# ⚠️ Error fetching market data for RARI/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RARIUSDT
# ⚠️ Error fetching market data for SAFE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SAFEUSDT
# ⚠️ Error fetching market data for APU/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=APUUSDT
# ⚠️ Error fetching market data for ALPH/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ALPHUSDT
# ⚠️ Error fetching market data for MERL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MERLUSDT
# ⚠️ Error fetching market data for CKB/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CKBUSDT
# ⚠️ Error fetching market data for AQT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AQTUSDT
# ⚠️ Error fetching market data for ARKM/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ARKMUSDT
# ⚠️ Error fetching market data for BITCOIN/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BITCOINUSDT
# ⚠️ Error fetching market data for UNIBOT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=UNIBOTUSDT
# ⚠️ Error fetching market data for MOG/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MOGUSDT
# ⚠️ Error fetching market data for SIX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SIXUSDT
# ⚠️ Error fetching market data for MANEKI/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MANEKIUSDT
# ⚠️ Error fetching market data for KUB/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=KUBUSDT
# ⚠️ Error fetching market data for ZBCN/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZBCNUSDT
# ⚠️ Error fetching market data for RTF/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RTFUSDT
# ⚠️ Error fetching market data for WLD/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WLDUSDT
# ⚠️ Error fetching market data for MX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MXUSDT
# ⚠️ Error fetching market data for MODE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MODEUSDT
# ⚠️ Error fetching market data for LNDX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LNDXUSDT
# ⚠️ Error fetching market data for ZEROLEND/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZEROLENDUSDT
# ⚠️ Error fetching market data for KMNO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=KMNOUSDT
# ⚠️ Error fetching market data for REZ/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=REZUSDT
# ⚠️ Error fetching market data for STIK/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=STIKUSDT
# ⚠️ Error fetching market data for AZIT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AZITUSDT
# ⚠️ Error fetching market data for BROCK/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BROCKUSDT
# ⚠️ Error fetching market data for SDEX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SDEXUSDT
# ⚠️ Error fetching market data for BB/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BBUSDT
# ⚠️ Error fetching market data for ZENT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZENTUSDT
# ⚠️ Error fetching market data for AL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ALUSDT
# ⚠️ Error fetching market data for BAD/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BADUSDT
# ⚠️ Error fetching market data for SEI/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SEIUSDT
# ⚠️ Error fetching market data for DAOT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DAOTUSDT
# ⚠️ Error fetching market data for NOT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NOTUSDT
# ⚠️ Error fetching market data for DRIFT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DRIFTUSDT
# ⚠️ Error fetching market data for VIRTUAL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=VIRTUALUSDT
# ⚠️ Error fetching market data for GAME2/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GAME2USDT
# ⚠️ Error fetching market data for CYBER/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CYBERUSDT
# ⚠️ Error fetching market data for FTN/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FTNUSDT
# ⚠️ Error fetching market data for TET/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TETUSDT
# ⚠️ Error fetching market data for BUBBLE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BUBBLEUSDT
# ⚠️ Error fetching market data for WSDM/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WSDMUSDT
# ⚠️ Error fetching market data for FUD/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FUDUSDT
# ⚠️ Error fetching market data for XLM/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=XLMUSDT
# ⚠️ Error fetching market data for AITECH/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AITECHUSDT
# ⚠️ Error fetching market data for GOMINING/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GOMININGUSDT
# ⚠️ Error fetching market data for SAUCE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SAUCEUSDT
# ⚠️ Error fetching market data for NYAN/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NYANUSDT
# ⚠️ Error fetching market data for VET/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=VETUSDT
# ⚠️ Error fetching market data for NUTS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NUTSUSDT
# ⚠️ Error fetching market data for MAXEXCHANGE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MAXEXCHANGEUSDT
# ⚠️ Error fetching market data for BANANA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BANANAUSDT
# ⚠️ Error fetching market data for MCADE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MCADEUSDT
# ⚠️ Error fetching market data for PYUSD/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PYUSDUSDT
# ⚠️ Error fetching market data for ZERC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZERCUSDT
# ⚠️ Error fetching market data for CBK/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CBKUSDT
# ⚠️ Error fetching market data for CRETA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CRETAUSDT
# ⚠️ Error fetching market data for BIGTIME/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BIGTIMEUSDT
# ⚠️ Error fetching market data for STRAX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=STRAXUSDT
# ⚠️ Error fetching market data for ORBS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ORBSUSDT
# ⚠️ Error fetching market data for SFP/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SFPUSDT
# ⚠️ Error fetching market data for BSV/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BSVUSDT
# ⚠️ Error fetching market data for PPT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PPTUSDT
# ⚠️ Error fetching market data for GAS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GASUSDT
# ⚠️ Error fetching market data for LAT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LATUSDT
# ⚠️ Error fetching market data for SYS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SYSUSDT
# ⚠️ Error fetching market data for XETA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=XETAUSDT
# ⚠️ Error fetching market data for DAO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DAOUSDT
# ⚠️ Error fetching market data for XCAD/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=XCADUSDT
# ⚠️ Error fetching market data for CSPR/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CSPRUSDT
# ⚠️ Error fetching market data for ALPACA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ALPACAUSDT
# ⚠️ Error fetching market data for ZIG/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZIGUSDT
# ⚠️ Error fetching market data for PSG/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PSGUSDT
# ⚠️ Error fetching market data for ACM/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ACMUSDT
# ⚠️ Error fetching market data for BAR/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BARUSDT
# ⚠️ Error fetching market data for PORTO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PORTOUSDT
# ⚠️ Error fetching market data for LAZIO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LAZIOUSDT
# ⚠️ Error fetching market data for SANTOS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SANTOSUSDT
# ⚠️ Error fetching market data for ASR/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ASRUSDT
# ⚠️ Error fetching market data for ATM/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ATMUSDT
# ⚠️ Error fetching market data for INTER/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=INTERUSDT
# ⚠️ Error fetching market data for AFC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AFCUSDT
# ⚠️ Error fetching market data for SWEAT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SWEATUSDT
# ⚠️ Error fetching market data for ETHW/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ETHWUSDT
# ⚠️ Error fetching market data for FET/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FETUSDT
# ⚠️ Error fetching market data for AERGO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AERGOUSDT
# ⚠️ Error fetching market data for AUCTION/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AUCTIONUSDT
# ⚠️ Error fetching market data for ACH/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ACHUSDT
# ⚠️ Error fetching market data for ALPINE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ALPINEUSDT
# ⚠️ Error fetching market data for BADGER/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BADGERUSDT
# ⚠️ Error fetching market data for BICO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BICOUSDT
# ⚠️ Error fetching market data for BLZ/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BLZUSDT
# ⚠️ Error fetching market data for BURGER/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BURGERUSDT
# ⚠️ Error fetching market data for BAKE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BAKEUSDT
# ⚠️ Error fetching market data for BORA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BORAUSDT
# ⚠️ Error fetching market data for BEL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BELUSDT
# ⚠️ Error fetching market data for CTSI/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CTSIUSDT
# ⚠️ Error fetching market data for CVC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CVCUSDT
# ⚠️ Error fetching market data for KDA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=KDAUSDT
# ⚠️ Error fetching market data for ELF/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ELFUSDT
# ⚠️ Error fetching market data for FLOW/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FLOWUSDT
# ⚠️ Error fetching market data for GHST/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GHSTUSDT
# ⚠️ Error fetching market data for GNO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GNOUSDT
# ⚠️ Error fetching market data for GTC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GTCUSDT
# ⚠️ Error fetching market data for GLMR/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GLMRUSDT
# ⚠️ Error fetching market data for FDUSD/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FDUSDUSDT
# ⚠️ Error fetching market data for DOG/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DOGUSDT
# ⚠️ Error fetching market data for MON/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MONUSDT
# ⚠️ Error fetching market data for SLT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SLTUSDT
# ⚠️ Error fetching market data for WUSD/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WUSDUSDT
# ⚠️ Error fetching market data for CWIF/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CWIFUSDT
# ⚠️ Error fetching market data for TAIKO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TAIKOUSDT
# ⚠️ Error fetching market data for SKR/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SKRUSDT
# ⚠️ Error fetching market data for POLYX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=POLYXUSDT
# ⚠️ Error fetching market data for BEAM/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BEAMUSDT
# ⚠️ Error fetching market data for IO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=IOUSDT
# ⚠️ Error fetching market data for AARK/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AARKUSDT
# ⚠️ Error fetching market data for PGPT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PGPTUSDT
# ⚠️ Error fetching market data for ULTI/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ULTIUSDT
# ⚠️ Error fetching market data for GHX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GHXUSDT
# ⚠️ Error fetching market data for MOTHER/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MOTHERUSDT
# ⚠️ Error fetching market data for POL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=POLUSDT
# ⚠️ Error fetching market data for TIA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TIAUSDT
# ⚠️ Error fetching market data for MEME/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MEMEUSDT
# ⚠️ Error fetching market data for MBL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MBLUSDT
# ⚠️ Error fetching market data for ZK/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZKUSDT
# ⚠️ Error fetching market data for COOKIE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=COOKIEUSDT
# ⚠️ Error fetching market data for PIRATE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PIRATEUSDT
# ⚠️ Error fetching market data for T2T2/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=T2T2USDT
# ⚠️ Error fetching market data for ATH/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ATHUSDT
# ⚠️ Error fetching market data for SATS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SATSUSDT
# ⚠️ Error fetching market data for HIFI/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HIFIUSDT
# ⚠️ Error fetching market data for GROK/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GROKUSDT
# ⚠️ Error fetching market data for BLAST/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BLASTUSDT
# ⚠️ Error fetching market data for ZRO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZROUSDT
# ⚠️ Error fetching market data for LISTA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LISTAUSDT
# ⚠️ Error fetching market data for LNQ/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LNQUSDT
# ⚠️ Error fetching market data for NAKA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NAKAUSDT
# ⚠️ Error fetching market data for NPC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NPCUSDT
# ✅ Found 447 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 577 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ⚠️ Error fetching market data for PUMLX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PUMLXUSDT&category=spot
# ⚠️ Error fetching market data for APT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=APTUSDT&category=spot
# ⚠️ Error fetching market data for MCRT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MCRTUSDT&category=spot
# ⚠️ Error fetching market data for MASK/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MASKUSDT&category=spot
# ⚠️ Error fetching market data for ECOX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ECOXUSDT&category=spot
# ⚠️ Error fetching market data for HFT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=HFTUSDT&category=spot
# ⚠️ Error fetching market data for KCAL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=KCALUSDT&category=spot
# ⚠️ Error fetching market data for PEOPLE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PEOPLEUSDT&category=spot
# ⚠️ Error fetching market data for TWT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TWTUSDT&category=spot
# ⚠️ Error fetching market data for ORT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ORTUSDT&category=spot
# ⚠️ Error fetching market data for HOOK/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=HOOKUSDT&category=spot
# ⚠️ Error fetching market data for OAS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=OASUSDT&category=spot
# ⚠️ Error fetching market data for MAGIC/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MAGICUSDT&category=spot
# ⚠️ Error fetching market data for MEE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MEEUSDT&category=spot
# ⚠️ Error fetching market data for TON/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TONUSDT&category=spot
# ⚠️ Error fetching market data for BONK/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BONKUSDT&category=spot
# ⚠️ Error fetching market data for FLR/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FLRUSDT&category=spot
# ⚠️ Error fetching market data for TIME/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TIMEUSDT&category=spot
# ⚠️ Error fetching market data for 3P/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=3PUSDT&category=spot
# ⚠️ Error fetching market data for RPL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=RPLUSDT&category=spot
# ⚠️ Error fetching market data for SSV/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SSVUSDT&category=spot
# ⚠️ Error fetching market data for FXS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FXSUSDT&category=spot
# ⚠️ Error fetching market data for CORE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=COREUSDT&category=spot
# ⚠️ Error fetching market data for RDNT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=RDNTUSDT&category=spot
# ⚠️ Error fetching market data for BLUR/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BLURUSDT&category=spot
# ⚠️ Error fetching market data for LIS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=LISUSDT&category=spot
# ⚠️ Error fetching market data for MDAO/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MDAOUSDT&category=spot
# ⚠️ Error fetching market data for ACS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ACSUSDT&category=spot
# ⚠️ Error fetching market data for HVH/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=HVHUSDT&category=spot
# ⚠️ Error fetching market data for PIP/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PIPUSDT&category=spot
# ⚠️ Error fetching market data for PRIME/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PRIMEUSDT&category=spot
# ⚠️ Error fetching market data for EVER/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=EVERUSDT&category=spot
# ⚠️ Error fetching market data for VRA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=VRAUSDT&category=spot
# ⚠️ Error fetching market data for ID/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=IDUSDT&category=spot
# ⚠️ Error fetching market data for ARB/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ARBUSDT&category=spot
# ⚠️ Error fetching market data for XCAD/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=XCADUSDT&category=spot
# ⚠️ Error fetching market data for MBX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MBXUSDT&category=spot
# ⚠️ Error fetching market data for AXL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=AXLUSDT&category=spot
# ⚠️ Error fetching market data for CGPT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=CGPTUSDT&category=spot
# ⚠️ Error fetching market data for AGI/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=AGIUSDT&category=spot
# ⚠️ Error fetching market data for SUI/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SUIUSDT&category=spot
# ⚠️ Error fetching market data for MVL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MVLUSDT&category=spot
# ⚠️ Error fetching market data for PEPE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PEPEUSDT&category=spot
# ⚠️ Error fetching market data for LADYS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=LADYSUSDT&category=spot
# ⚠️ Error fetching market data for LMWR/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=LMWRUSDT&category=spot
# ⚠️ Error fetching market data for BOB/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BOBUSDT&category=spot
# ⚠️ Error fetching market data for TOMI/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TOMIUSDT&category=spot
# ⚠️ Error fetching market data for KARATE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=KARATEUSDT&category=spot
# ⚠️ Error fetching market data for TURBOS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TURBOSUSDT&category=spot
# ⚠️ Error fetching market data for FMB/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FMBUSDT&category=spot
# ⚠️ Error fetching market data for TENET/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TENETUSDT&category=spot
# ⚠️ Error fetching market data for VELO/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=VELOUSDT&category=spot
# ⚠️ Error fetching market data for ELDA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ELDAUSDT&category=spot
# ⚠️ Error fetching market data for PENDLE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PENDLEUSDT&category=spot
# ⚠️ Error fetching market data for EGO/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=EGOUSDT&category=spot
# ⚠️ Error fetching market data for NYM/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=NYMUSDT&category=spot
# ⚠️ Error fetching market data for MNT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MNTUSDT&category=spot
# ⚠️ Error fetching market data for GSWIFT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=GSWIFTUSDT&category=spot
# ⚠️ Error fetching market data for SALD/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SALDUSDT&category=spot
# ⚠️ Error fetching market data for ARKM/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ARKMUSDT&category=spot
# ⚠️ Error fetching market data for NEON/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=NEONUSDT&category=spot
# ⚠️ Error fetching market data for WLD/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=WLDUSDT&category=spot
# ⚠️ Error fetching market data for PLANET/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PLANETUSDT&category=spot
# ⚠️ Error fetching market data for DSRUN/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=DSRUNUSDT&category=spot
# ⚠️ Error fetching market data for SPARTA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SPARTAUSDT&category=spot
# ⚠️ Error fetching market data for TAVA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TAVAUSDT&category=spot
# ⚠️ Error fetching market data for SEILOR/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SEILORUSDT&category=spot
# ⚠️ Error fetching market data for SEI/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SEIUSDT&category=spot
# ⚠️ Error fetching market data for CYBER/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=CYBERUSDT&category=spot
# ⚠️ Error fetching market data for ORDI/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ORDIUSDT&category=spot
# ⚠️ Error fetching market data for KAVA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=KAVAUSDT&category=spot
# ⚠️ Error fetching market data for SAIL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SAILUSDT&category=spot
# ⚠️ Error fetching market data for PYUSD/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PYUSDUSDT&category=spot
# ⚠️ Error fetching market data for VEXT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=VEXTUSDT&category=spot
# ⚠️ Error fetching market data for CTT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=CTTUSDT&category=spot
# ⚠️ Error fetching market data for KAS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=KASUSDT&category=spot
# ⚠️ Error fetching market data for NESS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=NESSUSDT&category=spot
# ⚠️ Error fetching market data for FET/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FETUSDT&category=spot
# ⚠️ Error fetching market data for LEVER/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=LEVERUSDT&category=spot
# ⚠️ Error fetching market data for ZTX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ZTXUSDT&category=spot
# ⚠️ Error fetching market data for JEFF/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=JEFFUSDT&category=spot
# ⚠️ Error fetching market data for PPT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PPTUSDT&category=spot
# ⚠️ Error fetching market data for TUSD/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TUSDUSDT&category=spot
# ⚠️ Error fetching market data for BEAM/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BEAMUSDT&category=spot
# ⚠️ Error fetching market data for POL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=POLUSDT&category=spot
# ⚠️ Error fetching market data for TIA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TIAUSDT&category=spot
# ⚠️ Error fetching market data for TOKEN/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TOKENUSDT&category=spot
# ⚠️ Error fetching market data for MEME/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MEMEUSDT&category=spot
# ⚠️ Error fetching market data for SHRAP/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SHRAPUSDT&category=spot
# ⚠️ Error fetching market data for RPK/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=RPKUSDT&category=spot
# ⚠️ Error fetching market data for FLIP/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FLIPUSDT&category=spot
# ⚠️ Error fetching market data for VRTX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=VRTXUSDT&category=spot
# ⚠️ Error fetching market data for ROOT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ROOTUSDT&category=spot
# ⚠️ Error fetching market data for PYTH/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PYTHUSDT&category=spot
# ⚠️ Error fetching market data for MLK/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MLKUSDT&category=spot
# ⚠️ Error fetching market data for KUB/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=KUBUSDT&category=spot
# ⚠️ Error fetching market data for 5IRE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=5IREUSDT&category=spot
# ⚠️ Error fetching market data for KCS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=KCSUSDT&category=spot
# ⚠️ Error fetching market data for VANRY/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=VANRYUSDT&category=spot
# ⚠️ Error fetching market data for INSP/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=INSPUSDT&category=spot
# ⚠️ Error fetching market data for JTO/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=JTOUSDT&category=spot
# ⚠️ Error fetching market data for METH/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=METHUSDT&category=spot
# ⚠️ Error fetching market data for CBK/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=CBKUSDT&category=spot
# ⚠️ Error fetching market data for ZIG/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ZIGUSDT&category=spot
# ⚠️ Error fetching market data for VPR/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=VPRUSDT&category=spot
# ⚠️ Error fetching market data for TRC/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TRCUSDT&category=spot
# ⚠️ Error fetching market data for FMC/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FMCUSDT&category=spot
# ⚠️ Error fetching market data for MYRIA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MYRIAUSDT&category=spot
# ⚠️ Error fetching market data for AKI/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=AKIUSDT&category=spot
# ⚠️ Error fetching market data for MBOX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MBOXUSDT&category=spot
# ⚠️ Error fetching market data for IRL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=IRLUSDT&category=spot
# ⚠️ Error fetching market data for ARTY/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ARTYUSDT&category=spot
# ⚠️ Error fetching market data for GRAPE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=GRAPEUSDT&category=spot
# ⚠️ Error fetching market data for COQ/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=COQUSDT&category=spot
# ⚠️ Error fetching market data for AIOZ/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=AIOZUSDT&category=spot
# ⚠️ Error fetching market data for GG/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=GGUSDT&category=spot
# ⚠️ Error fetching market data for VIC/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=VICUSDT&category=spot
# ⚠️ Error fetching market data for RATS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=RATSUSDT&category=spot
# ⚠️ Error fetching market data for SATS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SATSUSDT&category=spot
# ⚠️ Error fetching market data for PORT3/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PORT3USDT&category=spot
# ⚠️ Error fetching market data for XAI/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=XAIUSDT&category=spot
# ⚠️ Error fetching market data for ONDO/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ONDOUSDT&category=spot
# ⚠️ Error fetching market data for FAR/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FARUSDT&category=spot
# ⚠️ Error fetching market data for SQR/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SQRUSDT&category=spot
# ⚠️ Error fetching market data for DUEL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=DUELUSDT&category=spot
# ⚠️ Error fetching market data for APP/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=APPUSDT&category=spot
# ⚠️ Error fetching market data for SAROS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SAROSUSDT&category=spot
# ⚠️ Error fetching market data for USDY/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=USDYUSDT&category=spot
# ⚠️ Error fetching market data for MANTA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MANTAUSDT&category=spot
# ✅ Found 333 tradable tokens on Bybit
# ⚠️ Error fetching market data for NOT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NOTUSDT
# ⚠️ Error fetching market data for DRIFT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DRIFTUSDT
# ⚠️ Error fetching market data for VIRTUAL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=VIRTUALUSDT
# ⚠️ Error fetching market data for GAME2/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GAME2USDT
# ⚠️ Error fetching market data for CYBER/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CYBERUSDT
# ⚠️ Error fetching market data for FTN/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FTNUSDT
# ⚠️ Error fetching market data for TET/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TETUSDT
# ⚠️ Error fetching market data for BUBBLE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BUBBLEUSDT
# ⚠️ Error fetching market data for WSDM/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WSDMUSDT
# ⚠️ Error fetching market data for FUD/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FUDUSDT
# ⚠️ Error fetching market data for XLM/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=XLMUSDT
# ⚠️ Error fetching market data for AITECH/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AITECHUSDT
# ⚠️ Error fetching market data for GOMINING/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GOMININGUSDT
# ⚠️ Error fetching market data for SAUCE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SAUCEUSDT
# ⚠️ Error fetching market data for NYAN/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NYANUSDT
# ⚠️ Error fetching market data for VET/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=VETUSDT
# ⚠️ Error fetching market data for NUTS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NUTSUSDT
# ⚠️ Error fetching market data for MAXEXCHANGE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MAXEXCHANGEUSDT
# ⚠️ Error fetching market data for BANANA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BANANAUSDT
# ⚠️ Error fetching market data for MCADE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MCADEUSDT
# ⚠️ Error fetching market data for PYUSD/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PYUSDUSDT
# ⚠️ Error fetching market data for ZERC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZERCUSDT
# ⚠️ Error fetching market data for CBK/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CBKUSDT
# ⚠️ Error fetching market data for CRETA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CRETAUSDT
# ⚠️ Error fetching market data for BIGTIME/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BIGTIMEUSDT
# ⚠️ Error fetching market data for STRAX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=STRAXUSDT
# ⚠️ Error fetching market data for ORBS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ORBSUSDT
# ⚠️ Error fetching market data for SFP/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SFPUSDT
# ⚠️ Error fetching market data for BSV/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BSVUSDT
# ⚠️ Error fetching market data for PPT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PPTUSDT
# ⚠️ Error fetching market data for GAS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GASUSDT
# ⚠️ Error fetching market data for LAT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LATUSDT
# ⚠️ Error fetching market data for SYS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SYSUSDT
# ⚠️ Error fetching market data for XETA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=XETAUSDT
# ⚠️ Error fetching market data for DAO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DAOUSDT
# ⚠️ Error fetching market data for XCAD/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=XCADUSDT
# ⚠️ Error fetching market data for CSPR/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CSPRUSDT
# ⚠️ Error fetching market data for ALPACA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ALPACAUSDT
# ⚠️ Error fetching market data for ZIG/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZIGUSDT
# ⚠️ Error fetching market data for PSG/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PSGUSDT
# ⚠️ Error fetching market data for ACM/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ACMUSDT
# ⚠️ Error fetching market data for BAR/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BARUSDT
# ⚠️ Error fetching market data for PORTO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PORTOUSDT
# ⚠️ Error fetching market data for LAZIO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LAZIOUSDT
# ⚠️ Error fetching market data for SANTOS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SANTOSUSDT
# ⚠️ Error fetching market data for ASR/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ASRUSDT
# ⚠️ Error fetching market data for ATM/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ATMUSDT
# ⚠️ Error fetching market data for INTER/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=INTERUSDT
# ⚠️ Error fetching market data for AFC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AFCUSDT
# ⚠️ Error fetching market data for SWEAT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SWEATUSDT
# ⚠️ Error fetching market data for ETHW/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ETHWUSDT
# ...
# ⚠️ Error fetching market data for QKC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=QKCUSDT
# ⚠️ Error fetching market data for QNT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=QNTUSDT
# ⚠️ Error fetching market data for ROUTE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ROUTEUSDT
# ⚠️ Error fetching market data for APT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=APTUSDT
# ⚠️ Error fetching market data for SNT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SNTUSDT
# ⚠️ Error fetching market data for STMX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=STMXUSDT
# ⚠️ Error fetching market data for STPT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=STPTUSDT
# ⚠️ Error fetching market data for SUPER/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SUPERUSDT
# ⚠️ Error fetching market data for SYN/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SYNUSDT
# ⚠️ Error fetching market data for T/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TUSDT
# ⚠️ Error fetching market data for TRB/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TRBUSDT
# ⚠️ Error fetching market data for TWT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TWTUSDT
# ⚠️ Error fetching market data for VIB/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=VIBUSDT
# ⚠️ Error fetching market data for WAVES/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WAVESUSDT
# ⚠️ Error fetching market data for XCN/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=XCNUSDT
# ⚠️ Error fetching market data for XPR/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=XPRUSDT
# ⚠️ Error fetching market data for RAD/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RADUSDT
# ⚠️ Error fetching market data for HFT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HFTUSDT
# ⚠️ Error fetching market data for ONT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ONTUSDT
# ⚠️ Error fetching market data for WING/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WINGUSDT
# ⚠️ Error fetching market data for ONG/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ONGUSDT
# ⚠️ Error fetching market data for HOOK/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HOOKUSDT
# ⚠️ Error fetching market data for AGLD/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AGLDUSDT
# ⚠️ Error fetching market data for KAVA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=KAVAUSDT
# ⚠️ Error fetching market data for DYDX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DYDXUSDT
# ⚠️ Error fetching market data for OAS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=OASUSDT
# ⚠️ Error fetching market data for CELR/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CELRUSDT
# ⚠️ Error fetching market data for GEAR/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GEARUSDT
# ⚠️ Error fetching market data for RACA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RACAUSDT
# ⚠️ Error fetching market data for BONK/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BONKUSDT
# ⚠️ Error fetching market data for BETA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BETAUSDT
# ⚠️ Error fetching market data for MBOX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MBOXUSDT
# ⚠️ Error fetching market data for AXS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AXSUSDT
# ⚠️ Error fetching market data for HIGH/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HIGHUSDT
# ⚠️ Error fetching market data for GNS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GNSUSDT
# ⚠️ Error fetching market data for SLP/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SLPUSDT
# ⚠️ Error fetching market data for GALA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GALAUSDT
# ⚠️ Error fetching market data for SAND/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SANDUSDT
# ⚠️ Error fetching market data for ALICE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ALICEUSDT
# ⚠️ Error fetching market data for TLM/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TLMUSDT
# ⚠️ Error fetching market data for RPL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RPLUSDT
# ⚠️ Error fetching market data for GODS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GODSUSDT
# ⚠️ Error fetching market data for DOT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DOTUSDT
# ⚠️ Error fetching market data for ATOM/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ATOMUSDT
# ⚠️ Error fetching market data for IMX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=IMXUSDT
# ⚠️ Error fetching market data for MOVR/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MOVRUSDT
# ⚠️ Error fetching market data for ENS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ENSUSDT
# ⚠️ Error fetching market data for WILD/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WILDUSDT
# ⚠️ Error fetching market data for AVAX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AVAXUSDT
# ⚠️ Error fetching market data for CRO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CROUSDT
# ⚠️ Error fetching market data for JASMY/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=JASMYUSDT
# ⚠️ Error fetching market data for TON/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TONUSDT
# ⚠️ Error fetching market data for CVX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CVXUSDT
# ⚠️ Error fetching market data for SPELL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SPELLUSDT
# ⚠️ Error fetching market data for HOT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HOTUSDT
# ⚠️ Error fetching market data for COTI/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=COTIUSDT
# ⚠️ Error fetching market data for FXS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FXSUSDT
# ⚠️ Error fetching market data for CEEK/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CEEKUSDT
# ⚠️ Error fetching market data for DENT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DENTUSDT
# ⚠️ Error fetching market data for FLOKI/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FLOKIUSDT
# ⚠️ Error fetching market data for WHY/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WHYUSDT
# ⚠️ Error fetching market data for RENDER/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RENDERUSDT
# ⚠️ Error fetching market data for LSD/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LSDUSDT
# ⚠️ Error fetching market data for L3/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=L3USDT
# ⚠️ Error fetching market data for MAX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MAXUSDT
# ⚠️ Error fetching market data for INVITE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=INVITEUSDT
# ⚠️ Error fetching market data for NEIROETH/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NEIROETHUSDT
# ⚠️ Error fetching market data for DTEC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DTECUSDT
# ⚠️ Error fetching market data for AIN/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AINUSDT
# ⚠️ Error fetching market data for WUF/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WUFUSDT
# ⚠️ Error fetching market data for ICX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ICXUSDT
# ⚠️ Error fetching market data for NMT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NMTUSDT
# ⚠️ Error fetching market data for DOGS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DOGSUSDT
# ⚠️ Error fetching market data for SUNDOG/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SUNDOGUSDT
# ⚠️ Error fetching market data for CEC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CECUSDT
# ⚠️ Error fetching market data for MAK/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MAKUSDT
# ⚠️ Error fetching market data for CPOOL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CPOOLUSDT
# ⚠️ Error fetching market data for BRN/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BRNUSDT
# ⚠️ Error fetching market data for SLF/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SLFUSDT
# ⚠️ Error fetching market data for RFRM/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RFRMUSDT
# ⚠️ Error fetching market data for ORDER/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ORDERUSDT
# ⚠️ Error fetching market data for BOX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BOXUSDT
# ⚠️ Error fetching market data for LOGX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LOGXUSDT
# ⚠️ Error fetching market data for EGP/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=EGPUSDT
# ⚠️ Error fetching market data for WAT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WATUSDT
# ⚠️ Error fetching market data for CATI/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CATIUSDT
# ⚠️ Error fetching market data for NEIROCTO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NEIROCTOUSDT
# ⚠️ Error fetching market data for ZCX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZCXUSDT
# ⚠️ Error fetching market data for HMSTR/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HMSTRUSDT
# ⚠️ Error fetching market data for PUFFER/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PUFFERUSDT
# ⚠️ Error fetching market data for MOODENGETH/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MOODENGETHUSDT
# ⚠️ Error fetching market data for CARV/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CARVUSDT
# ⚠️ Error fetching market data for CATS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CATSUSDT
# ⚠️ Error fetching market data for EIGEN/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=EIGENUSDT
# ⚠️ Error fetching market data for MOODENG/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MOODENGUSDT
# ⚠️ Error fetching market data for GEEK/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GEEKUSDT
# ✅ Found 229 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 427 tradable tokens on Bybit
# ✅ Found 575 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 574 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 575 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 576 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 427 tradable tokens on Bybit
# ✅ Found 577 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 577 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 423 tradable tokens on Bybit
# ✅ Found 577 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 576 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 575 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 575 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 425 tradable tokens on Bybit
# ✅ Found 575 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 425 tradable tokens on Bybit
# ✅ Found 575 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 428 tradable tokens on Bybit
# ✅ Found 575 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 128
#     126 # Check arbitrage on Bybit
#     127 if bybit_tokens:
# --> 128     check_triangular_arbitrage(bybit, "Bybit", bybit_tokens)
#     130 # Check arbitrage on Bitget
#     131 if bitget_tokens:
#
# Cell In[7], line 77, in check_triangular_arbitrage(exchange, exchange_name, tradable_tokens)
#      74 mid_asset = route[1].split('/')[0]
#      75 final_asset = route[2].split('/')[1]  # Final conversion back to USDT
# ---> 77 if base_asset == final_asset:  # Ensure a valid cycle
#      78     try:
#      79         # Get price data for each leg
#      80         first_leg_price = get_price(exchange, route[0], exchange_name)
#
# KeyboardInterrupt:
