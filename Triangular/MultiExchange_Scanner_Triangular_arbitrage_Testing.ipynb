# %%
import ccxt
import time
from itertools import permutations
from ccxt.base.errors import RateLimitExceeded

# Replace with your actual API keys
BYBIT_API_KEY = 'I6m01uNAWiensHbIBA'
BYBIT_API_SECRET = 'vkaviS9xw903NJPncMtHgGfyiWB4mnhSJTyK'

BITGET_API_KEY = 'bg_b0a9d721607623216a87b066a3df34c3'
BITGET_API_SECRET = '6c4a5016562624b6d7f3b1c59563d4a1a573f630e0e49422fbf509399e56918b'
BITGET_PASSPHRASE = 'BgSecure789Trade2025'  # Required for Bitget authentication

# Connect to Bybit API
bybit = ccxt.bybit({
    'apiKey': BYBIT_API_KEY,
    'secret': BYBIT_API_SECRET,
    'options': {'adjustForTimeDifference': True}
})

# Connect to Bitget API
bitget = ccxt.bitget({
    'apiKey': BITGET_API_KEY,
    'secret': BITGET_API_SECRET,
    'password': BITGET_PASSPHRASE,
    'options': {'adjustForTimeDifference': True}
})

# %%
# Arbitrage settings
SPREAD_THRESHOLD = 0.1 / 100  # 0.1% profit target
MIN_VOLUME = 50000  # Minimum 24h volume required (in USDT)
CHECK_INTERVAL = 5  # Check every 5 seconds
STARTING_CAPITAL = 100  # Configurable capital in USDT

# Trading Fees per Exchange
TRADING_FEES = {
    "Bybit": 0.001,  # 0.1% per trade
    "Bitget": 0.001  # 0.1% per trade
}

def get_tradable_tokens(exchange, exchange_name):
    """Fetches only active spot trading pairs on the given exchange."""
    try:
        markets = exchange.load_markets()
        tradable_tokens = []

        for symbol, market in markets.items():
            # Ensure it's an active SPOT market
            if market.get("type") == "spot" and market.get("active", False):
                if '/USDT' in symbol and ':USDT' not in symbol:  # Ensure it's a valid USDT spot pair
                    try:
                        market_data = exchange.fetch_ticker(symbol)
                        volume = market_data.get('quoteVolume', 0)  # 24h volume
                        if volume and volume >= MIN_VOLUME:
                            tradable_tokens.append(symbol)
                    except RateLimitExceeded:
                        print(f"⚠️ Rate limit hit on {exchange_name}. Pausing...")
                        time.sleep(60)
                        continue
                    except Exception as e:
                        print(f"⚠️ Error fetching market data for {symbol} on {exchange_name}: {e}")
                        continue  # Skip symbols that cause errors

        print(f"✅ Found {len(tradable_tokens)} tradable tokens on {exchange_name}")
        return tradable_tokens

    except Exception as e:
        print(f"❌ Error fetching tradable tokens on {exchange_name}: {e}")
        return []

def get_price(exchange, symbol, exchange_name):
    """Fetch latest price for a given token from the specified exchange."""
    try:
        if exchange_name == "Bybit":
            # Bybit requires a manual request with category='spot'
            symbol_formatted = symbol.replace("/", "")  # Convert "XLM/USDT" -> "XLMUSDT"
            response = exchange.public_get_v5_market_tickers({'symbol': symbol_formatted, 'category': 'spot'})
            return float(response['result']['list'][0]['lastPrice']) if response['result']['list'] else None
        else:
            # Standard fetch_ticker for other exchanges
            if symbol in exchange.load_markets():
                ticker = exchange.fetch_ticker(symbol)
                return float(ticker.get("last", 0)) if ticker else None
        return None
    except RateLimitExceeded:
        print(f"⚠️ Rate limit hit while fetching price from {exchange_name}. Pausing...")
        time.sleep(60)
        return None
    except Exception as e:
        print(f"❌ Error fetching price for {symbol} from {exchange_name}: {e}")
        return None

def log_arbitrage(exchange_name, trade_path, expected_return, net_profit):
    """Logs detected arbitrage trades to a file."""
    with open(f"{exchange_name}_triangular_arbitrage.log", "a") as log_file:
        log_file.write(f"{trade_path} | Expected: {expected_return:.4%} | Net Profit: {net_profit:.4%}\n")

def check_triangular_arbitrage(exchange, exchange_name, tradable_tokens):
    """Checks for triangular arbitrage opportunities within a specific exchange."""
    for route in permutations(tradable_tokens, 3):  # Ensure three different assets
        base_asset = route[0].split('/')[0]  # First asset in the path
        mid_asset = route[1].split('/')[0]
        final_asset = route[2].split('/')[1]  # Final conversion back to USDT

        if base_asset == final_asset:  # Ensure a valid cycle
            try:
                # Get price data for each leg
                first_leg_price = get_price(exchange, route[0], exchange_name)
                second_leg_price = get_price(exchange, route[1], exchange_name)
                third_leg_price = get_price(exchange, route[2], exchange_name)

                # Ensure all prices are valid
                if None in [first_leg_price, second_leg_price, third_leg_price]:
                    continue  

                # Convert using proper exchange path
                amount_after_first_trade = (STARTING_CAPITAL / first_leg_price) * second_leg_price
                amount_after_second_trade = (amount_after_first_trade / second_leg_price) * third_leg_price
                final_amount = amount_after_second_trade

                expected_return = final_amount / STARTING_CAPITAL
                net_expected_return = expected_return * (1 - TRADING_FEES[exchange_name]) ** 3  # Adjust for fees

                # Print all paths for debugging
                print(f"🔍 Checking Arbitrage Path on {exchange_name}: {route[0]} ➝ {route[1]} ➝ {route[2]}")
                print(f"    ✅ Expected Return: {expected_return:.4%}")
                print(f"    ✅ Net Profit After Fees: {net_expected_return:.4%}")

                # Detect and log only profitable trades
                if net_expected_return > 1.001:  # Ensure profit > 0.1%
                    print(f"✅ VALID Triangular Arbitrage Detected on {exchange_name}")
                    print(f"    ✅ Trade Path: {route[0]} ➝ {route[1]} ➝ {route[2]}")
                    print(f"    ✅ Expected Return: {expected_return:.4%}")
                    print(f"    ✅ Net Profit After Fees: {net_expected_return:.4%}")
                    print("-" * 50)
                    log_arbitrage(exchange_name, f"{route[0]} ➝ {route[1]} ➝ {route[2]}", expected_return, net_expected_return)
            except Exception as e:
                print(f"⚠️ Error in arbitrage check on {exchange_name}: {e}")
                continue

while True:
    try:
        # Fetch tradable tokens for each exchange
        bybit_tokens = get_tradable_tokens(bybit, "Bybit")
        bitget_tokens = get_tradable_tokens(bitget, "Bitget")

        if not bybit_tokens and not bitget_tokens:
            print("❌ No tradable tokens found on either exchange. Retrying in 10 seconds...")
            time.sleep(10)
            continue

        print("🔄 Checking for arbitrage opportunities on Bybit and Bitget...")

        # Check arbitrage on Bybit
        if bybit_tokens:
            check_triangular_arbitrage(bybit, "Bybit", bybit_tokens)

        # Check arbitrage on Bitget
        if bitget_tokens:
            check_triangular_arbitrage(bitget, "Bitget", bitget_tokens)

        print("✅ Completed this cycle. Waiting for next check...")
        time.sleep(CHECK_INTERVAL)

    except Exception as e:
        print(f"❌ Error in main loop: {e}")
        time.sleep(10)  # Avoid infinite crash loops
# Out:
# ✅ Found 427 tradable tokens on Bybit
# ✅ Found 547 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 547 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 546 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 545 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 543 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 543 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 425 tradable tokens on Bybit
# ✅ Found 542 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 425 tradable tokens on Bybit
# ✅ Found 542 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 424 tradable tokens on Bybit
# ✅ Found 541 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 425 tradable tokens on Bybit
# ✅ Found 541 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 425 tradable tokens on Bybit
# ✅ Found 539 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 425 tradable tokens on Bybit
# ✅ Found 538 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 538 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ⚠️ Error fetching market data for ETH3L/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ETH3LUSDT&category=spot
# ⚠️ Error fetching market data for FAME/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FAMEUSDT&category=spot
# ⚠️ Error fetching market data for USDD/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=USDDUSDT&category=spot
# ⚠️ Error fetching market data for OP/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=OPUSDT&category=spot
# ⚠️ Error fetching market data for LUNA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=LUNAUSDT&category=spot
# ⚠️ Error fetching market data for THN/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=THNUSDT&category=spot
# ⚠️ Error fetching market data for VINU/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=VINUUSDT&category=spot
# ⚠️ Error fetching market data for BEL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BELUSDT&category=spot
# ⚠️ Error fetching market data for FORT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FORTUSDT&category=spot
# ⚠️ Error fetching market data for WLKN/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=WLKNUSDT&category=spot
# ⚠️ Error fetching market data for KON/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=KONUSDT&category=spot
# ⚠️ Error fetching market data for OBX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=OBXUSDT&category=spot
# ⚠️ Error fetching market data for SEOR/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SEORUSDT&category=spot
# ⚠️ Error fetching market data for CUSD/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=CUSDUSDT&category=spot
# ⚠️ Error fetching market data for GSTS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=GSTSUSDT&category=spot
# ⚠️ Error fetching market data for XETA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=XETAUSDT&category=spot
# ⚠️ Error fetching market data for FLOKI/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FLOKIUSDT&category=spot
# ⚠️ Error fetching market data for BABYDOGE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BABYDOGEUSDT&category=spot
# ⚠️ Error fetching market data for STAT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=STATUSDT&category=spot
# ⚠️ Error fetching market data for DICE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=DICEUSDT&category=spot
# ⚠️ Error fetching market data for WAXP/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=WAXPUSDT&category=spot
# ⚠️ Error fetching market data for AR/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ARUSDT&category=spot
# ⚠️ Error fetching market data for KDA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=KDAUSDT&category=spot
# ⚠️ Error fetching market data for ROSE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ROSEUSDT&category=spot
# ⚠️ Error fetching market data for PSG/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PSGUSDT&category=spot
# ⚠️ Error fetching market data for JUV/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=JUVUSDT&category=spot
# ⚠️ Error fetching market data for INTER/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=INTERUSDT&category=spot
# ⚠️ Error fetching market data for AFC/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=AFCUSDT&category=spot
# ⚠️ Error fetching market data for CITY/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=CITYUSDT&category=spot
# ⚠️ Error fetching market data for SOLO/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SOLOUSDT&category=spot
# ⚠️ Error fetching market data for CHRP/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=CHRPUSDT&category=spot
# ⚠️ Error fetching market data for WWY/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=WWYUSDT&category=spot
# ⚠️ Error fetching market data for SWEAT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SWEATUSDT&category=spot
# ⚠️ Error fetching market data for DLC/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=DLCUSDT&category=spot
# ⚠️ Error fetching market data for ETHW/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ETHWUSDT&category=spot
# ⚠️ Error fetching market data for INJ/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=INJUSDT&category=spot
# ⚠️ Error fetching market data for MPLX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MPLXUSDT&category=spot
# ⚠️ Error fetching market data for AGLA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=AGLAUSDT&category=spot
# ⚠️ Error fetching market data for ROND/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=RONDUSDT&category=spot
# ⚠️ Error fetching market data for PUMLX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PUMLXUSDT&category=spot
# ⚠️ Error fetching market data for APT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=APTUSDT&category=spot
# ⚠️ Error fetching market data for MCRT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MCRTUSDT&category=spot
# ⚠️ Error fetching market data for MASK/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MASKUSDT&category=spot
# ⚠️ Error fetching market data for ECOX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ECOXUSDT&category=spot
# ⚠️ Error fetching market data for HFT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=HFTUSDT&category=spot
# ⚠️ Error fetching market data for KCAL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=KCALUSDT&category=spot
# ⚠️ Error fetching market data for PEOPLE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PEOPLEUSDT&category=spot
# ⚠️ Error fetching market data for TWT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TWTUSDT&category=spot
# ⚠️ Error fetching market data for ORT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ORTUSDT&category=spot
# ⚠️ Error fetching market data for HOOK/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=HOOKUSDT&category=spot
# ⚠️ Error fetching market data for OAS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=OASUSDT&category=spot
# ⚠️ Error fetching market data for MAGIC/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MAGICUSDT&category=spot
# ⚠️ Error fetching market data for MEE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MEEUSDT&category=spot
# ⚠️ Error fetching market data for TON/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TONUSDT&category=spot
# ⚠️ Error fetching market data for BONK/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BONKUSDT&category=spot
# ⚠️ Error fetching market data for FLR/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FLRUSDT&category=spot
# ⚠️ Error fetching market data for TIME/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TIMEUSDT&category=spot
# ⚠️ Error fetching market data for 3P/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=3PUSDT&category=spot
# ⚠️ Error fetching market data for RPL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=RPLUSDT&category=spot
# ⚠️ Error fetching market data for SSV/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SSVUSDT&category=spot
# ⚠️ Error fetching market data for FXS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FXSUSDT&category=spot
# ⚠️ Error fetching market data for CORE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=COREUSDT&category=spot
# ⚠️ Error fetching market data for RDNT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=RDNTUSDT&category=spot
# ⚠️ Error fetching market data for BLUR/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BLURUSDT&category=spot
# ⚠️ Error fetching market data for LIS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=LISUSDT&category=spot
# ⚠️ Error fetching market data for MDAO/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MDAOUSDT&category=spot
# ⚠️ Error fetching market data for ACS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ACSUSDT&category=spot
# ⚠️ Error fetching market data for HVH/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=HVHUSDT&category=spot
# ⚠️ Error fetching market data for PIP/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PIPUSDT&category=spot
# ⚠️ Error fetching market data for PRIME/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PRIMEUSDT&category=spot
# ⚠️ Error fetching market data for EVER/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=EVERUSDT&category=spot
# ⚠️ Error fetching market data for VRA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=VRAUSDT&category=spot
# ⚠️ Error fetching market data for ID/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=IDUSDT&category=spot
# ⚠️ Error fetching market data for ARB/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ARBUSDT&category=spot
# ⚠️ Error fetching market data for XCAD/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=XCADUSDT&category=spot
# ⚠️ Error fetching market data for MBX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MBXUSDT&category=spot
# ⚠️ Error fetching market data for AXL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=AXLUSDT&category=spot
# ⚠️ Error fetching market data for CGPT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=CGPTUSDT&category=spot
# ⚠️ Error fetching market data for AGI/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=AGIUSDT&category=spot
# ⚠️ Error fetching market data for SUI/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SUIUSDT&category=spot
# ⚠️ Error fetching market data for MVL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MVLUSDT&category=spot
# ⚠️ Error fetching market data for PEPE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PEPEUSDT&category=spot
# ⚠️ Error fetching market data for LADYS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=LADYSUSDT&category=spot
# ⚠️ Error fetching market data for LMWR/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=LMWRUSDT&category=spot
# ⚠️ Error fetching market data for BOB/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BOBUSDT&category=spot
# ⚠️ Error fetching market data for TOMI/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TOMIUSDT&category=spot
# ⚠️ Error fetching market data for KARATE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=KARATEUSDT&category=spot
# ⚠️ Error fetching market data for TURBOS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TURBOSUSDT&category=spot
# ⚠️ Error fetching market data for FMB/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FMBUSDT&category=spot
# ⚠️ Error fetching market data for TENET/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TENETUSDT&category=spot
# ⚠️ Error fetching market data for VELO/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=VELOUSDT&category=spot
# ⚠️ Error fetching market data for ELDA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ELDAUSDT&category=spot
# ⚠️ Error fetching market data for PENDLE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PENDLEUSDT&category=spot
# ⚠️ Error fetching market data for EGO/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=EGOUSDT&category=spot
# ⚠️ Error fetching market data for NYM/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=NYMUSDT&category=spot
# ⚠️ Error fetching market data for MNT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MNTUSDT&category=spot
# ⚠️ Error fetching market data for GSWIFT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=GSWIFTUSDT&category=spot
# ⚠️ Error fetching market data for SALD/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SALDUSDT&category=spot
# ⚠️ Error fetching market data for ARKM/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ARKMUSDT&category=spot
# ⚠️ Error fetching market data for NEON/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=NEONUSDT&category=spot
# ⚠️ Error fetching market data for WLD/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=WLDUSDT&category=spot
# ⚠️ Error fetching market data for PLANET/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PLANETUSDT&category=spot
# ⚠️ Error fetching market data for DSRUN/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=DSRUNUSDT&category=spot
# ⚠️ Error fetching market data for SPARTA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SPARTAUSDT&category=spot
# ⚠️ Error fetching market data for TAVA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TAVAUSDT&category=spot
# ⚠️ Error fetching market data for SEILOR/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SEILORUSDT&category=spot
# ⚠️ Error fetching market data for SEI/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SEIUSDT&category=spot
# ⚠️ Error fetching market data for CYBER/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=CYBERUSDT&category=spot
# ⚠️ Error fetching market data for ORDI/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ORDIUSDT&category=spot
# ⚠️ Error fetching market data for KAVA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=KAVAUSDT&category=spot
# ⚠️ Error fetching market data for SAIL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SAILUSDT&category=spot
# ⚠️ Error fetching market data for PYUSD/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PYUSDUSDT&category=spot
# ⚠️ Error fetching market data for VEXT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=VEXTUSDT&category=spot
# ⚠️ Error fetching market data for CTT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=CTTUSDT&category=spot
# ⚠️ Error fetching market data for KAS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=KASUSDT&category=spot
# ⚠️ Error fetching market data for NESS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=NESSUSDT&category=spot
# ⚠️ Error fetching market data for FET/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FETUSDT&category=spot
# ⚠️ Error fetching market data for LEVER/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=LEVERUSDT&category=spot
# ⚠️ Error fetching market data for ZTX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ZTXUSDT&category=spot
# ⚠️ Error fetching market data for JEFF/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=JEFFUSDT&category=spot
# ⚠️ Error fetching market data for PPT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PPTUSDT&category=spot
# ⚠️ Error fetching market data for TUSD/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TUSDUSDT&category=spot
# ⚠️ Error fetching market data for BEAM/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BEAMUSDT&category=spot
# ⚠️ Error fetching market data for POL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=POLUSDT&category=spot
# ⚠️ Error fetching market data for TIA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TIAUSDT&category=spot
# ⚠️ Error fetching market data for TOKEN/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TOKENUSDT&category=spot
# ⚠️ Error fetching market data for MEME/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MEMEUSDT&category=spot
# ⚠️ Error fetching market data for SHRAP/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SHRAPUSDT&category=spot
# ⚠️ Error fetching market data for RPK/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=RPKUSDT&category=spot
# ⚠️ Error fetching market data for FLIP/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FLIPUSDT&category=spot
# ⚠️ Error fetching market data for VRTX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=VRTXUSDT&category=spot
# ⚠️ Error fetching market data for ROOT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ROOTUSDT&category=spot
# ⚠️ Error fetching market data for PYTH/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PYTHUSDT&category=spot
# ⚠️ Error fetching market data for MLK/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MLKUSDT&category=spot
# ⚠️ Error fetching market data for KUB/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=KUBUSDT&category=spot
# ⚠️ Error fetching market data for 5IRE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=5IREUSDT&category=spot
# ⚠️ Error fetching market data for KCS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=KCSUSDT&category=spot
# ⚠️ Error fetching market data for VANRY/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=VANRYUSDT&category=spot
# ⚠️ Error fetching market data for INSP/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=INSPUSDT&category=spot
# ⚠️ Error fetching market data for JTO/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=JTOUSDT&category=spot
# ⚠️ Error fetching market data for METH/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=METHUSDT&category=spot
# ⚠️ Error fetching market data for CBK/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=CBKUSDT&category=spot
# ⚠️ Error fetching market data for ZIG/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ZIGUSDT&category=spot
# ⚠️ Error fetching market data for VPR/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=VPRUSDT&category=spot
# ⚠️ Error fetching market data for TRC/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TRCUSDT&category=spot
# ⚠️ Error fetching market data for FMC/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FMCUSDT&category=spot
# ⚠️ Error fetching market data for MYRIA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MYRIAUSDT&category=spot
# ⚠️ Error fetching market data for AKI/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=AKIUSDT&category=spot
# ⚠️ Error fetching market data for MBOX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MBOXUSDT&category=spot
# ⚠️ Error fetching market data for IRL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=IRLUSDT&category=spot
# ⚠️ Error fetching market data for ARTY/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ARTYUSDT&category=spot
# ⚠️ Error fetching market data for GRAPE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=GRAPEUSDT&category=spot
# ⚠️ Error fetching market data for COQ/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=COQUSDT&category=spot
# ⚠️ Error fetching market data for AIOZ/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=AIOZUSDT&category=spot
# ⚠️ Error fetching market data for GG/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=GGUSDT&category=spot
# ⚠️ Error fetching market data for VIC/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=VICUSDT&category=spot
# ⚠️ Error fetching market data for RATS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=RATSUSDT&category=spot
# ⚠️ Error fetching market data for SATS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SATSUSDT&category=spot
# ⚠️ Error fetching market data for PORT3/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PORT3USDT&category=spot
# ⚠️ Error fetching market data for XAI/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=XAIUSDT&category=spot
# ⚠️ Error fetching market data for ONDO/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ONDOUSDT&category=spot
# ⚠️ Error fetching market data for FAR/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FARUSDT&category=spot
# ⚠️ Error fetching market data for SQR/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SQRUSDT&category=spot
# ⚠️ Error fetching market data for DUEL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=DUELUSDT&category=spot
# ⚠️ Error fetching market data for APP/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=APPUSDT&category=spot
# ⚠️ Error fetching market data for SAROS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SAROSUSDT&category=spot
# ⚠️ Error fetching market data for USDY/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=USDYUSDT&category=spot
# ⚠️ Error fetching market data for MANTA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MANTAUSDT&category=spot
# ⚠️ Error fetching market data for MYRO/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MYROUSDT&category=spot
# ⚠️ Error fetching market data for GTAI/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=GTAIUSDT&category=spot
# ⚠️ Error fetching market data for DMAIL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=DMAILUSDT&category=spot
# ⚠️ Error fetching market data for AFG/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=AFGUSDT&category=spot
# ⚠️ Error fetching market data for DYM/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=DYMUSDT&category=spot
# ⚠️ Error fetching market data for ZETA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ZETAUSDT&category=spot
# ⚠️ Error fetching market data for JUP/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=JUPUSDT&category=spot
# ⚠️ Error fetching market data for MXM/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MXMUSDT&category=spot
# ⚠️ Error fetching market data for DEFI/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=DEFIUSDT&category=spot
# ⚠️ Error fetching market data for FIRE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FIREUSDT&category=spot
# ⚠️ Error fetching market data for MAVIA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MAVIAUSDT&category=spot
# ⚠️ Error fetching market data for PURSE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PURSEUSDT&category=spot
# ⚠️ Error fetching market data for BCUT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BCUTUSDT&category=spot
# ⚠️ Error fetching market data for ALT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ALTUSDT&category=spot
# ⚠️ Error fetching market data for HTX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=HTXUSDT&category=spot
# ⚠️ Error fetching market data for CSPR/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=CSPRUSDT&category=spot
# ⚠️ Error fetching market data for STRK/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=STRKUSDT&category=spot
# ⚠️ Error fetching market data for CPOOL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=CPOOLUSDT&category=spot
# ⚠️ Error fetching market data for QORPO/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=QORPOUSDT&category=spot
# ⚠️ Error fetching market data for BBL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BBLUSDT&category=spot
# ⚠️ Error fetching market data for SQT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SQTUSDT&category=spot
# ✅ Found 294 tradable tokens on Bybit
# ✅ Found 538 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 538 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 425 tradable tokens on Bybit
# ✅ Found 535 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 425 tradable tokens on Bybit
# ✅ Found 534 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 425 tradable tokens on Bybit
# ✅ Found 533 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 533 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 535 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 535 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 535 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 534 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 427 tradable tokens on Bybit
# ✅ Found 535 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 426 tradable tokens on Bybit
# ✅ Found 536 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 427 tradable tokens on Bybit
# ✅ Found 538 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 428 tradable tokens on Bybit
# ✅ Found 539 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ⚠️ Error fetching market data for ETH/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ETHUSDT&category=spot
# ⚠️ Error fetching market data for XRP/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=XRPUSDT&category=spot
# ⚠️ Error fetching market data for EOS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=EOSUSDT&category=spot
# ⚠️ Error fetching market data for DOT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=DOTUSDT&category=spot
# ⚠️ Error fetching market data for XLM/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=XLMUSDT&category=spot
# ⚠️ Error fetching market data for LTC/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=LTCUSDT&category=spot
# ⚠️ Error fetching market data for DOGE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=DOGEUSDT&category=spot
# ⚠️ Error fetching market data for CHZ/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=CHZUSDT&category=spot
# ⚠️ Error fetching market data for AXS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=AXSUSDT&category=spot
# ⚠️ Error fetching market data for MANA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MANAUSDT&category=spot
# ⚠️ Error fetching market data for DYDX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=DYDXUSDT&category=spot
# ⚠️ Error fetching market data for MKR/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MKRUSDT&category=spot
# ⚠️ Error fetching market data for COMP/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=COMPUSDT&category=spot
# ⚠️ Error fetching market data for AAVE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=AAVEUSDT&category=spot
# ⚠️ Error fetching market data for YFI/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=YFIUSDT&category=spot
# ⚠️ Error fetching market data for LINK/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=LINKUSDT&category=spot
# ⚠️ Error fetching market data for SUSHI/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SUSHIUSDT&category=spot
# ⚠️ Error fetching market data for UNI/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=UNIUSDT&category=spot
# ⚠️ Error fetching market data for KSM/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=KSMUSDT&category=spot
# ⚠️ Error fetching market data for ICP/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ICPUSDT&category=spot
# ⚠️ Error fetching market data for ADA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ADAUSDT&category=spot
# ⚠️ Error fetching market data for ETC/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ETCUSDT&category=spot
# ⚠️ Error fetching market data for XTZ/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=XTZUSDT&category=spot
# ⚠️ Error fetching market data for BCH/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BCHUSDT&category=spot
# ⚠️ Error fetching market data for QNT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=QNTUSDT&category=spot
# ⚠️ Error fetching market data for USDC/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=USDCUSDT&category=spot
# ⚠️ Error fetching market data for GRT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=GRTUSDT&category=spot
# ⚠️ Error fetching market data for SOL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SOLUSDT&category=spot
# ⚠️ Error fetching market data for FIL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FILUSDT&category=spot
# ⚠️ Error fetching market data for OMG/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=OMGUSDT&category=spot
# ⚠️ Error fetching market data for BAT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BATUSDT&category=spot
# ⚠️ Error fetching market data for ZRX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ZRXUSDT&category=spot
# ⚠️ Error fetching market data for CRV/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=CRVUSDT&category=spot
# ⚠️ Error fetching market data for AGLD/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=AGLDUSDT&category=spot
# ⚠️ Error fetching market data for ANKR/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ANKRUSDT&category=spot
# ⚠️ Error fetching market data for PERP/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PERPUSDT&category=spot
# ⚠️ Error fetching market data for WAVES/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=WAVESUSDT&category=spot
# ⚠️ Error fetching market data for LUNC/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=LUNCUSDT&category=spot
# ⚠️ Error fetching market data for SPELL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SPELLUSDT&category=spot
# ⚠️ Error fetching market data for SHIB/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SHIBUSDT&category=spot
# ⚠️ Error fetching market data for ATOM/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ATOMUSDT&category=spot
# ⚠️ Error fetching market data for ALGO/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ALGOUSDT&category=spot
# ⚠️ Error fetching market data for ENJ/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ENJUSDT&category=spot
# ⚠️ Error fetching market data for SAND/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SANDUSDT&category=spot
# ⚠️ Error fetching market data for AVAX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=AVAXUSDT&category=spot
# ⚠️ Error fetching market data for WOO/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=WOOUSDT&category=spot
# ⚠️ Error fetching market data for FTT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FTTUSDT&category=spot
# ⚠️ Error fetching market data for GODS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=GODSUSDT&category=spot
# ⚠️ Error fetching market data for IMX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=IMXUSDT&category=spot
# ⚠️ Error fetching market data for ENS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ENSUSDT&category=spot
# ⚠️ Error fetching market data for CAKE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=CAKEUSDT&category=spot
# ⚠️ Error fetching market data for STETH/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=STETHUSDT&category=spot
# ⚠️ Error fetching market data for GALFT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=GALFTUSDT&category=spot
# ⚠️ Error fetching market data for SLP/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SLPUSDT&category=spot
# ⚠️ Error fetching market data for C98/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=C98USDT&category=spot
# ⚠️ Error fetching market data for GENE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=GENEUSDT&category=spot
# ⚠️ Error fetching market data for AVA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=AVAUSDT&category=spot
# ⚠️ Error fetching market data for ONE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ONEUSDT&category=spot
# ⚠️ Error fetching market data for PTU/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PTUUSDT&category=spot
# ⚠️ Error fetching market data for XYM/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=XYMUSDT&category=spot
# ⚠️ Error fetching market data for BOBA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BOBAUSDT&category=spot
# ⚠️ Error fetching market data for JASMY/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=JASMYUSDT&category=spot
# ⚠️ Error fetching market data for GALA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=GALAUSDT&category=spot
# ⚠️ Error fetching market data for TRVL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TRVLUSDT&category=spot
# ⚠️ Error fetching market data for WEMIX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=WEMIXUSDT&category=spot
# ⚠️ Error fetching market data for XEM/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=XEMUSDT&category=spot
# ⚠️ Error fetching market data for BICO/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BICOUSDT&category=spot
# ⚠️ Error fetching market data for CEL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=CELUSDT&category=spot
# ⚠️ Error fetching market data for UMA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=UMAUSDT&category=spot
# ⚠️ Error fetching market data for HOT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=HOTUSDT&category=spot
# ⚠️ Error fetching market data for NEXO/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=NEXOUSDT&category=spot
# ⚠️ Error fetching market data for SNX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SNXUSDT&category=spot
# ⚠️ Error fetching market data for REN/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=RENUSDT&category=spot
# ⚠️ Error fetching market data for 1INCH/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=1INCHUSDT&category=spot
# ⚠️ Error fetching market data for TEL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TELUSDT&category=spot
# ⚠️ Error fetching market data for SIS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SISUSDT&category=spot
# ⚠️ Error fetching market data for LRC/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=LRCUSDT&category=spot
# ⚠️ Error fetching market data for LDO/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=LDOUSDT&category=spot
# ⚠️ Error fetching market data for REAL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=REALUSDT&category=spot
# ⚠️ Error fetching market data for 1SOL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=1SOLUSDT&category=spot
# ⚠️ Error fetching market data for PLT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PLTUSDT&category=spot
# ⚠️ Error fetching market data for IZI/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=IZIUSDT&category=spot
# ⚠️ Error fetching market data for QTUM/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=QTUMUSDT&category=spot
# ⚠️ Error fetching market data for ZEN/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ZENUSDT&category=spot
# ⚠️ Error fetching market data for THETA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=THETAUSDT&category=spot
# ⚠️ Error fetching market data for MX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MXUSDT&category=spot
# ⚠️ Error fetching market data for DGB/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=DGBUSDT&category=spot
# ⚠️ Error fetching market data for RVN/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=RVNUSDT&category=spot
# ⚠️ Error fetching market data for EGLD/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=EGLDUSDT&category=spot
# ⚠️ Error fetching market data for RUNE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=RUNEUSDT&category=spot
# ⚠️ Error fetching market data for RAIN/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=RAINUSDT&category=spot
# ⚠️ Error fetching market data for XEC/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=XECUSDT&category=spot
# ⚠️ Error fetching market data for ICX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ICXUSDT&category=spot
# ⚠️ Error fetching market data for XDC/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=XDCUSDT&category=spot
# ⚠️ Error fetching market data for HNT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=HNTUSDT&category=spot
# ⚠️ Error fetching market data for ZIL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ZILUSDT&category=spot
# ⚠️ Error fetching market data for HBAR/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=HBARUSDT&category=spot
# ⚠️ Error fetching market data for FLOW/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FLOWUSDT&category=spot
# ⚠️ Error fetching market data for KASTA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=KASTAUSDT&category=spot
# ⚠️ Error fetching market data for STX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=STXUSDT&category=spot
# ⚠️ Error fetching market data for SIDUS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SIDUSUSDT&category=spot
# ⚠️ Error fetching market data for VPAD/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=VPADUSDT&category=spot
# ⚠️ Error fetching market data for LOOKS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=LOOKSUSDT&category=spot
# ⚠️ Error fetching market data for MBS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MBSUSDT&category=spot
# ⚠️ Error fetching market data for DAI/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=DAIUSDT&category=spot
# ⚠️ Error fetching market data for ACA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ACAUSDT&category=spot
# ⚠️ Error fetching market data for MV/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MVUSDT&category=spot
# ⚠️ Error fetching market data for MIX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MIXUSDT&category=spot
# ⚠️ Error fetching market data for RSS3/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=RSS3USDT&category=spot
# ⚠️ Error fetching market data for TAP/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TAPUSDT&category=spot
# ⚠️ Error fetching market data for ERTHA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ERTHAUSDT&category=spot
# ⚠️ Error fetching market data for GMX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=GMXUSDT&category=spot
# ⚠️ Error fetching market data for ACH/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ACHUSDT&category=spot
# ⚠️ Error fetching market data for JST/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=JSTUSDT&category=spot
# ⚠️ Error fetching market data for SUN/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SUNUSDT&category=spot
# ⚠️ Error fetching market data for BTT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BTTUSDT&category=spot
# ⚠️ Error fetching market data for TRX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=TRXUSDT&category=spot
# ⚠️ Error fetching market data for NFT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=NFTUSDT&category=spot
# ⚠️ Error fetching market data for POKT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=POKTUSDT&category=spot
# ⚠️ Error fetching market data for SCRT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SCRTUSDT&category=spot
# ⚠️ Error fetching market data for PSTAKE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=PSTAKEUSDT&category=spot
# ⚠️ Error fetching market data for SON/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SONUSDT&category=spot
# ⚠️ Error fetching market data for DOME/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=DOMEUSDT&category=spot
# ⚠️ Error fetching market data for USTC/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=USTCUSDT&category=spot
# ⚠️ Error fetching market data for BNB/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BNBUSDT&category=spot
# ⚠️ Error fetching market data for NEAR/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=NEARUSDT&category=spot
# ⚠️ Error fetching market data for SD/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SDUSDT&category=spot
# ⚠️ Error fetching market data for APE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=APEUSDT&category=spot
# ⚠️ Error fetching market data for BTC3S/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BTC3SUSDT&category=spot
# ⚠️ Error fetching market data for BTC3L/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BTC3LUSDT&category=spot
# ⚠️ Error fetching market data for FIDA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FIDAUSDT&category=spot
# ⚠️ Error fetching market data for MINA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MINAUSDT&category=spot
# ⚠️ Error fetching market data for SC/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SCUSDT&category=spot
# ⚠️ Error fetching market data for RACA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=RACAUSDT&category=spot
# ⚠️ Error fetching market data for CAPS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=CAPSUSDT&category=spot
# ⚠️ Error fetching market data for STG/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=STGUSDT&category=spot
# ⚠️ Error fetching market data for GLMR/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=GLMRUSDT&category=spot
# ⚠️ Error fetching market data for MOVR/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=MOVRUSDT&category=spot
# ⚠️ Error fetching market data for WBTC/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=WBTCUSDT&category=spot
# ⚠️ Error fetching market data for XAVA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=XAVAUSDT&category=spot
# ⚠️ Error fetching market data for GMT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=GMTUSDT&category=spot
# ⚠️ Error fetching market data for GST/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=GSTUSDT&category=spot
# ⚠️ Error fetching market data for CELO/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=CELOUSDT&category=spot
# ⚠️ Error fetching market data for SFUND/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SFUNDUSDT&category=spot
# ⚠️ Error fetching market data for LGX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=LGXUSDT&category=spot
# ⚠️ Error fetching market data for APEX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=APEXUSDT&category=spot
# ⚠️ Error fetching market data for CTC/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=CTCUSDT&category=spot
# ⚠️ Error fetching market data for COT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=COTUSDT&category=spot
# ⚠️ Error fetching market data for FITFI/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FITFIUSDT&category=spot
# ⚠️ Error fetching market data for ETH3S/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ETH3SUSDT&category=spot
# ⚠️ Error fetching market data for ETH3L/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ETH3LUSDT&category=spot
# ⚠️ Error fetching market data for FAME/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FAMEUSDT&category=spot
# ⚠️ Error fetching market data for USDD/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=USDDUSDT&category=spot
# ⚠️ Error fetching market data for OP/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=OPUSDT&category=spot
# ⚠️ Error fetching market data for LUNA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=LUNAUSDT&category=spot
# ⚠️ Error fetching market data for THN/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=THNUSDT&category=spot
# ⚠️ Error fetching market data for VINU/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=VINUUSDT&category=spot
# ⚠️ Error fetching market data for BEL/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BELUSDT&category=spot
# ⚠️ Error fetching market data for FORT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FORTUSDT&category=spot
# ⚠️ Error fetching market data for WLKN/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=WLKNUSDT&category=spot
# ⚠️ Error fetching market data for KON/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=KONUSDT&category=spot
# ⚠️ Error fetching market data for OBX/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=OBXUSDT&category=spot
# ⚠️ Error fetching market data for SEOR/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=SEORUSDT&category=spot
# ⚠️ Error fetching market data for CUSD/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=CUSDUSDT&category=spot
# ⚠️ Error fetching market data for GSTS/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=GSTSUSDT&category=spot
# ⚠️ Error fetching market data for XETA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=XETAUSDT&category=spot
# ⚠️ Error fetching market data for FLOKI/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=FLOKIUSDT&category=spot
# ⚠️ Error fetching market data for BABYDOGE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=BABYDOGEUSDT&category=spot
# ⚠️ Error fetching market data for STAT/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=STATUSDT&category=spot
# ⚠️ Error fetching market data for DICE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=DICEUSDT&category=spot
# ⚠️ Error fetching market data for WAXP/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=WAXPUSDT&category=spot
# ⚠️ Error fetching market data for AR/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ARUSDT&category=spot
# ⚠️ Error fetching market data for KDA/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=KDAUSDT&category=spot
# ⚠️ Error fetching market data for ROSE/USDT on Bybit: bybit GET https://api.bybit.com/v5/market/tickers?symbol=ROSEUSDT&category=spot
# ✅ Found 294 tradable tokens on Bybit
# ✅ Found 539 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 427 tradable tokens on Bybit
# ✅ Found 539 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 427 tradable tokens on Bybit
# ✅ Found 539 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 427 tradable tokens on Bybit
# ✅ Found 539 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
# ✅ Found 427 tradable tokens on Bybit
# ✅ Found 539 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bybit and Bitget...
# ✅ Completed this cycle. Waiting for next check...
