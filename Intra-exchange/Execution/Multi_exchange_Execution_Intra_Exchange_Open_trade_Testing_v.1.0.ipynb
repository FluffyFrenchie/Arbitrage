# %%
# Script Name: Option_1 (Arbitrage Bot - Clean, Accurate, Manual Execution)
import ccxt
import time
import datetime
from zoneinfo import ZoneInfo
import json
import os

# API Keys (Bybit and Bitget only for this trial)
BYBIT_API_KEY = 'I6m01uNAWiensHbIBA'
BYBIT_API_SECRET = 'vkaviS9xw903NJPncMtHgGfyiWB4mnhSJTyK'
BITGET_API_KEY = 'bg_b0a9d721607623216a87b066a3df34c3'
BITGET_API_SECRET = '6c4a5016562624b6d7f3b1c59563d4a1a573f630e0e49422fbf509399e56918b'
BITGET_API_PASSWORD = 'BgSecure789Trade2025'

# --- CONFIG ---
SPREAD_THRESHOLD = 0.7 / 100
ADD_POSITION_USDT = 15
TRADE_USDT_SIZE = 30
MIN_VOLUME = 50000
CHECK_INTERVAL = 1
LOCAL_TIMEZONE = ZoneInfo("Asia/Jakarta")
TRADE_FILE = 'open_trades.json'

TRADING_FEES = {'Bybit': 0.001, 'Bitget': 0.0008}
futures_markets_cache = {}
exchanges = {}

# --- INIT EXCHANGES ---
bybit = ccxt.bybit({
    'apiKey': BYBIT_API_KEY,
    'secret': BYBIT_API_SECRET,
    'enableRateLimit': True,
    'options': {'defaultType': 'spot'}
})
bitget = ccxt.bitget({
    'apiKey': BITGET_API_KEY,
    'secret': BITGET_API_SECRET,
    'password': BITGET_API_PASSWORD,
    'enableRateLimit': True,
    'options': {'defaultType': 'spot'}
})
exchanges = {'Bybit': bybit, 'Bitget': bitget}

# %%
# --- STORAGE ---
def load_open_trades():
    if os.path.exists(TRADE_FILE):
        with open(TRADE_FILE, 'r') as f:
            return json.load(f)
    return {}

def save_open_trades(trades):
    with open(TRADE_FILE, 'w') as f:
        json.dump(trades, f, indent=2)

open_trades = load_open_trades()

# --- HELPERS ---
def get_price(exchange, symbol):
    try:
        return exchange.fetch_ticker(symbol).get("last")
    except:
        return None

def get_best_bid_ask(exchange, symbol):
    ob = exchange.fetch_order_book(symbol)
    bid = ob['bids'][0][0] if ob['bids'] else None
    ask = ob['asks'][0][0] if ob['asks'] else None
    return bid, ask

def find_futures_symbol(spot_symbol, futures_list):
    base = spot_symbol.split('/')[0]
    return next((f for f in futures_list if f.startswith(f"{base}/USDT") or f.startswith(f"{base}-USDT")), None)

def get_tradable_tokens(exchange, exchange_name):
    try:
        markets = exchange.load_markets()
        tradable = []
        futures_markets_cache[exchange_name] = [s for s in markets if ":USDT" in s or "-USDT-SWAP" in s]
        for s, m in markets.items():
            if exchange_name == "Bitget" and not m.get('spot'): continue
            if '/USDT' in s and ':USDT' not in s and '-USDT-SWAP' not in s:
                try:
                    vol = exchange.fetch_ticker(s).get('quoteVolume', 0)
                    if vol and vol >= MIN_VOLUME:
                        tradable.append(s)
                except: continue
        return tradable
    except: return []

def ask_user_permission(symbol, spread, net_profit):
    ans = input(f"\n🔍 Opportunity: {symbol} | Spread: {spread:.4%} | Net: {net_profit:.4%}. Execute? (yes/no): ").strip().lower()
    return ans == 'yes'

def execute_trade(exchange_name, symbol, usdt_size):
    try:
        exchange = exchanges[exchange_name]
        spot_price = get_price(exchange, symbol)
        if not spot_price:
            print(f"❌ No spot price for {symbol}")
            return

        futures_list = futures_markets_cache.get(exchange_name, [])
        futures_symbol = find_futures_symbol(symbol, futures_list)
        if not futures_symbol:
            print(f"❌ No futures match for {symbol}")
            return

        amount = usdt_size / spot_price
        best_bid, _ = get_best_bid_ask(exchange, symbol)
        order = exchange.create_order(symbol=symbol, type='limit', side='buy', amount=amount, price=best_bid)

        wait_time, filled = 0, 0
        while wait_time < 15:
            o = exchange.fetch_order(order['id'], symbol)
            filled = o['filled']
            if filled > 0: break
            new_price = get_best_bid_ask(exchange, symbol)[0]
            if o['price'] != new_price:
                exchange.cancel_order(order['id'], symbol)
                order = exchange.create_order(symbol=symbol, type='limit', side='buy', amount=amount, price=new_price)
            time.sleep(1)
            wait_time += 1

        if filled == 0:
            exchange.cancel_order(order['id'], symbol)
            print("❌ Spot order not filled. Skipped.")
            return

        if exchange_name == 'Bybit':
            fut = ccxt.bybit({'apiKey': BYBIT_API_KEY, 'secret': BYBIT_API_SECRET, 'options': {'defaultType': 'future'}})
        else:
            fut = ccxt.bitget({'apiKey': BITGET_API_KEY, 'secret': BITGET_API_SECRET, 'password': BITGET_API_PASSWORD, 'options': {'defaultType': 'swap'}})
        fut.load_markets()
        fut.set_leverage(1, futures_symbol)
        fut.create_order(symbol=futures_symbol, type='market', side='sell', amount=filled)

        entry_spread = (get_price(fut, futures_symbol) - spot_price) / spot_price
        trade_id = f"{symbol.replace('/', '')}_{int(time.time())}"
        open_trades[trade_id] = {
            "symbol": symbol,
            "exchange": exchange_name,
            "amount": filled,
            "spot_price": spot_price,
            "futures_price": get_price(fut, futures_symbol),
            "entry_spread": entry_spread,
            "timestamp": datetime.datetime.now().isoformat()
        }
        save_open_trades(open_trades)
        print(f"✅ Executed & saved: {trade_id}")
    except Exception as e:
        print(f"❌ Execution error: {e}")

def check_arbitrage(exchange, exchange_name, symbol):
    spot_price = get_price(exchange, symbol)
    futures_symbol = find_futures_symbol(symbol, futures_markets_cache.get(exchange_name, []))
    if not futures_symbol: return

    futures_price = get_price(exchange, futures_symbol)
    if not spot_price or not futures_price: return

    spread = (futures_price - spot_price) / spot_price
    net_profit = spread - TRADING_FEES[exchange_name] * 2

    timestamp = datetime.datetime.now(LOCAL_TIMEZONE).strftime('%Y-%m-%d %H:%M:%S %Z')
    print(f"🔎 Arbitrage Opportunity on {exchange_name}: {symbol} | {timestamp}")
    print(f"  ✅ Spot Price: {spot_price:.5f} USDT")
    print(f"  ✅ Futures Price: {futures_price:.5f} USDT")
    print(f"  ✅ Spread: {spread:.4%}")
    print(f"  ✅ Net Profit After Fees: {net_profit:.4%}")

    print(f"⚠️  Arbitrage Signal on {exchange_name} - {symbol}")
    print(f"Spread: {spread:.4%} | Net Profit: {net_profit:.4%}")

    for tid, t in open_trades.items():
        if t['symbol'] == symbol and t['exchange'] == exchange_name:
            if spread - t['entry_spread'] >= 0.005:
                print(f"🔁 Spread increased +0.5%, eligible to scale position.")
                if ask_user_permission(symbol, spread, net_profit):
                    execute_trade(exchange_name, symbol, ADD_POSITION_USDT)
            return

    if net_profit >= SPREAD_THRESHOLD:
        if ask_user_permission(symbol, spread, net_profit):
            execute_trade(exchange_name, symbol, TRADE_USDT_SIZE)

def process_tokens(exchange, exchange_name, tokens):
    for token in tokens:
        check_arbitrage(exchange, exchange_name, token)

def main():
    while True:
        try:
            for name, ex in exchanges.items():
                tokens = get_tradable_tokens(ex, name)
                process_tokens(ex, name, tokens)
            time.sleep(CHECK_INTERVAL)
        except Exception as e:
            print(f"❌ Loop error: {e}")
            time.sleep(5)

if __name__ == '__main__':
    main()
# Out:
# 🔎 Arbitrage Opportunity on Bybit: BTC/USDT | 2025-04-12 01:30:53 WIB
#   ✅ Spot Price: 83975.00000 USDT
#   ✅ Futures Price: 83945.60000 USDT
#   ✅ Spread: -0.0350%
#   ✅ Net Profit After Fees: -0.2350%
# ⚠️  Arbitrage Signal on Bybit - BTC/USDT
# Spread: -0.0350% | Net Profit: -0.2350%
# 🔎 Arbitrage Opportunity on Bybit: ETH/USDT | 2025-04-12 01:30:53 WIB
#   ✅ Spot Price: 1573.61000 USDT
#   ✅ Futures Price: 1572.80000 USDT
#   ✅ Spread: -0.0515%
#   ✅ Net Profit After Fees: -0.2515%
# ⚠️  Arbitrage Signal on Bybit - ETH/USDT
# Spread: -0.0515% | Net Profit: -0.2515%
# 🔎 Arbitrage Opportunity on Bybit: XRP/USDT | 2025-04-12 01:30:53 WIB
#   ✅ Spot Price: 2.06060 USDT
#   ✅ Futures Price: 2.05950 USDT
#   ✅ Spread: -0.0534%
#   ✅ Net Profit After Fees: -0.2534%
# ⚠️  Arbitrage Signal on Bybit - XRP/USDT
# Spread: -0.0534% | Net Profit: -0.2534%
# 🔎 Arbitrage Opportunity on Bybit: EOS/USDT | 2025-04-12 01:30:53 WIB
#   ✅ Spot Price: 0.62980 USDT
#   ✅ Futures Price: 0.62940 USDT
#   ✅ Spread: -0.0635%
#   ✅ Net Profit After Fees: -0.2635%
# ⚠️  Arbitrage Signal on Bybit - EOS/USDT
# Spread: -0.0635% | Net Profit: -0.2635%
# 🔎 Arbitrage Opportunity on Bybit: DOT/USDT | 2025-04-12 01:30:53 WIB
#   ✅ Spot Price: 3.59300 USDT
#   ✅ Futures Price: 3.59050 USDT
#   ✅ Spread: -0.0696%
#   ✅ Net Profit After Fees: -0.2696%
# ⚠️  Arbitrage Signal on Bybit - DOT/USDT
# Spread: -0.0696% | Net Profit: -0.2696%
# 🔎 Arbitrage Opportunity on Bybit: XLM/USDT | 2025-04-12 01:30:54 WIB
#   ✅ Spot Price: 0.23570 USDT
#   ✅ Futures Price: 0.23547 USDT
#   ✅ Spread: -0.0976%
#   ✅ Net Profit After Fees: -0.2976%
# ⚠️  Arbitrage Signal on Bybit - XLM/USDT
# Spread: -0.0976% | Net Profit: -0.2976%
# 🔎 Arbitrage Opportunity on Bybit: LTC/USDT | 2025-04-12 01:30:54 WIB
#   ✅ Spot Price: 77.12000 USDT
#   ✅ Futures Price: 77.08000 USDT
#   ✅ Spread: -0.0519%
#   ✅ Net Profit After Fees: -0.2519%
# ⚠️  Arbitrage Signal on Bybit - LTC/USDT
# Spread: -0.0519% | Net Profit: -0.2519%
# 🔎 Arbitrage Opportunity on Bybit: DOGE/USDT | 2025-04-12 01:30:54 WIB
#   ✅ Spot Price: 0.16083 USDT
#   ✅ Futures Price: 0.16073 USDT
#   ✅ Spread: -0.0622%
#   ✅ Net Profit After Fees: -0.2622%
# ⚠️  Arbitrage Signal on Bybit - DOGE/USDT
# Spread: -0.0622% | Net Profit: -0.2622%
# 🔎 Arbitrage Opportunity on Bybit: CHZ/USDT | 2025-04-12 01:30:54 WIB
#   ✅ Spot Price: 0.04000 USDT
#   ✅ Futures Price: 0.03991 USDT
#   ✅ Spread: -0.2250%
#   ✅ Net Profit After Fees: -0.4250%
# ⚠️  Arbitrage Signal on Bybit - CHZ/USDT
# Spread: -0.2250% | Net Profit: -0.4250%
# 🔎 Arbitrage Opportunity on Bybit: AXS/USDT | 2025-04-12 01:30:54 WIB
#   ✅ Spot Price: 2.43600 USDT
#   ✅ Futures Price: 2.42300 USDT
#   ✅ Spread: -0.5337%
#   ✅ Net Profit After Fees: -0.7337%
# ⚠️  Arbitrage Signal on Bybit - AXS/USDT
# Spread: -0.5337% | Net Profit: -0.7337%
# 🔎 Arbitrage Opportunity on Bybit: MANA/USDT | 2025-04-12 01:30:55 WIB
#   ✅ Spot Price: 0.25300 USDT
#   ✅ Futures Price: 0.25260 USDT
#   ✅ Spread: -0.1581%
#   ✅ Net Profit After Fees: -0.3581%
# ⚠️  Arbitrage Signal on Bybit - MANA/USDT
# Spread: -0.1581% | Net Profit: -0.3581%
# 🔎 Arbitrage Opportunity on Bybit: DYDX/USDT | 2025-04-12 01:30:55 WIB
#   ✅ Spot Price: 0.56370 USDT
#   ✅ Futures Price: 0.56320 USDT
#   ✅ Spread: -0.0887%
#   ✅ Net Profit After Fees: -0.2887%
# ⚠️  Arbitrage Signal on Bybit - DYDX/USDT
# Spread: -0.0887% | Net Profit: -0.2887%
# 🔎 Arbitrage Opportunity on Bybit: MKR/USDT | 2025-04-12 01:30:55 WIB
#   ✅ Spot Price: 1341.00000 USDT
#   ✅ Futures Price: 1338.20000 USDT
#   ✅ Spread: -0.2088%
#   ✅ Net Profit After Fees: -0.4088%
# ⚠️  Arbitrage Signal on Bybit - MKR/USDT
# Spread: -0.2088% | Net Profit: -0.4088%
# 🔎 Arbitrage Opportunity on Bybit: COMP/USDT | 2025-04-12 01:30:55 WIB
#   ✅ Spot Price: 40.80000 USDT
#   ✅ Futures Price: 40.74000 USDT
#   ✅ Spread: -0.1471%
#   ✅ Net Profit After Fees: -0.3471%
# ⚠️  Arbitrage Signal on Bybit - COMP/USDT
# Spread: -0.1471% | Net Profit: -0.3471%
# 🔎 Arbitrage Opportunity on Bybit: AAVE/USDT | 2025-04-12 01:30:55 WIB
#   ✅ Spot Price: 137.74000 USDT
#   ✅ Futures Price: 137.61000 USDT
#   ✅ Spread: -0.0944%
#   ✅ Net Profit After Fees: -0.2944%
# ⚠️  Arbitrage Signal on Bybit - AAVE/USDT
# Spread: -0.0944% | Net Profit: -0.2944%
# 🔎 Arbitrage Opportunity on Bybit: YFI/USDT | 2025-04-12 01:30:56 WIB
#   ✅ Spot Price: 4617.00000 USDT
#   ✅ Futures Price: 4615.00000 USDT
#   ✅ Spread: -0.0433%
#   ✅ Net Profit After Fees: -0.2433%
# ⚠️  Arbitrage Signal on Bybit - YFI/USDT
# Spread: -0.0433% | Net Profit: -0.2433%
# 🔎 Arbitrage Opportunity on Bybit: LINK/USDT | 2025-04-12 01:30:56 WIB
#   ✅ Spot Price: 12.77000 USDT
#   ✅ Futures Price: 12.76100 USDT
#   ✅ Spread: -0.0705%
#   ✅ Net Profit After Fees: -0.2705%
# ⚠️  Arbitrage Signal on Bybit - LINK/USDT
# Spread: -0.0705% | Net Profit: -0.2705%
# 🔎 Arbitrage Opportunity on Bybit: SUSHI/USDT | 2025-04-12 01:30:56 WIB
#   ✅ Spot Price: 0.56500 USDT
#   ✅ Futures Price: 0.56520 USDT
#   ✅ Spread: 0.0354%
#   ✅ Net Profit After Fees: -0.1646%
# ⚠️  Arbitrage Signal on Bybit - SUSHI/USDT
# Spread: 0.0354% | Net Profit: -0.1646%
# 🔎 Arbitrage Opportunity on Bybit: UNI/USDT | 2025-04-12 01:30:56 WIB
#   ✅ Spot Price: 5.30400 USDT
#   ✅ Futures Price: 5.29800 USDT
#   ✅ Spread: -0.1131%
#   ✅ Net Profit After Fees: -0.3131%
# ⚠️  Arbitrage Signal on Bybit - UNI/USDT
# Spread: -0.1131% | Net Profit: -0.3131%
# 🔎 Arbitrage Opportunity on Bybit: KSM/USDT | 2025-04-12 01:30:56 WIB
#   ✅ Spot Price: 13.60000 USDT
#   ✅ Futures Price: 13.60000 USDT
#   ✅ Spread: 0.0000%
#   ✅ Net Profit After Fees: -0.2000%
# ⚠️  Arbitrage Signal on Bybit - KSM/USDT
# Spread: 0.0000% | Net Profit: -0.2000%
# 🔎 Arbitrage Opportunity on Bybit: ICP/USDT | 2025-04-12 01:30:57 WIB
#   ✅ Spot Price: 5.03000 USDT
#   ✅ Futures Price: 5.02400 USDT
#   ✅ Spread: -0.1193%
#   ✅ Net Profit After Fees: -0.3193%
# ⚠️  Arbitrage Signal on Bybit - ICP/USDT
# Spread: -0.1193% | Net Profit: -0.3193%
# 🔎 Arbitrage Opportunity on Bybit: ADA/USDT | 2025-04-12 01:30:57 WIB
#   ✅ Spot Price: 0.63210 USDT
#   ✅ Futures Price: 0.63180 USDT
#   ✅ Spread: -0.0475%
#   ✅ Net Profit After Fees: -0.2475%
# ⚠️  Arbitrage Signal on Bybit - ADA/USDT
# Spread: -0.0475% | Net Profit: -0.2475%
# 🔎 Arbitrage Opportunity on Bybit: ETC/USDT | 2025-04-12 01:30:57 WIB
#   ✅ Spot Price: 15.23000 USDT
#   ✅ Futures Price: 15.21400 USDT
#   ✅ Spread: -0.1051%
#   ✅ Net Profit After Fees: -0.3051%
# ⚠️  Arbitrage Signal on Bybit - ETC/USDT
# Spread: -0.1051% | Net Profit: -0.3051%
# 🔎 Arbitrage Opportunity on Bybit: XTZ/USDT | 2025-04-12 01:30:57 WIB
#   ✅ Spot Price: 0.55600 USDT
#   ✅ Futures Price: 0.55420 USDT
#   ✅ Spread: -0.3237%
#   ✅ Net Profit After Fees: -0.5237%
# ⚠️  Arbitrage Signal on Bybit - XTZ/USDT
# Spread: -0.3237% | Net Profit: -0.5237%
# 🔎 Arbitrage Opportunity on Bybit: BCH/USDT | 2025-04-12 01:30:57 WIB
#   ✅ Spot Price: 314.30000 USDT
#   ✅ Futures Price: 314.00000 USDT
#   ✅ Spread: -0.0955%
#   ✅ Net Profit After Fees: -0.2955%
# ⚠️  Arbitrage Signal on Bybit - BCH/USDT
# Spread: -0.0955% | Net Profit: -0.2955%
# 🔎 Arbitrage Opportunity on Bybit: QNT/USDT | 2025-04-12 01:30:58 WIB
#   ✅ Spot Price: 66.19000 USDT
#   ✅ Futures Price: 66.09000 USDT
#   ✅ Spread: -0.1511%
#   ✅ Net Profit After Fees: -0.3511%
# ⚠️  Arbitrage Signal on Bybit - QNT/USDT
# Spread: -0.1511% | Net Profit: -0.3511%
# 🔎 Arbitrage Opportunity on Bybit: USDC/USDT | 2025-04-12 01:30:58 WIB
#   ✅ Spot Price: 1.00050 USDT
#   ✅ Futures Price: 1.00060 USDT
#   ✅ Spread: 0.0100%
#   ✅ Net Profit After Fees: -0.1900%
# ⚠️  Arbitrage Signal on Bybit - USDC/USDT
# Spread: 0.0100% | Net Profit: -0.1900%
# 🔎 Arbitrage Opportunity on Bybit: GRT/USDT | 2025-04-12 01:30:58 WIB
#   ✅ Spot Price: 0.07990 USDT
#   ✅ Futures Price: 0.07977 USDT
#   ✅ Spread: -0.1627%
#   ✅ Net Profit After Fees: -0.3627%
# ⚠️  Arbitrage Signal on Bybit - GRT/USDT
# Spread: -0.1627% | Net Profit: -0.3627%
# 🔎 Arbitrage Opportunity on Bybit: SOL/USDT | 2025-04-12 01:30:58 WIB
#   ✅ Spot Price: 121.32000 USDT
#   ✅ Futures Price: 121.27000 USDT
#   ✅ Spread: -0.0412%
#   ✅ Net Profit After Fees: -0.2412%
# ⚠️  Arbitrage Signal on Bybit - SOL/USDT
# Spread: -0.0412% | Net Profit: -0.2412%
# 🔎 Arbitrage Opportunity on Bybit: FIL/USDT | 2025-04-12 01:30:58 WIB
#   ✅ Spot Price: 2.46100 USDT
#   ✅ Futures Price: 2.45800 USDT
#   ✅ Spread: -0.1219%
#   ✅ Net Profit After Fees: -0.3219%
# ⚠️  Arbitrage Signal on Bybit - FIL/USDT
# Spread: -0.1219% | Net Profit: -0.3219%
# 🔎 Arbitrage Opportunity on Bybit: ZRX/USDT | 2025-04-12 01:30:59 WIB
#   ✅ Spot Price: 0.23750 USDT
#   ✅ Futures Price: 0.23740 USDT
#   ✅ Spread: -0.0421%
#   ✅ Net Profit After Fees: -0.2421%
# ⚠️  Arbitrage Signal on Bybit - ZRX/USDT
# Spread: -0.0421% | Net Profit: -0.2421%
# 🔎 Arbitrage Opportunity on Bybit: CRV/USDT | 2025-04-12 01:30:59 WIB
#   ✅ Spot Price: 0.62120 USDT
#   ✅ Futures Price: 0.62120 USDT
#   ✅ Spread: 0.0000%
#   ✅ Net Profit After Fees: -0.2000%
# ⚠️  Arbitrage Signal on Bybit - CRV/USDT
# Spread: 0.0000% | Net Profit: -0.2000%
# 🔎 Arbitrage Opportunity on Bybit: AGLD/USDT | 2025-04-12 01:30:59 WIB
#   ✅ Spot Price: 0.79600 USDT
#   ✅ Futures Price: 0.79700 USDT
#   ✅ Spread: 0.1256%
#   ✅ Net Profit After Fees: -0.0744%
# ⚠️  Arbitrage Signal on Bybit - AGLD/USDT
# Spread: 0.1256% | Net Profit: -0.0744%
# 🔎 Arbitrage Opportunity on Bybit: ANKR/USDT | 2025-04-12 01:30:59 WIB
#   ✅ Spot Price: 0.01673 USDT
#   ✅ Futures Price: 0.01675 USDT
#   ✅ Spread: 0.1195%
#   ✅ Net Profit After Fees: -0.0805%
# ⚠️  Arbitrage Signal on Bybit - ANKR/USDT
# Spread: 0.1195% | Net Profit: -0.0805%
# 🔎 Arbitrage Opportunity on Bybit: PERP/USDT | 2025-04-12 01:30:59 WIB
#   ✅ Spot Price: 0.19770 USDT
#   ✅ Futures Price: 0.19750 USDT
#   ✅ Spread: -0.1012%
#   ✅ Net Profit After Fees: -0.3012%
# ⚠️  Arbitrage Signal on Bybit - PERP/USDT
# Spread: -0.1012% | Net Profit: -0.3012%
# 🔎 Arbitrage Opportunity on Bybit: WAVES/USDT | 2025-04-12 01:31:00 WIB
#   ✅ Spot Price: 1.09700 USDT
#   ✅ Futures Price: 1.08540 USDT
#   ✅ Spread: -1.0574%
#   ✅ Net Profit After Fees: -1.2574%
# ⚠️  Arbitrage Signal on Bybit - WAVES/USDT
# Spread: -1.0574% | Net Profit: -1.2574%
# 🔎 Arbitrage Opportunity on Bybit: SPELL/USDT | 2025-04-12 01:31:00 WIB
#   ✅ Spot Price: 0.00061 USDT
#   ✅ Futures Price: 0.00060 USDT
#   ✅ Spread: -0.2638%
#   ✅ Net Profit After Fees: -0.4638%
# ⚠️  Arbitrage Signal on Bybit - SPELL/USDT
# Spread: -0.2638% | Net Profit: -0.4638%
# 🔎 Arbitrage Opportunity on Bybit: ATOM/USDT | 2025-04-12 01:31:00 WIB
#   ✅ Spot Price: 4.28300 USDT
#   ✅ Futures Price: 4.27800 USDT
#   ✅ Spread: -0.1167%
#   ✅ Net Profit After Fees: -0.3167%
# ⚠️  Arbitrage Signal on Bybit - ATOM/USDT
# Spread: -0.1167% | Net Profit: -0.3167%
# 🔎 Arbitrage Opportunity on Bybit: ALGO/USDT | 2025-04-12 01:31:00 WIB
#   ✅ Spot Price: 0.18500 USDT
#   ✅ Futures Price: 0.18480 USDT
#   ✅ Spread: -0.1081%
#   ✅ Net Profit After Fees: -0.3081%
# ⚠️  Arbitrage Signal on Bybit - ALGO/USDT
# Spread: -0.1081% | Net Profit: -0.3081%
# 🔎 Arbitrage Opportunity on Bybit: ENJ/USDT | 2025-04-12 01:31:01 WIB
#   ✅ Spot Price: 0.06715 USDT
#   ✅ Futures Price: 0.06702 USDT
#   ✅ Spread: -0.1936%
#   ✅ Net Profit After Fees: -0.3936%
# ⚠️  Arbitrage Signal on Bybit - ENJ/USDT
# Spread: -0.1936% | Net Profit: -0.3936%
# 🔎 Arbitrage Opportunity on Bybit: SAND/USDT | 2025-04-12 01:31:01 WIB
#   ✅ Spot Price: 0.26310 USDT
#   ✅ Futures Price: 0.26280 USDT
#   ✅ Spread: -0.1140%
#   ✅ Net Profit After Fees: -0.3140%
# ⚠️  Arbitrage Signal on Bybit - SAND/USDT
# Spread: -0.1140% | Net Profit: -0.3140%
# 🔎 Arbitrage Opportunity on Bybit: AVAX/USDT | 2025-04-12 01:31:01 WIB
#   ✅ Spot Price: 19.46000 USDT
#   ✅ Futures Price: 19.44700 USDT
#   ✅ Spread: -0.0668%
#   ✅ Net Profit After Fees: -0.2668%
# ⚠️  Arbitrage Signal on Bybit - AVAX/USDT
# Spread: -0.0668% | Net Profit: -0.2668%
# 🔎 Arbitrage Opportunity on Bybit: WOO/USDT | 2025-04-12 01:31:01 WIB
#   ✅ Spot Price: 0.06350 USDT
#   ✅ Futures Price: 0.06338 USDT
#   ✅ Spread: -0.1890%
#   ✅ Net Profit After Fees: -0.3890%
# ⚠️  Arbitrage Signal on Bybit - WOO/USDT
# Spread: -0.1890% | Net Profit: -0.3890%
# 🔎 Arbitrage Opportunity on Bybit: IMX/USDT | 2025-04-12 01:31:02 WIB
#   ✅ Spot Price: 0.42500 USDT
#   ✅ Futures Price: 0.42400 USDT
#   ✅ Spread: -0.2353%
#   ✅ Net Profit After Fees: -0.4353%
# ⚠️  Arbitrage Signal on Bybit - IMX/USDT
# Spread: -0.2353% | Net Profit: -0.4353%
# 🔎 Arbitrage Opportunity on Bybit: ENS/USDT | 2025-04-12 01:31:02 WIB
#   ✅ Spot Price: 14.36000 USDT
#   ✅ Futures Price: 14.34700 USDT
#   ✅ Spread: -0.0905%
#   ✅ Net Profit After Fees: -0.2905%
# ⚠️  Arbitrage Signal on Bybit - ENS/USDT
# Spread: -0.0905% | Net Profit: -0.2905%
# 🔎 Arbitrage Opportunity on Bybit: CAKE/USDT | 2025-04-12 01:31:02 WIB
#   ✅ Spot Price: 2.03100 USDT
#   ✅ Futures Price: 2.02800 USDT
#   ✅ Spread: -0.1477%
#   ✅ Net Profit After Fees: -0.3477%
# ⚠️  Arbitrage Signal on Bybit - CAKE/USDT
# Spread: -0.1477% | Net Profit: -0.3477%
# 🔎 Arbitrage Opportunity on Bybit: C98/USDT | 2025-04-12 01:31:02 WIB
#   ✅ Spot Price: 0.05504 USDT
#   ✅ Futures Price: 0.05504 USDT
#   ✅ Spread: 0.0000%
#   ✅ Net Profit After Fees: -0.2000%
# ⚠️  Arbitrage Signal on Bybit - C98/USDT
# Spread: 0.0000% | Net Profit: -0.2000%
# 🔎 Arbitrage Opportunity on Bybit: AVA/USDT | 2025-04-12 01:31:02 WIB
#   ✅ Spot Price: 0.53210 USDT
#   ✅ Futures Price: 0.53200 USDT
#   ✅ Spread: -0.0188%
#   ✅ Net Profit After Fees: -0.2188%
# ⚠️  Arbitrage Signal on Bybit - AVA/USDT
# Spread: -0.0188% | Net Profit: -0.2188%
# 🔎 Arbitrage Opportunity on Bybit: ONE/USDT | 2025-04-12 01:31:03 WIB
#   ✅ Spot Price: 0.01075 USDT
#   ✅ Futures Price: 0.01073 USDT
#   ✅ Spread: -0.1860%
#   ✅ Net Profit After Fees: -0.3860%
# ⚠️  Arbitrage Signal on Bybit - ONE/USDT
# Spread: -0.1860% | Net Profit: -0.3860%
# 🔎 Arbitrage Opportunity on Bybit: BOBA/USDT | 2025-04-12 01:31:03 WIB
#   ✅ Spot Price: 0.07304 USDT
#   ✅ Futures Price: 0.07289 USDT
#   ✅ Spread: -0.2054%
#   ✅ Net Profit After Fees: -0.4054%
# ⚠️  Arbitrage Signal on Bybit - BOBA/USDT
# Spread: -0.2054% | Net Profit: -0.4054%
# 🔎 Arbitrage Opportunity on Bybit: JASMY/USDT | 2025-04-12 01:31:03 WIB
#   ✅ Spot Price: 0.01303 USDT
#   ✅ Futures Price: 0.01302 USDT
#   ✅ Spread: -0.0998%
#   ✅ Net Profit After Fees: -0.2998%
# ⚠️  Arbitrage Signal on Bybit - JASMY/USDT
# Spread: -0.0998% | Net Profit: -0.2998%
# 🔎 Arbitrage Opportunity on Bybit: GALA/USDT | 2025-04-12 01:31:03 WIB
#   ✅ Spot Price: 0.01464 USDT
#   ✅ Futures Price: 0.01464 USDT
#   ✅ Spread: 0.0000%
#   ✅ Net Profit After Fees: -0.2000%
# ⚠️  Arbitrage Signal on Bybit - GALA/USDT
# Spread: 0.0000% | Net Profit: -0.2000%
# 🔎 Arbitrage Opportunity on Bybit: XEM/USDT | 2025-04-12 01:31:04 WIB
#   ✅ Spot Price: 0.01615 USDT
#   ✅ Futures Price: 0.01610 USDT
#   ✅ Spread: -0.3096%
#   ✅ Net Profit After Fees: -0.5096%
# ⚠️  Arbitrage Signal on Bybit - XEM/USDT
# Spread: -0.3096% | Net Profit: -0.5096%
# 🔎 Arbitrage Opportunity on Bybit: UMA/USDT | 2025-04-12 01:31:04 WIB
#   ✅ Spot Price: 1.08200 USDT
#   ✅ Futures Price: 1.08000 USDT
#   ✅ Spread: -0.1848%
#   ✅ Net Profit After Fees: -0.3848%
# ⚠️  Arbitrage Signal on Bybit - UMA/USDT
# Spread: -0.1848% | Net Profit: -0.3848%
# 🔎 Arbitrage Opportunity on Bybit: SNX/USDT | 2025-04-12 01:31:04 WIB
#   ✅ Spot Price: 0.65650 USDT
#   ✅ Futures Price: 0.65570 USDT
#   ✅ Spread: -0.1219%
#   ✅ Net Profit After Fees: -0.3219%
# ⚠️  Arbitrage Signal on Bybit - SNX/USDT
# Spread: -0.1219% | Net Profit: -0.3219%
# 🔎 Arbitrage Opportunity on Bybit: 1INCH/USDT | 2025-04-12 01:31:04 WIB
#   ✅ Spot Price: 0.17320 USDT
#   ✅ Futures Price: 0.17310 USDT
#   ✅ Spread: -0.0577%
#   ✅ Net Profit After Fees: -0.2577%
# ⚠️  Arbitrage Signal on Bybit - 1INCH/USDT
# Spread: -0.0577% | Net Profit: -0.2577%
# 🔎 Arbitrage Opportunity on Bybit: LRC/USDT | 2025-04-12 01:31:05 WIB
#   ✅ Spot Price: 0.08940 USDT
#   ✅ Futures Price: 0.08937 USDT
#   ✅ Spread: -0.0336%
#   ✅ Net Profit After Fees: -0.2336%
# ⚠️  Arbitrage Signal on Bybit - LRC/USDT
# Spread: -0.0336% | Net Profit: -0.2336%
# 🔎 Arbitrage Opportunity on Bybit: LDO/USDT | 2025-04-12 01:31:05 WIB
#   ✅ Spot Price: 0.73700 USDT
#   ✅ Futures Price: 0.73690 USDT
#   ✅ Spread: -0.0136%
#   ✅ Net Profit After Fees: -0.2136%
# ⚠️  Arbitrage Signal on Bybit - LDO/USDT
# Spread: -0.0136% | Net Profit: -0.2136%
# 🔎 Arbitrage Opportunity on Bybit: ZEN/USDT | 2025-04-12 01:31:05 WIB
#   ✅ Spot Price: 8.49000 USDT
#   ✅ Futures Price: 8.46500 USDT
#   ✅ Spread: -0.2945%
#   ✅ Net Profit After Fees: -0.4945%
# ⚠️  Arbitrage Signal on Bybit - ZEN/USDT
# Spread: -0.2945% | Net Profit: -0.4945%
# 🔎 Arbitrage Opportunity on Bybit: THETA/USDT | 2025-04-12 01:31:05 WIB
#   ✅ Spot Price: 0.74900 USDT
#   ✅ Futures Price: 0.74840 USDT
#   ✅ Spread: -0.0801%
#   ✅ Net Profit After Fees: -0.2801%
# ⚠️  Arbitrage Signal on Bybit - THETA/USDT
# Spread: -0.0801% | Net Profit: -0.2801%
# 🔎 Arbitrage Opportunity on Bybit: DGB/USDT | 2025-04-12 01:31:06 WIB
#   ✅ Spot Price: 0.01013 USDT
#   ✅ Futures Price: 0.01011 USDT
#   ✅ Spread: -0.1086%
#   ✅ Net Profit After Fees: -0.3086%
# ⚠️  Arbitrage Signal on Bybit - DGB/USDT
# Spread: -0.1086% | Net Profit: -0.3086%
# 🔎 Arbitrage Opportunity on Bybit: RVN/USDT | 2025-04-12 01:31:06 WIB
#   ✅ Spot Price: 0.01060 USDT
#   ✅ Futures Price: 0.01061 USDT
#   ✅ Spread: 0.0943%
#   ✅ Net Profit After Fees: -0.1057%
# ⚠️  Arbitrage Signal on Bybit - RVN/USDT
# Spread: 0.0943% | Net Profit: -0.1057%
# 🔎 Arbitrage Opportunity on Bybit: EGLD/USDT | 2025-04-12 01:31:06 WIB
#   ✅ Spot Price: 14.53000 USDT
#   ✅ Futures Price: 14.51000 USDT
#   ✅ Spread: -0.1376%
#   ✅ Net Profit After Fees: -0.3376%
# ⚠️  Arbitrage Signal on Bybit - EGLD/USDT
# Spread: -0.1376% | Net Profit: -0.3376%
# 🔎 Arbitrage Opportunity on Bybit: RUNE/USDT | 2025-04-12 01:31:06 WIB
#   ✅ Spot Price: 1.13100 USDT
#   ✅ Futures Price: 1.13000 USDT
#   ✅ Spread: -0.0884%
#   ✅ Net Profit After Fees: -0.2884%
# ⚠️  Arbitrage Signal on Bybit - RUNE/USDT
# Spread: -0.0884% | Net Profit: -0.2884%
# 🔎 Arbitrage Opportunity on Bybit: ICX/USDT | 2025-04-12 01:31:06 WIB
#   ✅ Spot Price: 0.08825 USDT
#   ✅ Futures Price: 0.08817 USDT
#   ✅ Spread: -0.0907%
#   ✅ Net Profit After Fees: -0.2907%
# ⚠️  Arbitrage Signal on Bybit - ICX/USDT
# Spread: -0.0907% | Net Profit: -0.2907%
# 🔎 Arbitrage Opportunity on Bybit: XDC/USDT | 2025-04-12 01:31:07 WIB
#   ✅ Spot Price: 0.07056 USDT
#   ✅ Futures Price: 0.07054 USDT
#   ✅ Spread: -0.0283%
#   ✅ Net Profit After Fees: -0.2283%
# ⚠️  Arbitrage Signal on Bybit - XDC/USDT
# Spread: -0.0283% | Net Profit: -0.2283%
# 🔎 Arbitrage Opportunity on Bybit: HNT/USDT | 2025-04-12 01:31:07 WIB
#   ✅ Spot Price: 2.98500 USDT
#   ✅ Futures Price: 2.97700 USDT
#   ✅ Spread: -0.2680%
#   ✅ Net Profit After Fees: -0.4680%
# ⚠️  Arbitrage Signal on Bybit - HNT/USDT
# Spread: -0.2680% | Net Profit: -0.4680%
# 🔎 Arbitrage Opportunity on Bybit: ZIL/USDT | 2025-04-12 01:31:07 WIB
#   ✅ Spot Price: 0.01107 USDT
#   ✅ Futures Price: 0.01106 USDT
#   ✅ Spread: -0.0903%
#   ✅ Net Profit After Fees: -0.2903%
# ⚠️  Arbitrage Signal on Bybit - ZIL/USDT
# Spread: -0.0903% | Net Profit: -0.2903%
# 🔎 Arbitrage Opportunity on Bybit: HBAR/USDT | 2025-04-12 01:31:07 WIB
#   ✅ Spot Price: 0.16966 USDT
#   ✅ Futures Price: 0.16942 USDT
#   ✅ Spread: -0.1415%
#   ✅ Net Profit After Fees: -0.3415%
# ⚠️  Arbitrage Signal on Bybit - HBAR/USDT
# Spread: -0.1415% | Net Profit: -0.3415%
# 🔎 Arbitrage Opportunity on Bybit: FLOW/USDT | 2025-04-12 01:31:07 WIB
#   ✅ Spot Price: 0.35050 USDT
#   ✅ Futures Price: 0.35070 USDT
#   ✅ Spread: 0.0571%
#   ✅ Net Profit After Fees: -0.1429%
# ⚠️  Arbitrage Signal on Bybit - FLOW/USDT
# Spread: 0.0571% | Net Profit: -0.1429%
# 🔎 Arbitrage Opportunity on Bybit: STX/USDT | 2025-04-12 01:31:08 WIB
#   ✅ Spot Price: 0.62800 USDT
#   ✅ Futures Price: 0.62780 USDT
#   ✅ Spread: -0.0318%
#   ✅ Net Profit After Fees: -0.2318%
# ⚠️  Arbitrage Signal on Bybit - STX/USDT
# Spread: -0.0318% | Net Profit: -0.2318%
# 🔎 Arbitrage Opportunity on Bybit: LOOKS/USDT | 2025-04-12 01:31:08 WIB
#   ✅ Spot Price: 0.01166 USDT
#   ✅ Futures Price: 0.01164 USDT
#   ✅ Spread: -0.1715%
#   ✅ Net Profit After Fees: -0.3715%
# ⚠️  Arbitrage Signal on Bybit - LOOKS/USDT
# Spread: -0.1715% | Net Profit: -0.3715%
# 🔎 Arbitrage Opportunity on Bybit: RSS3/USDT | 2025-04-12 01:31:08 WIB
#   ✅ Spot Price: 0.05600 USDT
#   ✅ Futures Price: 0.05589 USDT
#   ✅ Spread: -0.1964%
#   ✅ Net Profit After Fees: -0.3964%
# ⚠️  Arbitrage Signal on Bybit - RSS3/USDT
# Spread: -0.1964% | Net Profit: -0.3964%
# 🔎 Arbitrage Opportunity on Bybit: GMX/USDT | 2025-04-12 01:31:09 WIB
#   ✅ Spot Price: 14.04000 USDT
#   ✅ Futures Price: 14.05400 USDT
#   ✅ Spread: 0.0997%
#   ✅ Net Profit After Fees: -0.1003%
# ⚠️  Arbitrage Signal on Bybit - GMX/USDT
# Spread: 0.0997% | Net Profit: -0.1003%
# 🔎 Arbitrage Opportunity on Bybit: ACH/USDT | 2025-04-12 01:31:09 WIB
#   ✅ Spot Price: 0.02082 USDT
#   ✅ Futures Price: 0.02078 USDT
#   ✅ Spread: -0.1825%
#   ✅ Net Profit After Fees: -0.3825%
# ⚠️  Arbitrage Signal on Bybit - ACH/USDT
# Spread: -0.1825% | Net Profit: -0.3825%
# 🔎 Arbitrage Opportunity on Bybit: SUN/USDT | 2025-04-12 01:31:09 WIB
#   ✅ Spot Price: 0.01646 USDT
#   ✅ Futures Price: 0.01637 USDT
#   ✅ Spread: -0.5407%
#   ✅ Net Profit After Fees: -0.7407%
# ⚠️  Arbitrage Signal on Bybit - SUN/USDT
# Spread: -0.5407% | Net Profit: -0.7407%
# 🔎 Arbitrage Opportunity on Bybit: TRX/USDT | 2025-04-12 01:31:09 WIB
#   ✅ Spot Price: 0.24280 USDT
#   ✅ Futures Price: 0.24277 USDT
#   ✅ Spread: -0.0124%
#   ✅ Net Profit After Fees: -0.2124%
# ⚠️  Arbitrage Signal on Bybit - TRX/USDT
# Spread: -0.0124% | Net Profit: -0.2124%
# 🔎 Arbitrage Opportunity on Bybit: SCRT/USDT | 2025-04-12 01:31:09 WIB
#   ✅ Spot Price: 0.18060 USDT
#   ✅ Futures Price: 0.18030 USDT
#   ✅ Spread: -0.1661%
#   ✅ Net Profit After Fees: -0.3661%
# ⚠️  Arbitrage Signal on Bybit - SCRT/USDT
# Spread: -0.1661% | Net Profit: -0.3661%
# 🔎 Arbitrage Opportunity on Bybit: USTC/USDT | 2025-04-12 01:31:10 WIB
#   ✅ Spot Price: 0.01185 USDT
#   ✅ Futures Price: 0.01184 USDT
#   ✅ Spread: -0.0844%
#   ✅ Net Profit After Fees: -0.2844%
# ⚠️  Arbitrage Signal on Bybit - USTC/USDT
# Spread: -0.0844% | Net Profit: -0.2844%
# 🔎 Arbitrage Opportunity on Bybit: BNB/USDT | 2025-04-12 01:31:10 WIB
#   ✅ Spot Price: 589.98000 USDT
#   ✅ Futures Price: 589.40000 USDT
#   ✅ Spread: -0.0983%
#   ✅ Net Profit After Fees: -0.2983%
# ⚠️  Arbitrage Signal on Bybit - BNB/USDT
# Spread: -0.0983% | Net Profit: -0.2983%
# 🔎 Arbitrage Opportunity on Bybit: NEAR/USDT | 2025-04-12 01:31:10 WIB
#   ✅ Spot Price: 2.10300 USDT
#   ✅ Futures Price: 2.10100 USDT
#   ✅ Spread: -0.0951%
#   ✅ Net Profit After Fees: -0.2951%
# ⚠️  Arbitrage Signal on Bybit - NEAR/USDT
# Spread: -0.0951% | Net Profit: -0.2951%
# 🔎 Arbitrage Opportunity on Bybit: SD/USDT | 2025-04-12 01:31:10 WIB
#   ✅ Spot Price: 0.48020 USDT
#   ✅ Futures Price: 0.47970 USDT
#   ✅ Spread: -0.1041%
#   ✅ Net Profit After Fees: -0.3041%
# ⚠️  Arbitrage Signal on Bybit - SD/USDT
# Spread: -0.1041% | Net Profit: -0.3041%
# 🔎 Arbitrage Opportunity on Bybit: APE/USDT | 2025-04-12 01:31:10 WIB
#   ✅ Spot Price: 0.42900 USDT
#   ✅ Futures Price: 0.42900 USDT
#   ✅ Spread: 0.0000%
#   ✅ Net Profit After Fees: -0.2000%
# ⚠️  Arbitrage Signal on Bybit - APE/USDT
# Spread: 0.0000% | Net Profit: -0.2000%
# 🔎 Arbitrage Opportunity on Bybit: FIDA/USDT | 2025-04-12 01:31:11 WIB
#   ✅ Spot Price: 0.07260 USDT
#   ✅ Futures Price: 0.07252 USDT
#   ✅ Spread: -0.1102%
#   ✅ Net Profit After Fees: -0.3102%
# ⚠️  Arbitrage Signal on Bybit - FIDA/USDT
# Spread: -0.1102% | Net Profit: -0.3102%
# 🔎 Arbitrage Opportunity on Bybit: MINA/USDT | 2025-04-12 01:31:11 WIB
#   ✅ Spot Price: 0.21400 USDT
#   ✅ Futures Price: 0.21380 USDT
#   ✅ Spread: -0.0935%
#   ✅ Net Profit After Fees: -0.2935%
# ⚠️  Arbitrage Signal on Bybit - MINA/USDT
# Spread: -0.0935% | Net Profit: -0.2935%
# 🔎 Arbitrage Opportunity on Bybit: SC/USDT | 2025-04-12 01:31:11 WIB
#   ✅ Spot Price: 0.00300 USDT
#   ✅ Futures Price: 0.00300 USDT
#   ✅ Spread: -0.1997%
#   ✅ Net Profit After Fees: -0.3997%
# ⚠️  Arbitrage Signal on Bybit - SC/USDT
# Spread: -0.1997% | Net Profit: -0.3997%
# 🔎 Arbitrage Opportunity on Bybit: STG/USDT | 2025-04-12 01:31:12 WIB
#   ✅ Spot Price: 0.18760 USDT
#   ✅ Futures Price: 0.18740 USDT
#   ✅ Spread: -0.1066%
#   ✅ Net Profit After Fees: -0.3066%
# ⚠️  Arbitrage Signal on Bybit - STG/USDT
# Spread: -0.1066% | Net Profit: -0.3066%
# 🔎 Arbitrage Opportunity on Bybit: GLMR/USDT | 2025-04-12 01:31:12 WIB
#   ✅ Spot Price: 0.06620 USDT
#   ✅ Futures Price: 0.06623 USDT
#   ✅ Spread: 0.0453%
#   ✅ Net Profit After Fees: -0.1547%
# ⚠️  Arbitrage Signal on Bybit - GLMR/USDT
# Spread: 0.0453% | Net Profit: -0.1547%
# 🔎 Arbitrage Opportunity on Bybit: GMT/USDT | 2025-04-12 01:31:12 WIB
#   ✅ Spot Price: 0.04520 USDT
#   ✅ Futures Price: 0.04511 USDT
#   ✅ Spread: -0.1991%
#   ✅ Net Profit After Fees: -0.3991%
# ⚠️  Arbitrage Signal on Bybit - GMT/USDT
# Spread: -0.1991% | Net Profit: -0.3991%
# 🔎 Arbitrage Opportunity on Bybit: CELO/USDT | 2025-04-12 01:31:12 WIB
#   ✅ Spot Price: 0.29740 USDT
#   ✅ Futures Price: 0.29720 USDT
#   ✅ Spread: -0.0672%
#   ✅ Net Profit After Fees: -0.2672%
# ⚠️  Arbitrage Signal on Bybit - CELO/USDT
# Spread: -0.0672% | Net Profit: -0.2672%
# 🔎 Arbitrage Opportunity on Bybit: CTC/USDT | 2025-04-12 01:31:13 WIB
#   ✅ Spot Price: 0.56880 USDT
#   ✅ Futures Price: 0.56880 USDT
#   ✅ Spread: 0.0000%
#   ✅ Net Profit After Fees: -0.2000%
# ⚠️  Arbitrage Signal on Bybit - CTC/USDT
# Spread: 0.0000% | Net Profit: -0.2000%
# 🔎 Arbitrage Opportunity on Bybit: OP/USDT | 2025-04-12 01:31:13 WIB
#   ✅ Spot Price: 0.66700 USDT
#   ✅ Futures Price: 0.66560 USDT
#   ✅ Spread: -0.2099%
#   ✅ Net Profit After Fees: -0.4099%
# ⚠️  Arbitrage Signal on Bybit - OP/USDT
# Spread: -0.2099% | Net Profit: -0.4099%
# 🔎 Arbitrage Opportunity on Bybit: BEL/USDT | 2025-04-12 01:31:14 WIB
#   ✅ Spot Price: 0.59880 USDT
#   ✅ Futures Price: 0.59770 USDT
#   ✅ Spread: -0.1837%
#   ✅ Net Profit After Fees: -0.3837%
# ⚠️  Arbitrage Signal on Bybit - BEL/USDT
# Spread: -0.1837% | Net Profit: -0.3837%
# 🔎 Arbitrage Opportunity on Bybit: WAXP/USDT | 2025-04-12 01:31:14 WIB
#   ✅ Spot Price: 0.02047 USDT
#   ✅ Futures Price: 0.02043 USDT
#   ✅ Spread: -0.1954%
#   ✅ Net Profit After Fees: -0.3954%
# ⚠️  Arbitrage Signal on Bybit - WAXP/USDT
# Spread: -0.1954% | Net Profit: -0.3954%
# 🔎 Arbitrage Opportunity on Bybit: AR/USDT | 2025-04-12 01:31:14 WIB
#   ✅ Spot Price: 5.58000 USDT
#   ✅ Futures Price: 5.57900 USDT
#   ✅ Spread: -0.0179%
#   ✅ Net Profit After Fees: -0.2179%
# ⚠️  Arbitrage Signal on Bybit - AR/USDT
# Spread: -0.0179% | Net Profit: -0.2179%
# 🔎 Arbitrage Opportunity on Bybit: KDA/USDT | 2025-04-12 01:31:15 WIB
#   ✅ Spot Price: 0.40040 USDT
#   ✅ Futures Price: 0.39990 USDT
#   ✅ Spread: -0.1249%
#   ✅ Net Profit After Fees: -0.3249%
# ⚠️  Arbitrage Signal on Bybit - KDA/USDT
# Spread: -0.1249% | Net Profit: -0.3249%
# 🔎 Arbitrage Opportunity on Bybit: ROSE/USDT | 2025-04-12 01:31:15 WIB
#   ✅ Spot Price: 0.02415 USDT
#   ✅ Futures Price: 0.02413 USDT
#   ✅ Spread: -0.0828%
#   ✅ Net Profit After Fees: -0.2828%
# ⚠️  Arbitrage Signal on Bybit - ROSE/USDT
# Spread: -0.0828% | Net Profit: -0.2828%
# 🔎 Arbitrage Opportunity on Bybit: SOLO/USDT | 2025-04-12 01:31:15 WIB
#   ✅ Spot Price: 0.22109 USDT
#   ✅ Futures Price: 0.22110 USDT
#   ✅ Spread: 0.0045%
#   ✅ Net Profit After Fees: -0.1955%
# ⚠️  Arbitrage Signal on Bybit - SOLO/USDT
# Spread: 0.0045% | Net Profit: -0.1955%
# 🔎 Arbitrage Opportunity on Bybit: INJ/USDT | 2025-04-12 01:31:16 WIB
#   ✅ Spot Price: 8.31000 USDT
#   ✅ Futures Price: 8.30300 USDT
#   ✅ Spread: -0.0842%
#   ✅ Net Profit After Fees: -0.2842%
# ⚠️  Arbitrage Signal on Bybit - INJ/USDT
# Spread: -0.0842% | Net Profit: -0.2842%
# 🔎 Arbitrage Opportunity on Bybit: APT/USDT | 2025-04-12 01:31:16 WIB
#   ✅ Spot Price: 4.87000 USDT
#   ✅ Futures Price: 4.85900 USDT
#   ✅ Spread: -0.2259%
#   ✅ Net Profit After Fees: -0.4259%
# ⚠️  Arbitrage Signal on Bybit - APT/USDT
# Spread: -0.2259% | Net Profit: -0.4259%
# 🔎 Arbitrage Opportunity on Bybit: MASK/USDT | 2025-04-12 01:31:17 WIB
#   ✅ Spot Price: 1.08400 USDT
#   ✅ Futures Price: 1.08200 USDT
#   ✅ Spread: -0.1845%
#   ✅ Net Profit After Fees: -0.3845%
# ⚠️  Arbitrage Signal on Bybit - MASK/USDT
# Spread: -0.1845% | Net Profit: -0.3845%
# 🔎 Arbitrage Opportunity on Bybit: HFT/USDT | 2025-04-12 01:31:17 WIB
#   ✅ Spot Price: 0.05740 USDT
#   ✅ Futures Price: 0.05729 USDT
#   ✅ Spread: -0.1916%
#   ✅ Net Profit After Fees: -0.3916%
# ⚠️  Arbitrage Signal on Bybit - HFT/USDT
# Spread: -0.1916% | Net Profit: -0.3916%
# 🔎 Arbitrage Opportunity on Bybit: PEOPLE/USDT | 2025-04-12 01:31:17 WIB
#   ✅ Spot Price: 0.01249 USDT
#   ✅ Futures Price: 0.01247 USDT
#   ✅ Spread: -0.1601%
#   ✅ Net Profit After Fees: -0.3601%
# ⚠️  Arbitrage Signal on Bybit - PEOPLE/USDT
# Spread: -0.1601% | Net Profit: -0.3601%
# 🔎 Arbitrage Opportunity on Bybit: TWT/USDT | 2025-04-12 01:31:17 WIB
#   ✅ Spot Price: 0.78790 USDT
#   ✅ Futures Price: 0.78740 USDT
#   ✅ Spread: -0.0635%
#   ✅ Net Profit After Fees: -0.2635%
# ⚠️  Arbitrage Signal on Bybit - TWT/USDT
# Spread: -0.0635% | Net Profit: -0.2635%
# 🔎 Arbitrage Opportunity on Bybit: HOOK/USDT | 2025-04-12 01:31:18 WIB
#   ✅ Spot Price: 0.11870 USDT
#   ✅ Futures Price: 0.11860 USDT
#   ✅ Spread: -0.0842%
#   ✅ Net Profit After Fees: -0.2842%
# ⚠️  Arbitrage Signal on Bybit - HOOK/USDT
# Spread: -0.0842% | Net Profit: -0.2842%
# 🔎 Arbitrage Opportunity on Bybit: MAGIC/USDT | 2025-04-12 01:31:18 WIB
#   ✅ Spot Price: 0.07770 USDT
#   ✅ Futures Price: 0.07790 USDT
#   ✅ Spread: 0.2574%
#   ✅ Net Profit After Fees: 0.0574%
# ⚠️  Arbitrage Signal on Bybit - MAGIC/USDT
# Spread: 0.2574% | Net Profit: 0.0574%
# 🔎 Arbitrage Opportunity on Bybit: TON/USDT | 2025-04-12 01:31:18 WIB
#   ✅ Spot Price: 2.98900 USDT
#   ✅ Futures Price: 2.98540 USDT
#   ✅ Spread: -0.1204%
#   ✅ Net Profit After Fees: -0.3204%
# ⚠️  Arbitrage Signal on Bybit - TON/USDT
# Spread: -0.1204% | Net Profit: -0.3204%
# 🔎 Arbitrage Opportunity on Bybit: FLR/USDT | 2025-04-12 01:31:19 WIB
#   ✅ Spot Price: 0.01526 USDT
#   ✅ Futures Price: 0.01518 USDT
#   ✅ Spread: -0.5242%
#   ✅ Net Profit After Fees: -0.7242%
# ⚠️  Arbitrage Signal on Bybit - FLR/USDT
# Spread: -0.5242% | Net Profit: -0.7242%
# 🔎 Arbitrage Opportunity on Bybit: SSV/USDT | 2025-04-12 01:31:19 WIB
#   ✅ Spot Price: 5.31500 USDT
#   ✅ Futures Price: 5.31600 USDT
#   ✅ Spread: 0.0188%
#   ✅ Net Profit After Fees: -0.1812%
# ⚠️  Arbitrage Signal on Bybit - SSV/USDT
# Spread: 0.0188% | Net Profit: -0.1812%
# 🔎 Arbitrage Opportunity on Bybit: FXS/USDT | 2025-04-12 01:31:20 WIB
#   ✅ Spot Price: 1.80400 USDT
#   ✅ Futures Price: 1.79860 USDT
#   ✅ Spread: -0.2993%
#   ✅ Net Profit After Fees: -0.4993%
# ⚠️  Arbitrage Signal on Bybit - FXS/USDT
# Spread: -0.2993% | Net Profit: -0.4993%
# 🔎 Arbitrage Opportunity on Bybit: CORE/USDT | 2025-04-12 01:31:20 WIB
#   ✅ Spot Price: 0.53590 USDT
#   ✅ Futures Price: 0.53530 USDT
#   ✅ Spread: -0.1120%
#   ✅ Net Profit After Fees: -0.3120%
# ⚠️  Arbitrage Signal on Bybit - CORE/USDT
# Spread: -0.1120% | Net Profit: -0.3120%
# 🔎 Arbitrage Opportunity on Bybit: BLUR/USDT | 2025-04-12 01:31:20 WIB
#   ✅ Spot Price: 0.09690 USDT
#   ✅ Futures Price: 0.09690 USDT
#   ✅ Spread: 0.0000%
#   ✅ Net Profit After Fees: -0.2000%
# ⚠️  Arbitrage Signal on Bybit - BLUR/USDT
# Spread: 0.0000% | Net Profit: -0.2000%
# 🔎 Arbitrage Opportunity on Bybit: PRIME/USDT | 2025-04-12 01:31:21 WIB
#   ✅ Spot Price: 2.97100 USDT
#   ✅ Futures Price: 2.96100 USDT
#   ✅ Spread: -0.3366%
#   ✅ Net Profit After Fees: -0.5366%
# ⚠️  Arbitrage Signal on Bybit - PRIME/USDT
# Spread: -0.3366% | Net Profit: -0.5366%
# 🔎 Arbitrage Opportunity on Bybit: VRA/USDT | 2025-04-12 01:31:21 WIB
#   ✅ Spot Price: 0.00144 USDT
#   ✅ Futures Price: 0.00144 USDT
#   ✅ Spread: -0.2083%
#   ✅ Net Profit After Fees: -0.4083%
# ⚠️  Arbitrage Signal on Bybit - VRA/USDT
# Spread: -0.2083% | Net Profit: -0.4083%
# 🔎 Arbitrage Opportunity on Bybit: ID/USDT | 2025-04-12 01:31:22 WIB
#   ✅ Spot Price: 0.18232 USDT
#   ✅ Futures Price: 0.18190 USDT
#   ✅ Spread: -0.2304%
#   ✅ Net Profit After Fees: -0.4304%
# ⚠️  Arbitrage Signal on Bybit - ID/USDT
# Spread: -0.2304% | Net Profit: -0.4304%
# 🔎 Arbitrage Opportunity on Bybit: ARB/USDT | 2025-04-12 01:31:22 WIB
#   ✅ Spot Price: 0.29830 USDT
#   ✅ Futures Price: 0.29790 USDT
#   ✅ Spread: -0.1341%
#   ✅ Net Profit After Fees: -0.3341%
# ⚠️  Arbitrage Signal on Bybit - ARB/USDT
# Spread: -0.1341% | Net Profit: -0.3341%
# 🔎 Arbitrage Opportunity on Bybit: AXL/USDT | 2025-04-12 01:31:22 WIB
#   ✅ Spot Price: 0.31690 USDT
#   ✅ Futures Price: 0.31620 USDT
#   ✅ Spread: -0.2209%
#   ✅ Net Profit After Fees: -0.4209%
# ⚠️  Arbitrage Signal on Bybit - AXL/USDT
# Spread: -0.2209% | Net Profit: -0.4209%
# 🔎 Arbitrage Opportunity on Bybit: CGPT/USDT | 2025-04-12 01:31:22 WIB
#   ✅ Spot Price: 0.06930 USDT
#   ✅ Futures Price: 0.06910 USDT
#   ✅ Spread: -0.2886%
#   ✅ Net Profit After Fees: -0.4886%
# ⚠️  Arbitrage Signal on Bybit - CGPT/USDT
# Spread: -0.2886% | Net Profit: -0.4886%
# 🔎 Arbitrage Opportunity on Bybit: AGI/USDT | 2025-04-12 01:31:23 WIB
#   ✅ Spot Price: 0.05682 USDT
#   ✅ Futures Price: 0.05670 USDT
#   ✅ Spread: -0.2112%
#   ✅ Net Profit After Fees: -0.4112%
# ⚠️  Arbitrage Signal on Bybit - AGI/USDT
# Spread: -0.2112% | Net Profit: -0.4112%
# 🔎 Arbitrage Opportunity on Bybit: SUI/USDT | 2025-04-12 01:31:23 WIB
#   ✅ Spot Price: 2.24170 USDT
#   ✅ Futures Price: 2.24070 USDT
#   ✅ Spread: -0.0446%
#   ✅ Net Profit After Fees: -0.2446%
# ⚠️  Arbitrage Signal on Bybit - SUI/USDT
# Spread: -0.0446% | Net Profit: -0.2446%
# 🔎 Arbitrage Opportunity on Bybit: MVL/USDT | 2025-04-12 01:31:23 WIB
#   ✅ Spot Price: 0.00311 USDT
#   ✅ Futures Price: 0.00310 USDT
#   ✅ Spread: -0.2575%
#   ✅ Net Profit After Fees: -0.4575%
# ⚠️  Arbitrage Signal on Bybit - MVL/USDT
# Spread: -0.2575% | Net Profit: -0.4575%
# 🔎 Arbitrage Opportunity on Bybit: VELO/USDT | 2025-04-12 01:31:24 WIB
#   ✅ Spot Price: 0.01168 USDT
#   ✅ Futures Price: 0.01165 USDT
#   ✅ Spread: -0.2654%
#   ✅ Net Profit After Fees: -0.4654%
# ⚠️  Arbitrage Signal on Bybit - VELO/USDT
# Spread: -0.2654% | Net Profit: -0.4654%
# 🔎 Arbitrage Opportunity on Bybit: PENDLE/USDT | 2025-04-12 01:31:25 WIB
#   ✅ Spot Price: 3.29500 USDT
#   ✅ Futures Price: 3.29020 USDT
#   ✅ Spread: -0.1457%
#   ✅ Net Profit After Fees: -0.3457%
# ⚠️  Arbitrage Signal on Bybit - PENDLE/USDT
# Spread: -0.1457% | Net Profit: -0.3457%
# 🔎 Arbitrage Opportunity on Bybit: MNT/USDT | 2025-04-12 01:31:25 WIB
#   ✅ Spot Price: 0.70290 USDT
#   ✅ Futures Price: 0.70210 USDT
#   ✅ Spread: -0.1138%
#   ✅ Net Profit After Fees: -0.3138%
# ⚠️  Arbitrage Signal on Bybit - MNT/USDT
# Spread: -0.1138% | Net Profit: -0.3138%
# 🔎 Arbitrage Opportunity on Bybit: ARKM/USDT | 2025-04-12 01:31:25 WIB
#   ✅ Spot Price: 0.47200 USDT
#   ✅ Futures Price: 0.47180 USDT
#   ✅ Spread: -0.0424%
#   ✅ Net Profit After Fees: -0.2424%
# ⚠️  Arbitrage Signal on Bybit - ARKM/USDT
# Spread: -0.0424% | Net Profit: -0.2424%
# 🔎 Arbitrage Opportunity on Bybit: WLD/USDT | 2025-04-12 01:31:26 WIB
#   ✅ Spot Price: 0.74000 USDT
#   ✅ Futures Price: 0.73960 USDT
#   ✅ Spread: -0.0541%
#   ✅ Net Profit After Fees: -0.2541%
# ⚠️  Arbitrage Signal on Bybit - WLD/USDT
# Spread: -0.0541% | Net Profit: -0.2541%
# 🔎 Arbitrage Opportunity on Bybit: SEI/USDT | 2025-04-12 01:31:26 WIB
#   ✅ Spot Price: 0.15750 USDT
#   ✅ Futures Price: 0.15730 USDT
#   ✅ Spread: -0.1270%
#   ✅ Net Profit After Fees: -0.3270%
# ⚠️  Arbitrage Signal on Bybit - SEI/USDT
# Spread: -0.1270% | Net Profit: -0.3270%
# 🔎 Arbitrage Opportunity on Bybit: CYBER/USDT | 2025-04-12 01:31:26 WIB
#   ✅ Spot Price: 1.06670 USDT
#   ✅ Futures Price: 1.06600 USDT
#   ✅ Spread: -0.0656%
#   ✅ Net Profit After Fees: -0.2656%
# ⚠️  Arbitrage Signal on Bybit - CYBER/USDT
# Spread: -0.0656% | Net Profit: -0.2656%
# 🔎 Arbitrage Opportunity on Bybit: ORDI/USDT | 2025-04-12 01:31:27 WIB
#   ✅ Spot Price: 7.13000 USDT
#   ✅ Futures Price: 7.12600 USDT
#   ✅ Spread: -0.0561%
#   ✅ Net Profit After Fees: -0.2561%
# ⚠️  Arbitrage Signal on Bybit - ORDI/USDT
# Spread: -0.0561% | Net Profit: -0.2561%
# 🔎 Arbitrage Opportunity on Bybit: KAVA/USDT | 2025-04-12 01:31:27 WIB
#   ✅ Spot Price: 0.41950 USDT
#   ✅ Futures Price: 0.41890 USDT
#   ✅ Spread: -0.1430%
#   ✅ Net Profit After Fees: -0.3430%
# ⚠️  Arbitrage Signal on Bybit - KAVA/USDT
# Spread: -0.1430% | Net Profit: -0.3430%
# 🔎 Arbitrage Opportunity on Bybit: KAS/USDT | 2025-04-12 01:31:27 WIB
#   ✅ Spot Price: 0.07547 USDT
#   ✅ Futures Price: 0.07540 USDT
#   ✅ Spread: -0.0928%
#   ✅ Net Profit After Fees: -0.2928%
# ⚠️  Arbitrage Signal on Bybit - KAS/USDT
# Spread: -0.0928% | Net Profit: -0.2928%
# 🔎 Arbitrage Opportunity on Bybit: LEVER/USDT | 2025-04-12 01:31:28 WIB
#   ✅ Spot Price: 0.00045 USDT
#   ✅ Futures Price: 0.00045 USDT
#   ✅ Spread: 0.0887%
#   ✅ Net Profit After Fees: -0.1113%
# ⚠️  Arbitrage Signal on Bybit - LEVER/USDT
# Spread: 0.0887% | Net Profit: -0.1113%
# 🔎 Arbitrage Opportunity on Bybit: BEAM/USDT | 2025-04-12 01:31:28 WIB
#   ✅ Spot Price: 0.00650 USDT
#   ✅ Futures Price: 0.00650 USDT
#   ✅ Spread: -0.0462%
#   ✅ Net Profit After Fees: -0.2462%
# ⚠️  Arbitrage Signal on Bybit - BEAM/USDT
# Spread: -0.0462% | Net Profit: -0.2462%
# 🔎 Arbitrage Opportunity on Bybit: POL/USDT | 2025-04-12 01:31:29 WIB
#   ✅ Spot Price: 0.18520 USDT
#   ✅ Futures Price: 0.18510 USDT
#   ✅ Spread: -0.0540%
#   ✅ Net Profit After Fees: -0.2540%
# ⚠️  Arbitrage Signal on Bybit - POL/USDT
# Spread: -0.0540% | Net Profit: -0.2540%
# 🔎 Arbitrage Opportunity on Bybit: TIA/USDT | 2025-04-12 01:31:29 WIB
#   ✅ Spot Price: 2.54800 USDT
#   ✅ Futures Price: 2.54600 USDT
#   ✅ Spread: -0.0785%
#   ✅ Net Profit After Fees: -0.2785%
# ⚠️  Arbitrage Signal on Bybit - TIA/USDT
# Spread: -0.0785% | Net Profit: -0.2785%
# 🔎 Arbitrage Opportunity on Bybit: TOKEN/USDT | 2025-04-12 01:31:29 WIB
#   ✅ Spot Price: 0.01330 USDT
#   ✅ Futures Price: 0.01329 USDT
#   ✅ Spread: -0.0752%
#   ✅ Net Profit After Fees: -0.2752%
# ⚠️  Arbitrage Signal on Bybit - TOKEN/USDT
# Spread: -0.0752% | Net Profit: -0.2752%
# 🔎 Arbitrage Opportunity on Bybit: MEME/USDT | 2025-04-12 01:31:29 WIB
#   ✅ Spot Price: 0.00161 USDT
#   ✅ Futures Price: 0.00162 USDT
#   ✅ Spread: 0.3727%
#   ✅ Net Profit After Fees: 0.1727%
# ⚠️  Arbitrage Signal on Bybit - MEME/USDT
# Spread: 0.3727% | Net Profit: 0.1727%
# 🔎 Arbitrage Opportunity on Bybit: PYTH/USDT | 2025-04-12 01:31:30 WIB
#   ✅ Spot Price: 0.12910 USDT
#   ✅ Futures Price: 0.12890 USDT
#   ✅ Spread: -0.1549%
#   ✅ Net Profit After Fees: -0.3549%
# ⚠️  Arbitrage Signal on Bybit - PYTH/USDT
# Spread: -0.1549% | Net Profit: -0.3549%
# 🔎 Arbitrage Opportunity on Bybit: VANRY/USDT | 2025-04-12 01:31:30 WIB
#   ✅ Spot Price: 0.02482 USDT
#   ✅ Futures Price: 0.02478 USDT
#   ✅ Spread: -0.1612%
#   ✅ Net Profit After Fees: -0.3612%
# ⚠️  Arbitrage Signal on Bybit - VANRY/USDT
# Spread: -0.1612% | Net Profit: -0.3612%
# 🔎 Arbitrage Opportunity on Bybit: JTO/USDT | 2025-04-12 01:31:31 WIB
#   ✅ Spot Price: 1.74200 USDT
#   ✅ Futures Price: 1.74000 USDT
#   ✅ Spread: -0.1148%
#   ✅ Net Profit After Fees: -0.3148%
# ⚠️  Arbitrage Signal on Bybit - JTO/USDT
# Spread: -0.1148% | Net Profit: -0.3148%
# 🔎 Arbitrage Opportunity on Bybit: MYRIA/USDT | 2025-04-12 01:31:31 WIB
#   ✅ Spot Price: 0.00076 USDT
#   ✅ Futures Price: 0.00076 USDT
#   ✅ Spread: -0.0921%
#   ✅ Net Profit After Fees: -0.2921%
# ⚠️  Arbitrage Signal on Bybit - MYRIA/USDT
# Spread: -0.0921% | Net Profit: -0.2921%
# 🔎 Arbitrage Opportunity on Bybit: MBOX/USDT | 2025-04-12 01:31:31 WIB
#   ✅ Spot Price: 0.04648 USDT
#   ✅ Futures Price: 0.04633 USDT
#   ✅ Spread: -0.3227%
#   ✅ Net Profit After Fees: -0.5227%
# ⚠️  Arbitrage Signal on Bybit - MBOX/USDT
# Spread: -0.3227% | Net Profit: -0.5227%
# 🔎 Arbitrage Opportunity on Bybit: AIOZ/USDT | 2025-04-12 01:31:32 WIB
#   ✅ Spot Price: 0.22440 USDT
#   ✅ Futures Price: 0.22340 USDT
#   ✅ Spread: -0.4456%
#   ✅ Net Profit After Fees: -0.6456%
# ⚠️  Arbitrage Signal on Bybit - AIOZ/USDT
# Spread: -0.4456% | Net Profit: -0.6456%
# 🔎 Arbitrage Opportunity on Bybit: VIC/USDT | 2025-04-12 01:31:32 WIB
#   ✅ Spot Price: 0.20030 USDT
#   ✅ Futures Price: 0.19990 USDT
#   ✅ Spread: -0.1997%
#   ✅ Net Profit After Fees: -0.3997%
# ⚠️  Arbitrage Signal on Bybit - VIC/USDT
# Spread: -0.1997% | Net Profit: -0.3997%
# 🔎 Arbitrage Opportunity on Bybit: XAI/USDT | 2025-04-12 01:31:32 WIB
#   ✅ Spot Price: 0.04510 USDT
#   ✅ Futures Price: 0.04512 USDT
#   ✅ Spread: 0.0443%
#   ✅ Net Profit After Fees: -0.1557%
# ⚠️  Arbitrage Signal on Bybit - XAI/USDT
# Spread: 0.0443% | Net Profit: -0.1557%
# 🔎 Arbitrage Opportunity on Bybit: ONDO/USDT | 2025-04-12 01:31:33 WIB
#   ✅ Spot Price: 0.91090 USDT
#   ✅ Futures Price: 0.91030 USDT
#   ✅ Spread: -0.0659%
#   ✅ Net Profit After Fees: -0.2659%
# ⚠️  Arbitrage Signal on Bybit - ONDO/USDT
# Spread: -0.0659% | Net Profit: -0.2659%
# 🔎 Arbitrage Opportunity on Bybit: MANTA/USDT | 2025-04-12 01:31:33 WIB
#   ✅ Spot Price: 0.18700 USDT
#   ✅ Futures Price: 0.18680 USDT
#   ✅ Spread: -0.1070%
#   ✅ Net Profit After Fees: -0.3070%
# ⚠️  Arbitrage Signal on Bybit - MANTA/USDT
# Spread: -0.1070% | Net Profit: -0.3070%
# 🔎 Arbitrage Opportunity on Bybit: MYRO/USDT | 2025-04-12 01:31:33 WIB
#   ✅ Spot Price: 0.01305 USDT
#   ✅ Futures Price: 0.01304 USDT
#   ✅ Spread: -0.0766%
#   ✅ Net Profit After Fees: -0.2766%
# ⚠️  Arbitrage Signal on Bybit - MYRO/USDT
# Spread: -0.0766% | Net Profit: -0.2766%
# 🔎 Arbitrage Opportunity on Bybit: DYM/USDT | 2025-04-12 01:31:34 WIB
#   ✅ Spot Price: 0.26130 USDT
#   ✅ Futures Price: 0.26100 USDT
#   ✅ Spread: -0.1148%
#   ✅ Net Profit After Fees: -0.3148%
# ⚠️  Arbitrage Signal on Bybit - DYM/USDT
# Spread: -0.1148% | Net Profit: -0.3148%
# 🔎 Arbitrage Opportunity on Bybit: ZETA/USDT | 2025-04-12 01:31:34 WIB
#   ✅ Spot Price: 0.24060 USDT
#   ✅ Futures Price: 0.24000 USDT
#   ✅ Spread: -0.2494%
#   ✅ Net Profit After Fees: -0.4494%
# ⚠️  Arbitrage Signal on Bybit - ZETA/USDT
# Spread: -0.2494% | Net Profit: -0.4494%
# 🔎 Arbitrage Opportunity on Bybit: JUP/USDT | 2025-04-12 01:31:34 WIB
#   ✅ Spot Price: 0.39430 USDT
#   ✅ Futures Price: 0.39400 USDT
#   ✅ Spread: -0.0761%
#   ✅ Net Profit After Fees: -0.2761%
# ⚠️  Arbitrage Signal on Bybit - JUP/USDT
# Spread: -0.0761% | Net Profit: -0.2761%
# 🔎 Arbitrage Opportunity on Bybit: MAVIA/USDT | 2025-04-12 01:31:34 WIB
#   ✅ Spot Price: 0.25420 USDT
#   ✅ Futures Price: 0.25400 USDT
#   ✅ Spread: -0.0787%
#   ✅ Net Profit After Fees: -0.2787%
# ⚠️  Arbitrage Signal on Bybit - MAVIA/USDT
# Spread: -0.0787% | Net Profit: -0.2787%
# 🔎 Arbitrage Opportunity on Bybit: ALT/USDT | 2025-04-12 01:31:35 WIB
#   ✅ Spot Price: 0.02681 USDT
#   ✅ Futures Price: 0.02675 USDT
#   ✅ Spread: -0.2238%
#   ✅ Net Profit After Fees: -0.4238%
# ⚠️  Arbitrage Signal on Bybit - ALT/USDT
# Spread: -0.2238% | Net Profit: -0.4238%
# 🔎 Arbitrage Opportunity on Bybit: STRK/USDT | 2025-04-12 01:31:35 WIB
#   ✅ Spot Price: 0.13530 USDT
#   ✅ Futures Price: 0.13500 USDT
#   ✅ Spread: -0.2217%
#   ✅ Net Profit After Fees: -0.4217%
# ⚠️  Arbitrage Signal on Bybit - STRK/USDT
# Spread: -0.2217% | Net Profit: -0.4217%
# 🔎 Arbitrage Opportunity on Bybit: CPOOL/USDT | 2025-04-12 01:31:35 WIB
#   ✅ Spot Price: 0.12783 USDT
#   ✅ Futures Price: 0.12753 USDT
#   ✅ Spread: -0.2347%
#   ✅ Net Profit After Fees: -0.4347%
# ⚠️  Arbitrage Signal on Bybit - CPOOL/USDT
# Spread: -0.2347% | Net Profit: -0.4347%
# 🔎 Arbitrage Opportunity on Bybit: PORTAL/USDT | 2025-04-12 01:31:36 WIB
#   ✅ Spot Price: 0.07410 USDT
#   ✅ Futures Price: 0.07393 USDT
#   ✅ Spread: -0.2294%
#   ✅ Net Profit After Fees: -0.4294%
# ⚠️  Arbitrage Signal on Bybit - PORTAL/USDT
# Spread: -0.2294% | Net Profit: -0.4294%
# 🔎 Arbitrage Opportunity on Bybit: SCA/USDT | 2025-04-12 01:31:36 WIB
#   ✅ Spot Price: 0.07908 USDT
#   ✅ Futures Price: 0.07879 USDT
#   ✅ Spread: -0.3667%
#   ✅ Net Profit After Fees: -0.5667%
# ⚠️  Arbitrage Signal on Bybit - SCA/USDT
# Spread: -0.3667% | Net Profit: -0.5667%
# 🔎 Arbitrage Opportunity on Bybit: AEVO/USDT | 2025-04-12 01:31:36 WIB
#   ✅ Spot Price: 0.09610 USDT
#   ✅ Futures Price: 0.09600 USDT
#   ✅ Spread: -0.1041%
#   ✅ Net Profit After Fees: -0.3041%
# ⚠️  Arbitrage Signal on Bybit - AEVO/USDT
# Spread: -0.1041% | Net Profit: -0.3041%
# 🔎 Arbitrage Opportunity on Bybit: BOME/USDT | 2025-04-12 01:31:37 WIB
#   ✅ Spot Price: 0.00114 USDT
#   ✅ Futures Price: 0.00114 USDT
#   ✅ Spread: -0.0874%
#   ✅ Net Profit After Fees: -0.2874%
# ⚠️  Arbitrage Signal on Bybit - BOME/USDT
# Spread: -0.0874% | Net Profit: -0.2874%
# 🔎 Arbitrage Opportunity on Bybit: ZKJ/USDT | 2025-04-12 01:31:37 WIB
#   ✅ Spot Price: 2.26060 USDT
#   ✅ Futures Price: 2.26350 USDT
#   ✅ Spread: 0.1283%
#   ✅ Net Profit After Fees: -0.0717%
# ⚠️  Arbitrage Signal on Bybit - ZKJ/USDT
# Spread: 0.1283% | Net Profit: -0.0717%
# 🔎 Arbitrage Opportunity on Bybit: ETHFI/USDT | 2025-04-12 01:31:37 WIB
#   ✅ Spot Price: 0.48600 USDT
#   ✅ Futures Price: 0.48510 USDT
#   ✅ Spread: -0.1852%
#   ✅ Net Profit After Fees: -0.3852%
# ⚠️  Arbitrage Signal on Bybit - ETHFI/USDT
# Spread: -0.1852% | Net Profit: -0.3852%
# 🔎 Arbitrage Opportunity on Bybit: DEGEN/USDT | 2025-04-12 01:31:38 WIB
#   ✅ Spot Price: 0.00224 USDT
#   ✅ Futures Price: 0.00223 USDT
#   ✅ Spread: -0.3571%
#   ✅ Net Profit After Fees: -0.5571%
# ⚠️  Arbitrage Signal on Bybit - DEGEN/USDT
# Spread: -0.3571% | Net Profit: -0.5571%
# 🔎 Arbitrage Opportunity on Bybit: ENA/USDT | 2025-04-12 01:31:38 WIB
#   ✅ Spot Price: 0.32090 USDT
#   ✅ Futures Price: 0.32050 USDT
#   ✅ Spread: -0.1246%
#   ✅ Net Profit After Fees: -0.3246%
# ⚠️  Arbitrage Signal on Bybit - ENA/USDT
# Spread: -0.1246% | Net Profit: -0.3246%
# 🔎 Arbitrage Opportunity on Bybit: USDE/USDT | 2025-04-12 01:31:38 WIB
#   ✅ Spot Price: 0.99930 USDT
#   ✅ Futures Price: 0.99870 USDT
#   ✅ Spread: -0.0600%
#   ✅ Net Profit After Fees: -0.2600%
# ⚠️  Arbitrage Signal on Bybit - USDE/USDT
# Spread: -0.0600% | Net Profit: -0.2600%
# 🔎 Arbitrage Opportunity on Bybit: W/USDT | 2025-04-12 01:31:38 WIB
#   ✅ Spot Price: 0.07450 USDT
#   ✅ Futures Price: 0.07434 USDT
#   ✅ Spread: -0.2148%
#   ✅ Net Profit After Fees: -0.4148%
# ⚠️  Arbitrage Signal on Bybit - W/USDT
# Spread: -0.2148% | Net Profit: -0.4148%
# 🔎 Arbitrage Opportunity on Bybit: TNSR/USDT | 2025-04-12 01:31:39 WIB
#   ✅ Spot Price: 0.12970 USDT
#   ✅ Futures Price: 0.12950 USDT
#   ✅ Spread: -0.1542%
#   ✅ Net Profit After Fees: -0.3542%
# ⚠️  Arbitrage Signal on Bybit - TNSR/USDT
# Spread: -0.1542% | Net Profit: -0.3542%
# 🔎 Arbitrage Opportunity on Bybit: MASA/USDT | 2025-04-12 01:31:39 WIB
#   ✅ Spot Price: 0.01603 USDT
#   ✅ Futures Price: 0.01600 USDT
#   ✅ Spread: -0.1871%
#   ✅ Net Profit After Fees: -0.3871%
# ⚠️  Arbitrage Signal on Bybit - MASA/USDT
# Spread: -0.1871% | Net Profit: -0.3871%
# 🔎 Arbitrage Opportunity on Bybit: FOXY/USDT | 2025-04-12 01:31:39 WIB
#   ✅ Spot Price: 0.00131 USDT
#   ✅ Futures Price: 0.00131 USDT
#   ✅ Spread: -0.1526%
#   ✅ Net Profit After Fees: -0.3526%
# ⚠️  Arbitrage Signal on Bybit - FOXY/USDT
# Spread: -0.1526% | Net Profit: -0.3526%
# 🔎 Arbitrage Opportunity on Bybit: PRCL/USDT | 2025-04-12 01:31:39 WIB
#   ✅ Spot Price: 0.06280 USDT
#   ✅ Futures Price: 0.06252 USDT
#   ✅ Spread: -0.4459%
#   ✅ Net Profit After Fees: -0.6459%
# ⚠️  Arbitrage Signal on Bybit - PRCL/USDT
# Spread: -0.4459% | Net Profit: -0.6459%
# 🔎 Arbitrage Opportunity on Bybit: OMNI/USDT | 2025-04-12 01:31:40 WIB
#   ✅ Spot Price: 2.01100 USDT
#   ✅ Futures Price: 2.00900 USDT
#   ✅ Spread: -0.0995%
#   ✅ Net Profit After Fees: -0.2995%
# ⚠️  Arbitrage Signal on Bybit - OMNI/USDT
# Spread: -0.0995% | Net Profit: -0.2995%
# 🔎 Arbitrage Opportunity on Bybit: BRETT/USDT | 2025-04-12 01:31:40 WIB
#   ✅ Spot Price: 0.02725 USDT
#   ✅ Futures Price: 0.02722 USDT
#   ✅ Spread: -0.1101%
#   ✅ Net Profit After Fees: -0.3101%
# ⚠️  Arbitrage Signal on Bybit - BRETT/USDT
# Spread: -0.1101% | Net Profit: -0.3101%
# 🔎 Arbitrage Opportunity on Bybit: MEW/USDT | 2025-04-12 01:31:40 WIB
#   ✅ Spot Price: 0.00244 USDT
#   ✅ Futures Price: 0.00243 USDT
#   ✅ Spread: -0.0821%
#   ✅ Net Profit After Fees: -0.2821%
# ⚠️  Arbitrage Signal on Bybit - MEW/USDT
# Spread: -0.0821% | Net Profit: -0.2821%
# 🔎 Arbitrage Opportunity on Bybit: MERL/USDT | 2025-04-12 01:31:40 WIB
#   ✅ Spot Price: 0.08700 USDT
#   ✅ Futures Price: 0.08691 USDT
#   ✅ Spread: -0.1034%
#   ✅ Net Profit After Fees: -0.3034%
# ⚠️  Arbitrage Signal on Bybit - MERL/USDT
# Spread: -0.1034% | Net Profit: -0.3034%
# 🔎 Arbitrage Opportunity on Bybit: SAFE/USDT | 2025-04-12 01:31:40 WIB
#   ✅ Spot Price: 0.45590 USDT
#   ✅ Futures Price: 0.45530 USDT
#   ✅ Spread: -0.1316%
#   ✅ Net Profit After Fees: -0.3316%
# ⚠️  Arbitrage Signal on Bybit - SAFE/USDT
# Spread: -0.1316% | Net Profit: -0.3316%
# 🔎 Arbitrage Opportunity on Bybit: WIF/USDT | 2025-04-12 01:31:41 WIB
#   ✅ Spot Price: 0.39800 USDT
#   ✅ Futures Price: 0.39850 USDT
#   ✅ Spread: 0.1256%
#   ✅ Net Profit After Fees: -0.0744%
# ⚠️  Arbitrage Signal on Bybit - WIF/USDT
# Spread: 0.1256% | Net Profit: -0.0744%
# 🔎 Arbitrage Opportunity on Bybit: KMNO/USDT | 2025-04-12 01:31:41 WIB
#   ✅ Spot Price: 0.04584 USDT
#   ✅ Futures Price: 0.04577 USDT
#   ✅ Spread: -0.1527%
#   ✅ Net Profit After Fees: -0.3527%
# ⚠️  Arbitrage Signal on Bybit - KMNO/USDT
# Spread: -0.1527% | Net Profit: -0.3527%
# 🔎 Arbitrage Opportunity on Bybit: ZENT/USDT | 2025-04-12 01:31:41 WIB
#   ✅ Spot Price: 0.00924 USDT
#   ✅ Futures Price: 0.00927 USDT
#   ✅ Spread: 0.3030%
#   ✅ Net Profit After Fees: 0.1030%
# ⚠️  Arbitrage Signal on Bybit - ZENT/USDT
# Spread: 0.3030% | Net Profit: 0.1030%
# 🔎 Arbitrage Opportunity on Bybit: TAI/USDT | 2025-04-12 01:31:41 WIB
#   ✅ Spot Price: 0.03194 USDT
#   ✅ Futures Price: 0.03192 USDT
#   ✅ Spread: -0.0626%
#   ✅ Net Profit After Fees: -0.2626%
# ⚠️  Arbitrage Signal on Bybit - TAI/USDT
# Spread: -0.0626% | Net Profit: -0.2626%
# 🔎 Arbitrage Opportunity on Bybit: SPEC/USDT | 2025-04-12 01:31:42 WIB
# ...
#   ✅ Spot Price: 0.01990 USDT
#   ✅ Futures Price: 0.01987 USDT
#   ✅ Spread: -0.1508%
#   ✅ Net Profit After Fees: -0.3108%
# ⚠️  Arbitrage Signal on Bitget - KOMA/USDT
# Spread: -0.1508% | Net Profit: -0.3108%
# 🔎 Arbitrage Opportunity on Bitget: ME/USDT | 2025-04-12 01:50:24 WIB
#   ✅ Spot Price: 0.96530 USDT
#   ✅ Futures Price: 0.96300 USDT
#   ✅ Spread: -0.2383%
#   ✅ Net Profit After Fees: -0.3983%
# ⚠️  Arbitrage Signal on Bitget - ME/USDT
# Spread: -0.2383% | Net Profit: -0.3983%
# 🔎 Arbitrage Opportunity on Bitget: BGSC/USDT | 2025-04-12 01:50:25 WIB
#   ✅ Spot Price: 0.00873 USDT
#   ✅ Futures Price: 0.00872 USDT
#   ✅ Spread: -0.1145%
#   ✅ Net Profit After Fees: -0.2745%
# ⚠️  Arbitrage Signal on Bitget - BGSC/USDT
# Spread: -0.1145% | Net Profit: -0.2745%
# 🔎 Arbitrage Opportunity on Bitget: MOVE/USDT | 2025-04-12 01:50:25 WIB
#   ✅ Spot Price: 0.33920 USDT
#   ✅ Futures Price: 0.33920 USDT
#   ✅ Spread: 0.0000%
#   ✅ Net Profit After Fees: -0.1600%
# ⚠️  Arbitrage Signal on Bitget - MOVE/USDT
# Spread: 0.0000% | Net Profit: -0.1600%
# 🔎 Arbitrage Opportunity on Bitget: ARC/USDT | 2025-04-12 01:50:25 WIB
#   ✅ Spot Price: 0.03430 USDT
#   ✅ Futures Price: 0.03426 USDT
#   ✅ Spread: -0.1166%
#   ✅ Net Profit After Fees: -0.2766%
# ⚠️  Arbitrage Signal on Bitget - ARC/USDT
# Spread: -0.1166% | Net Profit: -0.2766%
# 🔎 Arbitrage Opportunity on Bitget: GRIFFAIN/USDT | 2025-04-12 01:50:25 WIB
#   ✅ Spot Price: 0.03050 USDT
#   ✅ Futures Price: 0.03053 USDT
#   ✅ Spread: 0.0984%
#   ✅ Net Profit After Fees: -0.0616%
# ⚠️  Arbitrage Signal on Bitget - GRIFFAIN/USDT
# Spread: 0.0984% | Net Profit: -0.0616%
# 🔎 Arbitrage Opportunity on Bitget: HYPE/USDT | 2025-04-12 01:50:26 WIB
#   ✅ Spot Price: 15.63000 USDT
#   ✅ Futures Price: 15.62600 USDT
#   ✅ Spread: -0.0256%
#   ✅ Net Profit After Fees: -0.1856%
# ⚠️  Arbitrage Signal on Bitget - HYPE/USDT
# Spread: -0.0256% | Net Profit: -0.1856%
# 🔎 Arbitrage Opportunity on Bitget: USUAL/USDT | 2025-04-12 01:50:26 WIB
#   ✅ Spot Price: 0.15860 USDT
#   ✅ Futures Price: 0.15810 USDT
#   ✅ Spread: -0.3153%
#   ✅ Net Profit After Fees: -0.4753%
# ⚠️  Arbitrage Signal on Bitget - USUAL/USDT
# Spread: -0.3153% | Net Profit: -0.4753%
# 🔎 Arbitrage Opportunity on Bitget: PENGU/USDT | 2025-04-12 01:50:26 WIB
#   ✅ Spot Price: 0.00509 USDT
#   ✅ Futures Price: 0.00506 USDT
#   ✅ Spread: -0.4720%
#   ✅ Net Profit After Fees: -0.6320%
# ⚠️  Arbitrage Signal on Bitget - PENGU/USDT
# Spread: -0.4720% | Net Profit: -0.6320%
# 🔎 Arbitrage Opportunity on Bitget: VANA/USDT | 2025-04-12 01:50:27 WIB
#   ✅ Spot Price: 5.52310 USDT
#   ✅ Futures Price: 5.51700 USDT
#   ✅ Spread: -0.1104%
#   ✅ Net Profit After Fees: -0.2704%
# ⚠️  Arbitrage Signal on Bitget - VANA/USDT
# Spread: -0.1104% | Net Profit: -0.2704%
# 🔎 Arbitrage Opportunity on Bitget: ALGO/USDT | 2025-04-12 01:50:27 WIB
#   ✅ Spot Price: 0.18380 USDT
#   ✅ Futures Price: 0.18380 USDT
#   ✅ Spread: 0.0000%
#   ✅ Net Profit After Fees: -0.1600%
# ⚠️  Arbitrage Signal on Bitget - ALGO/USDT
# Spread: 0.0000% | Net Profit: -0.1600%
# 🔎 Arbitrage Opportunity on Bitget: FUEL/USDT | 2025-04-12 01:50:27 WIB
#   ✅ Spot Price: 0.00863 USDT
#   ✅ Futures Price: 0.00858 USDT
#   ✅ Spread: -0.5794%
#   ✅ Net Profit After Fees: -0.7394%
# ⚠️  Arbitrage Signal on Bitget - FUEL/USDT
# Spread: -0.5794% | Net Profit: -0.7394%
# 🔎 Arbitrage Opportunity on Bitget: SONIC/USDT | 2025-04-12 01:50:27 WIB
#   ✅ Spot Price: 0.24696 USDT
#   ✅ Futures Price: 0.24680 USDT
#   ✅ Spread: -0.0652%
#   ✅ Net Profit After Fees: -0.2252%
# ⚠️  Arbitrage Signal on Bitget - SONIC/USDT
# Spread: -0.0652% | Net Profit: -0.2252%
# 🔎 Arbitrage Opportunity on Bitget: BIO/USDT | 2025-04-12 01:50:28 WIB
#   ✅ Spot Price: 0.05850 USDT
#   ✅ Futures Price: 0.05842 USDT
#   ✅ Spread: -0.1368%
#   ✅ Net Profit After Fees: -0.2968%
# ⚠️  Arbitrage Signal on Bitget - BIO/USDT
# Spread: -0.1368% | Net Profit: -0.2968%
# 🔎 Arbitrage Opportunity on Bitget: SWARMS/USDT | 2025-04-12 01:50:28 WIB
#   ✅ Spot Price: 0.02275 USDT
#   ✅ Futures Price: 0.02273 USDT
#   ✅ Spread: -0.0879%
#   ✅ Net Profit After Fees: -0.2479%
# ⚠️  Arbitrage Signal on Bitget - SWARMS/USDT
# Spread: -0.0879% | Net Profit: -0.2479%
# 🔎 Arbitrage Opportunity on Bitget: ZEREBRO/USDT | 2025-04-12 01:50:28 WIB
#   ✅ Spot Price: 0.02320 USDT
#   ✅ Futures Price: 0.02315 USDT
#   ✅ Spread: -0.2155%
#   ✅ Net Profit After Fees: -0.3755%
# ⚠️  Arbitrage Signal on Bitget - ZEREBRO/USDT
# Spread: -0.2155% | Net Profit: -0.3755%
# 🔎 Arbitrage Opportunity on Bitget: PHA/USDT | 2025-04-12 01:50:29 WIB
#   ✅ Spot Price: 0.09390 USDT
#   ✅ Futures Price: 0.09396 USDT
#   ✅ Spread: 0.0639%
#   ✅ Net Profit After Fees: -0.0961%
# ⚠️  Arbitrage Signal on Bitget - PHA/USDT
# Spread: 0.0639% | Net Profit: -0.0961%
# 🔎 Arbitrage Opportunity on Bitget: AI16Z/USDT | 2025-04-12 01:50:29 WIB
#   ✅ Spot Price: 0.13650 USDT
#   ✅ Futures Price: 0.13630 USDT
#   ✅ Spread: -0.1465%
#   ✅ Net Profit After Fees: -0.3065%
# ⚠️  Arbitrage Signal on Bitget - AI16Z/USDT
# Spread: -0.1465% | Net Profit: -0.3065%
# 🔎 Arbitrage Opportunity on Bitget: GPS/USDT | 2025-04-12 01:50:29 WIB
#   ✅ Spot Price: 0.02150 USDT
#   ✅ Futures Price: 0.02136 USDT
#   ✅ Spread: -0.6512%
#   ✅ Net Profit After Fees: -0.8112%
# ⚠️  Arbitrage Signal on Bitget - GPS/USDT
# Spread: -0.6512% | Net Profit: -0.8112%
# 🔎 Arbitrage Opportunity on Bitget: SOLV/USDT | 2025-04-12 01:50:29 WIB
#   ✅ Spot Price: 0.02521 USDT
#   ✅ Futures Price: 0.02512 USDT
#   ✅ Spread: -0.3570%
#   ✅ Net Profit After Fees: -0.5170%
# ⚠️  Arbitrage Signal on Bitget - SOLV/USDT
# Spread: -0.3570% | Net Profit: -0.5170%
# 🔎 Arbitrage Opportunity on Bitget: PIPPIN/USDT | 2025-04-12 01:50:30 WIB
#   ✅ Spot Price: 0.01228 USDT
#   ✅ Futures Price: 0.01226 USDT
#   ✅ Spread: -0.1629%
#   ✅ Net Profit After Fees: -0.3229%
# ⚠️  Arbitrage Signal on Bitget - PIPPIN/USDT
# Spread: -0.1629% | Net Profit: -0.3229%
# 🔎 Arbitrage Opportunity on Bitget: HIVE/USDT | 2025-04-12 01:50:30 WIB
#   ✅ Spot Price: 0.22170 USDT
#   ✅ Futures Price: 0.22150 USDT
#   ✅ Spread: -0.0902%
#   ✅ Net Profit After Fees: -0.2502%
# ⚠️  Arbitrage Signal on Bitget - HIVE/USDT
# Spread: -0.0902% | Net Profit: -0.2502%
# 🔎 Arbitrage Opportunity on Bitget: S/USDT | 2025-04-12 01:50:31 WIB
#   ✅ Spot Price: 0.48600 USDT
#   ✅ Futures Price: 0.48550 USDT
#   ✅ Spread: -0.1029%
#   ✅ Net Profit After Fees: -0.2629%
# ⚠️  Arbitrage Signal on Bitget - S/USDT
# Spread: -0.1029% | Net Profit: -0.2629%
# 🔎 Arbitrage Opportunity on Bitget: MELANIA/USDT | 2025-04-12 01:50:31 WIB
#   ✅ Spot Price: 0.50300 USDT
#   ✅ Futures Price: 0.50200 USDT
#   ✅ Spread: -0.1988%
#   ✅ Net Profit After Fees: -0.3588%
# ⚠️  Arbitrage Signal on Bitget - MELANIA/USDT
# Spread: -0.1988% | Net Profit: -0.3588%
# 🔎 Arbitrage Opportunity on Bitget: TRUMP/USDT | 2025-04-12 01:50:31 WIB
#   ✅ Spot Price: 8.11100 USDT
#   ✅ Futures Price: 8.11300 USDT
#   ✅ Spread: 0.0247%
#   ✅ Net Profit After Fees: -0.1353%
# ⚠️  Arbitrage Signal on Bitget - TRUMP/USDT
# Spread: 0.0247% | Net Profit: -0.1353%
# 🔎 Arbitrage Opportunity on Bitget: AVAAI/USDT | 2025-04-12 01:50:31 WIB
#   ✅ Spot Price: 0.02170 USDT
#   ✅ Futures Price: 0.02179 USDT
#   ✅ Spread: 0.4147%
#   ✅ Net Profit After Fees: 0.2547%
# ⚠️  Arbitrage Signal on Bitget - AVAAI/USDT
# Spread: 0.4147% | Net Profit: 0.2547%
# 🔎 Arbitrage Opportunity on Bitget: DUCK/USDT | 2025-04-12 01:50:32 WIB
#   ✅ Spot Price: 0.00244 USDT
#   ✅ Futures Price: 0.00244 USDT
#   ✅ Spread: -0.2458%
#   ✅ Net Profit After Fees: -0.4058%
# ⚠️  Arbitrage Signal on Bitget - DUCK/USDT
# Spread: -0.2458% | Net Profit: -0.4058%
# 🔎 Arbitrage Opportunity on Bitget: VINE/USDT | 2025-04-12 01:50:32 WIB
#   ✅ Spot Price: 0.03923 USDT
#   ✅ Futures Price: 0.03919 USDT
#   ✅ Spread: -0.1020%
#   ✅ Net Profit After Fees: -0.2620%
# ⚠️  Arbitrage Signal on Bitget - VINE/USDT
# Spread: -0.1020% | Net Profit: -0.2620%
# 🔎 Arbitrage Opportunity on Bitget: ANIME/USDT | 2025-04-12 01:50:32 WIB
#   ✅ Spot Price: 0.01520 USDT
#   ✅ Futures Price: 0.01517 USDT
#   ✅ Spread: -0.1974%
#   ✅ Net Profit After Fees: -0.3574%
# ⚠️  Arbitrage Signal on Bitget - ANIME/USDT
# Spread: -0.1974% | Net Profit: -0.3574%
# 🔎 Arbitrage Opportunity on Bitget: VTHO/USDT | 2025-04-12 01:50:33 WIB
#   ✅ Spot Price: 0.00214 USDT
#   ✅ Futures Price: 0.00214 USDT
#   ✅ Spread: -0.0468%
#   ✅ Net Profit After Fees: -0.2068%
# ⚠️  Arbitrage Signal on Bitget - VTHO/USDT
# Spread: -0.0468% | Net Profit: -0.2068%
# 🔎 Arbitrage Opportunity on Bitget: J/USDT | 2025-04-12 01:50:33 WIB
#   ✅ Spot Price: 0.18970 USDT
#   ✅ Futures Price: 0.18950 USDT
#   ✅ Spread: -0.1054%
#   ✅ Net Profit After Fees: -0.2654%
# ⚠️  Arbitrage Signal on Bitget - J/USDT
# Spread: -0.1054% | Net Profit: -0.2654%
# 🔎 Arbitrage Opportunity on Bitget: PLUME/USDT | 2025-04-12 01:50:33 WIB
#   ✅ Spot Price: 0.16222 USDT
#   ✅ Futures Price: 0.16210 USDT
#   ✅ Spread: -0.0740%
#   ✅ Net Profit After Fees: -0.2340%
# ⚠️  Arbitrage Signal on Bitget - PLUME/USDT
# Spread: -0.0740% | Net Profit: -0.2340%
# 🔎 Arbitrage Opportunity on Bitget: BERA/USDT | 2025-04-12 01:50:34 WIB
#   ✅ Spot Price: 4.24700 USDT
#   ✅ Futures Price: 4.23700 USDT
#   ✅ Spread: -0.2355%
#   ✅ Net Profit After Fees: -0.3955%
# ⚠️  Arbitrage Signal on Bitget - BERA/USDT
# Spread: -0.2355% | Net Profit: -0.3955%
# 🔎 Arbitrage Opportunity on Bitget: AEVO/USDT | 2025-04-12 01:50:35 WIB
#   ✅ Spot Price: 0.09610 USDT
#   ✅ Futures Price: 0.09560 USDT
#   ✅ Spread: -0.5203%
#   ✅ Net Profit After Fees: -0.6803%
# ⚠️  Arbitrage Signal on Bitget - AEVO/USDT
# Spread: -0.5203% | Net Profit: -0.6803%
# 🔎 Arbitrage Opportunity on Bitget: ID/USDT | 2025-04-12 01:50:35 WIB
#   ✅ Spot Price: 0.18190 USDT
#   ✅ Futures Price: 0.18180 USDT
#   ✅ Spread: -0.0550%
#   ✅ Net Profit After Fees: -0.2150%
# ⚠️  Arbitrage Signal on Bitget - ID/USDT
# Spread: -0.0550% | Net Profit: -0.2150%
# 🔎 Arbitrage Opportunity on Bitget: ARB/USDT | 2025-04-12 01:50:36 WIB
#   ✅ Spot Price: 0.29750 USDT
#   ✅ Futures Price: 0.29750 USDT
#   ✅ Spread: 0.0000%
#   ✅ Net Profit After Fees: -0.1600%
# ⚠️  Arbitrage Signal on Bitget - ARB/USDT
# Spread: 0.0000% | Net Profit: -0.1600%
# 🔎 Arbitrage Opportunity on Bitget: TAO/USDT | 2025-04-12 01:50:36 WIB
#   ✅ Spot Price: 252.20000 USDT
#   ✅ Futures Price: 251.99000 USDT
#   ✅ Spread: -0.0833%
#   ✅ Net Profit After Fees: -0.2433%
# ⚠️  Arbitrage Signal on Bitget - TAO/USDT
# Spread: -0.0833% | Net Profit: -0.2433%
# 🔎 Arbitrage Opportunity on Bitget: BOME/USDT | 2025-04-12 01:50:36 WIB
#   ✅ Spot Price: 0.00114 USDT
#   ✅ Futures Price: 0.00114 USDT
#   ✅ Spread: -0.1753%
#   ✅ Net Profit After Fees: -0.3353%
# ⚠️  Arbitrage Signal on Bitget - BOME/USDT
# Spread: -0.1753% | Net Profit: -0.3353%
# 🔎 Arbitrage Opportunity on Bitget: BRETT/USDT | 2025-04-12 01:50:36 WIB
#   ✅ Spot Price: 0.02735 USDT
#   ✅ Futures Price: 0.02737 USDT
#   ✅ Spread: 0.0731%
#   ✅ Net Profit After Fees: -0.0869%
# ⚠️  Arbitrage Signal on Bitget - BRETT/USDT
# Spread: 0.0731% | Net Profit: -0.0869%
# 🔎 Arbitrage Opportunity on Bitget: CGPT/USDT | 2025-04-12 01:50:36 WIB
#   ✅ Spot Price: 0.06839 USDT
#   ✅ Futures Price: 0.06823 USDT
#   ✅ Spread: -0.2340%
#   ✅ Net Profit After Fees: -0.3940%
# ⚠️  Arbitrage Signal on Bitget - CGPT/USDT
# Spread: -0.2340% | Net Profit: -0.3940%
# 🔎 Arbitrage Opportunity on Bitget: PENDLE/USDT | 2025-04-12 01:50:37 WIB
#   ✅ Spot Price: 3.29200 USDT
#   ✅ Futures Price: 3.28990 USDT
#   ✅ Spread: -0.0638%
#   ✅ Net Profit After Fees: -0.2238%
# ⚠️  Arbitrage Signal on Bitget - PENDLE/USDT
# Spread: -0.0638% | Net Profit: -0.2238%
# 🔎 Arbitrage Opportunity on Bitget: PEPE/USDT | 2025-04-12 01:50:37 WIB
#   ✅ Spot Price: 0.00001 USDT
#   ✅ Futures Price: 0.00001 USDT
#   ✅ Spread: 0.0447%
#   ✅ Net Profit After Fees: -0.1153%
# ⚠️  Arbitrage Signal on Bitget - PEPE/USDT
# Spread: 0.0447% | Net Profit: -0.1153%
# 🔎 Arbitrage Opportunity on Bitget: ZKJ/USDT | 2025-04-12 01:50:38 WIB
#   ✅ Spot Price: 2.26000 USDT
#   ✅ Futures Price: 2.26100 USDT
#   ✅ Spread: 0.0442%
#   ✅ Net Profit After Fees: -0.1158%
# ⚠️  Arbitrage Signal on Bitget - ZKJ/USDT
# Spread: 0.0442% | Net Profit: -0.1158%
# 🔎 Arbitrage Opportunity on Bitget: SLERF/USDT | 2025-04-12 01:50:38 WIB
#   ✅ Spot Price: 0.05630 USDT
#   ✅ Futures Price: 0.05611 USDT
#   ✅ Spread: -0.3375%
#   ✅ Net Profit After Fees: -0.4975%
# ⚠️  Arbitrage Signal on Bitget - SLERF/USDT
# Spread: -0.3375% | Net Profit: -0.4975%
# 🔎 Arbitrage Opportunity on Bitget: SUI/USDT | 2025-04-12 01:50:39 WIB
#   ✅ Spot Price: 2.23500 USDT
#   ✅ Futures Price: 2.23330 USDT
#   ✅ Spread: -0.0761%
#   ✅ Net Profit After Fees: -0.2361%
# ⚠️  Arbitrage Signal on Bitget - SUI/USDT
# Spread: -0.0761% | Net Profit: -0.2361%
# 🔎 Arbitrage Opportunity on Bitget: DegenReborn/USDT | 2025-04-12 01:50:39 WIB
#   ✅ Spot Price: 0.00223 USDT
#   ✅ Futures Price: 0.00222 USDT
#   ✅ Spread: -0.2242%
#   ✅ Net Profit After Fees: -0.3842%
# ⚠️  Arbitrage Signal on Bitget - DegenReborn/USDT
# Spread: -0.2242% | Net Profit: -0.3842%
# 🔎 Arbitrage Opportunity on Bitget: TURBO/USDT | 2025-04-12 01:50:39 WIB
#   ✅ Spot Price: 0.00179 USDT
#   ✅ Futures Price: 0.00178 USDT
#   ✅ Spread: -0.3356%
#   ✅ Net Profit After Fees: -0.4956%
# ⚠️  Arbitrage Signal on Bitget - TURBO/USDT
# Spread: -0.3356% | Net Profit: -0.4956%
# 🔎 Arbitrage Opportunity on Bitget: KAS/USDT | 2025-04-12 01:50:39 WIB
#   ✅ Spot Price: 0.07550 USDT
#   ✅ Futures Price: 0.07534 USDT
#   ✅ Spread: -0.2119%
#   ✅ Net Profit After Fees: -0.3719%
# ⚠️  Arbitrage Signal on Bitget - KAS/USDT
# Spread: -0.2119% | Net Profit: -0.3719%
# 🔎 Arbitrage Opportunity on Bitget: ORDI/USDT | 2025-04-12 01:50:40 WIB
#   ✅ Spot Price: 7.15000 USDT
#   ✅ Futures Price: 7.13700 USDT
#   ✅ Spread: -0.1818%
#   ✅ Net Profit After Fees: -0.3418%
# ⚠️  Arbitrage Signal on Bitget - ORDI/USDT
# Spread: -0.1818% | Net Profit: -0.3418%
# 🔎 Arbitrage Opportunity on Bitget: AERO/USDT | 2025-04-12 01:50:40 WIB
#   ✅ Spot Price: 0.38600 USDT
#   ✅ Futures Price: 0.38550 USDT
#   ✅ Spread: -0.1295%
#   ✅ Net Profit After Fees: -0.2895%
# ⚠️  Arbitrage Signal on Bitget - AERO/USDT
# Spread: -0.1295% | Net Profit: -0.2895%
# 🔎 Arbitrage Opportunity on Bitget: ZIL/USDT | 2025-04-12 01:50:41 WIB
#   ✅ Spot Price: 0.01106 USDT
#   ✅ Futures Price: 0.01103 USDT
#   ✅ Spread: -0.2712%
#   ✅ Net Profit After Fees: -0.4312%
# ⚠️  Arbitrage Signal on Bitget - ZIL/USDT
# Spread: -0.2712% | Net Profit: -0.4312%
# 🔎 Arbitrage Opportunity on Bitget: MAV/USDT | 2025-04-12 01:50:41 WIB
#   ✅ Spot Price: 0.05281 USDT
#   ✅ Futures Price: 0.05277 USDT
#   ✅ Spread: -0.0757%
#   ✅ Net Profit After Fees: -0.2357%
# ⚠️  Arbitrage Signal on Bitget - MAV/USDT
# Spread: -0.0757% | Net Profit: -0.2357%
# 🔎 Arbitrage Opportunity on Bitget: AMP/USDT | 2025-04-12 01:50:41 WIB
#   ✅ Spot Price: 0.00374 USDT
#   ✅ Futures Price: 0.00373 USDT
#   ✅ Spread: -0.3209%
#   ✅ Net Profit After Fees: -0.4809%
# ⚠️  Arbitrage Signal on Bitget - AMP/USDT
# Spread: -0.3209% | Net Profit: -0.4809%
# 🔎 Arbitrage Opportunity on Bitget: LPT/USDT | 2025-04-12 01:50:42 WIB
#   ✅ Spot Price: 3.96000 USDT
#   ✅ Futures Price: 3.95200 USDT
#   ✅ Spread: -0.2020%
#   ✅ Net Profit After Fees: -0.3620%
# ⚠️  Arbitrage Signal on Bitget - LPT/USDT
# Spread: -0.2020% | Net Profit: -0.3620%
# 🔎 Arbitrage Opportunity on Bitget: PAXG/USDT | 2025-04-12 01:50:42 WIB
#   ✅ Spot Price: 3259.00000 USDT
#   ✅ Futures Price: 3259.62000 USDT
#   ✅ Spread: 0.0190%
#   ✅ Net Profit After Fees: -0.1410%
# ⚠️  Arbitrage Signal on Bitget - PAXG/USDT
# Spread: 0.0190% | Net Profit: -0.1410%
# 🔎 Arbitrage Opportunity on Bitget: GLM/USDT | 2025-04-12 01:50:42 WIB
#   ✅ Spot Price: 0.24310 USDT
#   ✅ Futures Price: 0.24260 USDT
#   ✅ Spread: -0.2057%
#   ✅ Net Profit After Fees: -0.3657%
# ⚠️  Arbitrage Signal on Bitget - GLM/USDT
# Spread: -0.2057% | Net Profit: -0.3657%
# 🔎 Arbitrage Opportunity on Bitget: FLUX/USDT | 2025-04-12 01:50:43 WIB
#   ✅ Spot Price: 0.21390 USDT
#   ✅ Futures Price: 0.21410 USDT
#   ✅ Spread: 0.0935%
#   ✅ Net Profit After Fees: -0.0665%
# ⚠️  Arbitrage Signal on Bitget - FLUX/USDT
# Spread: 0.0935% | Net Profit: -0.0665%
# 🔎 Arbitrage Opportunity on Bitget: ROSE/USDT | 2025-04-12 01:50:43 WIB
#   ✅ Spot Price: 0.02410 USDT
#   ✅ Futures Price: 0.02413 USDT
#   ✅ Spread: 0.1245%
#   ✅ Net Profit After Fees: -0.0355%
# ⚠️  Arbitrage Signal on Bitget - ROSE/USDT
# Spread: 0.1245% | Net Profit: -0.0355%
# 🔎 Arbitrage Opportunity on Bitget: NEAR/USDT | 2025-04-12 01:50:43 WIB
#   ✅ Spot Price: 2.09700 USDT
#   ✅ Futures Price: 2.09300 USDT
#   ✅ Spread: -0.1907%
#   ✅ Net Profit After Fees: -0.3507%
# ⚠️  Arbitrage Signal on Bitget - NEAR/USDT
# Spread: -0.1907% | Net Profit: -0.3507%
