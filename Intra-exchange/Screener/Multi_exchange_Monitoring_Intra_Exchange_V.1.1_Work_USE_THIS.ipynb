# %%
import ccxt
import time

# Replace with your actual API keys for Bybit and Bitget
BYBIT_API_KEY = 'I6m01uNAWiensHbIBA'
BYBIT_API_SECRET = 'vkaviS9xw903NJPncMtHgGfyiWB4mnhSJTyK'
BITGET_API_KEY = 'bg_b0a9d721607623216a87b066a3df34c3'
BITGET_API_SECRET = '6c4a5016562624b6d7f3b1c59563d4a1a573f630e0e49422fbf509399e56918b'

# Connect to Bybit API
bybit = ccxt.bybit({
    'apiKey': BYBIT_API_KEY,
    'secret': BYBIT_API_SECRET,
    'options': {'adjustForTimeDifference': True}
})

# Connect to Bitget API
bitget = ccxt.bitget({
    'apiKey': BITGET_API_KEY,
    'secret': BITGET_API_SECRET,
    'options': {'adjustForTimeDifference': True}
})

# %%
# Arbitrage settings
SPREAD_THRESHOLD = 0.5 / 100  # 0.5% profit target
MIN_VOLUME = 50000  # Minimum 24h volume required (in USDT)
CHECK_INTERVAL = 5  # Check every 5 seconds
TRADING_FEE = 0.001  # 0.1% trading fee per trade

exchanges = {'Bybit': bybit, 'Bitget': bitget}

def get_tradable_tokens(exchange, exchange_name):
    """Fetches all tradable tokens on an exchange and filters out low-volume pairs"""
    try:
        markets = exchange.load_markets()
        tradable_tokens = []
        for symbol, market in markets.items():
            if exchange_name == "Bitget":
                if not market.get('spot', False):  # Ensure it's a spot market
                    continue
            if '/USDT' in symbol and ':USDT' not in symbol:
                try:
                    market_data = exchange.fetch_ticker(symbol)
                    volume = market_data.get('quoteVolume', 0)
                    if volume and volume >= MIN_VOLUME:
                        tradable_tokens.append(symbol)
                except Exception as e:
                    print(f"⚠️ Skipping {symbol} on {exchange_name} due to error: {e}")
        print(f"✅ Found {len(tradable_tokens)} tradable tokens on {exchange_name}")
        return tradable_tokens
    except Exception as e:
        print(f"❌ Error fetching tradable tokens from {exchange_name}: {e}")
        return []

def get_price(exchange, symbol):
    """Fetch latest price for a given token if the market exists on an exchange"""
    try:
        if symbol in exchange.load_markets():
            ticker = exchange.fetch_ticker(symbol)
            return ticker.get("last", None)
    except Exception as e:
        print(f"❌ Error fetching price for {symbol} on {exchange}: {e}")
    return None

def check_intra_exchange_arbitrage(exchange, exchange_name, symbol):
    """Checks for spot vs futures arbitrage opportunities within an exchange"""
    spot_price = get_price(exchange, symbol)
    futures_symbol = symbol.replace('/USDT', '/USDT:USDT')

    if futures_symbol not in exchange.load_markets():
        return
    
    futures_price = get_price(exchange, futures_symbol)
    if not spot_price or not futures_price:
        return
    
    spread = (futures_price - spot_price) / spot_price  # Calculate spread %
    net_profit = spread - (TRADING_FEE * 2)  # Adjust for fees

    if net_profit >= SPREAD_THRESHOLD:
        print(f"🔍 Arbitrage Opportunity on {exchange_name}: {symbol}")
        print(f"    ✅ Spot Price: {spot_price:.2f} USDT")
        print(f"    ✅ Futures Price: {futures_price:.2f} USDT")
        print(f"    ✅ Spread: {spread:.4%}")
        print(f"    ✅ Net Profit After Fees: {net_profit:.4%}")
        print(f"    ⚡ Execute arbitrage on {exchange_name}")
        print("-" * 50)

def main():
    while True:
        try:
            for exchange_name, exchange in exchanges.items():
                tradable_tokens = get_tradable_tokens(exchange, exchange_name)
                if not tradable_tokens:
                    print(f"❌ No tradable tokens found on {exchange_name}. Retrying in 10 seconds...")
                    time.sleep(10)
                    continue
                print(f"🔄 Checking for arbitrage opportunities on {exchange_name}...")
                for token in tradable_tokens:
                    check_intra_exchange_arbitrage(exchange, exchange_name, token)
            print("✅ Cycle complete. Waiting for next check...")
            time.sleep(CHECK_INTERVAL)
        except Exception as e:
            print(f"❌ Error in main loop: {e}")
            time.sleep(10)

if __name__ == "__main__":
    main()
# Out:
# ✅ Found 430 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 550 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: LUCE/USDT
#     ✅ Spot Price: 0.01 USDT
#     ✅ Futures Price: 0.01 USDT
#     ✅ Spread: 0.7114%
#     ✅ Net Profit After Fees: 0.5114%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 430 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 549 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: AEVO/USDT
#     ✅ Spot Price: 0.13 USDT
#     ✅ Futures Price: 0.13 USDT
#     ✅ Spread: 0.9050%
#     ✅ Net Profit After Fees: 0.7050%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 430 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 549 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: AEVO/USDT
#     ✅ Spot Price: 0.13 USDT
#     ✅ Futures Price: 0.13 USDT
#     ✅ Spread: 0.9050%
#     ✅ Net Profit After Fees: 0.7050%
#     ⚡ Execute arbitrage on Bitget
# --------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 429 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 550 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# ❌ Error fetching price for XION/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=XIONUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for HBAR/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HBARUSDT
# ❌ Error fetching price for HBAR/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=HBARUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for ALCH/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ALCHUSDT
# ❌ Error fetching price for ALCH/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=ALCHUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for KOMA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=KOMAUSDT
# ❌ Error fetching price for KOMA/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=KOMAUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for MOZ/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MOZUSDT
# ❌ Error fetching price for ME/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MEUSDT
# ❌ Error fetching price for ME/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=MEUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for BGSC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BGSCUSDT
# ❌ Error fetching price for BGSC/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=BGSCUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for MOVE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MOVEUSDT
# ❌ Error fetching price for MOVE/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=MOVEUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for ARC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ARCUSDT
# ❌ Error fetching price for ARC/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=ARCUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for STNK/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=STNKUSDT
# ❌ Error fetching price for GRIFFAIN/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GRIFFAINUSDT
# ❌ Error fetching price for GRIFFAIN/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=GRIFFAINUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for HYPE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HYPEUSDT
# ❌ Error fetching price for HYPE/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=HYPEUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for REX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=REXUSDT
# ❌ Error fetching price for ISLAND/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ISLANDUSDT
# ❌ Error fetching price for USUAL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=USUALUSDT
# ❌ Error fetching price for USUAL/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=USUALUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for PENGU/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PENGUUSDT
# ❌ Error fetching price for PENGU/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=PENGUUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for VANA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=VANAUSDT
# ❌ Error fetching price for VANA/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=VANAUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for ALGO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ALGOUSDT
# ❌ Error fetching price for ALGO/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=ALGOUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for FUEL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FUELUSDT
# ❌ Error fetching price for FUEL/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=FUELUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for SONIC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SONICUSDT
# ❌ Error fetching price for SONIC/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=SONICUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for BIO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BIOUSDT
# ❌ Error fetching price for BIO/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=BIOUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for SWARMS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SWARMSUSDT
# ❌ Error fetching price for SWARMS/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=SWARMSUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for ZEREBRO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZEREBROUSDT
# ❌ Error fetching price for ZEREBRO/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=ZEREBROUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for PHA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PHAUSDT
# ❌ Error fetching price for PHA/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=PHAUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for AI16Z/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AI16ZUSDT
# ❌ Error fetching price for AI16Z/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=AI16ZUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for GPS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GPSUSDT
# ❌ Error fetching price for GPS/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=GPSUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for SOLV/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SOLVUSDT
# ❌ Error fetching price for SOLV/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=SOLVUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for TREAT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TREATUSDT
# ❌ Error fetching price for PIPPIN/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PIPPINUSDT
# ❌ Error fetching price for PIPPIN/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=PIPPINUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for D/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DUSDT
# ❌ Error fetching price for BUZZ/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BUZZUSDT
# ❌ Error fetching price for U2U/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=U2UUSDT
# ❌ Error fetching price for XTER/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=XTERUSDT
# ❌ Error fetching price for HIVE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HIVEUSDT
# ❌ Error fetching price for HIVE/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=HIVEUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for S/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SUSDT
# ❌ Error fetching price for S/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=SUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for MELANIA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MELANIAUSDT
# ❌ Error fetching price for MELANIA/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=MELANIAUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for TRUMP/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TRUMPUSDT
# ❌ Error fetching price for TRUMP/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=TRUMPUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for AVAAI/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AVAAIUSDT
# ❌ Error fetching price for AVAAI/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=AVAAIUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for MXNA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MXNAUSDT
# ❌ Error fetching price for DUCK/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DUCKUSDT
# ❌ Error fetching price for DUCK/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=DUCKUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for USDS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=USDSUSDT
# ❌ Error fetching price for VINE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=VINEUSDT
# ❌ Error fetching price for VINE/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=VINEUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for ANIME/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ANIMEUSDT
# ❌ Error fetching price for ANIME/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=ANIMEUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for SKY/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SKYUSDT
# ❌ Error fetching price for MDOGS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MDOGSUSDT
# ❌ Error fetching price for VTHO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=VTHOUSDT
# ❌ Error fetching price for VTHO/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=VTHOUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for PLUME/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PLUMEUSDT
# ❌ Error fetching price for PLUME/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=PLUMEUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for TRIAS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TRIASUSDT
# ❌ Error fetching price for ANLOG/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ANLOGUSDT
# ❌ Error fetching price for JELLYJELLY/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=JELLYJELLYUSDT
# ❌ Error fetching price for GPT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GPTUSDT
# ❌ Error fetching price for ICE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ICEUSDT
# ❌ Error fetching price for UFD/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=UFDUSDT
# ❌ Error fetching price for ML/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MLUSDT
# ❌ Error fetching price for MAPO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MAPOUSDT
# ❌ Error fetching price for NESS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NESSUSDT
# ❌ Error fetching price for BERA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BERAUSDT
# ❌ Error fetching price for BERA/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=BERAUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for NUUM/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NUUMUSDT
# ❌ Error fetching price for KLV/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=KLVUSDT
# ❌ Error fetching price for AEVO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AEVOUSDT
# ❌ Error fetching price for AEVO/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=AEVOUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for FMB/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FMBUSDT
# ❌ Error fetching price for ID/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=IDUSDT
# ❌ Error fetching price for ID/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=IDUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for SCA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SCAUSDT
# ❌ Error fetching price for ARB/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ARBUSDT
# ❌ Error fetching price for ARB/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=ARBUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for TAO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TAOUSDT
# ❌ Error fetching price for TAO/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=TAOUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for ETHFI/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ETHFIUSDT
# ❌ Error fetching price for ETHFI/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=ETHFIUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for BOME/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BOMEUSDT
# ❌ Error fetching price for BOME/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=BOMEUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for BRETT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BRETTUSDT
# ❌ Error fetching price for BRETT/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=BRETTUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for CGPT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CGPTUSDT
# ❌ Error fetching price for CGPT/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=CGPTUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for CREO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CREOUSDT
# ❌ Error fetching price for PENDLE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PENDLEUSDT
# ❌ Error fetching price for PENDLE/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=PENDLEUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for STETH/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=STETHUSDT
# ❌ Error fetching price for AIDOGE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AIDOGEUSDT
# ❌ Error fetching price for PEPE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PEPEUSDT
# ❌ Error fetching price for PEPE/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=PEPEUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for SHIDO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SHIDOUSDT
# ❌ Error fetching price for SLERF/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SLERFUSDT
# ❌ Error fetching price for SLERF/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=SLERFUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for TOMI/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TOMIUSDT
# ❌ Error fetching price for ALE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ALEUSDT
# ❌ Error fetching price for MC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MCUSDT
# ❌ Error fetching price for MVL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MVLUSDT
# ❌ Error fetching price for SUI/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SUIUSDT
# ❌ Error fetching price for SUI/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=SUIUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for DegenReborn/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DEGENUSDT
# ❌ Error fetching price for DegenReborn/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=DEGENUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for TURBO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TURBOUSDT
# ❌ Error fetching price for TURBO/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=TURBOUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for KAS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=KASUSDT
# ❌ Error fetching price for KAS/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=KASUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for PCI/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PCIUSDT
# ❌ Error fetching price for GFI/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GFIUSDT
# ❌ Error fetching price for ZBU/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZBUUSDT
# ❌ Error fetching price for ORDI/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ORDIUSDT
# ❌ Error fetching price for ORDI/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=ORDIUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for CATBOY/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CATBOYUSDT
# ❌ Error fetching price for AERO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AEROUSDT
# ❌ Error fetching price for AERO/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=AEROUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for LADYS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LADYSUSDT
# ❌ Error fetching price for USDE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=USDEUSDT
# ❌ Error fetching price for PROPC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PROPCUSDT
# ❌ Error fetching price for COMBO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=COMBOUSDT
# ❌ Error fetching price for ZIL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZILUSDT
# ❌ Error fetching price for ZIL/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=ZILUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for MAV/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MAVUSDT
# ❌ Error fetching price for MAV/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=MAVUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for AMP/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AMPUSDT
# ❌ Error fetching price for LPT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LPTUSDT
# ❌ Error fetching price for LPT/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=LPTUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for PEPE2/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PEPE2USDT
# ❌ Error fetching price for PAXG/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PAXGUSDT
# ❌ Error fetching price for PAXG/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=PAXGUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for TEL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TELUSDT
# ❌ Error fetching price for TUSD/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TUSDUSDT
# ❌ Error fetching price for BTT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BTTUSDT
# ❌ Error fetching price for GLM/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GLMUSDT
# ❌ Error fetching price for GLM/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=GLMUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for NYM/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NYMUSDT
# ❌ Error fetching price for VT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=VTUSDT
# ❌ Error fetching price for FLUX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FLUXUSDT
# ❌ Error fetching price for FLUX/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=FLUXUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for FITFI/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FITFIUSDT
# ❌ Error fetching price for ROSE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ROSEUSDT
# ❌ Error fetching price for ROSE/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=ROSEUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for NEAR/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NEARUSDT
# ❌ Error fetching price for NEAR/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=NEARUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for DAI/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DAIUSDT
# ❌ Error fetching price for HNT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HNTUSDT
# ❌ Error fetching price for HNT/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=HNTUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for WAXP/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WAXPUSDT
# ❌ Error fetching price for WAXP/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=WAXPUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for GALFAN/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GALFANUSDT
# ❌ Error fetching price for LINA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LINAUSDT
# ❌ Error fetching price for ENJ/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ENJUSDT
# ❌ Error fetching price for ENJ/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=ENJUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for MANA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MANAUSDT
# ❌ Error fetching price for MANA/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=MANAUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for XRP/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=XRPUSDT
# ❌ Error fetching price for XRP/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=XRPUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for BTC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BTCUSDT
# ❌ Error fetching price for BTC/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=BTCUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for ETH/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ETHUSDT
# ❌ Error fetching price for ETH/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=ETHUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for LTC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LTCUSDT
# ❌ Error fetching price for LTC/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=LTCUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for BCH/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BCHUSDT
# ❌ Error fetching price for BCH/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=BCHUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for ETC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ETCUSDT
# ❌ Error fetching price for ETC/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=ETCUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for EOS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=EOSUSDT
# ❌ Error fetching price for EOS/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=EOSUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for SHIB/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SHIBUSDT
# ❌ Error fetching price for SHIB/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=SHIBUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for 1INCH/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=1INCHUSDT
# ❌ Error fetching price for 1INCH/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=1INCHUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for MKR/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MKRUSDT
# ❌ Error fetching price for MKR/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=MKRUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for REN/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RENUSDT
# ❌ Error fetching price for UMA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=UMAUSDT
# ❌ Error fetching price for UMA/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=UMAUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for ZRX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZRXUSDT
# ❌ Error fetching price for ZRX/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=ZRXUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for LUNC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LUNCUSDT
# ❌ Error fetching price for LUNC/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=LUNCUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for SXP/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SXPUSDT
# ❌ Error fetching price for SXP/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=SXPUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for OP/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=OPUSDT
# ❌ Error fetching price for OP/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=OPUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for LRC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LRCUSDT
# ❌ Error fetching price for LRC/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=LRCUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for BAL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BALUSDT
# ❌ Error fetching price for BNT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BNTUSDT
# ❌ Error fetching price for BNT/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=BNTUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for CRV/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CRVUSDT
# ❌ Error fetching price for CRV/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=CRVUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for STORJ/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=STORJUSDT
# ❌ Error fetching price for STORJ/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=STORJUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for SNX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SNXUSDT
# ❌ Error fetching price for SNX/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=SNXUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for QTUM/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=QTUMUSDT
# ❌ Error fetching price for QTUM/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=QTUMUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for OMG/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=OMGUSDT
# ❌ Error fetching price for KNC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=KNCUSDT
# ❌ Error fetching price for KNC/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=KNCUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for GRT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=GRTUSDT
# ❌ Error fetching price for GRT/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=GRTUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for JOE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=JOEUSDT
# ❌ Error fetching price for JOE/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=JOEUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for QUICK/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=QUICKUSDT
# ❌ Error fetching price for QUICK/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=QUICKUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for WBTC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WBTCUSDT
# ❌ Error fetching price for RLC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RLCUSDT
# ❌ Error fetching price for OGN/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=OGNUSDT
# ❌ Error fetching price for OGN/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=OGNUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for CAKE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CAKEUSDT
# ❌ Error fetching price for CAKE/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=CAKEUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for BNB/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BNBUSDT
# ❌ Error fetching price for BNB/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=BNBUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for CHR/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CHRUSDT
# ❌ Error fetching price for CHR/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=CHRUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for ANKR/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ANKRUSDT
# ❌ Error fetching price for ANKR/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=ANKRUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for RSR/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RSRUSDT
# ❌ Error fetching price for RSR/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=RSRUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for JST/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=JSTUSDT
# ❌ Error fetching price for ICP/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ICPUSDT
# ❌ Error fetching price for ICP/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=ICPUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for MASK/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MASKUSDT
# ❌ Error fetching price for MASK/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=MASKUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for TSTBSC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TSTBSCUSDT
# ❌ Error fetching price for TSTBSC/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=TSTBSCUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for BROCCOLI/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BROCCOLIUSDT
# ❌ Error fetching price for BROCCOLI/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=BROCCOLIUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for PI/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PIUSDT
# ❌ Error fetching price for PI/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=PIUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for SHELL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SHELLUSDT
# ❌ Error fetching price for SHELL/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=SHELLUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for SOL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SOLUSDT
# ❌ Error fetching price for SOL/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=SOLUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for IP/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=IPUSDT
# ❌ Error fetching price for IP/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=IPUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for HEI/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HEIUSDT
# ❌ Error fetching price for HEI/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=HEIUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for LAYER/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LAYERUSDT
# ❌ Error fetching price for LAYER/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=LAYERUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for JAILSTOOL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=JAILSTOOLUSDT
# ❌ Error fetching price for JAILSTOOL/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=JAILSTOOLUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for ZOO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZOOUSDT
# ❌ Error fetching price for BGSOL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BGSOLUSDT
# ❌ Error fetching price for KAITO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=KAITOUSDT
# ❌ Error fetching price for KAITO/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=KAITOUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for TAPS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TAPSUSDT
# ❌ Error fetching price for RED/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=REDUSDT
# ❌ Error fetching price for RED/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=REDUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for ROAM/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ROAMUSDT
# ❌ Error fetching price for ROAM/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=ROAMUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for FIL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FILUSDT
# ❌ Error fetching price for FIL/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=FILUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for DEUSD/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DEUSDUSDT
# ❌ Error fetching price for CELO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CELOUSDT
# ❌ Error fetching price for CELO/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=CELOUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for AB/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ABUSDT
# ❌ Error fetching price for BGB/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BGBUSDT
# ❌ Error fetching price for BGB/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=BGBUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for MEMHASH/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MEMHASHUSDT
# ❌ Error fetching price for YGG/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=YGGUSDT
# ❌ Error fetching price for YGG/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=YGGUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for PDA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PDAUSDT
# ❌ Error fetching price for LDO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LDOUSDT
# ❌ Error fetching price for LDO/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=LDOUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for OIK/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=OIKUSDT
# ❌ Error fetching price for OIK/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=OIKUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for LVVA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=LVVAUSDT
# ❌ Error fetching price for BMT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BMTUSDT
# ❌ Error fetching price for BMT/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=BMTUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for MINT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MINTUSDT
# ❌ Error fetching price for ELX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ELXUSDT
# ❌ Error fetching price for ELX/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=ELXUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for FORM/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FORMUSDT
# ❌ Error fetching price for FORM/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=FORMUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for BR/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BRUSDT
# ❌ Error fetching price for BR/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=BRUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for TUT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TUTUSDT
# ❌ Error fetching price for TUT/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=TUTUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for MUBARAK/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MUBARAKUSDT
# ❌ Error fetching price for MUBARAK/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=MUBARAKUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for BUBB/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BUBBUSDT
# ❌ Error fetching price for SIREN/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SIRENUSDT
# ❌ Error fetching price for SIREN/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=SIRENUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for MEW/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MEWUSDT
# ❌ Error fetching price for MEW/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=MEWUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for W/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WUSDT
# ❌ Error fetching price for W/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=WUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for IAG/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=IAGUSDT
# ❌ Error fetching price for SERSH/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SERSHUSDT
# ❌ Error fetching price for ENA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ENAUSDT
# ❌ Error fetching price for ENA/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=ENAUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for SAGA/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SAGAUSDT
# ❌ Error fetching price for SAGA/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=SAGAUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for TNSR/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=TNSRUSDT
# ❌ Error fetching price for TNSR/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=TNSRUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for MUMU/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MUMUUSDT
# ❌ Error fetching price for MOEW/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MOEWUSDT
# ❌ Error fetching price for OMNI1/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=OMNI1USDT
# ❌ Error fetching price for OMNI1/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=OMNI1USDT&productType=USDT-FUTURES
# ❌ Error fetching price for PRCL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PRCLUSDT
# ❌ Error fetching price for PRCL/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=PRCLUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for 0X0/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=0X0USDT
# ❌ Error fetching price for SAFE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SAFEUSDT
# ❌ Error fetching price for SAFE/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=SAFEUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for MERL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MERLUSDT
# ❌ Error fetching price for MERL/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=MERLUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for CKB/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CKBUSDT
# ❌ Error fetching price for CKB/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=CKBUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for ARKM/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ARKMUSDT
# ❌ Error fetching price for ARKM/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=ARKMUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for MOG/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MOGUSDT
# ❌ Error fetching price for SIX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SIXUSDT
# ❌ Error fetching price for MANEKI/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MANEKIUSDT
# ...
# ❌ Error fetching price for CVX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CVXUSDT
# ❌ Error fetching price for CVX/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=CVXUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for SPELL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SPELLUSDT
# ❌ Error fetching price for SPELL/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=SPELLUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for HOT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HOTUSDT
# ❌ Error fetching price for HOT/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=HOTUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for COTI/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=COTIUSDT
# ❌ Error fetching price for COTI/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=COTIUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for FXS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FXSUSDT
# ❌ Error fetching price for FXS/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=FXSUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for CEEK/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CEEKUSDT
# ❌ Error fetching price for FLOKI/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=FLOKIUSDT
# ❌ Error fetching price for FLOKI/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=FLOKIUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for RENDER/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RENDERUSDT
# ❌ Error fetching price for RENDER/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=RENDERUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for L3/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=L3USDT
# ❌ Error fetching price for MAX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MAXUSDT
# ❌ Error fetching price for MAX/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=MAXUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for INVITE/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=INVITEUSDT
# ❌ Error fetching price for NEIROETH/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NEIROETHUSDT
# ❌ Error fetching price for NEIROETH/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=NEIROETHUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for DTEC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DTECUSDT
# ❌ Error fetching price for AIN/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=AINUSDT
# ❌ Error fetching price for WUF/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WUFUSDT
# ❌ Error fetching price for ICX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ICXUSDT
# ❌ Error fetching price for ICX/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=ICXUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for DOGS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=DOGSUSDT
# ❌ Error fetching price for DOGS/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=DOGSUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for SUNDOG/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SUNDOGUSDT
# ❌ Error fetching price for SUNDOG/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=SUNDOGUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for CEC/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CECUSDT
# ❌ Error fetching price for MAK/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MAKUSDT
# ❌ Error fetching price for CPOOL/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CPOOLUSDT
# ❌ Error fetching price for BRN/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BRNUSDT
# ❌ Error fetching price for SLF/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=SLFUSDT
# ❌ Error fetching price for RFRM/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=RFRMUSDT
# ❌ Error fetching price for ORDER/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ORDERUSDT
# ❌ Error fetching price for ORDER/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=ORDERUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for BOX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=BOXUSDT
# ❌ Error fetching price for EGP/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=EGPUSDT
# ❌ Error fetching price for WAT/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=WATUSDT
# ❌ Error fetching price for CATI/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CATIUSDT
# ❌ Error fetching price for CATI/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=CATIUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for NEIROCTO/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=NEIROCTOUSDT
# ❌ Error fetching price for NEIROCTO/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=NEIROCTOUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for ZCX/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=ZCXUSDT
# ❌ Error fetching price for HMSTR/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=HMSTRUSDT
# ❌ Error fetching price for HMSTR/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=HMSTRUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for PUFFER/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=PUFFERUSDT
# ❌ Error fetching price for PUFFER/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=PUFFERUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for MOODENGETH/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MOODENGETHUSDT
# ❌ Error fetching price for CARV/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CARVUSDT
# ❌ Error fetching price for CARV/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=CARVUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for CATS/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=CATSUSDT
# ❌ Error fetching price for EIGEN/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=EIGENUSDT
# ❌ Error fetching price for EIGEN/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=EIGENUSDT&productType=USDT-FUTURES
# ❌ Error fetching price for MOODENG/USDT on Bitget: bitget GET https://api.bitget.com/api/v2/spot/market/tickers?symbol=MOODENGUSDT
# ❌ Error fetching price for MOODENG/USDT:USDT on Bitget: bitget GET https://api.bitget.com/api/v2/mix/market/ticker?symbol=MOODENGUSDT&productType=USDT-FUTURES
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 429 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 553 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 85
#      82             time.sleep(10)
#      84 if __name__ == "__main__":
# ---> 85     main()
#
# Cell In[2], line 77, in main()
#      75     print(f"🔄 Checking for arbitrage opportunities on {exchange_name}...")
#      76     for token in tradable_tokens:
# ---> 77         check_intra_exchange_arbitrage(exchange, exchange_name, token)
#      78 print("✅ Cycle complete. Waiting for next check...")
#      79 time.sleep(CHECK_INTERVAL)
#
# Cell In[2], line 44, in check_intra_exchange_arbitrage(exchange, exchange_name, symbol)
#      42 def check_intra_exchange_arbitrage(exchange, exchange_name, symbol):
#      43     """Checks for spot vs futures arbitrage opportunities within an exchange"""
# ---> 44     spot_price = get_price(exchange, symbol)
#      45     futures_symbol = symbol.replace('/USDT', '/USDT:USDT')
#      47     if futures_symbol not in exchange.load_markets():
#
# Cell In[2], line 36, in get_price(exchange, symbol)
#      34 try:
#      35     if symbol in exchange.load_markets():
# ---> 36         ticker = exchange.fetch_ticker(symbol)
#      37         return ticker.get("last", None)
#      38 except Exception as e:
#
# File ~\anaconda3\Lib\site-packages\ccxt\bitget.py:2840, in bitget.fetch_ticker(self, symbol, params)
#    2838 response = None
#    2839 if market['spot']:
# -> 2840     response = self.publicSpotGetV2SpotMarketTickers(self.extend(request, params))
#    2841 else:
#    2842     productType = None
#
# File ~\anaconda3\Lib\site-packages\ccxt\base\types.py:35, in Entry.__init__.<locals>.unbound_method(_self, params)
#      34 def unbound_method(_self, params={}):
# ---> 35     return _self.request(self.path, self.api, self.method, params, config=self.config)
#
# File ~\anaconda3\Lib\site-packages\ccxt\base\exchange.py:4368, in Exchange.request(self, path, api, method, params, headers, body, config)
#    4367 def request(self, path, api: Any = 'public', method='GET', params={}, headers: Any = None, body: Any = None, config={}):
# -> 4368     return self.fetch2(path, api, method, params, headers, body, config)
#
# File ~\anaconda3\Lib\site-packages\ccxt\base\exchange.py:4353, in Exchange.fetch2(self, path, api, method, params, headers, body, config)
#    4351 for i in range(0, retries + 1):
#    4352     try:
# -> 4353         return self.fetch(request['url'], request['method'], request['headers'], request['body'])
#    4354     except Exception as e:
#    4355         if isinstance(e, OperationFailed):
#
# File ~\anaconda3\Lib\site-packages\ccxt\base\exchange.py:548, in Exchange.fetch(self, url, method, headers, body)
#     546 json_response = None
#     547 try:
# --> 548     response = self.session.request(
#     549         method,
#     550         url,
#     551         data=body,
#     552         headers=request_headers,
#     553         timeout=(self.timeout / 1000),
#     554         proxies=proxies,
#     555         verify=self.verify and self.validateServerSsl
#     556     )
#     557     # does not try to detect encoding
#     558     response.encoding = 'utf-8'
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File ~\anaconda3\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File ~\anaconda3\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~\anaconda3\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~\anaconda3\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File ~\anaconda3\Lib\ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\Lib\ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:
