# %%
import ccxt
import time
import concurrent.futures

# Replace with your actual API keys for Bybit and Bitget
BYBIT_API_KEY = 'I6m01uNAWiensHbIBA'
BYBIT_API_SECRET = 'vkaviS9xw903NJPncMtHgGfyiWB4mnhSJTyK'
BITGET_API_KEY = 'bg_b0a9d721607623216a87b066a3df34c3'
BITGET_API_SECRET = '6c4a5016562624b6d7f3b1c59563d4a1a573f630e0e49422fbf509399e56918b'

# Connect to Bybit API
bybit = ccxt.bybit({
    'apiKey': BYBIT_API_KEY,
    'secret': BYBIT_API_SECRET,
    'options': {'adjustForTimeDifference': True}
})

# Connect to Bitget API
bitget = ccxt.bitget({
    'apiKey': BITGET_API_KEY,
    'secret': BITGET_API_SECRET,
    'options': {'adjustForTimeDifference': True}
})

# %%
# Arbitrage settings
SPREAD_THRESHOLD = 0.1 / 100  # 0.1% for testing
MIN_VOLUME = 50000  # Minimum 24h volume required (in USDT)
CHECK_INTERVAL = 5  # Check every 5 seconds

# Adjustable trading fees per exchange
TRADING_FEES = {
    'Bybit': 0.001,   # 0.1%
    'Bitget': 0.0008  # 0.08%
}

exchanges = {'Bybit': bybit, 'Bitget': bitget}

# Cache futures markets
futures_markets_cache = {}

def get_tradable_tokens(exchange, exchange_name):
    try:
        markets = exchange.load_markets()
        tradable_tokens = []
        futures_markets_cache[exchange_name] = [symbol for symbol in markets if ":USDT" in symbol]

        for symbol, market in markets.items():
            if exchange_name == "Bitget" and not market.get('spot', False):
                continue
            if '/USDT' in symbol and ':USDT' not in symbol:
                try:
                    market_data = exchange.fetch_ticker(symbol)
                    volume = market_data.get('quoteVolume', 0)
                    if volume and volume >= MIN_VOLUME:
                        tradable_tokens.append(symbol)
                except Exception:
                    continue
        print(f"✅ Found {len(tradable_tokens)} tradable tokens on {exchange_name}")
        return tradable_tokens
    except Exception as e:
        print(f"❌ Error fetching tradable tokens from {exchange_name}: {e}")
        return []

def get_price(exchange, symbol):
    try:
        ticker = exchange.fetch_ticker(symbol)
        return ticker.get("last", None)
    except Exception:
        return None

def find_futures_symbol(spot_symbol, futures_list):
    base = spot_symbol.split('/')[0]
    match = [f for f in futures_list if f.startswith(f"{base}/USDT") and ":USDT" in f]
    return match[0] if match else None

def check_intra_exchange_arbitrage(exchange, exchange_name, symbol):
    spot_price = get_price(exchange, symbol)
    futures_list = futures_markets_cache.get(exchange_name, [])
    futures_symbol = find_futures_symbol(symbol, futures_list)

    if not futures_symbol:
        return

    futures_price = get_price(exchange, futures_symbol)
    if not spot_price or not futures_price:
        return

    trading_fee = TRADING_FEES.get(exchange_name, 0.001)
    spread = (futures_price - spot_price) / spot_price
    net_profit = spread - (trading_fee * 2)

    if net_profit >= SPREAD_THRESHOLD:
        print(f"🔍 Arbitrage Opportunity on {exchange_name}: {symbol}")
        print(f"    ✅ Spot Price: {spot_price:.5f} USDT")
        print(f"    ✅ Futures Price: {futures_price:.5f} USDT")
        print(f"    ✅ Spread: {spread:.4%}")
        print(f"    ✅ Net Profit After Fees: {net_profit:.4%}")
        print(f"    ⚡ Execute arbitrage on {exchange_name}")
        print("-" * 60)

def process_tokens(exchange, exchange_name, tokens):
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = [executor.submit(check_intra_exchange_arbitrage, exchange, exchange_name, token) for token in tokens]
        concurrent.futures.wait(futures)

def main():
    while True:
        try:
            for exchange_name, exchange in exchanges.items():
                tradable_tokens = get_tradable_tokens(exchange, exchange_name)
                if not tradable_tokens:
                    print(f"❌ No tradable tokens found on {exchange_name}. Retrying in 10 seconds...")
                    time.sleep(10)
                    continue
                print(f"🔄 Checking for arbitrage opportunities on {exchange_name}...")
                process_tokens(exchange, exchange_name, tradable_tokens)
            print("✅ Cycle complete. Waiting for next check...")
            time.sleep(CHECK_INTERVAL)
        except Exception as e:
            print(f"❌ Error in main loop: {e}")
            time.sleep(10)

if __name__ == "__main__":
    main()
# Out:
# ✅ Found 435 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: XEM/USDT
#     ✅ Spot Price: 0.01932 USDT
#     ✅ Futures Price: 0.01942 USDT
#     ✅ Spread: 0.5176%
#     ✅ Net Profit After Fees: 0.3176%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT
#     ✅ Spot Price: 6.65080 USDT
#     ✅ Futures Price: 6.68890 USDT
#     ✅ Spread: 0.5729%
#     ✅ Net Profit After Fees: 0.3729%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 562 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: HIPPO/USDT
#     ✅ Spot Price: 0.00423 USDT
#     ✅ Futures Price: 0.00424 USDT
#     ✅ Spread: 0.3546%
#     ✅ Net Profit After Fees: 0.1946%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: MORPHO/USDT
#     ✅ Spot Price: 1.37190 USDT
#     ✅ Futures Price: 1.37550 USDT
#     ✅ Spread: 0.2624%
#     ✅ Net Profit After Fees: 0.1024%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: CHILLGUY/USDT
#     ✅ Spot Price: 0.03015 USDT
#     ✅ Futures Price: 0.03024 USDT
#     ✅ Spread: 0.2985%
#     ✅ Net Profit After Fees: 0.1385%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BIO/USDT
#     ✅ Spot Price: 0.09760 USDT
#     ✅ Futures Price: 0.09790 USDT
#     ✅ Spread: 0.3074%
#     ✅ Net Profit After Fees: 0.1474%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NIL/USDT
#     ✅ Spot Price: 0.74600 USDT
#     ✅ Futures Price: 0.75180 USDT
#     ✅ Spread: 0.7775%
#     ✅ Net Profit After Fees: 0.6175%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: ENA/USDT
#     ✅ Spot Price: 0.39590 USDT
#     ✅ Futures Price: 0.39730 USDT
#     ✅ Spread: 0.3536%
#     ✅ Net Profit After Fees: 0.1936%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: ARKM/USDT
#     ✅ Spot Price: 0.61800 USDT
#     ✅ Futures Price: 0.61980 USDT
#     ✅ Spread: 0.2913%
#     ✅ Net Profit After Fees: 0.1313%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BURGER/USDT
#     ✅ Spot Price: 0.06760 USDT
#     ✅ Futures Price: 0.06850 USDT
#     ✅ Spread: 1.3314%
#     ✅ Net Profit After Fees: 1.1714%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: MYRO/USDT
#     ✅ Spot Price: 0.01853 USDT
#     ✅ Futures Price: 0.01858 USDT
#     ✅ Spread: 0.2698%
#     ✅ Net Profit After Fees: 0.1098%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: VIC/USDT
#     ✅ Spot Price: 0.24970 USDT
#     ✅ Futures Price: 0.25040 USDT
#     ✅ Spread: 0.2803%
#     ✅ Net Profit After Fees: 0.1203%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: GMX/USDT
#     ✅ Spot Price: 14.50000 USDT
#     ✅ Futures Price: 14.55000 USDT
#     ✅ Spread: 0.3448%
#     ✅ Net Profit After Fees: 0.1848%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: ALICE/USDT
#     ✅ Spot Price: 0.53400 USDT
#     ✅ Futures Price: 0.53570 USDT
#     ✅ Spread: 0.3184%
#     ✅ Net Profit After Fees: 0.1584%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NEIROETH/USDT
#     ✅ Spot Price: 0.02660 USDT
#     ✅ Futures Price: 0.02667 USDT
#     ✅ Spread: 0.2632%
#     ✅ Net Profit After Fees: 0.1032%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: SUNDOG/USDT
#     ✅ Spot Price: 0.05700 USDT
#     ✅ Futures Price: 0.05750 USDT
#     ✅ Spread: 0.8772%
#     ✅ Net Profit After Fees: 0.7172%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: ORDER/USDT
#     ✅ Spot Price: 0.14210 USDT
#     ✅ Futures Price: 0.14250 USDT
#     ✅ Spread: 0.2815%
#     ✅ Net Profit After Fees: 0.1215%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 437 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: XEM/USDT
#     ✅ Spot Price: 0.01935 USDT
#     ✅ Futures Price: 0.01945 USDT
#     ✅ Spread: 0.5168%
#     ✅ Net Profit After Fees: 0.3168%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT
#     ✅ Spot Price: 6.65860 USDT
#     ✅ Futures Price: 6.69830 USDT
#     ✅ Spread: 0.5962%
#     ✅ Net Profit After Fees: 0.3962%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 570 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: LUMIA/USDT
#     ✅ Spot Price: 0.49300 USDT
#     ✅ Futures Price: 0.49480 USDT
#     ✅ Spread: 0.3651%
#     ✅ Net Profit After Fees: 0.2051%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: HIPPO/USDT
#     ✅ Spot Price: 0.00424 USDT
#     ✅ Futures Price: 0.00425 USDT
#     ✅ Spread: 0.3302%
#     ✅ Net Profit After Fees: 0.1702%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: LUCE/USDT
#     ✅ Spot Price: 0.00962 USDT
#     ✅ Futures Price: 0.00965 USDT
#     ✅ Spread: 0.3119%
#     ✅ Net Profit After Fees: 0.1519%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT
#     ✅ Spot Price: 6.64870 USDT
#     ✅ Futures Price: 6.71310 USDT
#     ✅ Spread: 0.9686%
#     ✅ Net Profit After Fees: 0.8086%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: CHILLGUY/USDT
#     ✅ Spot Price: 0.03016 USDT
#     ✅ Futures Price: 0.03026 USDT
#     ✅ Spread: 0.3316%
#     ✅ Net Profit After Fees: 0.1716%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: PIPPIN/USDT
#     ✅ Spot Price: 0.01920 USDT
#     ✅ Futures Price: 0.01926 USDT
#     ✅ Spread: 0.3125%
#     ✅ Net Profit After Fees: 0.1525%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: SHELL/USDT
#     ✅ Spot Price: 0.27120 USDT
#     ✅ Futures Price: 0.27234 USDT
#     ✅ Spread: 0.4204%
#     ✅ Net Profit After Fees: 0.2604%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NIL/USDT
#     ✅ Spot Price: 0.74600 USDT
#     ✅ Futures Price: 0.74990 USDT
#     ✅ Spread: 0.5228%
#     ✅ Net Profit After Fees: 0.3628%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: ARKM/USDT
#     ✅ Spot Price: 0.61800 USDT
#     ✅ Futures Price: 0.62020 USDT
#     ✅ Spread: 0.3560%
#     ✅ Net Profit After Fees: 0.1960%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BURGER/USDT
#     ✅ Spot Price: 0.06770 USDT
#     ✅ Futures Price: 0.06800 USDT
#     ✅ Spread: 0.4431%
#     ✅ Net Profit After Fees: 0.2831%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: QKC/USDT
#     ✅ Spot Price: 0.00725 USDT
#     ✅ Futures Price: 0.00728 USDT
#     ✅ Spread: 0.3033%
#     ✅ Net Profit After Fees: 0.1433%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NEIROETH/USDT
#     ✅ Spot Price: 0.02660 USDT
#     ✅ Futures Price: 0.02678 USDT
#     ✅ Spread: 0.6767%
#     ✅ Net Profit After Fees: 0.5167%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: SUNDOG/USDT
#     ✅ Spot Price: 0.05700 USDT
#     ✅ Futures Price: 0.05750 USDT
#     ✅ Spread: 0.8772%
#     ✅ Net Profit After Fees: 0.7172%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 437 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: XEM/USDT
#     ✅ Spot Price: 0.01934 USDT
#     ✅ Futures Price: 0.01944 USDT
#     ✅ Spread: 0.5171%
#     ✅ Net Profit After Fees: 0.3171%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: MYRIA/USDT
#     ✅ Spot Price: 0.00091 USDT
#     ✅ Futures Price: 0.00091 USDT
#     ✅ Spread: 0.3960%
#     ✅ Net Profit After Fees: 0.1960%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: MAJOR/USDT
#     ✅ Spot Price: 0.18930 USDT
#     ✅ Futures Price: 0.19000 USDT
#     ✅ Spread: 0.3698%
#     ✅ Net Profit After Fees: 0.1698%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT
#     ✅ Spot Price: 6.67690 USDT
#     ✅ Futures Price: 6.71660 USDT
#     ✅ Spread: 0.5946%
#     ✅ Net Profit After Fees: 0.3946%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 559 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: LUMIA/USDT
#     ✅ Spot Price: 0.49400 USDT
#     ✅ Futures Price: 0.49540 USDT
#     ✅ Spread: 0.2834%
#     ✅ Net Profit After Fees: 0.1234%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: JUP/USDT
#     ✅ Spot Price: 0.55850 USDT
#     ✅ Futures Price: 0.56110 USDT
#     ✅ Spread: 0.4655%
#     ✅ Net Profit After Fees: 0.3055%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: MAGIC/USDT
#     ✅ Spot Price: 0.13960 USDT
#     ✅ Futures Price: 0.14030 USDT
#     ✅ Spread: 0.5014%
#     ✅ Net Profit After Fees: 0.3414%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT
#     ✅ Spot Price: 6.67460 USDT
#     ✅ Futures Price: 6.73000 USDT
#     ✅ Spread: 0.8300%
#     ✅ Net Profit After Fees: 0.6700%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BGSC/USDT
#     ✅ Spot Price: 0.00814 USDT
#     ✅ Futures Price: 0.00817 USDT
#     ✅ Spread: 0.4056%
#     ✅ Net Profit After Fees: 0.2456%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: SHELL/USDT
#     ✅ Spot Price: 0.27120 USDT
#     ✅ Futures Price: 0.27304 USDT
#     ✅ Spread: 0.6785%
#     ✅ Net Profit After Fees: 0.5185%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NIL/USDT
#     ✅ Spot Price: 0.74400 USDT
#     ✅ Futures Price: 0.74690 USDT
#     ✅ Spread: 0.3898%
#     ✅ Net Profit After Fees: 0.2298%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BB/USDT
#     ✅ Spot Price: 0.14860 USDT
#     ✅ Futures Price: 0.14907 USDT
#     ✅ Spread: 0.3163%
#     ✅ Net Profit After Fees: 0.1563%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: ALICE/USDT
#     ✅ Spot Price: 0.53500 USDT
#     ✅ Futures Price: 0.53670 USDT
#     ✅ Spread: 0.3178%
#     ✅ Net Profit After Fees: 0.1578%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NEIROETH/USDT
#     ✅ Spot Price: 0.02660 USDT
#     ✅ Futures Price: 0.02688 USDT
#     ✅ Spread: 1.0526%
#     ✅ Net Profit After Fees: 0.8926%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: SUNDOG/USDT
#     ✅ Spot Price: 0.05700 USDT
#     ✅ Futures Price: 0.05770 USDT
#     ✅ Spread: 1.2281%
#     ✅ Net Profit After Fees: 1.0681%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 436 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: XEM/USDT
#     ✅ Spot Price: 0.01936 USDT
#     ✅ Futures Price: 0.01945 USDT
#     ✅ Spread: 0.4649%
#     ✅ Net Profit After Fees: 0.2649%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: FXS/USDT
#     ✅ Spot Price: 2.11900 USDT
#     ✅ Futures Price: 2.12560 USDT
#     ✅ Spread: 0.3115%
#     ✅ Net Profit After Fees: 0.1115%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT
#     ✅ Spot Price: 6.68250 USDT
#     ✅ Futures Price: 6.72350 USDT
#     ✅ Spread: 0.6135%
#     ✅ Net Profit After Fees: 0.4135%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 567 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: HIPPO/USDT
#     ✅ Spot Price: 0.00424 USDT
#     ✅ Futures Price: 0.00426 USDT
#     ✅ Spread: 0.3774%
#     ✅ Net Profit After Fees: 0.2174%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: MANTA/USDT
#     ✅ Spot Price: 0.28180 USDT
#     ✅ Futures Price: 0.28270 USDT
#     ✅ Spread: 0.3194%
#     ✅ Net Profit After Fees: 0.1594%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: MAGIC/USDT
#     ✅ Spot Price: 0.13960 USDT
#     ✅ Futures Price: 0.14020 USDT
#     ✅ Spread: 0.4298%
#     ✅ Net Profit After Fees: 0.2698%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BGSC/USDT
#     ✅ Spot Price: 0.00814 USDT
#     ✅ Futures Price: 0.00817 USDT
#     ✅ Spread: 0.3193%
#     ✅ Net Profit After Fees: 0.1593%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: ARC/USDT
#     ✅ Spot Price: 0.07150 USDT
#     ✅ Futures Price: 0.07174 USDT
#     ✅ Spread: 0.3357%
#     ✅ Net Profit After Fees: 0.1757%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: GPS/USDT
#     ✅ Spot Price: 0.03223 USDT
#     ✅ Futures Price: 0.03234 USDT
#     ✅ Spread: 0.3413%
#     ✅ Net Profit After Fees: 0.1813%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: DegenReborn/USDT
#     ✅ Spot Price: 0.00337 USDT
#     ✅ Futures Price: 0.00338 USDT
#     ✅ Spread: 0.3858%
#     ✅ Net Profit After Fees: 0.2258%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: YGG/USDT
#     ✅ Spot Price: 0.20880 USDT
#     ✅ Futures Price: 0.20980 USDT
#     ✅ Spread: 0.4789%
#     ✅ Net Profit After Fees: 0.3189%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NIL/USDT
#     ✅ Spot Price: 0.73300 USDT
#     ✅ Futures Price: 0.73900 USDT
#     ✅ Spread: 0.8186%
#     ✅ Net Profit After Fees: 0.6586%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BB/USDT
#     ✅ Spot Price: 0.14860 USDT
#     ✅ Futures Price: 0.14908 USDT
#     ✅ Spread: 0.3230%
#     ✅ Net Profit After Fees: 0.1630%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BURGER/USDT
#     ✅ Spot Price: 0.06710 USDT
#     ✅ Futures Price: 0.06730 USDT
#     ✅ Spread: 0.2981%
#     ✅ Net Profit After Fees: 0.1381%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: CETUS/USDT🔍 Arbitrage Opportunity on Bitget: JTO/USDT
#     ✅ Spot Price: 2.22700 USDT
#     ✅ Futures Price: 2.23390 USDT
#     ✅ Spread: 0.3098%
#     ✅ Net Profit After Fees: 0.1498%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
#
#     ✅ Spot Price: 0.11300 USDT
#     ✅ Futures Price: 0.11342 USDT
#     ✅ Spread: 0.3717%
#     ✅ Net Profit After Fees: 0.2117%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: ALICE/USDT
#     ✅ Spot Price: 0.53500 USDT
#     ✅ Futures Price: 0.53710 USDT
#     ✅ Spread: 0.3925%
#     ✅ Net Profit After Fees: 0.2325%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: FXS/USDT
#     ✅ Spot Price: 2.12100 USDT
#     ✅ Futures Price: 2.12800 USDT
#     ✅ Spread: 0.3300%
#     ✅ Net Profit After Fees: 0.1700%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NEIROETH/USDT
#     ✅ Spot Price: 0.02690 USDT
#     ✅ Futures Price: 0.02700 USDT
#     ✅ Spread: 0.3717%
#     ✅ Net Profit After Fees: 0.2117%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: SUNDOG/USDT
#     ✅ Spot Price: 0.05700 USDT
#     ✅ Futures Price: 0.05760 USDT
#     ✅ Spread: 1.0526%
#     ✅ Net Profit After Fees: 0.8926%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: EIGEN/USDT
#     ✅ Spot Price: 1.13000 USDT
#     ✅ Futures Price: 1.13460 USDT
#     ✅ Spread: 0.4071%
#     ✅ Net Profit After Fees: 0.2471%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: MOODENG/USDT
#     ✅ Spot Price: 0.03870 USDT
#     ✅ Futures Price: 0.03882 USDT
#     ✅ Spread: 0.3101%
#     ✅ Net Profit After Fees: 0.1501%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 437 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: XEM/USDT
#     ✅ Spot Price: 0.01935 USDT
#     ✅ Futures Price: 0.01944 USDT
#     ✅ Spread: 0.4651%
#     ✅ Net Profit After Fees: 0.2651%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: MYRIA/USDT
#     ✅ Spot Price: 0.00092 USDT
#     ✅ Futures Price: 0.00092 USDT
#     ✅ Spread: 0.3275%
#     ✅ Net Profit After Fees: 0.1275%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT
#     ✅ Spot Price: 6.68030 USDT
#     ✅ Futures Price: 6.71820 USDT
#     ✅ Spread: 0.5673%
#     ✅ Net Profit After Fees: 0.3673%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
