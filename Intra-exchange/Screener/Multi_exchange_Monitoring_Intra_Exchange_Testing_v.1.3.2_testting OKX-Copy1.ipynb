# %%
import ccxt
import time
import concurrent.futures
from datetime import datetime, timezone

# Replace with your actual OKX API credentials
OKX_API_KEY = '48af790d-3250-44ec-9528-54d5cd1c1009'
OKX_API_SECRET = 'C91F9F5826FD2F5A8ADC91D945643AD9'
OKX_API_PASSWORD = 'OkX!?Secure789Trade2025?!'

# Connect to OKX
okx = ccxt.okx({
    'apiKey': OKX_API_KEY,
    'secret': OKX_API_SECRET,
    'password': OKX_API_PASSWORD,
    'enableRateLimit': True,
    'options': {'adjustForTimeDifference': True}
})

# %%
# ⚙️ Config Settings
SPREAD_THRESHOLD = 0.01 / 100  # 0.1%
MIN_VOLUME = 50000  # Minimum 24h USDT volume
TRADING_FEE = 0.0007  # 0.07% fee per side
CHECK_INTERVAL = 5  # seconds

futures_markets_cache = []

# 📅 Timestamped logger
def log(msg):
    timestamp = datetime.now(timezone.utc).strftime("%Y-%m-%d %H:%M:%S")
    print(f"[{timestamp}] {msg}")

# 🔎 Load tradable tokens (spot) and cache USDT futures
def get_tradable_tokens():
    try:
        markets = okx.load_markets()
        tradable_tokens = []
        global futures_markets_cache

        # ✅ Cache USDT-margined perpetual futures
        futures_markets_cache = [
            symbol for symbol, market in markets.items()
            if market.get('type') == 'swap' and market.get('linear') and market.get('quote') == 'USDT'
        ]
        log(f"📦 Cached {len(futures_markets_cache)} futures markets")
        print("🔍 Sample futures markets:", futures_markets_cache[:5])

        for symbol, market in markets.items():
            if market.get('spot') and '/USDT' in symbol:
                try:
                    ticker = okx.fetch_ticker(symbol)
                    volume = ticker.get('quoteVolume', 0)
                    if volume >= MIN_VOLUME:
                        tradable_tokens.append(symbol)
                except Exception:
                    continue

        log(f"✅ Found {len(tradable_tokens)} tradable tokens on OKX")
        return tradable_tokens
    except Exception as e:
        log(f"❌ Error loading markets: {e}")
        return []

# 📈 Fetch latest price
def get_price(symbol):
    try:
        ticker = okx.fetch_ticker(symbol)
        return ticker.get("last")
    except Exception:
        return None

# 🧵 Multithreaded price fetcher
def fetch_prices_concurrently(symbols):
    prices = {}
    def fetch(symbol):
        prices[symbol] = get_price(symbol)
    with concurrent.futures.ThreadPoolExecutor() as executor:
        executor.map(fetch, symbols)
    return prices

# 🔗 Match futures for a spot symbol
def find_futures_symbol(spot_symbol):
    base = spot_symbol.split('/')[0]
    future_symbol = f"{base}/USDT:USDT"
    return future_symbol if future_symbol in futures_markets_cache else None

# 💰 Check for profitable arbitrage
def check_arbitrage(symbol, spot_prices, futures_prices, profitable_opps):
    spot_price = spot_prices.get(symbol)
    futures_symbol = find_futures_symbol(symbol)
    if not futures_symbol:
        return
    futures_price = futures_prices.get(futures_symbol)
    if not spot_price or not futures_price:
        return

    spread = (futures_price - spot_price) / spot_price
    net_profit = spread - (TRADING_FEE * 2)

    if net_profit >= SPREAD_THRESHOLD:
        profitable_opps.append({
            'symbol': symbol,
            'spot_price': spot_price,
            'futures_price': futures_price,
            'spread': spread,
            'net_profit': net_profit
        })

# 🚀 Main arbitrage scanner loop
def main():
    while True:
        try:
            tokens = get_tradable_tokens()
            if not tokens:
                time.sleep(10)
                continue

            matched = []
            unmatched = []

            for token in tokens:
                if find_futures_symbol(token):
                    matched.append(token)
                else:
                    unmatched.append(token)

            log(f"🔗 Matched: {len(matched)} tokens with futures")
            log(f"❌ Unmatched: {len(unmatched)} tokens with no futures pair")

            if unmatched:
                print("⚠️ Unmatched Tokens:")
                for u in unmatched[:10]:
                    print(f"   - {u}")

            spot_prices = fetch_prices_concurrently(matched)
            futures_symbols = [find_futures_symbol(t) for t in matched]
            futures_prices = fetch_prices_concurrently(futures_symbols)

            profitable_opps = []
            with concurrent.futures.ThreadPoolExecutor() as executor:
                tasks = [
                    executor.submit(check_arbitrage, token, spot_prices, futures_prices, profitable_opps)
                    for token in matched
                ]
                concurrent.futures.wait(tasks)

            if profitable_opps:
                print("\n💰 PROFITABLE ARBITRAGE OPPORTUNITIES FOUND:\n")
                profitable_opps.sort(key=lambda x: x['net_profit'], reverse=True)
                for opp in profitable_opps:
                    print(f"🔍 Arbitrage Opportunity on OKX: {opp['symbol']}")
                    print(f"✅ Spot Price: {opp['spot_price']:.5f} USDT")
                    print(f"✅ Futures Price: {opp['futures_price']:.5f} USDT")
                    print(f"✅ Spread: {opp['spread']:.4%}")
                    print(f"✅ Net Profit After Fees: {opp['net_profit']:.4%}")
                    print(f"⚡ Execute arbitrage on OKX")
                    print("-" * 60)
            else:
                print("🕵️ No profitable arbitrage opportunities this round.")

            log("✅ OKX scan complete. Waiting for next cycle...\n")
            time.sleep(CHECK_INTERVAL)

        except Exception as e:
            log(f"❌ Main loop error: {type(e).__name__}: {e}")
            time.sleep(10)

if __name__ == '__main__':
    main()
# Out:
# [2025-03-25 07:36:27] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:37:00] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:37:00] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:37:00] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:37:04] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:37:09] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:37:42] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:37:42] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:37:42] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:37:46] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:37:51] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:38:25] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:38:25] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:38:25] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:38:29] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:38:34] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:39:07] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:39:07] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:39:07] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:39:17] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:39:22] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:39:55] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:39:55] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:39:55] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:39:59] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:40:04] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:40:37] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:40:37] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:40:37] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:40:40] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:40:45] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:41:17] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:41:17] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:41:17] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:41:21] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:41:26] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:41:58] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:41:58] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:41:58] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:42:01] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:42:06] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:42:39] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:42:39] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:42:39] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:42:43] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:42:48] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:43:20] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:43:20] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:43:20] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:43:24] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:43:29] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:44:01] ✅ Found 272 tradable tokens on OKX
# [2025-03-25 07:44:01] 🔗 Matched: 202 tokens with futures
# [2025-03-25 07:44:01] ❌ Unmatched: 70 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:44:04] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:44:09] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:44:43] ✅ Found 168 tradable tokens on OKX
# [2025-03-25 07:44:43] 🔗 Matched: 131 tokens with futures
# [2025-03-25 07:44:43] ❌ Unmatched: 37 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - ACA/USDT
#    - ALCX/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BTT/USDT
#    - CELR/USDT
#    - CFG/USDT
#    - CXT/USDT
#    - DAI/USDT
#    - DAO/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:44:46] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:44:51] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:45:24] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:45:24] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:45:24] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:45:28] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:45:33] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:46:09] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:46:09] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:46:09] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:46:13] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:46:18] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:46:51] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:46:51] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:46:51] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:46:55] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:47:00] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:47:33] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:47:33] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:47:33] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:47:36] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:47:41] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:48:15] ✅ Found 153 tradable tokens on OKX
# [2025-03-25 07:48:15] 🔗 Matched: 113 tokens with futures
# [2025-03-25 07:48:15] ❌ Unmatched: 40 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ALCX/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BTT/USDT
#    - CELR/USDT
#    - CFG/USDT
#    - CTXC/USDT
#    - CXT/USDT
#    - DAI/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:48:17] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:48:22] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:48:54] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:48:54] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:48:54] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:48:58] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:49:03] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:49:36] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:49:36] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:49:36] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:49:58] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:50:03] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:50:37] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:50:37] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:50:37] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:50:41] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:50:46] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:51:21] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:51:21] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:51:21] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:51:25] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:51:30] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:52:08] ✅ Found 174 tradable tokens on OKX
# [2025-03-25 07:52:08] 🔗 Matched: 136 tokens with futures
# [2025-03-25 07:52:08] ❌ Unmatched: 38 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BONE/USDT
#    - CLV/USDT
#    - CTXC/USDT
#    - DORA/USDT
#    - ELF/USDT
#    - ELON/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:52:11] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:52:16] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:52:52] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:52:52] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:52:52] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:53:03] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:53:08] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:53:44] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:53:44] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:53:44] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:53:49] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:53:54] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:54:32] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:54:32] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:54:32] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:54:36] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:54:41] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:55:21] ✅ Found 281 tradable tokens on OKX
# [2025-03-25 07:55:21] 🔗 Matched: 210 tokens with futures
# [2025-03-25 07:55:21] ❌ Unmatched: 71 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:55:26] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:55:31] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:56:08] ✅ Found 172 tradable tokens on OKX
# [2025-03-25 07:56:08] 🔗 Matched: 132 tokens with futures
# [2025-03-25 07:56:08] ❌ Unmatched: 40 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - CELR/USDT
#    - CFG/USDT
#    - CLV/USDT
#    - CXT/USDT
#    - DAI/USDT
#
# 💰 PROFITABLE ARBITRAGE OPPORTUNITIES FOUND:
#
# 🔍 Arbitrage Opportunity on OKX: AGLD/USDT
# ✅ Spot Price: 0.99470 USDT
# ✅ Futures Price: 0.99650 USDT
# ✅ Spread: 0.1810%
# ✅ Net Profit After Fees: 0.0410%
# ⚡ Execute arbitrage on OKX
# ------------------------------------------------------------
# [2025-03-25 07:56:20] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:56:25] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:56:59] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:56:59] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:56:59] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
#
# 💰 PROFITABLE ARBITRAGE OPPORTUNITIES FOUND:
#
# 🔍 Arbitrage Opportunity on OKX: MKR/USDT
# ✅ Spot Price: 1265.10000 USDT
# ✅ Futures Price: 1267.50000 USDT
# ✅ Spread: 0.1897%
# ✅ Net Profit After Fees: 0.0497%
# ⚡ Execute arbitrage on OKX
# ------------------------------------------------------------
# [2025-03-25 07:57:03] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:57:08] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:57:44] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:57:44] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:57:44] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
#
# 💰 PROFITABLE ARBITRAGE OPPORTUNITIES FOUND:
#
# 🔍 Arbitrage Opportunity on OKX: SLP/USDT
# ✅ Spot Price: 0.00177 USDT
# ✅ Futures Price: 0.00178 USDT
# ✅ Spread: 0.1691%
# ✅ Net Profit After Fees: 0.0291%
# ⚡ Execute arbitrage on OKX
# ------------------------------------------------------------
# [2025-03-25 07:57:48] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:57:53] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:58:28] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:58:28] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:58:28] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:58:32] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:58:37] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:59:15] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:59:15] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:59:15] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 07:59:19] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 07:59:24] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 07:59:59] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 07:59:59] 🔗 Matched: 215 tokens with futures
# [2025-03-25 07:59:59] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:00:04] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:00:09] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:00:43] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:00:43] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:00:43] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:00:47] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:00:52] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:01:27] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:01:27] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:01:27] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:01:30] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:01:35] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:02:11] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:02:11] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:02:11] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
#
# 💰 PROFITABLE ARBITRAGE OPPORTUNITIES FOUND:
#
# 🔍 Arbitrage Opportunity on OKX: AEVO/USDT
# ✅ Spot Price: 0.13010 USDT
# ✅ Futures Price: 0.13040 USDT
# ✅ Spread: 0.2306%
# ✅ Net Profit After Fees: 0.0906%
# ⚡ Execute arbitrage on OKX
# ------------------------------------------------------------
# [2025-03-25 08:02:17] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:02:22] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:02:57] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:02:57] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:02:57] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:03:00] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:03:05] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:03:40] ✅ Found 223 tradable tokens on OKX
# [2025-03-25 08:03:40] 🔗 Matched: 169 tokens with futures
# [2025-03-25 08:03:40] ❌ Unmatched: 54 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:03:43] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:03:48] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:04:24] ✅ Found 236 tradable tokens on OKX
# [2025-03-25 08:04:24] 🔗 Matched: 176 tokens with futures
# [2025-03-25 08:04:24] ❌ Unmatched: 60 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BTT/USDT
#    - CELR/USDT
#    - CFG/USDT
#    - CTXC/USDT
#    - CXT/USDT
#    - DAI/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:04:29] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:04:34] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:05:09] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:05:09] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:05:09] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:05:23] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:05:28] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:06:03] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:06:03] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:06:03] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:06:07] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:06:12] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:06:45] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:06:45] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:06:45] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:06:49] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:06:54] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:07:37] ✅ Found 224 tradable tokens on OKX
# [2025-03-25 08:07:37] 🔗 Matched: 167 tokens with futures
# [2025-03-25 08:07:37] ❌ Unmatched: 57 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:07:41] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:07:46] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:08:23] ✅ Found 257 tradable tokens on OKX
# [2025-03-25 08:08:23] 🔗 Matched: 189 tokens with futures
# [2025-03-25 08:08:23] ❌ Unmatched: 68 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ASTR/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
#    - CFG/USDT
#    - CLV/USDT
#    - CTXC/USDT
#    - CXT/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:08:26] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:08:31] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:09:09] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:09:09] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:09:09] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
#
# 💰 PROFITABLE ARBITRAGE OPPORTUNITIES FOUND:
#
# 🔍 Arbitrage Opportunity on OKX: EGLD/USDT
# ✅ Spot Price: 19.35000 USDT
# ✅ Futures Price: 19.38000 USDT
# ✅ Spread: 0.1550%
# ✅ Net Profit After Fees: 0.0150%
# ⚡ Execute arbitrage on OKX
# ------------------------------------------------------------
# [2025-03-25 08:09:13] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:09:18] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:09:54] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:09:54] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:09:54] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:10:01] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:10:06] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:10:44] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:10:44] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:10:44] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:10:49] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:10:54] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:11:31] ✅ Found 200 tradable tokens on OKX
# [2025-03-25 08:11:31] 🔗 Matched: 153 tokens with futures
# [2025-03-25 08:11:31] ❌ Unmatched: 47 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:11:34] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:11:39] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:12:15] ✅ Found 247 tradable tokens on OKX
# [2025-03-25 08:12:15] 🔗 Matched: 183 tokens with futures
# [2025-03-25 08:12:15] ❌ Unmatched: 64 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
#    - CFG/USDT
#    - CLV/USDT
#    - CTXC/USDT
#    - CXT/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:12:25] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:12:30] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:13:07] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:13:07] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:13:07] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:13:13] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:13:18] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:13:54] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:13:54] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:13:54] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
#
# 💰 PROFITABLE ARBITRAGE OPPORTUNITIES FOUND:
#
# 🔍 Arbitrage Opportunity on OKX: NMR/USDT
# ✅ Spot Price: 9.20300 USDT
# ✅ Futures Price: 9.23200 USDT
# ✅ Spread: 0.3151%
# ✅ Net Profit After Fees: 0.1751%
# ⚡ Execute arbitrage on OKX
# ------------------------------------------------------------
# [2025-03-25 08:13:58] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:14:03] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:14:38] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:14:38] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:14:38] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:14:41] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:14:46] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:15:25] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:15:25] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:15:25] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:15:39] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:15:44] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:16:27] ✅ Found 199 tradable tokens on OKX
# [2025-03-25 08:16:27] 🔗 Matched: 152 tokens with futures
# [2025-03-25 08:16:27] ❌ Unmatched: 47 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - CLV/USDT
#    - DORA/USDT
#    - ELF/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:16:30] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:16:35] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:17:10] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:17:10] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:17:10] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:17:14] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:17:19] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:17:55] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:17:55] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:17:55] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:18:13] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:18:18] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:18:52] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:18:52] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:18:52] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:18:56] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:19:01] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:19:38] ✅ Found 257 tradable tokens on OKX
# [2025-03-25 08:19:38] 🔗 Matched: 192 tokens with futures
# [2025-03-25 08:19:38] ❌ Unmatched: 65 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:19:41] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:19:46] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:20:28] ✅ Found 202 tradable tokens on OKX
# [2025-03-25 08:20:28] 🔗 Matched: 154 tokens with futures
# [2025-03-25 08:20:28] ❌ Unmatched: 48 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CTXC/USDT
#    - CXT/USDT
#    - ELF/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:20:31] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:20:36] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:21:15] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:21:15] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:21:15] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:21:19] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:21:24] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:21:59] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:21:59] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:21:59] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:22:20] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:22:25] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:22:59] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:22:59] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:22:59] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:23:03] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:23:08] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:23:43] ✅ Found 226 tradable tokens on OKX
# [2025-03-25 08:23:43] 🔗 Matched: 171 tokens with futures
# [2025-03-25 08:23:43] ❌ Unmatched: 55 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:23:46] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:23:51] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:24:30] ✅ Found 227 tradable tokens on OKX
# [2025-03-25 08:24:30] 🔗 Matched: 171 tokens with futures
# [2025-03-25 08:24:30] ❌ Unmatched: 56 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - CFG/USDT
#    - CLV/USDT
#    - DAO/USDT
#    - G/USDT
#    - GEAR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:24:34] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:24:39] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:25:15] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:25:15] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:25:15] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:25:35] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:25:40] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:26:15] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:26:15] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:26:15] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:26:19] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:26:24] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:26:58] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:26:58] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:26:58] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:27:03] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:27:08] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:27:44] ✅ Found 187 tradable tokens on OKX
# [2025-03-25 08:27:44] 🔗 Matched: 143 tokens with futures
# [2025-03-25 08:27:44] ❌ Unmatched: 44 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CLV/USDT
#    - CTXC/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:27:47] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:27:52] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:28:27] ✅ Found 277 tradable tokens on OKX
# [2025-03-25 08:28:27] 🔗 Matched: 206 tokens with futures
# [2025-03-25 08:28:27] ❌ Unmatched: 71 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
#    - CFG/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:28:31] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:28:36] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:29:12] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:29:12] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:29:12] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:29:17] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:29:22] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:29:56] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:29:56] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:29:56] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:30:00] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:30:05] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:30:39] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:30:39] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:30:39] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:30:43] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:30:48] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:31:21] ✅ Found 194 tradable tokens on OKX
# [2025-03-25 08:31:21] 🔗 Matched: 147 tokens with futures
# [2025-03-25 08:31:21] ❌ Unmatched: 47 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:31:27] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:31:32] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:32:06] ✅ Found 254 tradable tokens on OKX
# [2025-03-25 08:32:06] 🔗 Matched: 186 tokens with futures
# [2025-03-25 08:32:06] ❌ Unmatched: 68 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
#    - CFG/USDT
#    - CLV/USDT
#    - CTXC/USDT
#    - CXT/USDT
# ...
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:37:25] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:37:30] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:38:04] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:38:04] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:38:04] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
#
# 💰 PROFITABLE ARBITRAGE OPPORTUNITIES FOUND:
#
# 🔍 Arbitrage Opportunity on OKX: LQTY/USDT
# ✅ Spot Price: 0.77030 USDT
# ✅ Futures Price: 0.77150 USDT
# ✅ Spread: 0.1558%
# ✅ Net Profit After Fees: 0.0158%
# ⚡ Execute arbitrage on OKX
# ------------------------------------------------------------
# [2025-03-25 08:38:21] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:38:26] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:38:59] ✅ Found 267 tradable tokens on OKX
# [2025-03-25 08:38:59] 🔗 Matched: 200 tokens with futures
# [2025-03-25 08:38:59] ❌ Unmatched: 67 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:39:03] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:39:08] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:39:43] ✅ Found 192 tradable tokens on OKX
# [2025-03-25 08:39:43] 🔗 Matched: 142 tokens with futures
# [2025-03-25 08:39:43] ❌ Unmatched: 50 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BTT/USDT
#    - CELR/USDT
#    - CFG/USDT
#    - CTXC/USDT
#    - CXT/USDT
#    - DAI/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:39:47] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:39:52] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:40:26] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:40:26] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:40:26] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:40:30] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:40:35] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:41:08] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:41:08] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:41:08] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:41:27] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:41:32] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:42:08] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:42:08] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:42:08] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:42:12] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:42:17] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:42:52] ✅ Found 282 tradable tokens on OKX
# [2025-03-25 08:42:52] 🔗 Matched: 210 tokens with futures
# [2025-03-25 08:42:52] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:42:56] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:43:01] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:43:40] ✅ Found 185 tradable tokens on OKX
# [2025-03-25 08:43:40] 🔗 Matched: 144 tokens with futures
# [2025-03-25 08:43:40] ❌ Unmatched: 41 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BONE/USDT
#    - CLV/USDT
#    - CTXC/USDT
#    - DORA/USDT
#    - ELF/USDT
#    - FET/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:43:43] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:43:48] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:44:23] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:44:23] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:44:23] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:44:27] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:44:32] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:45:06] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:45:06] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:45:06] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:45:11] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:45:16] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:45:51] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:45:51] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:45:51] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:45:55] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:46:00] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:46:37] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:46:37] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:46:37] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
#
# 💰 PROFITABLE ARBITRAGE OPPORTUNITIES FOUND:
#
# 🔍 Arbitrage Opportunity on OKX: DGB/USDT
# ✅ Spot Price: 0.00915 USDT
# ✅ Futures Price: 0.00916 USDT
# ✅ Spread: 0.1531%
# ✅ Net Profit After Fees: 0.0131%
# ⚡ Execute arbitrage on OKX
# ------------------------------------------------------------
# [2025-03-25 08:46:41] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:46:46] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:47:25] ✅ Found 183 tradable tokens on OKX
# [2025-03-25 08:47:25] 🔗 Matched: 137 tokens with futures
# [2025-03-25 08:47:25] ❌ Unmatched: 46 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - CELR/USDT
#    - CFG/USDT
#    - CLV/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:47:28] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:47:33] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:48:06] ✅ Found 280 tradable tokens on OKX
# [2025-03-25 08:48:06] 🔗 Matched: 209 tokens with futures
# [2025-03-25 08:48:06] ❌ Unmatched: 71 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
#    - CFG/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:48:11] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:48:16] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:48:53] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:48:53] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:48:53] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:48:57] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:49:02] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:49:36] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:49:36] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:49:36] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:49:39] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:49:44] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:51:04] ✅ Found 179 tradable tokens on OKX
# [2025-03-25 08:51:04] 🔗 Matched: 141 tokens with futures
# [2025-03-25 08:51:04] ❌ Unmatched: 38 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:51:05] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:51:10] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:51:56] ✅ Found 130 tradable tokens on OKX
# [2025-03-25 08:51:56] 🔗 Matched: 95 tokens with futures
# [2025-03-25 08:51:56] ❌ Unmatched: 35 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - CTXC/USDT
#    - CXT/USDT
#    - DAI/USDT
#    - DAO/USDT
#    - ELF/USDT
#    - ELON/USDT
#    - ERN/USDT
#    - G/USDT
#    - GEAR/USDT
#    - GLMR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:51:58] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:52:03] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:52:35] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:52:35] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:52:35] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:52:39] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:52:44] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:53:16] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:53:16] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:53:16] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:53:39] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:53:44] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:54:17] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:54:17] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:54:17] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:54:20] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:54:25] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:54:58] ✅ Found 206 tradable tokens on OKX
# [2025-03-25 08:54:58] 🔗 Matched: 154 tokens with futures
# [2025-03-25 08:54:58] ❌ Unmatched: 52 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:55:02] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:55:07] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:55:40] ✅ Found 232 tradable tokens on OKX
# [2025-03-25 08:55:40] 🔗 Matched: 173 tokens with futures
# [2025-03-25 08:55:40] ❌ Unmatched: 59 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ALCX/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BONE/USDT
#    - ELF/USDT
#    - ELON/USDT
#    - ERN/USDT
#    - FET/USDT
#    - FLR/USDT
# 🕵️ No profitable arbitrage opportunities this round.
# [2025-03-25 08:55:43] ✅ OKX scan complete. Waiting for next cycle...
#
# [2025-03-25 08:55:48] 📦 Cached 243 futures markets
# 🔍 Sample futures markets: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'SOL/USDT:USDT', 'TON/USDT:USDT', 'DOGE/USDT:USDT']
# [2025-03-25 08:56:25] ✅ Found 287 tradable tokens on OKX
# [2025-03-25 08:56:25] 🔗 Matched: 215 tokens with futures
# [2025-03-25 08:56:25] ❌ Unmatched: 72 tokens with no futures pair
# ⚠️ Unmatched Tokens:
#    - OKB/USDT
#    - ACA/USDT
#    - ALCX/USDT
#    - ASTR/USDT
#    - BABYDOGE/USDT
#    - BANANA/USDT
#    - BETH/USDT
#    - BONE/USDT
#    - BTT/USDT
#    - CELR/USDT
