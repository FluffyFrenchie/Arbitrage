# %%
import ccxt
import time
import datetime
import concurrent.futures

# Replace with your actual API keys for Bybit, Bitget, and OKX
BYBIT_API_KEY = 'I6m01uNAWiensHbIBA'
BYBIT_API_SECRET = 'vkaviS9xw903NJPncMtHgGfyiWB4mnhSJTyK'
BITGET_API_KEY = 'bg_b0a9d721607623216a87b066a3df34c3'
BITGET_API_SECRET = '6c4a5016562624b6d7f3b1c59563d4a1a573f630e0e49422fbf509399e56918b'
OKX_API_KEY = '48af790d-3250-44ec-9528-54d5cd1c1009'
OKX_API_SECRET = 'C91F9F5826FD2F5A8ADC91D945643AD9'
OKX_API_PASSWORD = 'OkX!?Secure789Trade2025?!'

# Connect to Bybit API
bybit = ccxt.bybit({
    'apiKey': BYBIT_API_KEY,
    'secret': BYBIT_API_SECRET,
    'options': {'adjustForTimeDifference': True}
})

# Connect to Bitget API
bitget = ccxt.bitget({
    'apiKey': BITGET_API_KEY,
    'secret': BITGET_API_SECRET,
    'options': {'adjustForTimeDifference': True}
})

# Connect to OKX API
okx = ccxt.okx({
    'apiKey': OKX_API_KEY,
    'secret': OKX_API_SECRET,
    'password': OKX_API_PASSWORD,
    'options': {'adjustForTimeDifference': True}
})

# %%
# Arbitrage settings
SPREAD_THRESHOLD = 0.1 / 100  # 0.1% for testing
MIN_VOLUME = 50000  # Minimum 24h volume required (in USDT)
CHECK_INTERVAL = 5  # Check every 5 seconds

# Adjustable trading fees per exchange
TRADING_FEES = {
    'Bybit': 0.001,   # 0.1%
    'Bitget': 0.0008, # 0.08%
    'OKX': 0.0007     # 0.07%
}

exchanges = {'Bybit': bybit, 'Bitget': bitget, 'OKX': okx}

# Cache futures markets
futures_markets_cache = {}

def get_tradable_tokens(exchange, exchange_name):
    try:
        markets = exchange.load_markets()
        tradable_tokens = []
        futures_markets_cache[exchange_name] = [symbol for symbol in markets if ":USDT" in symbol or "-USDT-SWAP" in symbol]

        for symbol, market in markets.items():
            if exchange_name == "Bitget" and not market.get('spot', False):
                continue
            if exchange_name == "OKX" and market.get('type') != 'spot':
                continue
            if '/USDT' in symbol and ':USDT' not in symbol and '-USDT-SWAP' not in symbol:
                try:
                    market_data = exchange.fetch_ticker(symbol)
                    volume = market_data.get('quoteVolume', 0)
                    if volume and volume >= MIN_VOLUME:
                        tradable_tokens.append(symbol)
                except Exception:
                    continue
        print(f"✅ Found {len(tradable_tokens)} tradable tokens on {exchange_name}")
        return tradable_tokens
    except Exception as e:
        print(f"❌ Error fetching tradable tokens from {exchange_name}: {e}")
        return []

def get_price(exchange, symbol):
    try:
        ticker = exchange.fetch_ticker(symbol)
        return ticker.get("last", None)
    except Exception:
        return None

def fetch_prices_concurrently(exchange, symbols):
    prices = {}
    def fetch(symbol):
        prices[symbol] = get_price(exchange, symbol)
    with concurrent.futures.ThreadPoolExecutor() as executor:
        executor.map(fetch, symbols)
    return prices

def find_futures_symbol(spot_symbol, futures_list):
    base = spot_symbol.split('/')[0]
    match = [f for f in futures_list if f.startswith(f"{base}/USDT") or f.startswith(f"{base}-USDT")]
    return match[0] if match else None

def check_intra_exchange_arbitrage(exchange, exchange_name, symbol, spot_prices, futures_prices):
    spot_price = spot_prices.get(symbol)
    futures_list = futures_markets_cache.get(exchange_name, [])
    futures_symbol = find_futures_symbol(symbol, futures_list)

    if not futures_symbol:
        return

    futures_price = futures_prices.get(futures_symbol)
    if not spot_price or not futures_price:
        return

    trading_fee = TRADING_FEES.get(exchange_name, 0.001)
    spread = (futures_price - spot_price) / spot_price
    net_profit = spread - (trading_fee * 2)

    if net_profit >= SPREAD_THRESHOLD:
        timestamp = datetime.datetime.utcnow().strftime('%Y-%m-%d %H:%M:%S UTC')
        print(f"🔍 Arbitrage Opportunity on {exchange_name}: {symbol} | {timestamp}")
        print(f"    ✅ Spot Price: {spot_price:.5f} USDT")
        print(f"    ✅ Futures Price: {futures_price:.5f} USDT")
        print(f"    ✅ Spread: {spread:.4%}")
        print(f"    ✅ Net Profit After Fees: {net_profit:.4%}")
        print(f"    ⚡ Execute arbitrage on {exchange_name}")
        print("-" * 60)

def process_tokens(exchange, exchange_name, tokens):
    futures_list = futures_markets_cache.get(exchange_name, [])
    futures_symbols = [find_futures_symbol(t, futures_list) for t in tokens if find_futures_symbol(t, futures_list)]

    spot_prices = fetch_prices_concurrently(exchange, tokens)
    futures_prices = fetch_prices_concurrently(exchange, futures_symbols)

    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = [executor.submit(check_intra_exchange_arbitrage, exchange, exchange_name, token, spot_prices, futures_prices) for token in tokens]
        concurrent.futures.wait(futures)

def main():
    while True:
        try:
            for exchange_name, exchange in exchanges.items():
                tradable_tokens = get_tradable_tokens(exchange, exchange_name)
                if not tradable_tokens:
                    print(f"❌ No tradable tokens found on {exchange_name}. Retrying in 10 seconds...")
                    time.sleep(10)
                    continue
                print(f"🔄 Checking for arbitrage opportunities on {exchange_name}...")
                process_tokens(exchange, exchange_name, tradable_tokens)
            print("✅ Cycle complete. Waiting for next check...")
            time.sleep(CHECK_INTERVAL)
        except Exception as e:
            print(f"❌ Error in main loop: {e}")
            time.sleep(10)

if __name__ == "__main__":
    main()
# Out:
# ✅ Found 409 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_28600\1531106719.py:80: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   timestamp = datetime.datetime.utcnow().strftime('%Y-%m-%d %H:%M:%S UTC')
# 🔍 Arbitrage Opportunity on Bybit: L3/USDT | 2025-03-28 06:31:29 UTC
#     ✅ Spot Price: 0.12365 USDT
#     ✅ Futures Price: 0.12412 USDT
#     ✅ Spread: 0.3801%
#     ✅ Net Profit After Fees: 0.1801%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT | 2025-03-28 06:31:29 UTC
#     ✅ Spot Price: 6.33680 USDT
#     ✅ Futures Price: 6.37970 USDT
#     ✅ Spread: 0.6770%
#     ✅ Net Profit After Fees: 0.4770%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 570 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: LUCE/USDT | 2025-03-28 06:33:17 UTC
#     ✅ Spot Price: 0.00855 USDT
#     ✅ Futures Price: 0.00858 USDT
#     ✅ Spread: 0.3509%
#     ✅ Net Profit After Fees: 0.1909%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NFP/USDT | 2025-03-28 06:33:17 UTC
#     ✅ Spot Price: 0.08480 USDT
#     ✅ Futures Price: 0.08510 USDT
#     ✅ Spread: 0.3538%
#     ✅ Net Profit After Fees: 0.1938%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: AR/USDT | 2025-03-28 06:33:17 UTC
#     ✅ Spot Price: 7.07000 USDT
#     ✅ Futures Price: 7.10000 USDT
#     ✅ Spread: 0.4243%
#     ✅ Net Profit After Fees: 0.2643%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BRETT/USDT | 2025-03-28 06:33:17 UTC
#     ✅ Spot Price: 0.03460 USDT
#     ✅ Futures Price: 0.03472 USDT
#     ✅ Spread: 0.3468%
#     ✅ Net Profit After Fees: 0.1868%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: UMA/USDT | 2025-03-28 06:33:17 UTC
#     ✅ Spot Price: 1.28900 USDT
#     ✅ Futures Price: 1.29300 USDT
#     ✅ Spread: 0.3103%
#     ✅ Net Profit After Fees: 0.1503%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Found 291 tradable tokens on OKX
# 🔄 Checking for arbitrage opportunities on OKX...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 409 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: L3/USDT | 2025-03-28 06:35:09 UTC
#     ✅ Spot Price: 0.12500 USDT
#     ✅ Futures Price: 0.12554 USDT
#     ✅ Spread: 0.4320%
#     ✅ Net Profit After Fees: 0.2320%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT | 2025-03-28 06:35:09 UTC
#     ✅ Spot Price: 6.37270 USDT
#     ✅ Futures Price: 6.41840 USDT
#     ✅ Spread: 0.7171%
#     ✅ Net Profit After Fees: 0.5171%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 570 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: LUCE/USDT | 2025-03-28 06:36:48 UTC🔍 Arbitrage Opportunity on Bitget: BAN/USDT | 2025-03-28 06:36:48 UTC
#     ✅ Spot Price: 0.05640 USDT
#     ✅ Futures Price: 0.05660 USDT
#     ✅ Spread: 0.3546%
#     ✅ Net Profit After Fees: 0.1946%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
#
#     ✅ Spot Price: 0.00855 USDT
#     ✅ Futures Price: 0.00858 USDT
#     ✅ Spread: 0.3509%
#     ✅ Net Profit After Fees: 0.1909%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget:
USDT | 2025-03-28 07:04:06 UTC
#     ✅ Spot Price: 0.05570 USDT
#     ✅ Futures Price: 0.05590 USDT
#     ✅ Spread: 0.3591%
#     ✅ Net Profit After Fees: 0.1991%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: CHESS/USDT | 2025-03-28 07:04:06 UTC
#     ✅ Spot Price: 0.08440 USDT
#     ✅ Futures Price: 0.08465 USDT
#     ✅ Spread: 0.2962%
#     ✅ Net Profit After Fees: 0.1362%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: JUP/USDT | 2025-03-28 07:04:06 UTC
#     ✅ Spot Price: 0.51860 USDT
#     ✅ Futures Price: 0.52010 USDT
#     ✅ Spread: 0.2892%
#     ✅ Net Profit After Fees: 0.1292%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: EGLD/USDT | 2025-03-28 07:04:06 UTC
#     ✅ Spot Price: 17.38000 USDT
#     ✅ Futures Price: 17.43000 USDT
#     ✅ Spread: 0.2877%
#     ✅ Net Profit After Fees: 0.1277%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: RAY/USDT | 2025-03-28 07:04:06 UTC
#     ✅ Spot Price: 1.90500 USDT
#     ✅ Futures Price: 1.91220 USDT
#     ✅ Spread: 0.3780%
#     ✅ Net Profit After Fees: 0.2180%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: MORPHO/USDT | 2025-03-28 07:04:06 UTC
#     ✅ Spot Price: 1.43370 USDT
#     ✅ Futures Price: 1.44090 USDT
#     ✅ Spread: 0.5022%
#     ✅ Net Profit After Fees: 0.3422%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: GRIFFAIN/USDT | 2025-03-28 07:04:06 UTC
#     ✅ Spot Price: 0.04200 USDT
#     ✅ Futures Price: 0.04222 USDT
#     ✅ Spread: 0.5238%
#     ✅ Net Profit After Fees: 0.3638%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: UMA/USDT | 2025-03-28 07:04:06 UTC
#     ✅ Spot Price: 1.27700 USDT
#     ✅ Futures Price: 1.28300 USDT
#     ✅ Spread: 0.4699%
#     ✅ Net Profit After Fees: 0.3099%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: GRT/USDT | 2025-03-28 07:04:06 UTC
#     ✅ Spot Price: 0.09760 USDT
#     ✅ Futures Price: 0.09793 USDT
#     ✅ Spread: 0.3381%
#     ✅ Net Profit After Fees: 0.1781%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: OGN/USDT | 2025-03-28 07:04:06 UTC
#     ✅ Spot Price: 0.06340 USDT
#     ✅ Futures Price: 0.06359 USDT
#     ✅ Spread: 0.2997%
#     ✅ Net Profit After Fees: 0.1397%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: TSTBSC/USDT | 2025-03-28 07:04:06 UTC
#     ✅ Spot Price: 0.06109 USDT
#     ✅ Futures Price: 0.06126 USDT
#     ✅ Spread: 0.2783%
#     ✅ Net Profit After Fees: 0.1183%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NIL/USDT | 2025-03-28 07:04:06 UTC
#     ✅ Spot Price: 0.56900 USDT
#     ✅ Futures Price: 0.57050 USDT
#     ✅ Spread: 0.2636%
#     ✅ Net Profit After Fees: 0.1036%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: W/USDT | 2025-03-28 07:04:06 UTC
#     ✅ Spot Price: 0.09380 USDT
#     ✅ Futures Price: 0.09408 USDT
#     ✅ Spread: 0.2985%
#     ✅ Net Profit After Fees: 0.1385%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: SAGA/USDT | 2025-03-28 07:04:06 UTC
#     ✅ Spot Price: 0.36080 USDT
#     ✅ Futures Price: 0.36240 USDT
#     ✅ Spread: 0.4435%
#     ✅ Net Profit After Fees: 0.2835%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: ARKM/USDT | 2025-03-28 07:04:06 UTC
#     ✅ Spot Price: 0.59200 USDT
#     ✅ Futures Price: 0.59420 USDT
#     ✅ Spread: 0.3716%
#     ✅ Net Profit After Fees: 0.2116%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: MOODENG/USDT | 2025-03-28 07:04:06 UTC
#     ✅ Spot Price: 0.03800 USDT
#     ✅ Futures Price: 0.03810 USDT
#     ✅ Spread: 0.2632%
#     ✅ Net Profit After Fees: 0.1032%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: GPS/USDT | 2025-03-28 07:04:06 UTC
#     ✅ Spot Price: 0.02927 USDT
#     ✅ Futures Price: 0.02945 USDT
#     ✅ Spread: 0.6150%
#     ✅ Net Profit After Fees: 0.4550%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Found 291 tradable tokens on OKX
# 🔄 Checking for arbitrage opportunities on OKX...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 406 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: SLP/USDT | 2025-03-28 07:05:48 UTC
#     ✅ Spot Price: 0.00167 USDT
#     ✅ Futures Price: 0.00168 USDT
#     ✅ Spread: 0.4189%
#     ✅ Net Profit After Fees: 0.2189%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: UMA/USDT | 2025-03-28 07:05:48 UTC
#     ✅ Spot Price: 1.27780 USDT
#     ✅ Futures Price: 1.28200 USDT
#     ✅ Spread: 0.3287%
#     ✅ Net Profit After Fees: 0.1287%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT | 2025-03-28 07:05:48 UTC
#     ✅ Spot Price: 6.32140 USDT
#     ✅ Futures Price: 6.35750 USDT
#     ✅ Spread: 0.5711%
#     ✅ Net Profit After Fees: 0.3711%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 571 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: LUCE/USDT | 2025-03-28 07:07:28 UTC
#     ✅ Spot Price: 0.00859 USDT
#     ✅ Futures Price: 0.00863 USDT
#     ✅ Spread: 0.4657%
#     ✅ Net Profit After Fees: 0.3057%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: JUP/USDT | 2025-03-28 07:07:28 UTC
#     ✅ Spot Price: 0.51860 USDT
#     ✅ Futures Price: 0.52040 USDT
#     ✅ Spread: 0.3471%
#     ✅ Net Profit After Fees: 0.1871%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT | 2025-03-28 07:07:28 UTC
#     ✅ Spot Price: 6.31970 USDT
#     ✅ Futures Price: 6.36926 USDT
#     ✅ Spread: 0.7842%
#     ✅ Net Profit After Fees: 0.6242%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: J/USDT | 2025-03-28 07:07:28 UTC
#     ✅ Spot Price: 0.22500 USDT
#     ✅ Futures Price: 0.22670 USDT
#     ✅ Spread: 0.7556%
#     ✅ Net Profit After Fees: 0.5956%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BRETT/USDT | 2025-03-28 07:07:28 UTC
#     ✅ Spot Price: 0.03430 USDT
#     ✅ Futures Price: 0.03439 USDT
#     ✅ Spread: 0.2624%
#     ✅ Net Profit After Fees: 0.1024%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: CKB/USDT | 2025-03-28 07:07:28 UTC
#     ✅ Spot Price: 0.00537 USDT
#     ✅ Futures Price: 0.00539 USDT
#     ✅ Spread: 0.3165%
#     ✅ Net Profit After Fees: 0.1565%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NEIROETH/USDT | 2025-03-28 07:07:28 UTC
#     ✅ Spot Price: 0.02850 USDT
#     ✅ Futures Price: 0.02865 USDT
#     ✅ Spread: 0.5263%
#     ✅ Net Profit After Fees: 0.3663%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Found 291 tradable tokens on OKX
# 🔄 Checking for arbitrage opportunities on OKX...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 406 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: UMA/USDT | 2025-03-28 07:09:10 UTC
#     ✅ Spot Price: 1.27780 USDT
#     ✅ Futures Price: 1.28200 USDT
#     ✅ Spread: 0.3287%
#     ✅ Net Profit After Fees: 0.1287%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: F/USDT | 2025-03-28 07:09:10 UTC
#     ✅ Spot Price: 0.01915 USDT
#     ✅ Futures Price: 0.01924 USDT
#     ✅ Spread: 0.4700%
#     ✅ Net Profit After Fees: 0.2700%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT | 2025-03-28 07:09:10 UTC
#     ✅ Spot Price: 6.31560 USDT
#     ✅ Futures Price: 6.35300 USDT
#     ✅ Spread: 0.5922%
#     ✅ Net Profit After Fees: 0.3922%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 572 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: PEAQ/USDT | 2025-03-28 07:10:48 UTC
#     ✅ Spot Price: 0.13870 USDT
#     ✅ Futures Price: 0.13910 USDT
#     ✅ Spread: 0.2884%
#     ✅ Net Profit After Fees: 0.1284%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: RDNT/USDT | 2025-03-28 07:10:48 UTC
#     ✅ Spot Price: 0.02493 USDT
#     ✅ Futures Price: 0.02504 USDT
#     ✅ Spread: 0.4412%
#     ✅ Net Profit After Fees: 0.2812%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: JUP/USDT | 2025-03-28 07:10:48 UTC
#     ✅ Spot Price: 0.51860 USDT
#     ✅ Futures Price: 0.52050 USDT
#     ✅ Spread: 0.3664%
#     ✅ Net Profit After Fees: 0.2064%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT | 2025-03-28 07:10:48 UTC
#     ✅ Spot Price: 6.31970 USDT
#     ✅ Futures Price: 6.36310 USDT
#     ✅ Spread: 0.6867%
#     ✅ Net Profit After Fees: 0.5267%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: GRIFFAIN/USDT | 2025-03-28 07:10:48 UTC
#     ✅ Spot Price: 0.04180 USDT
#     ✅ Futures Price: 0.04191 USDT
#     ✅ Spread: 0.2632%
#     ✅ Net Profit After Fees: 0.1032%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: J/USDT | 2025-03-28 07:10:48 UTC
#     ✅ Spot Price: 0.22500 USDT
#     ✅ Futures Price: 0.22600 USDT
#     ✅ Spread: 0.4444%
#     ✅ Net Profit After Fees: 0.2844%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: ETHFI/USDT | 2025-03-28 07:10:48 UTC
#     ✅ Spot Price: 0.63420 USDT
#     ✅ Futures Price: 0.63740 USDT
#     ✅ Spread: 0.5046%
#     ✅ Net Profit After Fees: 0.3446%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget:

#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NEIROETH/USDT | 2025-03-28 07:17:36 UTC
#     ✅ Spot Price: 0.02840 USDT
#     ✅ Futures Price: 0.02861 USDT
#     ✅ Spread: 0.7394%
#     ✅ Net Profit After Fees: 0.5794%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Found 291 tradable tokens on OKX
# 🔄 Checking for arbitrage opportunities on OKX...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 408 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: DGB/USDT | 2025-03-28 07:19:21 UTC
#     ✅ Spot Price: 0.01087 USDT
#     ✅ Futures Price: 0.01091 USDT
#     ✅ Spread: 0.3218%
#     ✅ Net Profit After Fees: 0.1218%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: ETHW/USDT | 2025-03-28 07:19:21 UTC
#     ✅ Spot Price: 1.39560 USDT
#     ✅ Futures Price: 1.40000 USDT
#     ✅ Spread: 0.3153%
#     ✅ Net Profit After Fees: 0.1153%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: L3/USDT | 2025-03-28 07:19:21 UTC
#     ✅ Spot Price: 0.13100 USDT
#     ✅ Futures Price: 0.13212 USDT
#     ✅ Spread: 0.8550%
#     ✅ Net Profit After Fees: 0.6550%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT | 2025-03-28 07:19:21 UTC
#     ✅ Spot Price: 6.32810 USDT
#     ✅ Futures Price: 6.36610 USDT
#     ✅ Spread: 0.6005%
#     ✅ Net Profit After Fees: 0.4005%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 571 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: PONKE/USDT | 2025-03-28 07:20:59 UTC
#     ✅ Spot Price: 0.10143 USDT
#     ✅ Futures Price: 0.10212 USDT
#     ✅ Spread: 0.6803%
#     ✅ Net Profit After Fees: 0.5203%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: RARE/USDT | 2025-03-28 07:20:59 UTC
#     ✅ Spot Price: 0.06540 USDT
#     ✅ Futures Price: 0.06558 USDT
#     ✅ Spread: 0.2752%
#     ✅ Net Profit After Fees: 0.1152%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: CFX/USDT | 2025-03-28 07:20:59 UTC
#     ✅ Spot Price: 0.08560 USDT
#     ✅ Futures Price: 0.08595 USDT
#     ✅ Spread: 0.4089%
#     ✅ Net Profit After Fees: 0.2489%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: RED/USDT | 2025-03-28 07:20:59 UTC
#     ✅ Spot Price: 0.54350 USDT
#     ✅ Futures Price: 0.54560 USDT
#     ✅ Spread: 0.3864%
#     ✅ Net Profit After Fees: 0.2264%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: OIK/USDT | 2025-03-28 07:20:59 UTC
#     ✅ Spot Price: 0.04210 USDT
#     ✅ Futures Price: 0.04230 USDT
#     ✅ Spread: 0.4751%
#     ✅ Net Profit After Fees: 0.3151%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NIL/USDT | 2025-03-28 07:20:59 UTC
#     ✅ Spot Price: 0.56500 USDT
#     ✅ Futures Price: 0.56660 USDT
#     ✅ Spread: 0.2832%
#     ✅ Net Profit After Fees: 0.1232%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: ACX/USDT | 2025-03-28 07:20:59 UTC
#     ✅ Spot Price: 0.26520 USDT
#     ✅ Futures Price: 0.26590 USDT
#     ✅ Spread: 0.2640%
#     ✅ Net Profit After Fees: 0.1040%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NEIROETH/USDT | 2025-03-28 07:20:59 UTC
#     ✅ Spot Price: 0.02860 USDT
#     ✅ Futures Price: 0.02887 USDT
#     ✅ Spread: 0.9441%
#     ✅ Net Profit After Fees: 0.7841%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: EIGEN/USDT | 2025-03-28 07:20:59 UTC
#     ✅ Spot Price: 1.04900 USDT
#     ✅ Futures Price: 1.05190 USDT
#     ✅ Spread: 0.2765%
#     ✅ Net Profit After Fees: 0.1165%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Found 291 tradable tokens on OKX
# 🔄 Checking for arbitrage opportunities on OKX...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 407 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: ANKR/USDT | 2025-03-28 07:22:39 UTC
#     ✅ Spot Price: 0.01876 USDT
#     ✅ Futures Price: 0.01882 USDT
#     ✅ Spread: 0.3198%
#     ✅ Net Profit After Fees: 0.1198%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: LOOKS/USDT | 2025-03-28 07:22:39 UTC
#     ✅ Spot Price: 0.01518 USDT
#     ✅ Futures Price: 0.01523 USDT
#     ✅ Spread: 0.3294%
#     ✅ Net Profit After Fees: 0.1294%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: MYRIA/USDT | 2025-03-28 07:22:39 UTC
#     ✅ Spot Price: 0.00084 USDT
#     ✅ Futures Price: 0.00084 USDT
#     ✅ Spread: 0.3805%
#     ✅ Net Profit After Fees: 0.1805%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: LUCE/USDT | 2025-03-28 07:22:39 UTC
#     ✅ Spot Price: 0.00854 USDT
#     ✅ Futures Price: 0.00859 USDT
#     ✅ Spread: 0.6089%
#     ✅ Net Profit After Fees: 0.4089%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT | 2025-03-28 07:22:39 UTC
#     ✅ Spot Price: 6.34340 USDT
#     ✅ Futures Price: 6.37980 USDT
#     ✅ Spread: 0.5738%
#     ✅ Net Profit After Fees: 0.3738%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 572 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: DOG/USDT | 2025-03-28 07:24:16 UTC
#     ✅ Spot Price: 0.00174 USDT
#     ✅ Futures Price: 0.00174 USDT
#     ✅ Spread: 0.2875%
#     ✅ Net Profit After Fees: 0.1275%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Found 291 tradable tokens on OKX
# 🔄 Checking for arbitrage opportunities on OKX...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 407 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT | 2025-03-28 07:25:57 UTC
#     ✅ Spot Price: 6.34450 USDT
#     ✅ Futures Price: 6.37870 USDT
#     ✅ Spread: 0.5390%
#     ✅ Net Profit After Fees: 0.3390%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 572 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: LUMIA/USDT | 2025-03-28 07:27:29 UTC
#     ✅ Spot Price: 0.43600 USDT
#     ✅ Futures Price: 0.43730 USDT
#     ✅ Spread: 0.2982%
#     ✅ Net Profit After Fees: 0.1382%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: LUCE/USDT | 2025-03-28 07:27:29 UTC
#     ✅ Spot Price: 0.00857 USDT
#     ✅ Futures Price: 0.00862 USDT
#     ✅ Spread: 0.5834%
#     ✅ Net Profit After Fees: 0.4234%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: RUNE/USDT | 2025-03-28 07:27:29 UTC
#     ✅ Spot Price: 1.18100 USDT
#     ✅ Futures Price: 1.18500 USDT
#     ✅ Spread: 0.3387%
#     ✅ Net Profit After Fees: 0.1787%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT | 2025-03-28 07:27:29 UTC
#     ✅ Spot Price: 6.33220 USDT
#     ✅ Futures Price: 6.38680 USDT
#     ✅ Spread: 0.8623%
#     ✅ Net Profit After Fees: 0.7023%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NEIROETH/USDT | 2025-03-28 07:27:29 UTC
#     ✅ Spot Price: 0.02880 USDT
#     ✅ Futures Price: 0.02889 USDT
#     ✅ Spread: 0.3125%
#     ✅ Net Profit After Fees: 0.1525%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Found 291 tradable tokens on OKX
# 🔄 Checking for arbitrage opportunities on OKX...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 407 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: L3/USDT | 2025-03-28 07:29:17 UTC🔍 Arbitrage Opportunity on Bybit: OM/USDT | 2025-03-28 07:29:17 UTC
#     ✅ Spot Price: 6.34730 USDT
#     ✅ Futures Price: 6.38380 USDT
#     ✅ Spread: 0.5750%
#     ✅ Net Profit After Fees: 0.3750%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
#
#     ✅ Spot Price: 0.12476 USDT
#     ✅ Futures Price: 0.12547 USDT
#     ✅ Spread: 0.5691%
#     ✅ Net Profit After Fees: 0.3691%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 571 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: SCR/USDT | 2025-03-28 07:30:55 UTC
#     ✅ Spot Price: 0.34300 USDT
#     ✅ Futures Price: 0.34390 USDT
#     ✅ Spread: 0.2624%
#     ✅ Net Profit After Fees: 0.1024%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: CFX/USDT | 2025-03-28 07:30:55 UTC
#     ✅ Spot Price: 0.08560 USDT
#     ✅ Futures Price: 0.08594 USDT
#     ✅ Spread: 0.3972%
#     ✅ Net Profit After Fees: 0.2372%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT | 2025-03-28 07:30:55 UTC
#     ✅ Spot Price: 6.33220 USDT
#     ✅ Futures Price: 6.39088 USDT
#     ✅ Spread: 0.9267%
#     ✅ Net Profit After Fees: 0.7667%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: J/USDT | 2025-03-28 07:30:55 UTC
#     ✅ Spot Price: 0.22740 USDT
#     ✅ Futures Price: 0.22800 USDT
#     ✅ Spread: 0.2639%
#     ✅ Net Profit After Fees: 0.1039%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: DegenReborn/USDT | 2025-03-28 07:30:55 UTC
#     ✅ Spot Price: 0.00320 USDT
#     ✅ Futures Price: 0.00321 USDT
#     ✅ Spread: 0.3437%
#     ✅ Net Profit After Fees: 0.1837%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: TSTBSC/USDT | 2025-03-28 07:30:55 UTC
#     ✅ Spot Price: 0.06090 USDT
#     ✅ Futures Price: 0.06106 USDT
#     ✅ Spread: 0.2627%
#     ✅ Net Profit After Fees: 0.1027%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: RED/USDT | 2025-03-28 07:30:55 UTC
#     ✅ Spot Price: 0.54610 USDT
#     ✅ Futures Price: 0.54760 USDT
#     ✅ Spread: 0.2747%
#     ✅ Net Profit After Fees: 0.1147%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: OIK/USDT | 2025-03-28 07:30:55 UTC
#     ✅ Spot Price: 0.04230 USDT
#     ✅ Futures Price: 0.04250 USDT
#     ✅ Spread: 0.4728%
#     ✅ Net Profit After Fees: 0.3128%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: GMX/USDT | 2025-03-28 07:30:55 UTC
#     ✅ Spot Price: 13.38000 USDT
#     ✅ Futures Price: 13.42000 USDT
#     ✅ Spread: 0.2990%
#     ✅ Net Profit After Fees: 0.1390%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NEIROETH/USDT | 2025-03-28 07:30:55 UTC
#     ✅ Spot Price: 0.02880 USDT
#     ✅ Futures Price: 0.02900 USDT
#     ✅ Spread: 0.6944%
#     ✅ Net Profit After Fees: 0.5344%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Found 291 tradable tokens on OKX
# 🔄 Checking for arbitrage opportunities on OKX...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 407 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: LUCE/USDT | 2025-03-28 07:32:36 UTC🔍 Arbitrage Opportunity on Bybit: HPOS10I/USDT | 2025-03-28 07:32:36 UTC
#     ✅ Spot Price: 0.05520 USDT
#     ✅ Futures Price: 0.05540 USDT
#     ✅ Spread: 0.3623%
#     ✅ Net Profit After Fees: 0.1623%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT | 2025-03-28 07:32:36 UTC
#     ✅ Spot Price: 6.35180 USDT
#     ✅ Futures Price: 6.38900 USDT
#     ✅ Spread: 0.5857%
#     ✅ Net Profit After Fees: 0.3857%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
#
#     ✅ Spot Price: 0.00856 USDT
#     ✅ Futures Price: 0.00859 USDT
#     ✅ Spread: 0.3037%
#     ✅ Net Profit After Fees: 0.1037%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 570 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: CFX/USDT | 2025-03-28 07:34:14 UTC
#     ✅ Spot Price: 0.08560 USDT
#     ✅ Futures Price: 0.08584 USDT
#     ✅ Spread: 0.2804%
#     ✅ Net Profit After Fees: 0.1204%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT | 2025-03-28 07:34:14 UTC
#     ✅ Spot Price: 6.32920 USDT
#     ✅ Futures Price: 6.38900 USDT
#     ✅ Spread: 0.9448%
#     ✅ Net Profit After Fees: 0.7848%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: MERL/USDT | 2025-03-28 07:34:14 UTC
#     ✅ Spot Price: 0.11037 USDT
#     ✅ Futures Price: 0.11080 USDT
#     ✅ Spread: 0.3896%
#     ✅ Net Profit After Fees: 0.2296%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BAKE/USDT | 2025-03-28 07:34:14 UTC
#     ✅ Spot Price: 0.13860 USDT
#     ✅ Futures Price: 0.13900 USDT
#     ✅ Spread: 0.2886%
#     ✅ Net Profit After Fees: 0.1286%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Found 291 tradable tokens on OKX
# 🔄 Checking for arbitrage opportunities on OKX...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 408 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: ANKR/USDT | 2025-03-28 07:35:57 UTC
#     ✅ Spot Price: 0.01879 USDT
#     ✅ Futures Price: 0.01886 USDT
#     ✅ Spread: 0.3725%
#     ✅ Net Profit After Fees: 0.1725%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT | 2025-03-28 07:35:57 UTC
#     ✅ Spot Price: 6.34270 USDT
#     ✅ Futures Price: 6.38020 USDT
#     ✅ Spread: 0.5912%
#     ✅ Net Profit After Fees: 0.3912%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 570 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: SCR/USDT | 2025-03-28 07:37:33 UTC
#     ✅ Spot Price: 0.34300 USDT
#     ✅ Futures Price: 0.34400 USDT
#     ✅ Spread: 0.2915%
#     ✅ Net Profit After Fees: 0.1315%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NAVX/USDT | 2025-03-28 07:37:33 UTC
#     ✅ Spot Price: 0.06780 USDT
#     ✅ Futures Price: 0.06800 USDT
#     ✅ Spread: 0.2950%
#     ✅ Net Profit After Fees: 0.1350%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: MORPHO/USDT | 2025-03-28 07:37:33 UTC
#     ✅ Spot Price: 1.43270 USDT
#     ✅ Futures Price: 1.43720 USDT
#     ✅ Spread: 0.3141%
#     ✅ Net Profit After Fees: 0.1541%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT | 2025-03-28 07:37:33 UTC
#     ✅ Spot Price: 6.33100 USDT
#     ✅ Futures Price: 6.39250 USDT
#     ✅ Spread: 0.9714%
#     ✅ Net Profit After Fees: 0.8114%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: AEVO/USDT | 2025-03-28 07:37:33 UTC
#     ✅ Spot Price: 0.11920 USDT
#     ✅ Futures Price: 0.11960 USDT
#     ✅ Spread: 0.3356%
#     ✅ Net Profit After Fees: 0.1756%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BRETT/USDT | 2025-03-28 07:37:33 UTC
#     ✅ Spot Price: 0.03410 USDT
#     ✅ Futures Price: 0.03424 USDT
#     ✅ Spread: 0.4106%
#     ✅ Net Profit After Fees: 0.2506%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: OIK/USDT | 2025-03-28 07:37:33 UTC
#     ✅ Spot Price: 0.04230 USDT
#     ✅ Futures Price: 0.04260 USDT
#     ✅ Spread: 0.7092%
#     ✅ Net Profit After Fees: 0.5492%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Found 293 tradable tokens on OKX
# 🔄 Checking for arbitrage opportunities on OKX...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 408 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: ANKR/USDT | 2025-03-28 07:39:15 UTC
#     ✅ Spot Price: 0.01879 USDT
#     ✅ Futures Price: 0.01885 USDT
#     ✅ Spread: 0.3193%
#     ✅ Net Profit After Fees: 0.1193%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT | 2025-03-28 07:39:15 UTC
#     ✅ Spot Price: 6.32240 USDT
#     ✅ Futures Price: 6.35950 USDT
#     ✅ Spread: 0.5868%
#     ✅ Net Profit After Fees: 0.3868%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 571 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: MEMEFI/USDT | 2025-03-28 07:40:52 UTC
#     ✅ Spot Price: 0.00092 USDT
#     ✅ Futures Price: 0.00092 USDT
#     ✅ Spread: 0.4372%
#     ✅ Net Profit After Fees: 0.2772%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: AVAAI/USDT | 2025-03-28 07:40:52 UTC
#     ✅ Spot Price: 0.03600 USDT
#     ✅ Futures Price: 0.03615 USDT
#     ✅ Spread: 0.4167%
#     ✅ Net Profit After Fees: 0.2567%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: J/USDT | 2025-03-28 07:40:52 UTC
#     ✅ Spot Price: 0.22740 USDT
#     ✅ Futures Price: 0.22810 USDT
#     ✅ Spread: 0.3078%
#     ✅ Net Profit After Fees: 0.1478%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: PLUME/USDT | 2025-03-28 07:40:52 UTC
#     ✅ Spot Price: 0.17816 USDT
#     ✅ Futures Price: 0.17870 USDT
#     ✅ Spread: 0.3031%
#     ✅ Net Profit After Fees: 0.1431%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: ZIL/USDT | 2025-03-28 07:40:52 UTC
#     ✅ Spot Price: 0.01203 USDT
#     ✅ Futures Price: 0.01207 USDT
#     ✅ Spread: 0.3325%
#     ✅ Net Profit After Fees: 0.1725%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Found 293 tradable tokens on OKX
# 🔄 Checking for arbitrage opportunities on OKX...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 408 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT | 2025-03-28 07:42:32 UTC
#     ✅ Spot Price: 6.31410 USDT
#     ✅ Futures Price: 6.34900 USDT
#     ✅ Spread: 0.5527%
#     ✅ Net Profit After Fees: 0.3527%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# KeyboardInterrupt
