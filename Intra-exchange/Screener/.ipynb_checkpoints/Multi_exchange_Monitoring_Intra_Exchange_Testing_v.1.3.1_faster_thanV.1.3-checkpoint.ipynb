# %%
import ccxt
import time
import concurrent.futures

# Replace with your actual API keys for Bybit and Bitget
BYBIT_API_KEY = 'I6m01uNAWiensHbIBA'
BYBIT_API_SECRET = 'vkaviS9xw903NJPncMtHgGfyiWB4mnhSJTyK'
BITGET_API_KEY = 'bg_b0a9d721607623216a87b066a3df34c3'
BITGET_API_SECRET = '6c4a5016562624b6d7f3b1c59563d4a1a573f630e0e49422fbf509399e56918b'

# Connect to Bybit API
bybit = ccxt.bybit({
    'apiKey': BYBIT_API_KEY,
    'secret': BYBIT_API_SECRET,
    'options': {'adjustForTimeDifference': True}
})

# Connect to Bitget API
bitget = ccxt.bitget({
    'apiKey': BITGET_API_KEY,
    'secret': BITGET_API_SECRET,
    'options': {'adjustForTimeDifference': True}
})

# %%
# Arbitrage settings
SPREAD_THRESHOLD = 0.5 / 100  # 0.5% profit target
MIN_VOLUME = 50000  # Minimum 24h volume required (in USDT)
CHECK_INTERVAL = 5  # Check every 5 seconds

# Adjustable trading fees per exchange
TRADING_FEES = {
    'Bybit': 0.001,   # 0.1%
    'Bitget': 0.0008  # 0.08%
}

exchanges = {'Bybit': bybit, 'Bitget': bitget}

def get_tradable_tokens(exchange, exchange_name):
    try:
        markets = exchange.load_markets()
        tradable_tokens = []
        for symbol, market in markets.items():
            if exchange_name == "Bitget" and not market.get('spot', False):
                continue
            if '/USDT' in symbol and ':USDT' not in symbol:
                try:
                    market_data = exchange.fetch_ticker(symbol)
                    volume = market_data.get('quoteVolume', 0)
                    if volume and volume >= MIN_VOLUME:
                        tradable_tokens.append(symbol)
                except Exception:
                    continue
        print(f"✅ Found {len(tradable_tokens)} tradable tokens on {exchange_name}")
        return tradable_tokens
    except Exception as e:
        print(f"❌ Error fetching tradable tokens from {exchange_name}: {e}")
        return []

def get_price(exchange, symbol):
    try:
        if symbol in exchange.load_markets():
            ticker = exchange.fetch_ticker(symbol)
            return ticker.get("last", None)
    except Exception:
        return None

def check_intra_exchange_arbitrage(exchange, exchange_name, symbol):
    spot_price = get_price(exchange, symbol)
    futures_symbol = symbol.replace('/USDT', '/USDT:USDT')

    if futures_symbol not in exchange.load_markets():
        return

    futures_price = get_price(exchange, futures_symbol)
    if not spot_price or not futures_price:
        return

    trading_fee = TRADING_FEES.get(exchange_name, 0.001)
    spread = (futures_price - spot_price) / spot_price
    net_profit = spread - (trading_fee * 2)

    if net_profit >= SPREAD_THRESHOLD:
        print(f"🔍 Arbitrage Opportunity on {exchange_name}: {symbol}")
        print(f"    ✅ Spot Price: {spot_price:.5f} USDT")
        print(f"    ✅ Futures Price: {futures_price:.5f} USDT")
        print(f"    ✅ Spread: {spread:.4%}")
        print(f"    ✅ Net Profit After Fees: {net_profit:.4%}")
        print(f"    ⚡ Execute arbitrage on {exchange_name}")
        print("-" * 60)

def process_tokens(exchange, exchange_name, tokens):
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = [executor.submit(check_intra_exchange_arbitrage, exchange, exchange_name, token) for token in tokens]
        concurrent.futures.wait(futures)

def main():
    while True:
        try:
            for exchange_name, exchange in exchanges.items():
                tradable_tokens = get_tradable_tokens(exchange, exchange_name)
                if not tradable_tokens:
                    print(f"❌ No tradable tokens found on {exchange_name}. Retrying in 10 seconds...")
                    time.sleep(10)
                    continue
                print(f"🔄 Checking for arbitrage opportunities on {exchange_name}...")
                process_tokens(exchange, exchange_name, tradable_tokens)
            print("✅ Cycle complete. Waiting for next check...")
            time.sleep(CHECK_INTERVAL)
        except Exception as e:
            print(f"❌ Error in main loop: {e}")
            time.sleep(10)

if __name__ == "__main__":
    main()
# Out:
# ✅ Found 436 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 575 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT
#     ✅ Spot Price: 6.65840 USDT
#     ✅ Futures Price: 6.70830 USDT
#     ✅ Spread: 0.7494%
#     ✅ Net Profit After Fees: 0.5894%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 435 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 574 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT
#     ✅ Spot Price: 6.67300 USDT
#     ✅ Futures Price: 6.71934 USDT
#     ✅ Spread: 0.6944%
#     ✅ Net Profit After Fees: 0.5344%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 436 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 575 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: LUCE/USDT
#     ✅ Spot Price: 0.00936 USDT
#     ✅ Futures Price: 0.00943 USDT
#     ✅ Spread: 0.7479%
#     ✅ Net Profit After Fees: 0.5879%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT
#     ✅ Spot Price: 6.67430 USDT
#     ✅ Futures Price: 6.72638 USDT
#     ✅ Spread: 0.7803%
#     ✅ Net Profit After Fees: 0.6203%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NIL/USDT
#     ✅ Spot Price: 0.75500 USDT
#     ✅ Futures Price: 0.76070 USDT
#     ✅ Spread: 0.7550%
#     ✅ Net Profit After Fees: 0.5950%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 437 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 364 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 400 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 574 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: SUNDOG/USDT
#     ✅ Spot Price: 0.05690 USDT
#     ✅ Futures Price: 0.05740 USDT
#     ✅ Spread: 0.8787%
#     ✅ Net Profit After Fees: 0.7187%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 437 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 574 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT
#     ✅ Spot Price: 6.68980 USDT
#     ✅ Futures Price: 6.73700 USDT
#     ✅ Spread: 0.7056%
#     ✅ Net Profit After Fees: 0.5456%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: MERL/USDT
#     ✅ Spot Price: 0.11962 USDT
#     ✅ Futures Price: 0.12060 USDT
#     ✅ Spread: 0.8193%
#     ✅ Net Profit After Fees: 0.6593%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 437 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 574 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: MERL/USDT
#     ✅ Spot Price: 0.11962 USDT
#     ✅ Futures Price: 0.12060 USDT
#     ✅ Spread: 0.8193%
#     ✅ Net Profit After Fees: 0.6593%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: SUNDOG/USDT
#     ✅ Spot Price: 0.05710 USDT
#     ✅ Futures Price: 0.05790 USDT
#     ✅ Spread: 1.4011%
#     ✅ Net Profit After Fees: 1.2411%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 437 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 573 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: KSM/USDT
#     ✅ Spot Price: 18.08000 USDT
#     ✅ Futures Price: 18.20000 USDT
#     ✅ Spread: 0.6637%
#     ✅ Net Profit After Fees: 0.5037%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT
#     ✅ Spot Price: 6.67380 USDT
#     ✅ Futures Price: 6.72750 USDT
#     ✅ Spread: 0.8046%
#     ✅ Net Profit After Fees: 0.6446%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: SUNDOG/USDT
#     ✅ Spot Price: 0.05710 USDT
#     ✅ Futures Price: 0.05770 USDT
#     ✅ Spread: 1.0508%
#     ✅ Net Profit After Fees: 0.8908%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 436 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 573 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: SUNDOG/USDT
#     ✅ Spot Price: 0.05710 USDT
#     ✅ Futures Price: 0.05760 USDT
#     ✅ Spread: 0.8757%
#     ✅ Net Profit After Fees: 0.7157%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 436 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 573 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT
#     ✅ Spot Price: 6.67380 USDT
#     ✅ Futures Price: 6.72630 USDT
#     ✅ Spread: 0.7867%
#     ✅ Net Profit After Fees: 0.6267%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 435 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 571 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT
#     ✅ Spot Price: 6.68870 USDT
#     ✅ Futures Price: 6.73924 USDT
#     ✅ Spread: 0.7556%
#     ✅ Net Profit After Fees: 0.5956%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BURGER/USDT
#     ✅ Spot Price: 0.07120 USDT
#     ✅ Futures Price: 0.07200 USDT
#     ✅ Spread: 1.1236%
#     ✅ Net Profit After Fees: 0.9636%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 435 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 572 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT
#     ✅ Spot Price: 6.68530 USDT
#     ✅ Futures Price: 6.73258 USDT
#     ✅ Spread: 0.7072%
#     ✅ Net Profit After Fees: 0.5472%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 436 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 572 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: NIL/USDT
#     ✅ Spot Price: 0.75300 USDT
#     ✅ Futures Price: 0.75880 USDT
#     ✅ Spread: 0.7703%
#     ✅ Net Profit After Fees: 0.6103%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 436 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 572 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: BURGER/USDT
#     ✅ Spot Price: 0.07120 USDT
#     ✅ Futures Price: 0.07170 USDT
#     ✅ Spread: 0.7022%
#     ✅ Net Profit After Fees: 0.5422%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 435 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 571 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT
#     ✅ Spot Price: 6.66390 USDT
#     ✅ Futures Price: 6.72288 USDT
#     ✅ Spread: 0.8851%
#     ✅ Net Profit After Fees: 0.7251%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NIL/USDT
#     ✅ Spot Price: 0.75600 USDT
#     ✅ Futures Price: 0.76190 USDT
#     ✅ Spread: 0.7804%
#     ✅ Net Profit After Fees: 0.6204%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 435 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# ✅ Found 572 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT
#     ✅ Spot Price: 6.66390 USDT
#     ✅ Futures Price: 6.71529 USDT
#     ✅ Spread: 0.7712%
#     ✅ Net Profit After Fees: 0.6112%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NIL/USDT
#     ✅ Spot Price: 0.75200 USDT
#     ✅ Futures Price: 0.75760 USDT
#     ✅ Spread: 0.7447%
#     ✅ Net Profit After Fees: 0.5847%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BURGER/USDT
#     ✅ Spot Price: 0.07080 USDT
#     ✅ Futures Price: 0.07160 USDT
#     ✅ Spread: 1.1299%
#     ✅ Net Profit After Fees: 0.9699%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 436 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
