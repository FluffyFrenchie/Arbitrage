# %%
import ccxt
import time
import concurrent.futures

# Replace with your actual API keys for Bybit and Bitget
BYBIT_API_KEY = 'I6m01uNAWiensHbIBA'
BYBIT_API_SECRET = 'vkaviS9xw903NJPncMtHgGfyiWB4mnhSJTyK'
BITGET_API_KEY = 'bg_b0a9d721607623216a87b066a3df34c3'
BITGET_API_SECRET = '6c4a5016562624b6d7f3b1c59563d4a1a573f630e0e49422fbf509399e56918b'

# Connect to Bybit API
bybit = ccxt.bybit({
    'apiKey': BYBIT_API_KEY,
    'secret': BYBIT_API_SECRET,
    'options': {'adjustForTimeDifference': True}
})

# Connect to Bitget API
bitget = ccxt.bitget({
    'apiKey': BITGET_API_KEY,
    'secret': BITGET_API_SECRET,
    'options': {'adjustForTimeDifference': True}
})

# %%
# Arbitrage settings
SPREAD_THRESHOLD = 0.1 / 100  # 0.1% for testing
MIN_VOLUME = 50000  # Minimum 24h volume required (in USDT)
CHECK_INTERVAL = 5  # Check every 5 seconds

# Adjustable trading fees per exchange
TRADING_FEES = {
    'Bybit': 0.001,   # 0.1%
    'Bitget': 0.0008  # 0.08%
}

exchanges = {'Bybit': bybit, 'Bitget': bitget}

# Cache futures markets
futures_markets_cache = {}

def get_tradable_tokens(exchange, exchange_name):
    try:
        markets = exchange.load_markets()
        tradable_tokens = []
        futures_markets_cache[exchange_name] = [symbol for symbol in markets if ":USDT" in symbol]

        for symbol, market in markets.items():
            if exchange_name == "Bitget" and not market.get('spot', False):
                continue
            if '/USDT' in symbol and ':USDT' not in symbol:
                try:
                    market_data = exchange.fetch_ticker(symbol)
                    volume = market_data.get('quoteVolume', 0)
                    if volume and volume >= MIN_VOLUME:
                        tradable_tokens.append(symbol)
                except Exception:
                    continue
        print(f"✅ Found {len(tradable_tokens)} tradable tokens on {exchange_name}")
        return tradable_tokens
    except Exception as e:
        print(f"❌ Error fetching tradable tokens from {exchange_name}: {e}")
        return []

def get_price(exchange, symbol):
    try:
        ticker = exchange.fetch_ticker(symbol)
        return ticker.get("last", None)
    except Exception:
        return None

def find_futures_symbol(spot_symbol, futures_list):
    base = spot_symbol.split('/')[0]
    match = [f for f in futures_list if f.startswith(f"{base}/USDT") and ":USDT" in f]
    return match[0] if match else None

def check_intra_exchange_arbitrage(exchange, exchange_name, symbol):
    futures_list = futures_markets_cache.get(exchange_name, [])
    futures_symbol = find_futures_symbol(symbol, futures_list)

    if not futures_symbol:
        return

    with concurrent.futures.ThreadPoolExecutor() as executor:
        future_spot = executor.submit(get_price, exchange, symbol)
        future_futures = executor.submit(get_price, exchange, futures_symbol)
        spot_price = future_spot.result()
        futures_price = future_futures.result()

    if not spot_price or not futures_price:
        return

    trading_fee = TRADING_FEES.get(exchange_name, 0.001)
    spread = (futures_price - spot_price) / spot_price
    net_profit = spread - (trading_fee * 2)

    if net_profit >= SPREAD_THRESHOLD:
        print(f"🔍 Arbitrage Opportunity on {exchange_name}: {symbol}")
        print(f"    ✅ Spot Price: {spot_price:.5f} USDT")
        print(f"    ✅ Futures Price: {futures_price:.5f} USDT")
        print(f"    ✅ Spread: {spread:.4%}")
        print(f"    ✅ Net Profit After Fees: {net_profit:.4%}")
        print(f"    ⚡ Execute arbitrage on {exchange_name}")
        print("-" * 60)

def process_tokens(exchange, exchange_name, tokens):
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = [executor.submit(check_intra_exchange_arbitrage, exchange, exchange_name, token) for token in tokens]
        concurrent.futures.wait(futures)

def main():
    while True:
        try:
            for exchange_name, exchange in exchanges.items():
                tradable_tokens = get_tradable_tokens(exchange, exchange_name)
                if not tradable_tokens:
                    print(f"❌ No tradable tokens found on {exchange_name}. Retrying in 10 seconds...")
                    time.sleep(10)
                    continue
                print(f"🔄 Checking for arbitrage opportunities on {exchange_name}...")
                process_tokens(exchange, exchange_name, tradable_tokens)
            print("✅ Cycle complete. Waiting for next check...")
            time.sleep(CHECK_INTERVAL)
        except Exception as e:
            print(f"❌ Error in main loop: {e}")
            time.sleep(10)

if __name__ == "__main__":
    main()
# Out:
# ✅ Found 437 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: XEM/USDT
#     ✅ Spot Price: 0.01934 USDT
#     ✅ Futures Price: 0.01942 USDT
#     ✅ Spread: 0.4137%
#     ✅ Net Profit After Fees: 0.2137%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT
#     ✅ Spot Price: 6.66070 USDT
#     ✅ Futures Price: 6.69900 USDT
#     ✅ Spread: 0.5750%
#     ✅ Net Profit After Fees: 0.3750%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 552 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: LUCE/USDT
#     ✅ Spot Price: 0.00965 USDT
#     ✅ Futures Price: 0.00969 USDT
#     ✅ Spread: 0.4145%
#     ✅ Net Profit After Fees: 0.2545%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: HIPPO/USDT
#     ✅ Spot Price: 0.00424 USDT
#     ✅ Futures Price: 0.00425 USDT
#     ✅ Spread: 0.3302%
#     ✅ Net Profit After Fees: 0.1702%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: WOO/USDT
#     ✅ Spot Price: 0.09270 USDT
#     ✅ Futures Price: 0.09303 USDT
#     ✅ Spread: 0.3560%
#     ✅ Net Profit After Fees: 0.1960%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: ASTR/USDT
#     ✅ Spot Price: 0.03390 USDT
#     ✅ Futures Price: 0.03400 USDT
#     ✅ Spread: 0.2950%
#     ✅ Net Profit After Fees: 0.1350%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: MAGIC/USDT
#     ✅ Spot Price: 0.13960 USDT
#     ✅ Futures Price: 0.14010 USDT
#     ✅ Spread: 0.3582%
#     ✅ Net Profit After Fees: 0.1982%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT
#     ✅ Spot Price: 6.64870 USDT
#     ✅ Futures Price: 6.72581 USDT
#     ✅ Spread: 1.1598%
#     ✅ Net Profit After Fees: 0.9998%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: GPS/USDT
#     ✅ Spot Price: 0.03214 USDT
#     ✅ Futures Price: 0.03225 USDT
#     ✅ Spread: 0.3423%
#     ✅ Net Profit After Fees: 0.1823%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NIL/USDT
#     ✅ Spot Price: 0.74600 USDT
#     ✅ Futures Price: 0.74980 USDT
#     ✅ Spread: 0.5094%
#     ✅ Net Profit After Fees: 0.3494%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: ARKM/USDT
#     ✅ Spot Price: 0.61800 USDT
#     ✅ Futures Price: 0.62150 USDT
#     ✅ Spread: 0.5663%
#     ✅ Net Profit After Fees: 0.4063%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: ALICE/USDT
#     ✅ Spot Price: 0.53500 USDT
#     ✅ Futures Price: 0.53660 USDT
#     ✅ Spread: 0.2991%
#     ✅ Net Profit After Fees: 0.1391%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NEIROETH/USDT
#     ✅ Spot Price: 0.02660 USDT
#     ✅ Futures Price: 0.02687 USDT
#     ✅ Spread: 1.0150%
#     ✅ Net Profit After Fees: 0.8550%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: EIGEN/USDT
#     ✅ Spot Price: 1.13000 USDT
#     ✅ Futures Price: 1.13560 USDT
#     ✅ Spread: 0.4956%
#     ✅ Net Profit After Fees: 0.3356%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 436 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: UMA/USDT
#     ✅ Spot Price: 1.37300 USDT
#     ✅ Futures Price: 1.37800 USDT
#     ✅ Spread: 0.3642%
#     ✅ Net Profit After Fees: 0.1642%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: XEM/USDT
#     ✅ Spot Price: 0.01934 USDT
#     ✅ Futures Price: 0.01945 USDT
#     ✅ Spread: 0.5688%
#     ✅ Net Profit After Fees: 0.3688%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT
#     ✅ Spot Price: 6.67410 USDT
#     ✅ Futures Price: 6.71490 USDT
#     ✅ Spread: 0.6113%
#     ✅ Net Profit After Fees: 0.4113%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 557 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: LUCE/USDT
#     ✅ Spot Price: 0.00967 USDT
#     ✅ Futures Price: 0.00970 USDT
#     ✅ Spread: 0.3102%
#     ✅ Net Profit After Fees: 0.1502%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: LUMIA/USDT
#     ✅ Spot Price: 0.49400 USDT
#     ✅ Futures Price: 0.49590 USDT
#     ✅ Spread: 0.3846%
#     ✅ Net Profit After Fees: 0.2246%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: HIPPO/USDT
#     ✅ Spot Price: 0.00424 USDT
#     ✅ Futures Price: 0.00426 USDT
#     ✅ Spread: 0.4009%
#     ✅ Net Profit After Fees: 0.2409%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: MANTA/USDT
#     ✅ Spot Price: 0.28180 USDT
#     ✅ Futures Price: 0.28270 USDT
#     ✅ Spread: 0.3194%
#     ✅ Net Profit After Fees: 0.1594%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: MAGIC/USDT
#     ✅ Spot Price: 0.13960 USDT
#     ✅ Futures Price: 0.14020 USDT
#     ✅ Spread: 0.4298%
#     ✅ Net Profit After Fees: 0.2698%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT
#     ✅ Spot Price: 6.68760 USDT
#     ✅ Futures Price: 6.73600 USDT
#     ✅ Spread: 0.7237%
#     ✅ Net Profit After Fees: 0.5637%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BGSC/USDT
#     ✅ Spot Price: 0.00815 USDT
#     ✅ Futures Price: 0.00818 USDT
#     ✅ Spread: 0.3557%
#     ✅ Net Profit After Fees: 0.1957%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: SOLV/USDT
#     ✅ Spot Price: 0.03553 USDT
#     ✅ Futures Price: 0.03570 USDT
#     ✅ Spread: 0.4785%
#     ✅ Net Profit After Fees: 0.3185%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: DegenReborn/USDT
#     ✅ Spot Price: 0.00337 USDT
#     ✅ Futures Price: 0.00338 USDT
#     ✅ Spread: 0.3858%
#     ✅ Net Profit After Fees: 0.2258%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: OP/USDT
#     ✅ Spot Price: 0.89000 USDT
#     ✅ Futures Price: 0.89250 USDT
#     ✅ Spread: 0.2809%
#     ✅ Net Profit After Fees: 0.1209%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: ROAM/USDT
#     ✅ Spot Price: 0.18540 USDT
#     ✅ Futures Price: 0.18590 USDT
#     ✅ Spread: 0.2697%
#     ✅ Net Profit After Fees: 0.1097%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: YGG/USDT
#     ✅ Spot Price: 0.20880 USDT
#     ✅ Futures Price: 0.20970 USDT
#     ✅ Spread: 0.4310%
#     ✅ Net Profit After Fees: 0.2710%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NIL/USDT
#     ✅ Spot Price: 0.73300 USDT
#     ✅ Futures Price: 0.73630 USDT
#     ✅ Spread: 0.4502%
#     ✅ Net Profit After Fees: 0.2902%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NOT/USDT
#     ✅ Spot Price: 0.00260 USDT
#     ✅ Futures Price: 0.00261 USDT
#     ✅ Spread: 0.3851%
#     ✅ Net Profit After Fees: 0.2251%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BB/USDT
#     ✅ Spot Price: 0.14860 USDT
#     ✅ Futures Price: 0.14922 USDT
#     ✅ Spread: 0.4172%
#     ✅ Net Profit After Fees: 0.2572%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: LSK/USDT
#     ✅ Spot Price: 0.58300 USDT
#     ✅ Futures Price: 0.58460 USDT
#     ✅ Spread: 0.2744%
#     ✅ Net Profit After Fees: 0.1144%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: MYRO/USDT
#     ✅ Spot Price: 0.01862 USDT
#     ✅ Futures Price: 0.01868 USDT
#     ✅ Spread: 0.3222%
#     ✅ Net Profit After Fees: 0.1622%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: JTO/USDT
#     ✅ Spot Price: 2.22700 USDT
#     ✅ Futures Price: 2.23310 USDT
#     ✅ Spread: 0.2739%
#     ✅ Net Profit After Fees: 0.1139%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NEIROETH/USDT
#     ✅ Spot Price: 0.02690 USDT
#     ✅ Futures Price: 0.02700 USDT
#     ✅ Spread: 0.3717%
#     ✅ Net Profit After Fees: 0.2117%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: SUNDOG/USDT
#     ✅ Spot Price: 0.05700 USDT
#     ✅ Futures Price: 0.05760 USDT
#     ✅ Spread: 1.0526%
#     ✅ Net Profit After Fees: 0.8926%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: MOODENG/USDT
#     ✅ Spot Price: 0.03870 USDT
#     ✅ Futures Price: 0.03884 USDT
#     ✅ Spread: 0.3618%
#     ✅ Net Profit After Fees: 0.2018%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: EIGEN/USDT
#     ✅ Spot Price: 1.13000 USDT
#     ✅ Futures Price: 1.13660 USDT
#     ✅ Spread: 0.5841%
#     ✅ Net Profit After Fees: 0.4241%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 437 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: PERP/USDT
#     ✅ Spot Price: 0.38230 USDT
#     ✅ Futures Price: 0.38370 USDT
#     ✅ Spread: 0.3662%
#     ✅ Net Profit After Fees: 0.1662%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: XEM/USDT
#     ✅ Spot Price: 0.01935 USDT
#     ✅ Futures Price: 0.01946 USDT
#     ✅ Spread: 0.5685%
#     ✅ Net Profit After Fees: 0.3685%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT
#     ✅ Spot Price: 6.68510 USDT
#     ✅ Futures Price: 6.72530 USDT
#     ✅ Spread: 0.6013%
#     ✅ Net Profit After Fees: 0.4013%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
