# %%
import ccxt
import time
import datetime
from datetime import datetime as dt
from zoneinfo import ZoneInfo
import concurrent.futures

# Replace with your actual API keys for Bybit, Bitget, and OKX
BYBIT_API_KEY = 'I6m01uNAWiensHbIBA'
BYBIT_API_SECRET = 'vkaviS9xw903NJPncMtHgGfyiWB4mnhSJTyK'
BITGET_API_KEY = 'bg_b0a9d721607623216a87b066a3df34c3'
BITGET_API_SECRET = '6c4a5016562624b6d7f3b1c59563d4a1a573f630e0e49422fbf509399e56918b'
OKX_API_KEY = '48af790d-3250-44ec-9528-54d5cd1c1009'
OKX_API_SECRET = 'C91F9F5826FD2F5A8ADC91D945643AD9'
OKX_API_PASSWORD = 'OkX!?Secure789Trade2025?!'

# Connect to Bybit API
bybit = ccxt.bybit({
    'apiKey': BYBIT_API_KEY,
    'secret': BYBIT_API_SECRET,
    'options': {'adjustForTimeDifference': True}
})

# Connect to Bitget API
bitget = ccxt.bitget({
    'apiKey': BITGET_API_KEY,
    'secret': BITGET_API_SECRET,
    'options': {'adjustForTimeDifference': True}
})

# Connect to OKX API
okx = ccxt.okx({
    'apiKey': OKX_API_KEY,
    'secret': OKX_API_SECRET,
    'password': OKX_API_PASSWORD,
    'options': {'adjustForTimeDifference': True}
})

# %%
# Arbitrage settings
SPREAD_THRESHOLD = 0.1 / 100  # 0.1% for testing
MIN_VOLUME = 50000  # Minimum 24h volume required (in USDT)
CHECK_INTERVAL = 5  # Check every 5 seconds

# Adjustable trading fees per exchange
TRADING_FEES = {
    'Bybit': 0.001,   # 0.1%
    'Bitget': 0.0008, # 0.08%
    'OKX': 0.0007     # 0.07%
}

exchanges = {'Bybit': bybit, 'Bitget': bitget, 'OKX': okx}

# Cache futures markets
futures_markets_cache = {}

def get_tradable_tokens(exchange, exchange_name):
    try:
        markets = exchange.load_markets()
        tradable_tokens = []
        futures_markets_cache[exchange_name] = [symbol for symbol in markets if ":USDT" in symbol or "-USDT-SWAP" in symbol]

        for symbol, market in markets.items():
            if exchange_name == "Bitget" and not market.get('spot', False):
                continue
            if exchange_name == "OKX" and market.get('type') != 'spot':
                continue
            if '/USDT' in symbol and ':USDT' not in symbol and '-USDT-SWAP' not in symbol:
                try:
                    market_data = exchange.fetch_ticker(symbol)
                    volume = market_data.get('quoteVolume', 0)
                    if volume and volume >= MIN_VOLUME:
                        tradable_tokens.append(symbol)
                except Exception:
                    continue
        print(f"✅ Found {len(tradable_tokens)} tradable tokens on {exchange_name}")
        return tradable_tokens
    except Exception as e:
        print(f"❌ Error fetching tradable tokens from {exchange_name}: {e}")
        return []

def get_price(exchange, symbol):
    try:
        ticker = exchange.fetch_ticker(symbol)
        return ticker.get("last", None)
    except Exception:
        return None

def fetch_prices_concurrently(exchange, symbols):
    prices = {}
    def fetch(symbol):
        prices[symbol] = get_price(exchange, symbol)
    with concurrent.futures.ThreadPoolExecutor() as executor:
        executor.map(fetch, symbols)
    return prices

def find_futures_symbol(spot_symbol, futures_list):
    base = spot_symbol.split('/')[0]
    match = [f for f in futures_list if f.startswith(f"{base}/USDT") or f.startswith(f"{base}-USDT")]
    return match[0] if match else None

def check_intra_exchange_arbitrage(exchange, exchange_name, symbol, spot_prices, futures_prices):
    spot_price = spot_prices.get(symbol)
    futures_list = futures_markets_cache.get(exchange_name, [])
    futures_symbol = find_futures_symbol(symbol, futures_list)

    if not futures_symbol:
        return

    futures_price = futures_prices.get(futures_symbol)
    if not spot_price or not futures_price:
        return

    trading_fee = TRADING_FEES.get(exchange_name, 0.001)
    spread = (futures_price - spot_price) / spot_price
    net_profit = spread - (trading_fee * 2)

    if net_profit >= SPREAD_THRESHOLD:
        timestamp = datetime.datetime.now(ZoneInfo("Asia/Jakarta")).strftime('%Y-%m-%d %H:%M:%S %Z')
        print(f"🔍 Arbitrage Opportunity on {exchange_name}: {symbol} | {timestamp}")
        print(f"    ✅ Spot Price: {spot_price:.5f} USDT")
        print(f"    ✅ Futures Price: {futures_price:.5f} USDT")
        print(f"    ✅ Spread: {spread:.4%}")
        print(f"    ✅ Net Profit After Fees: {net_profit:.4%}")
        print(f"    ⚡ Execute arbitrage on {exchange_name}")
        print("-" * 60)

def process_tokens(exchange, exchange_name, tokens):
    futures_list = futures_markets_cache.get(exchange_name, [])
    futures_symbols = [find_futures_symbol(t, futures_list) for t in tokens if find_futures_symbol(t, futures_list)]

    spot_prices = fetch_prices_concurrently(exchange, tokens)
    futures_prices = fetch_prices_concurrently(exchange, futures_symbols)

    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = [executor.submit(check_intra_exchange_arbitrage, exchange, exchange_name, token, spot_prices, futures_prices) for token in tokens]
        concurrent.futures.wait(futures)

def main():
    while True:
        try:
            for exchange_name, exchange in exchanges.items():
                tradable_tokens = get_tradable_tokens(exchange, exchange_name)
                if not tradable_tokens:
                    print(f"❌ No tradable tokens found on {exchange_name}. Retrying in 10 seconds...")
                    time.sleep(10)
                    continue
                print(f"🔄 Checking for arbitrage opportunities on {exchange_name}...")
                process_tokens(exchange, exchange_name, tradable_tokens)
            print("✅ Cycle complete. Waiting for next check...")
            time.sleep(CHECK_INTERVAL)
        except Exception as e:
            print(f"❌ Error in main loop: {e}")
            time.sleep(10)

if __name__ == "__main__":
    main()
# Out:
# ✅ Found 414 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: DGB/USDT | 2025-03-26 15:28:42 WIB
#     ✅ Spot Price: 0.01086 USDT
#     ✅ Futures Price: 0.01090 USDT
#     ✅ Spread: 0.3222%
#     ✅ Net Profit After Fees: 0.1222%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT | 2025-03-26 15:28:42 WIB
#     ✅ Spot Price: 6.70470 USDT
#     ✅ Futures Price: 6.75670 USDT
#     ✅ Spread: 0.7756%
#     ✅ Net Profit After Fees: 0.5756%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 556 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: XAI/USDT | 2025-03-26 15:30:57 WIB
#     ✅ Spot Price: 0.07170 USDT
#     ✅ Futures Price: 0.07189 USDT
#     ✅ Spread: 0.2650%
#     ✅ Net Profit After Fees: 0.1050%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: AUDIO/USDT | 2025-03-26 15:30:57 WIB
#     ✅ Spot Price: 0.08270 USDT
#     ✅ Futures Price: 0.08297 USDT
#     ✅ Spread: 0.3265%
#     ✅ Net Profit After Fees: 0.1665%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: AR/USDT | 2025-03-26 15:30:57 WIB
#     ✅ Spot Price: 7.49000 USDT
#     ✅ Futures Price: 7.51100 USDT
#     ✅ Spread: 0.2804%
#     ✅ Net Profit After Fees: 0.1204%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BROCCOLI/USDT | 2025-03-26 15:30:57 WIB
#     ✅ Spot Price: 0.05780 USDT
#     ✅ Futures Price: 0.05800 USDT
#     ✅ Spread: 0.3460%
#     ✅ Net Profit After Fees: 0.1860%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NIL/USDT | 2025-03-26 15:30:57 WIB
#     ✅ Spot Price: 0.63000 USDT
#     ✅ Futures Price: 0.63190 USDT
#     ✅ Spread: 0.3016%
#     ✅ Net Profit After Fees: 0.1416%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: G/USDT | 2025-03-26 15:30:57 WIB
#     ✅ Spot Price: 0.01728 USDT
#     ✅ Futures Price: 0.01733 USDT
#     ✅ Spread: 0.2894%
#     ✅ Net Profit After Fees: 0.1294%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: WAVES/USDT | 2025-03-26 15:30:57 WIB
#     ✅ Spot Price: 1.43760 USDT
#     ✅ Futures Price: 1.44200 USDT
#     ✅ Spread: 0.3061%
#     ✅ Net Profit After Fees: 0.1461%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NEIROETH/USDT | 2025-03-26 15:30:57 WIB
#     ✅ Spot Price: 0.02710 USDT
#     ✅ Futures Price: 0.02720 USDT
#     ✅ Spread: 0.3690%
#     ✅ Net Profit After Fees: 0.2090%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: DOGS/USDT | 2025-03-26 15:30:57 WIB
#     ✅ Spot Price: 0.00017 USDT
#     ✅ Futures Price: 0.00017 USDT
#     ✅ Spread: 0.2969%
#     ✅ Net Profit After Fees: 0.1369%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Found 280 tradable tokens on OKX
# 🔄 Checking for arbitrage opportunities on OKX...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 414 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: VIC/USDT | 2025-03-26 15:32:58 WIB
#     ✅ Spot Price: 0.25030 USDT
#     ✅ Futures Price: 0.25140 USDT
#     ✅ Spread: 0.4395%
#     ✅ Net Profit After Fees: 0.2395%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit

#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: HOT/USDT | 2025-03-26 16:01:27 WIB
#     ✅ Spot Price: 0.00120 USDT
#     ✅ Futures Price: 0.00121 USDT
#     ✅ Spread: 0.3322%
#     ✅ Net Profit After Fees: 0.1722%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Found 188 tradable tokens on OKX
# 🔄 Checking for arbitrage opportunities on OKX...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 413 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT | 2025-03-26 16:03:09 WIB
#     ✅ Spot Price: 6.68270 USDT
#     ✅ Futures Price: 6.73270 USDT
#     ✅ Spread: 0.7482%
#     ✅ Net Profit After Fees: 0.5482%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 550 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: LUCE/USDT | 2025-03-26 16:04:52 WIB
#     ✅ Spot Price: 0.00971 USDT
#     ✅ Futures Price: 0.00978 USDT
#     ✅ Spread: 0.7209%
#     ✅ Net Profit After Fees: 0.5609%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: PONKE/USDT | 2025-03-26 16:04:52 WIB
#     ✅ Spot Price: 0.11726 USDT
#     ✅ Futures Price: 0.11794 USDT
#     ✅ Spread: 0.5799%
#     ✅ Net Profit After Fees: 0.4199%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: METIS/USDT | 2025-03-26 16:04:52 WIB
#     ✅ Spot Price: 18.91000 USDT
#     ✅ Futures Price: 18.96000 USDT
#     ✅ Spread: 0.2644%
#     ✅ Net Profit After Fees: 0.1044%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: AUDIO/USDT | 2025-03-26 16:04:52 WIB
#     ✅ Spot Price: 0.08230 USDT
#     ✅ Futures Price: 0.08257 USDT
#     ✅ Spread: 0.3281%
#     ✅ Net Profit After Fees: 0.1681%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: KOMA/USDT | 2025-03-26 16:04:52 WIB
#     ✅ Spot Price: 0.03870 USDT
#     ✅ Futures Price: 0.03883 USDT
#     ✅ Spread: 0.3359%
#     ✅ Net Profit After Fees: 0.1759%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BIO/USDT | 2025-03-26 16:04:52 WIB
#     ✅ Spot Price: 0.10030 USDT
#     ✅ Futures Price: 0.10080 USDT
#     ✅ Spread: 0.4985%
#     ✅ Net Profit After Fees: 0.3385%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: LRC/USDT | 2025-03-26 16:04:52 WIB
#     ✅ Spot Price: 0.11440 USDT
#     ✅ Futures Price: 0.11470 USDT
#     ✅ Spread: 0.2622%
#     ✅ Net Profit After Fees: 0.1022%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: ALPACA/USDT | 2025-03-26 16:04:52 WIB
#     ✅ Spot Price: 0.06140 USDT
#     ✅ Futures Price: 0.06164 USDT
#     ✅ Spread: 0.3909%
#     ✅ Net Profit After Fees: 0.2309%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: MYRO/USDT | 2025-03-26 16:04:52 WIB
#     ✅ Spot Price: 0.01967 USDT
#     ✅ Futures Price: 0.01973 USDT
#     ✅ Spread: 0.3050%
#     ✅ Net Profit After Fees: 0.1450%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: HOT/USDT | 2025-03-26 16:04:52 WIB
#     ✅ Spot Price: 0.00120 USDT
#     ✅ Futures Price: 0.00121 USDT
#     ✅ Spread: 0.3322%
#     ✅ Net Profit After Fees: 0.1722%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: SUNDOG/USDT | 2025-03-26 16:04:52 WIB
#     ✅ Spot Price: 0.05890 USDT
#     ✅ Futures Price: 0.05920 USDT
#     ✅ Spread: 0.5093%
#     ✅ Net Profit After Fees: 0.3493%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Found 154 tradable tokens on OKX
# 🔄 Checking for arbitrage opportunities on OKX...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 413 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: BB/USDT | 2025-03-26 16:06:51 WIB
#     ✅ Spot Price: 0.16260 USDT
#     ✅ Futures Price: 0.16310 USDT
#     ✅ Spread: 0.3075%
#     ✅ Net Profit After Fees: 0.1075%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT | 2025-03-26 16:06:51 WIB
#     ✅ Spot Price: 6.69220 USDT
#     ✅ Futures Price: 6.73920 USDT
#     ✅ Spread: 0.7023%
#     ✅ Net Profit After Fees: 0.5023%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 550 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: LUCE/USDT | 2025-03-26 16:08:33 WIB
#     ✅ Spot Price: 0.00972 USDT
#     ✅ Futures Price: 0.00975 USDT
#     ✅ Spread: 0.3086%
#     ✅ Net Profit After Fees: 0.1486%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BAN/USDT | 2025-03-26 16:08:33 WIB
#     ✅ Spot Price: 0.05880 USDT
#     ✅ Futures Price: 0.05910 USDT
#     ✅ Spread: 0.5102%
#     ✅ Net Profit After Fees: 0.3502%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: PONKE/USDT | 2025-03-26 16:08:33 WIB
#     ✅ Spot Price: 0.11726 USDT
#     ✅ Futures Price: 0.11831 USDT
#     ✅ Spread: 0.8954%
#     ✅ Net Profit After Fees: 0.7354%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: METIS/USDT | 2025-03-26 16:08:33 WIB
#     ✅ Spot Price: 18.91000 USDT
#     ✅ Futures Price: 18.96000 USDT
#     ✅ Spread: 0.2644%
#     ✅ Net Profit After Fees: 0.1044%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT | 2025-03-26 16:08:33 WIB
#     ✅ Spot Price: 6.69380 USDT
#     ✅ Futures Price: 6.76144 USDT
#     ✅ Spread: 1.0105%
#     ✅ Net Profit After Fees: 0.8505%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: ZKJ/USDT | 2025-03-26 16:08:33 WIB
#     ✅ Spot Price: 2.20100 USDT
#     ✅ Futures Price: 2.20800 USDT
#     ✅ Spread: 0.3180%
#     ✅ Net Profit After Fees: 0.1580%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BURGER/USDT | 2025-03-26 16:08:33 WIB
#     ✅ Spot Price: 0.05330 USDT
#     ✅ Futures Price: 0.05350 USDT
#     ✅ Spread: 0.3752%
#     ✅ Net Profit After Fees: 0.2152%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: HOT/USDT | 2025-03-26 16:08:33 WIB
#     ✅ Spot Price: 0.00120 USDT
#     ✅ Futures Price: 0.00121 USDT
#     ✅ Spread: 0.3322%
#     ✅ Net Profit After Fees: 0.1722%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Found 158 tradable tokens on OKX
# 🔄 Checking for arbitrage opportunities on OKX...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 413 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT | 2025-03-26 16:10:28 WIB
#     ✅ Spot Price: 6.67570 USDT
#     ✅ Futures Price: 6.72760 USDT
#     ✅ Spread: 0.7774%
#     ✅ Net Profit After Fees: 0.5774%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 554 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: SCR/USDT | 2025-03-26 16:12:24 WIB
#     ✅ Spot Price: 0.38800 USDT
#     ✅ Futures Price: 0.38940 USDT
#     ✅ Spread: 0.3608%
#     ✅ Net Profit After Fees: 0.2008%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: PONKE/USDT | 2025-03-26 16:12:24 WIB
#     ✅ Spot Price: 0.11726 USDT
#     ✅ Futures Price: 0.11809 USDT
#     ✅ Spread: 0.7078%
#     ✅ Net Profit After Fees: 0.5478%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: API3/USDT | 2025-03-26 16:12:24 WIB
#     ✅ Spot Price: 1.25900 USDT
#     ✅ Futures Price: 1.26530 USDT
#     ✅ Spread: 0.5004%
#     ✅ Net Profit After Fees: 0.3404%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: ZEREBRO/USDT | 2025-03-26 16:12:24 WIB
#     ✅ Spot Price: 0.03900 USDT
#     ✅ Futures Price: 0.03922 USDT
#     ✅ Spread: 0.5641%
#     ✅ Net Profit After Fees: 0.4041%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: ANIME/USDT | 2025-03-26 16:12:24 WIB
#     ✅ Spot Price: 0.02110 USDT
#     ✅ Futures Price: 0.02116 USDT
#     ✅ Spread: 0.2844%
#     ✅ Net Profit After Fees: 0.1244%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: MANA/USDT | 2025-03-26 16:12:24 WIB
#     ✅ Spot Price: 0.28640 USDT
#     ✅ Futures Price: 0.28720 USDT
#     ✅ Spread: 0.2793%
#     ✅ Net Profit After Fees: 0.1193%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: JAILSTOOL/USDT | 2025-03-26 16:12:24 WIB
#     ✅ Spot Price: 0.00872 USDT
#     ✅ Futures Price: 0.00875 USDT
#     ✅ Spread: 0.3555%
#     ✅ Net Profit After Fees: 0.1955%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BURGER/USDT | 2025-03-26 16:12:24 WIB
#     ✅ Spot Price: 0.05320 USDT
#     ✅ Futures Price: 0.05350 USDT
#     ✅ Spread: 0.5639%
#     ✅ Net Profit After Fees: 0.4039%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: CVX/USDT | 2025-03-26 16:12:24 WIB
#     ✅ Spot Price: 2.48100 USDT
#     ✅ Futures Price: 2.48800 USDT
#     ✅ Spread: 0.2821%
#     ✅ Net Profit After Fees: 0.1221%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NEIROETH/USDT | 2025-03-26 16:12:24 WIB
#     ✅ Spot Price: 0.02720 USDT
#     ✅ Futures Price: 0.02729 USDT
#     ✅ Spread: 0.3309%
#     ✅ Net Profit After Fees: 0.1709%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: SUNDOG/USDT | 2025-03-26 16:12:24 WIB
#     ✅ Spot Price: 0.05900 USDT
#     ✅ Futures Price: 0.05950 USDT
#     ✅ Spread: 0.8475%
#     ✅ Net Profit After Fees: 0.6875%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Found 48 tradable tokens on OKX
# 🔄 Checking for arbitrage opportunities on OKX...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 352 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit

#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: SLERF/USDT | 2025-03-26 16:24:05 WIB
#     ✅ Spot Price: 0.06840 USDT
#     ✅ Futures Price: 0.06860 USDT
#     ✅ Spread: 0.2924%
#     ✅ Net Profit After Fees: 0.1324%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: VANRY/USDT | 2025-03-26 16:24:05 WIB
#     ✅ Spot Price: 0.03510 USDT
#     ✅ Futures Price: 0.03520 USDT
#     ✅ Spread: 0.2849%
#     ✅ Net Profit After Fees: 0.1249%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NEIROETH/USDT | 2025-03-26 16:24:05 WIB
#     ✅ Spot Price: 0.02710 USDT
#     ✅ Futures Price: 0.02723 USDT
#     ✅ Spread: 0.4797%
#     ✅ Net Profit After Fees: 0.3197%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Found 221 tradable tokens on OKX
# 🔄 Checking for arbitrage opportunities on OKX...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 413 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: HPOS10I/USDT | 2025-03-26 16:25:45 WIB🔍 Arbitrage Opportunity on Bybit: OM/USDT | 2025-03-26 16:25:45 WIB
#     ✅ Spot Price: 6.70200 USDT
#     ✅ Futures Price: 6.75350 USDT
#     ✅ Spread: 0.7684%
#     ✅ Net Profit After Fees: 0.5684%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
#
#     ✅ Spot Price: 0.06100 USDT
#     ✅ Futures Price: 0.06124 USDT
#     ✅ Spread: 0.3934%
#     ✅ Net Profit After Fees: 0.1934%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 559 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: SCR/USDT | 2025-03-26 16:27:29 WIB
#     ✅ Spot Price: 0.38800 USDT
#     ✅ Futures Price: 0.38920 USDT
#     ✅ Spread: 0.3093%
#     ✅ Net Profit After Fees: 0.1493%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BAN/USDT | 2025-03-26 16:27:29 WIB
#     ✅ Spot Price: 0.05900 USDT
#     ✅ Futures Price: 0.05920 USDT
#     ✅ Spread: 0.3390%
#     ✅ Net Profit After Fees: 0.1790%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: XAI/USDT | 2025-03-26 16:27:29 WIB
#     ✅ Spot Price: 0.07150 USDT
#     ✅ Futures Price: 0.07179 USDT
#     ✅ Spread: 0.4056%
#     ✅ Net Profit After Fees: 0.2456%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: PONKE/USDT | 2025-03-26 16:27:29 WIB
#     ✅ Spot Price: 0.11754 USDT
#     ✅ Futures Price: 0.11801 USDT
#     ✅ Spread: 0.3999%
#     ✅ Net Profit After Fees: 0.2399%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: FLM/USDT | 2025-03-26 16:27:29 WIB
#     ✅ Spot Price: 0.03655 USDT
#     ✅ Futures Price: 0.03665 USDT
#     ✅ Spread: 0.2736%
#     ✅ Net Profit After Fees: 0.1136%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: AR/USDT | 2025-03-26 16:27:29 WIB
#     ✅ Spot Price: 7.43000 USDT
#     ✅ Futures Price: 7.46000 USDT
#     ✅ Spread: 0.4038%
#     ✅ Net Profit After Fees: 0.2438%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT | 2025-03-26 16:27:29 WIB
#     ✅ Spot Price: 6.70490 USDT
#     ✅ Futures Price: 6.77300 USDT
#     ✅ Spread: 1.0157%
#     ✅ Net Profit After Fees: 0.8557%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: AVAAI/USDT | 2025-03-26 16:27:29 WIB
#     ✅ Spot Price: 0.04550 USDT
#     ✅ Futures Price: 0.04564 USDT
#     ✅ Spread: 0.3077%
#     ✅ Net Profit After Fees: 0.1477%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: ANIME/USDT | 2025-03-26 16:27:29 WIB
#     ✅ Spot Price: 0.02100 USDT
#     ✅ Futures Price: 0.02114 USDT
#     ✅ Spread: 0.6667%
#     ✅ Net Profit After Fees: 0.5067%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: DegenReborn/USDT | 2025-03-26 16:27:29 WIB
#     ✅ Spot Price: 0.00356 USDT
#     ✅ Futures Price: 0.00357 USDT
#     ✅ Spread: 0.3090%
#     ✅ Net Profit After Fees: 0.1490%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: TURBO/USDT | 2025-03-26 16:27:29 WIB
#     ✅ Spot Price: 0.00257 USDT
#     ✅ Futures Price: 0.00259 USDT
#     ✅ Spread: 0.7390%
#     ✅ Net Profit After Fees: 0.5790%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: OIK/USDT | 2025-03-26 16:27:29 WIB
#     ✅ Spot Price: 0.05200 USDT
#     ✅ Futures Price: 0.05220 USDT
#     ✅ Spread: 0.3846%
#     ✅ Net Profit After Fees: 0.2246%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Found 197 tradable tokens on OKX
# 🔄 Checking for arbitrage opportunities on OKX...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 415 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: ZRX/USDT | 2025-03-26 16:29:09 WIB
#     ✅ Spot Price: 0.28340 USDT
#     ✅ Futures Price: 0.28430 USDT
#     ✅ Spread: 0.3176%
#     ✅ Net Profit After Fees: 0.1176%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit

#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: BB/USDT | 2025-03-26 17:49:14 WIB
#     ✅ Spot Price: 0.16290 USDT
#     ✅ Futures Price: 0.16340 USDT
#     ✅ Spread: 0.3069%
#     ✅ Net Profit After Fees: 0.1069%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT | 2025-03-26 17:49:14 WIB
#     ✅ Spot Price: 6.76420 USDT
#     ✅ Futures Price: 6.80730 USDT
#     ✅ Spread: 0.6372%
#     ✅ Net Profit After Fees: 0.4372%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 568 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: BAN/USDT | 2025-03-26 17:50:59 WIB
#     ✅ Spot Price: 0.05990 USDT
#     ✅ Futures Price: 0.06010 USDT
#     ✅ Spread: 0.3339%
#     ✅ Net Profit After Fees: 0.1739%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: ANIME/USDT | 2025-03-26 17:50:59 WIB
#     ✅ Spot Price: 0.02110 USDT
#     ✅ Futures Price: 0.02121 USDT
#     ✅ Spread: 0.5213%
#     ✅ Net Profit After Fees: 0.3613%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: MANA/USDT | 2025-03-26 17:50:59 WIB
#     ✅ Spot Price: 0.28860 USDT
#     ✅ Futures Price: 0.28960 USDT
#     ✅ Spread: 0.3465%
#     ✅ Net Profit After Fees: 0.1865%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BAND/USDT | 2025-03-26 17:50:59 WIB
#     ✅ Spot Price: 0.85800 USDT
#     ✅ Futures Price: 0.86120 USDT
#     ✅ Spread: 0.3730%
#     ✅ Net Profit After Fees: 0.2130%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: JAILSTOOL/USDT | 2025-03-26 17:50:59 WIB
#     ✅ Spot Price: 0.00885 USDT
#     ✅ Futures Price: 0.00888 USDT
#     ✅ Spread: 0.3844%
#     ✅ Net Profit After Fees: 0.2244%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: CLOUD/USDT | 2025-03-26 17:50:59 WIB
#     ✅ Spot Price: 0.09020 USDT
#     ✅ Futures Price: 0.09050 USDT
#     ✅ Spread: 0.3326%
#     ✅ Net Profit After Fees: 0.1726%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Found 280 tradable tokens on OKX
# 🔄 Checking for arbitrage opportunities on OKX...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 414 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT | 2025-03-26 17:52:42 WIB
#     ✅ Spot Price: 6.75350 USDT
#     ✅ Futures Price: 6.79540 USDT
#     ✅ Spread: 0.6204%
#     ✅ Net Profit After Fees: 0.4204%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 568 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: XDC/USDT | 2025-03-26 17:54:24 WIB
#     ✅ Spot Price: 0.07368 USDT
#     ✅ Futures Price: 0.07391 USDT
#     ✅ Spread: 0.3122%
#     ✅ Net Profit After Fees: 0.1522%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: OM/USDT | 2025-03-26 17:54:24 WIB
#     ✅ Spot Price: 6.75760 USDT
#     ✅ Futures Price: 6.81740 USDT
#     ✅ Spread: 0.8849%
#     ✅ Net Profit After Fees: 0.7249%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BGSC/USDT | 2025-03-26 17:54:24 WIB
#     ✅ Spot Price: 0.00829 USDT
#     ✅ Futures Price: 0.00831 USDT
#     ✅ Spread: 0.2895%
#     ✅ Net Profit After Fees: 0.1295%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: ZEREBRO/USDT | 2025-03-26 17:54:24 WIB
#     ✅ Spot Price: 0.04280 USDT
#     ✅ Futures Price: 0.04294 USDT
#     ✅ Spread: 0.3271%
#     ✅ Net Profit After Fees: 0.1671%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: ORDI/USDT | 2025-03-26 17:54:24 WIB
#     ✅ Spot Price: 10.23000 USDT
#     ✅ Futures Price: 10.26000 USDT
#     ✅ Spread: 0.2933%
#     ✅ Net Profit After Fees: 0.1333%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: MANA/USDT | 2025-03-26 17:54:24 WIB
#     ✅ Spot Price: 0.28860 USDT
#     ✅ Futures Price: 0.28960 USDT
#     ✅ Spread: 0.3465%
#     ✅ Net Profit After Fees: 0.1865%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: 1INCH/USDT | 2025-03-26 17:54:24 WIB
#     ✅ Spot Price: 0.21900 USDT
#     ✅ Futures Price: 0.21960 USDT
#     ✅ Spread: 0.2740%
#     ✅ Net Profit After Fees: 0.1140%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: OIK/USDT | 2025-03-26 17:54:24 WIB
#     ✅ Spot Price: 0.05060 USDT
#     ✅ Futures Price: 0.05090 USDT
#     ✅ Spread: 0.5929%
#     ✅ Net Profit After Fees: 0.4329%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BURGER/USDT | 2025-03-26 17:54:24 WIB
#     ✅ Spot Price: 0.05500 USDT
#     ✅ Futures Price: 0.05580 USDT
#     ✅ Spread: 1.4545%
#     ✅ Net Profit After Fees: 1.2945%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: ORDER/USDT | 2025-03-26 17:54:24 WIB
#     ✅ Spot Price: 0.14570 USDT
#     ✅ Futures Price: 0.14610 USDT
#     ✅ Spread: 0.2745%
#     ✅ Net Profit After Fees: 0.1145%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Found 280 tradable tokens on OKX
# 🔄 Checking for arbitrage opportunities on OKX...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 414 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT | 2025-03-26 17:56:05 WIB
#     ✅ Spot Price: 6.75440 USDT
#     ✅ Futures Price: 6.79720 USDT
#     ✅ Spread: 0.6337%
#     ✅ Net Profit After Fees: 0.4337%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 569 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: PONKE/USDT | 2025-03-26 17:57:50 WIB
#     ✅ Spot Price: 0.11978 USDT
#     ✅ Futures Price: 0.12019 USDT
#     ✅ Spread: 0.3423%
#     ✅ Net Profit After Fees: 0.1823%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: PIPPIN/USDT | 2025-03-26 17:57:50 WIB
#     ✅ Spot Price: 0.02130 USDT
#     ✅ Futures Price: 0.02138 USDT
#     ✅ Spread: 0.3756%
#     ✅ Net Profit After Fees: 0.2156%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: VTHO/USDT | 2025-03-26 17:57:50 WIB
#     ✅ Spot Price: 0.00263 USDT
#     ✅ Futures Price: 0.00263 USDT
#     ✅ Spread: 0.2665%
#     ✅ Net Profit After Fees: 0.1065%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BROCCOLI/USDT | 2025-03-26 17:57:50 WIB
#     ✅ Spot Price: 0.05350 USDT
#     ✅ Futures Price: 0.05376 USDT
#     ✅ Spread: 0.4860%
#     ✅ Net Profit After Fees: 0.3260%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: JAILSTOOL/USDT | 2025-03-26 17:57:50 WIB
#     ✅ Spot Price: 0.00886 USDT
#     ✅ Futures Price: 0.00890 USDT
#     ✅ Spread: 0.4288%
#     ✅ Net Profit After Fees: 0.2688%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BURGER/USDT | 2025-03-26 17:57:50 WIB
#     ✅ Spot Price: 0.05440 USDT
#     ✅ Futures Price: 0.05580 USDT
#     ✅ Spread: 2.5735%
#     ✅ Net Profit After Fees: 2.4135%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: CLOUD/USDT | 2025-03-26 17:57:50 WIB
#     ✅ Spot Price: 0.09010 USDT
#     ✅ Futures Price: 0.09040 USDT
#     ✅ Spread: 0.3330%
#     ✅ Net Profit After Fees: 0.1730%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Found 280 tradable tokens on OKX
# 🔄 Checking for arbitrage opportunities on OKX...
# ✅ Cycle complete. Waiting for next check...
# ✅ Found 413 tradable tokens on Bybit
# 🔄 Checking for arbitrage opportunities on Bybit...
# 🔍 Arbitrage Opportunity on Bybit: OM/USDT | 2025-03-26 17:59:30 WIB
#     ✅ Spot Price: 6.74630 USDT
#     ✅ Futures Price: 6.79060 USDT
#     ✅ Spread: 0.6567%
#     ✅ Net Profit After Fees: 0.4567%
#     ⚡ Execute arbitrage on Bybit
# ------------------------------------------------------------
# ✅ Found 570 tradable tokens on Bitget
# 🔄 Checking for arbitrage opportunities on Bitget...
# 🔍 Arbitrage Opportunity on Bitget: GOAT/USDT | 2025-03-26 18:01:13 WIB
#     ✅ Spot Price: 0.06710 USDT
#     ✅ Futures Price: 0.06744 USDT
#     ✅ Spread: 0.5067%
#     ✅ Net Profit After Fees: 0.3467%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BAN/USDT | 2025-03-26 18:01:13 WIB
#     ✅ Spot Price: 0.05980 USDT
#     ✅ Futures Price: 0.06000 USDT
#     ✅ Spread: 0.3344%
#     ✅ Net Profit After Fees: 0.1744%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: GMT/USDT | 2025-03-26 18:01:13 WIB
#     ✅ Spot Price: 0.05600 USDT
#     ✅ Futures Price: 0.05620 USDT
#     ✅ Spread: 0.3571%
#     ✅ Net Profit After Fees: 0.1971%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: TURBO/USDT | 2025-03-26 18:01:13 WIB
#     ✅ Spot Price: 0.00265 USDT
#     ✅ Futures Price: 0.00266 USDT
#     ✅ Spread: 0.2641%
#     ✅ Net Profit After Fees: 0.1041%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: 1INCH/USDT | 2025-03-26 18:01:13 WIB
#     ✅ Spot Price: 0.21900 USDT
#     ✅ Futures Price: 0.21970 USDT
#     ✅ Spread: 0.3196%
#     ✅ Net Profit After Fees: 0.1596%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: JAILSTOOL/USDT | 2025-03-26 18:01:13 WIB
#     ✅ Spot Price: 0.00881 USDT
#     ✅ Futures Price: 0.00885 USDT
#     ✅ Spread: 0.4540%
#     ✅ Net Profit After Fees: 0.2940%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: W/USDT | 2025-03-26 18:01:13 WIB
#     ✅ Spot Price: 0.10300 USDT
#     ✅ Futures Price: 0.10340 USDT
#     ✅ Spread: 0.3883%
#     ✅ Net Profit After Fees: 0.2283%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: BURGER/USDT | 2025-03-26 18:01:13 WIB
#     ✅ Spot Price: 0.05410 USDT
#     ✅ Futures Price: 0.05580 USDT
#     ✅ Spread: 3.1423%
#     ✅ Net Profit After Fees: 2.9823%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: WAVES/USDT | 2025-03-26 18:01:13 WIB
#     ✅ Spot Price: 1.44280 USDT
#     ✅ Futures Price: 1.44700 USDT
#     ✅ Spread: 0.2911%
#     ✅ Net Profit After Fees: 0.1311%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: CELR/USDT | 2025-03-26 18:01:13 WIB
#     ✅ Spot Price: 0.01125 USDT
#     ✅ Futures Price: 0.01128 USDT
#     ✅ Spread: 0.2667%
#     ✅ Net Profit After Fees: 0.1067%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: DOGS/USDT | 2025-03-26 18:01:13 WIB
#     ✅ Spot Price: 0.00017 USDT
#     ✅ Futures Price: 0.00017 USDT
#     ✅ Spread: 0.2914%
#     ✅ Net Profit After Fees: 0.1314%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# 🔍 Arbitrage Opportunity on Bitget: NEIROETH/USDT | 2025-03-26 18:01:13 WIB
#     ✅ Spot Price: 0.02800 USDT
#     ✅ Futures Price: 0.02808 USDT
#     ✅ Spread: 0.2857%
#     ✅ Net Profit After Fees: 0.1257%
#     ⚡ Execute arbitrage on Bitget
# ------------------------------------------------------------
# ✅ Found 280 tradable tokens on OKX
# 🔄 Checking for arbitrage opportunities on OKX...
# ✅ Cycle complete. Waiting for next check...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 118
#     115             time.sleep(10)
#     117 if __name__ == "__main__":
# --> 118     main()
#
# Cell In[4], line 104, in main()
#     102 try:
#     103     for exchange_name, exchange in exchanges.items():
# --> 104         tradable_tokens = get_tradable_tokens(exchange, exchange_name)
#     105         if not tradable_tokens:
#     106             print(f"❌ No tradable tokens found on {exchange_name}. Retrying in 10 seconds...")
#
# Cell In[4], line 31, in get_tradable_tokens(exchange, exchange_name)
#      29 if '/USDT' in symbol and ':USDT' not in symbol and '-USDT-SWAP' not in symbol:
#      30     try:
# ---> 31         market_data = exchange.fetch_ticker(symbol)
#      32         volume = market_data.get('quoteVolume', 0)
#      33         if volume and volume >= MIN_VOLUME:
#
# File ~\anaconda3\Lib\site-packages\ccxt\bybit.py:2328, in bybit.fetch_ticker(self, symbol, params)
#    2326     elif market['inverse']:
#    2327         request['category'] = 'inverse'
# -> 2328 response = self.publicGetV5MarketTickers(self.extend(request, params))
#    2329 #
#    2330 #     {
#    2331 #         "retCode": 0,
#    (...)
#    2365 #     }
#    2366 #
#    2367 result = self.safe_dict(response, 'result', {})
#
# File ~\anaconda3\Lib\site-packages\ccxt\base\types.py:35, in Entry.__init__.<locals>.unbound_method(_self, params)
#      34 def unbound_method(_self, params={}):
# ---> 35     return _self.request(self.path, self.api, self.method, params, config=self.config)
#
# File ~\anaconda3\Lib\site-packages\ccxt\base\exchange.py:4368, in Exchange.request(self, path, api, method, params, headers, body, config)
#    4367 def request(self, path, api: Any = 'public', method='GET', params={}, headers: Any = None, body: Any = None, config={}):
# -> 4368     return self.fetch2(path, api, method, params, headers, body, config)
#
# File ~\anaconda3\Lib\site-packages\ccxt\base\exchange.py:4341, in Exchange.fetch2(self, path, api, method, params, headers, body, config)
#    4339 if self.enableRateLimit:
#    4340     cost = self.calculate_rate_limiter_cost(api, method, path, params, config)
# -> 4341     self.throttle(cost)
#    4342 self.lastRestRequestTimestamp = self.milliseconds()
#    4343 request = self.sign(path, api, method, params, headers, body)
#
# File ~\anaconda3\Lib\site-packages\ccxt\base\exchange.py:460, in Exchange.throttle(self, cost)
#     458 if elapsed < sleep_time:
#     459     delay = sleep_time - elapsed
# --> 460     time.sleep(delay / 1000.0)
#
# KeyboardInterrupt:
